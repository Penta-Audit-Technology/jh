# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./비율/또다른재무비율13.csv', encoding='cp949')
# df = df.drop(columns=)
# df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0        -1.43    -2.02  ...     33.95          17.88           35.59
# 1         7.73    75.17  ...     44.68           6.27            7.33
# 2        56.29    55.10  ...     12.37          12.09           14.12
# 3         6.37     0.01  ...     15.61          17.36           25.09
# 4        11.04    -4.48  ...     17.20          20.77           31.32
# ...        ...      ...  ...       ...            ...             ...
# 15145   -12.92     3.39  ...     78.14           8.43            0.00
# 15146    56.39    11.22  ...     79.92          17.60            0.00
# 15147    11.18   -39.28  ...     86.23          17.27            0.00
# 15148    -5.85   -37.42  ...     90.90          17.36            0.00
# 15149   -58.98   -57.73  ...     92.83           8.22            0.00
#
#        순운전자본비율   노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율
# 0        28.23   71.32  19.75   204.06   35.86    12.72  19.56
# 1        70.60   69.14  18.64   425.29    2.89     0.47   1.66
# 2        58.50   66.01  17.77   411.48   77.91    12.51  34.29
# 3        33.72  113.90  32.60   354.43   37.80    12.16  31.04
# 4        30.82  114.25  30.43   362.77   24.21     7.63  15.96
# ...        ...     ...    ...      ...     ...      ...    ...
# 15145   -15.94  589.65   0.00   948.60   21.49    13.11  12.28
# 15146   -16.34  703.55   0.00  1000.62   15.81    10.98  12.66
# 15147   -24.48    0.00   0.00     0.00    8.35     5.43   5.51
# 15148   -25.40    0.00   0.00     0.00    6.91     4.24   4.52
# 15149   -25.18    0.00   0.00     0.00    5.59     3.10  13.08
#
# [15150 rows x 53 columns]

# %%
df[df['이자보상배율']==0]
# Out:
#                회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 2687      (주)서부티엔디    6730  18-Dec     0.0   14.78    -2.85    -5.68   87.87
# 3775   (주)아이에스이커머스   69920  11-Dec     0.0   -2.00     5.36    -9.39    9.67
# 5942       (주)이수화학    5950  13-Dec     0.0    0.23     7.42     4.19   -7.11
# 5944       (주)이수화학    5950  15-Dec     0.0   -5.96    -2.23    -6.77  -20.54
# 6138      (주)인바이오젠  101140  18-Dec     0.0   81.64   -56.61    79.88    6.92
# 6352    (주)정상제이엘에스   40420  13-Dec     0.0   -0.64     5.42   -17.69   -7.55
# 6354    (주)정상제이엘에스   40420  15-Dec     0.0    2.64    10.76    -1.74    2.66
# 7026    (주)케이아이엔엑스   93320  12-Dec     0.0   12.94     6.17    -0.90   34.90
# 7029    (주)케이아이엔엑스   93320  15-Dec     0.0    9.65    -0.26    27.45   15.42
# 7422      (주)코썬바이오  204990  16-Dec     0.0   56.74     1.33    73.30   10.89
# 7452        (주)코엔텍   29960  13-Dec     0.0   11.15     3.48    10.83    2.13
# 7453        (주)코엔텍   29960  14-Dec     0.0   12.24    26.38    -9.41    7.32
# 7611     (주)클라우드에어   36170  19-Dec     0.0   -8.26    -3.84   -36.09   -6.41
# 8588       (주)한국특강    7280  13-Dec     0.0   -3.78    -5.34    -1.49  -13.02
# 8806         (주)한탑    2680  11-Dec     0.0   12.70    17.16    11.18    8.56
# 12439      엑스큐어(주)   70300  15-Dec     0.0   11.47   -18.22    79.48   55.18
# 12456      엔시트론(주)  101400  16-Dec     0.0    5.71   -25.25     9.01  -26.04
# 12589      영풍정밀(주)   36560  17-Dec     0.0    2.57   -23.65    15.76    8.68
# 12590      영풍정밀(주)   36560  18-Dec     0.0   -9.30    -2.87    15.27    0.07
# 14809   한전케이피에스(주)   51600  14-Dec     0.0   10.04    10.10     5.55   -3.58
# 15149      흥아해운(주)    3280  19-Dec     0.0  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 2687     15.88    34.09  ...     62.40           0.40            0.00
# 3775     70.25    -2.57  ...     49.99          44.44          842.60
# 5942     18.53   -15.75  ...     68.74          21.19          106.45
# 5944    -30.42   -11.38  ...     65.89          25.05          269.26
# 6138     62.01   106.21  ...      3.98           7.21            7.41
# 6352      9.27     0.30  ...     14.78           6.98           11.64
# 6354     23.10    -0.42  ...     17.85           9.30           17.12
# 7026      0.00    12.31  ...      6.14           0.00            0.00
# 7029      0.00     9.60  ...      5.88           0.00            0.00
# 7422    -13.14    70.99  ...     11.41           2.99            3.34
# 7452     23.16    12.53  ...     11.92           0.13            0.16
# 7453     27.93     9.89  ...     13.76           0.18            0.27
# 7611      3.13    16.54  ...     13.63           2.85            3.55
# 8588     14.54   -10.79  ...     79.90          57.32            0.00
# 8806      3.73     0.59  ...     65.49          21.63         9821.09
# 12439   139.13     7.36  ...     16.38          37.66           59.37
# 12456   -26.24    -1.55  ...     64.66          34.76          157.58
# 12589    -1.14     3.65  ...     15.91          25.04           29.83
# 12590    -3.21    -8.64  ...     15.30          21.03           25.31
# 14809   -20.97    12.21  ...     24.58           0.42            0.69
# 15149   -58.98   -57.73  ...     92.83           8.22            0.00
#
#        순운전자본비율   노동장비율   기계장비율    자본집약도   설비투자효율  총자본투자효율  부가가치율
# 2687    -13.21    0.00    0.00     0.00     7.16     3.56  56.76
# 3775      2.50    4.32    0.01   146.98     7.71     0.56   0.29
# 5942     10.32  461.35  108.41  2776.78    27.63     3.91   2.44
# 5944      4.82  450.57  125.72  2309.58    31.43     5.52   3.86
# 6138     95.89    0.00    0.00     0.00  7890.58     8.60  27.63
# 6352     17.71  119.31    0.00   266.71    74.36    33.55  30.87
# 6354     17.04  128.05    0.00   270.72    67.79    32.12  29.19
# 7026     45.85  132.48   23.46   452.01   149.05    41.98  56.68
# 7029     56.38  116.77   12.37   510.20   203.41    43.05  53.56
# 7422     76.20   65.05   30.48   476.74   188.76    25.76  45.48
# 7452     26.43  734.94  191.25  1430.91    47.24    23.71  56.95
# 7453     18.26  735.15  227.69  1552.01    50.20    23.14  58.13
# 7611     42.63    0.00    0.00     0.00   -23.90    -3.14 -23.80
# 8588    -27.74  697.04  251.34  1253.91    19.22    10.68  10.11
# 8806      0.12  197.39   24.13   896.52    18.56     4.30   6.04
# 12439    26.60   13.18    0.00   414.30   850.57    27.07  43.78
# 12456    12.95    0.00    0.00     0.00   269.15    18.02  14.92
# 12589    16.15    0.00    0.00     0.00    44.52     6.03  33.92
# 12590    20.31    0.00    0.00     0.00    51.04     7.40  37.74
# 14809    30.55   63.19    2.97   171.40   195.75    71.98  61.37
# 15149   -25.18    0.00    0.00     0.00     5.59     3.10  13.08
#
# [21 rows x 53 columns]

# %%
df['이자보상배율'] = df['이자보상배율'].astype(float)
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0        -1.43    -2.02  ...     33.95          17.88           35.59
# 1         7.73    75.17  ...     44.68           6.27            7.33
# 2        56.29    55.10  ...     12.37          12.09           14.12
# 3         6.37     0.01  ...     15.61          17.36           25.09
# 4        11.04    -4.48  ...     17.20          20.77           31.32
# ...        ...      ...  ...       ...            ...             ...
# 15145   -12.92     3.39  ...     78.14           8.43            0.00
# 15146    56.39    11.22  ...     79.92          17.60            0.00
# 15147    11.18   -39.28  ...     86.23          17.27            0.00
# 15148    -5.85   -37.42  ...     90.90          17.36            0.00
# 15149   -58.98   -57.73  ...     92.83           8.22            0.00
#
#        순운전자본비율   노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율
# 0        28.23   71.32  19.75   204.06   35.86    12.72  19.56
# 1        70.60   69.14  18.64   425.29    2.89     0.47   1.66
# 2        58.50   66.01  17.77   411.48   77.91    12.51  34.29
# 3        33.72  113.90  32.60   354.43   37.80    12.16  31.04
# 4        30.82  114.25  30.43   362.77   24.21     7.63  15.96
# ...        ...     ...    ...      ...     ...      ...    ...
# 15145   -15.94  589.65   0.00   948.60   21.49    13.11  12.28
# 15146   -16.34  703.55   0.00  1000.62   15.81    10.98  12.66
# 15147   -24.48    0.00   0.00     0.00    8.35     5.43   5.51
# 15148   -25.40    0.00   0.00     0.00    6.91     4.24   4.52
# 15149   -25.18    0.00   0.00     0.00    5.59     3.10  13.08
#
# [15150 rows x 53 columns]

# %%
# 분석 과정에서 NaN이 NaN이 아닌 다른 어떤 값인 것으로 판명되었습니다.
# 어쩔 수 없이 분석의 용이함을 위해 임의의 값을 채웠습니다
# df = df.fillna(77777.77)

# 이건 우리의 기준에 맞는 이자보상 배율을 저장하기 위한 컬럼입니다.
# df['이자보상배율'] = 0.0

# %%
# df_1 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS)']]
# df_2 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS연결)']]

# %%
# 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

f_company = [] # 한계기업을 저장하는 리스트
f_company_x = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
f_safe = []
fs_company = []
count = 0 # 한계기업 카운트용
s_count = 0
company = 'x' # 한계기업 기록용
s_company = 'o'

# 이거도 csv 한바퀴 돌립니다
for i in range(0, len(df)-1):

    # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
    if company == df.loc[i]['회사명']:
        # 다만 그 기업이 한계기업인데
        if count > 2:
            # 어머? 4년 연속이네요? 기록!!!
            if df.iloc[i]['이자보상배율'] < 1:
                f_company_x.append(company)
                count = 0
                # 반복문에서 볼일 다 끝났으니 통과합니다
            continue
        
        # 그게 아니라면 반복문을 통과합니다
        continue

    # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
    if df.iloc[i]['이자보상배율'] < 1:
            count += 1
    # 도중에 이자보상배율이 1 이상이면 탈출합니다
    else:
        count = 0
    # 한계 기업 클럽에 오셨습니다. 환영합니다.
    if count == 2:
        company = df.loc[i]['회사명']
        f_company.append(company)
        count += 1
        
    # else: 
    #     if count == 7:
    #         company == df.loc[i]['회사명']
    #         f_safe.append(company)
    #         count += 1

# %%
# f_company = [] # 한계기업을 저장하는 리스트
# f_safe = []
# fs_company = []
# s_count = 0
# s_company = 'o'

# for i in range(len(df)):
#     if s_company == df.loc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if s_count == 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df.iloc[i]['이자보상배율'] > 1:
#                 f_company_x.append(company)
#                 count = 0
#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#             continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue
    
#     if s_company == df.loc[i]['회사명']:
#         if s_count < 2:
#             f_safe.append(s_company)
#             s_count = 0
#         continue
    
#     if df.loc[i]['이자보상배율'] < 1:
#         s_count += 1
#     else:
#         s_count += 
        
#     if s_count == 2:
#         s_company = df.loc[i]['회사명']
#         f_company.append(s_company)
#         s_count += 1

# %%
# # 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

# f_company_1 = [] # 한계기업을 저장하는 리스트
# f_company_x_1 = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
# count_1 = 0 # 한계기업 카운트용
# company_1 = 'x' # 한계기업 기록용

# # 이거도 csv 한바퀴 돌립니다
# for i in range(0, len(df_2)-1):

#     # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
#     if company_1 == df_2.iloc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if count > 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#                 f_company_x_1.append(company_1)
#                 count = 0

#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#                 continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue

#     # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
#     if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#             count += 1
#     # 도중에 이자보상배율이 1 미만이면 탈출합니다
#     else:
#         count = 0

#     # 한계 기업 클럽에 오셨습니다. 환영합니다.
#     if count == 3:
#         company_1 = df_2.iloc[i]['회사명']
#         f_company_1.append(company_1)
#         count += 1

# %%
# 분명히 이거보다 더 좋은 방법이 있을건데
# 맷돌이 굴러가질 않네요

# 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
df_3 = df.isin(f_company)
df_3
# Out:
#         회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  재고자산증가율  \
# 0      True  False  False   False   False    False    False   False    False
# 1      True  False  False   False   False    False    False   False    False
# 2      True  False  False   False   False    False    False   False    False
# 3      True  False  False   False   False    False    False   False    False
# 4      True  False  False   False   False    False    False   False    False
# ...     ...    ...    ...     ...     ...      ...      ...     ...      ...
# 15145  True  False  False   False   False    False    False   False    False
# 15146  True  False  False   False   False    False    False   False    False
# 15147  True  False  False   False   False    False    False   False    False
# 15148  True  False  False   False   False    False    False   False    False
# 15149  True  False  False   False   False    False    False   False    False
#
#        자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  노동장비율  \
# 0        False  ...     False          False           False    False  False
# 1        False  ...     False          False           False    False  False
# 2        False  ...     False          False           False    False  False
# 3        False  ...     False          False           False    False  False
# 4        False  ...     False          False           False    False  False
# ...        ...  ...       ...            ...             ...      ...    ...
# 15145    False  ...     False          False           False    False  False
# 15146    False  ...     False          False           False    False  False
# 15147    False  ...     False          False           False    False  False
# 15148    False  ...     False          False           False    False  False
# 15149    False  ...     False          False           False    False  False
#
#        기계장비율  자본집약도  설비투자효율  총자본투자효율  부가가치율
# 0      False  False   False    False  False
# 1      False  False   False    False  False
# 2      False  False   False    False  False
# 3      False  False   False    False  False
# 4      False  False   False    False  False
# ...      ...    ...     ...      ...    ...
# 15145  False  False   False    False  False
# 15146  False  False   False    False  False
# 15147  False  False   False    False  False
# 15148  False  False   False    False  False
# 15149  False  False   False    False  False
#
# [15150 rows x 53 columns]

# %%
dd = df.isin(f_safe)
dd
# Out:
#          회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  재고자산증가율  \
# 0      False  False  False   False   False    False    False   False    False
# 1      False  False  False   False   False    False    False   False    False
# 2      False  False  False   False   False    False    False   False    False
# 3      False  False  False   False   False    False    False   False    False
# 4      False  False  False   False   False    False    False   False    False
# ...      ...    ...    ...     ...     ...      ...      ...     ...      ...
# 15145  False  False  False   False   False    False    False   False    False
# 15146  False  False  False   False   False    False    False   False    False
# 15147  False  False  False   False   False    False    False   False    False
# 15148  False  False  False   False   False    False    False   False    False
# 15149  False  False  False   False   False    False    False   False    False
#
#        자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  노동장비율  \
# 0        False  ...     False          False           False    False  False
# 1        False  ...     False          False           False    False  False
# 2        False  ...     False          False           False    False  False
# 3        False  ...     False          False           False    False  False
# 4        False  ...     False          False           False    False  False
# ...        ...  ...       ...            ...             ...      ...    ...
# 15145    False  ...     False          False           False    False  False
# 15146    False  ...     False          False           False    False  False
# 15147    False  ...     False          False           False    False  False
# 15148    False  ...     False          False           False    False  False
# 15149    False  ...     False          False           False    False  False
#
#        기계장비율  자본집약도  설비투자효율  총자본투자효율  부가가치율
# 0      False  False   False    False  False
# 1      False  False   False    False  False
# 2      False  False   False    False  False
# 3      False  False   False    False  False
# 4      False  False   False    False  False
# ...      ...    ...     ...      ...    ...
# 15145  False  False   False    False  False
# 15146  False  False   False    False  False
# 15147  False  False   False    False  False
# 15148  False  False   False    False  False
# 15149  False  False   False    False  False
#
# [15150 rows x 53 columns]

# %%
# # 분명히 이거보다 더 좋은 방법이 있을건데
# # 맷돌이 굴러가질 않네요

# # 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
# df_4 = df_2.isin(f_company_1)
# df_4

# %%
df_5 = [] # 임시 저장용 리스트

# 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
for i in range(0, len(df_3)-1):
    if df_3.iloc[i]["회사명"] == True:
        df_5.append(df.loc[i])
        
df_5_frame = pd.DataFrame(df_5).reset_index(drop=True)

# %%
# 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

df_6 = df.isin(f_company_x)
df_7 = []

for i in range(0, len(df_6)-1):
    if df_6.iloc[i]["회사명"] == True:
        df_7.append(df.loc[i])

df_7_frame = pd.DataFrame(df_7).reset_index(drop=True)

# %%
# df_8 = df_5_frame.isin()
# df_9 = []

# for i in range(0, len(dd)-1):
#     if dd.iloc[i]["회사명"] == False:
#         df_9.append(df.loc[i])

# df_9_frame = pd.DataFrame(df_9).reset_index(drop=True)

# %%
# df_8 = [] # 임시 저장용 리스트

# # 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
# for i in range(0, len(df_4)-1):
#     if df_4.iloc[i]["회사명"] == True:
#         df_8.append(df_2.loc[i])
        
# df_8_frame = pd.DataFrame(df_8).reset_index(drop=True)

# %%
# # 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

# df_9 = df_1.isin(f_company_x_1)
# df_10 = []

# for i in range(0, len(df_9)-1):
#     if df_9.iloc[i]["회사명"] == True:
#         df_10.append(df_2.loc[i])

# df_10_frame = pd.DataFrame(df_10).reset_index(drop=True)

# %%
# c = df_5_frame.copy()
# c['회계년도'] = pd.to_datetime(c['회계년도'], format='%d-%b').dt.strftime('20%d-%m')
# # 거래소 코드 6자리가 아닌 것들은 6자리가 될 때까지 앞에 0 추가
# c['거래소코드'] = c['거래소코드'].astype(str).str.zfill(6)

# %%
# # 회계년도가 12월이 아닌 행 리스트 생성
# not_dec_list = c[~c.loc[:,'회계년도'].str.endswith('12')].index.tolist()
# not_dec_list

# %%
# # 회계년도가 12월이 아닌 행 제거
# print(c.shape)
# c.drop(c.index[not_dec_list], inplace=True)
# c.reset_index(drop=True, inplace=True)
# print(c.shape)

# %%
# # 거래소코드가 9로 시작하는 기업
# code_nine_list = c['회사명'][c['거래소코드'].astype(str).str.startswith('9')].unique()
# code_nine_list

# %%
# # 거래소코드가 9로 시작하는 기업 제거
# c = c[~c['회사명'].isin(code_nine_list)]
# c.reset_index(drop=True, inplace=True)
# print(c.shape)

# %%
# # 기업 기록이 하나인 기업
# single_rows = c['회사명'].value_counts() < 2
# single_rows[single_rows]

# %%
# # 기업 기록이 하나인 기업 제거
# c = c[~c['회사명'].isin(single_rows[single_rows].index)]
# c.reset_index(drop=True, inplace=True)
# print(c.shape)

# %%
# c.to_csv('1년부실징후직접계산.csv',encoding='cp949',index=False)

# %%
# c.isna().sum()

# %%
# df_5_frame.to_csv('3년연속성한계기업.csv',index=False,encoding='cp949')

# %%
# a.to_csv('3년연속한계기업.csv',index=False,encoding='cp949')

# %%
# df_7_frame.to_csv('4년째연속성나락간기업.csv',index=False,encoding='cp949')

# %%
# b.to_csv('4년째나락간기업.csv',index=False,encoding='cp949')

# %%
# pd.options.display.max_columns = None

# %%
# 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
a = df_5_frame.copy().drop_duplicates('회사명')
# a = a.reset_index(drop=True)
a
# Out:
#                    회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 0             (주)CMG제약   58820  11-Dec    3.53    1.98    -5.90    17.64
# 9             (주)DB하이텍     990  11-Dec   -0.75  -13.19    -7.89   -10.08
# 18             (주)ES큐브   50120  11-Dec -245.99    0.00     0.00     0.00
# 27            (주)MH에탄올   23150  11-Dec    0.12   -0.49     2.92    -0.67
# 36              (주)STX   11810  11-Dec    1.66  -14.09   -43.60   -37.48
# ...                ...     ...     ...     ...     ...      ...      ...
# 6425  현대일렉트릭앤에너지시스템(주)  267260  17-Dec    4.31     NaN      NaN      NaN
# 6428           현우산업(주)   92300  11-Dec    2.86    6.48     8.40     4.77
# 6437           휴림로봇(주)   90710  11-Dec    2.96   35.07    27.83    38.25
# 6446           휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN
# 6452           흥아해운(주)    3280  11-Dec   -0.33   -3.13    -0.34   -15.59
#
#       매출액증가율  재고자산증가율  자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0      56.40    -1.43    -2.02  ...     33.95          17.88           35.59
# 9     -10.94    -3.28   -22.60  ...     74.31          27.57            0.00
# 18      0.00     0.00     0.00  ...     29.26          15.59           27.56
# 27    -18.64    18.30    -8.46  ...     68.21          21.31            0.00
# 36     47.50   -26.60    28.79  ...     63.40          22.04            0.00
# ...      ...      ...      ...  ...       ...            ...             ...
# 6425     NaN      NaN      NaN  ...       NaN            NaN             NaN
# 6428    7.58    -8.72     0.42  ...     49.44          34.56            0.00
# 6437   58.70    17.70    37.53  ...     54.18          24.76           91.17
# 6446     NaN      NaN      NaN  ...       NaN            NaN             NaN
# 6452   12.78    49.62   -17.19  ...     78.67          12.38            0.00
#
#       순운전자본비율   노동장비율   기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율
# 0       28.23   71.32   19.75   204.06   35.86    12.72  19.56
# 9      -42.95  284.94  107.56   461.22   29.75    18.17  39.45
# 18      34.75    5.94    0.00   190.86  279.20    21.71  22.56
# 27     -24.28  689.66   18.92  2665.24   11.62     6.51  19.52
# 36     -11.68  185.72    0.00  8424.10   66.29    10.01   8.78
# ...       ...     ...     ...      ...     ...      ...    ...
# 6425      NaN     NaN     NaN      NaN     NaN      NaN    NaN
# 6428   -12.68  214.27  115.74   352.34   32.34    19.67  22.14
# 6437    17.83   58.76    0.78   278.75  103.19    18.88  20.15
# 6446      NaN     NaN     NaN      NaN     NaN      NaN    NaN
# 6452   -14.68  357.93    0.00   752.66   14.67     6.92   5.37
#
# [789 rows x 53 columns]

# %%
# a.to_csv('3차테스트.csv',encoding='cp949',index=False)

# %%
# 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
b = df_7_frame.copy().drop_duplicates(['회사명'])
# b = b.reset_index(drop=True)
b
# Out:
#                회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0         (주)CMG제약   58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 9         (주)DB하이텍     990  11-Dec   -0.75  -13.19    -7.89   -10.08  -10.94
# 18          (주)STX   11810  11-Dec    1.66  -14.09   -43.60   -37.48   47.50
# 27        (주)TCC스틸    2710  11-Dec    1.41    9.56     4.88     5.46   11.61
# 36      (주)강스템바이오텍  217730  15-Dec   -5.41    0.00     0.00     0.00    0.00
# ...            ...     ...     ...     ...     ...      ...      ...     ...
# 4975  현대바이오사이언스(주)   48410  11-Dec  -18.41  -41.39   -23.21   -44.34  -44.11
# 4984       현우산업(주)   92300  11-Dec    2.86    6.48     8.40     4.77    7.58
# 4993       휴림로봇(주)   90710  11-Dec    2.96   35.07    27.83    38.25   58.70
# 5002       휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN     NaN
# 5008       흥아해운(주)    3280  11-Dec   -0.33   -3.13    -0.34   -15.59   12.78
#
#       재고자산증가율  자기자본증가율  ...  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0       -1.43    -2.02  ...     33.95          17.88           35.59    28.23
# 9       -3.28   -22.60  ...     74.31          27.57            0.00   -42.95
# 18     -26.60    28.79  ...     63.40          22.04            0.00   -11.68
# 27      16.95     0.10  ...     50.38          43.40          445.09     3.94
# 36       0.00     0.00  ...     14.99           1.77            2.10    63.77
# ...       ...      ...  ...       ...            ...             ...      ...
# 4975   -44.81   -55.29  ...     53.48          53.24          148.32    28.99
# 4984    -8.72     0.42  ...     49.44          34.56            0.00   -12.68
# 4993    17.70    37.53  ...     54.18          24.76           91.17    17.83
# 5002      NaN      NaN  ...       NaN            NaN             NaN      NaN
# 5008    49.62   -17.19  ...     78.67          12.38            0.00   -14.68
#
#        노동장비율   기계장비율    자본집약도  설비투자효율  총자본투자효율   부가가치율
# 0      71.32   19.75   204.06   35.86    12.72   19.56
# 9     284.94  107.56   461.22   29.75    18.17   39.45
# 18    185.72    0.00  8424.10   66.29    10.01    8.78
# 27    235.44   58.92  1294.42   60.97    11.18    9.88
# 36     48.06    8.13   402.95  -96.67   -11.53 -194.04
# ...      ...     ...      ...     ...      ...     ...
# 4975   62.35   27.22   464.03  -91.86   -15.51   -9.92
# 4984  214.27  115.74   352.34   32.34    19.67   22.14
# 4993   58.76    0.78   278.75  103.19    18.88   20.15
# 5002     NaN     NaN      NaN     NaN      NaN     NaN
# 5008  357.93    0.00   752.66   14.67     6.92    5.37
#
# [593 rows x 53 columns]

# %%
c = a.columns - b.columns

# %%
# # 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
# df_8_frame.copy().drop_duplicates(['회사명'])

# %%
# # 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
# df_10_frame.copy().drop_duplicates(['회사명'])

# %%
# 회사명 리스트 생성
company_list = df['회사명'].unique()
company_list
# Out:
# array(['(주)CMG제약', '(주)DB하이텍', '(주)ES큐브', ..., '휴젤(주)', '흥구석유(주)',
#        '흥아해운(주)'], dtype=object)

# %%
# 행 개수가 3개 이상인 기업 리스트 및 수
over_three = []
for i in company_list:
    if len(df[df['회사명']==i]) >= 2:
        over_three.append(i)
print(len(over_three))
print(over_three)

# %%
# 행 개수가 3개 이상인 기업 인덱스
over_three_index = []
for i in over_three:
    over_three_index.append(df[df['회사명']==i].index)
over_three_index

# %%
# 3년 연속 이자보상배율이 1미만인 기업을 부실기업으로 정의
icr_count = 0
df['부실기업1'] = ''

for i in over_three_index:
    for j in i:
        if df.loc[j, '이자보상배율'] < 1:
            icr_count += 1
        else:
            icr_count = 0
                    
        if icr_count >= 2:
            df.loc[j, '부실기업1'] = 1
        else:
            df.loc[j, '부실기업1'] = 0

# %%
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율   노동장비율  \
# 0        -1.43    -2.02  ...          17.88           35.59    28.23   71.32
# 1         7.73    75.17  ...           6.27            7.33    70.60   69.14
# 2        56.29    55.10  ...          12.09           14.12    58.50   66.01
# 3         6.37     0.01  ...          17.36           25.09    33.72  113.90
# 4        11.04    -4.48  ...          20.77           31.32    30.82  114.25
# ...        ...      ...  ...            ...             ...      ...     ...
# 15145   -12.92     3.39  ...           8.43            0.00   -15.94  589.65
# 15146    56.39    11.22  ...          17.60            0.00   -16.34  703.55
# 15147    11.18   -39.28  ...          17.27            0.00   -24.48    0.00
# 15148    -5.85   -37.42  ...          17.36            0.00   -25.40    0.00
# 15149   -58.98   -57.73  ...           8.22            0.00   -25.18    0.00
#
#        기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 0      19.75   204.06   35.86    12.72  19.56      0
# 1      18.64   425.29    2.89     0.47   1.66      0
# 2      17.77   411.48   77.91    12.51  34.29      1
# 3      32.60   354.43   37.80    12.16  31.04      0
# 4      30.43   362.77   24.21     7.63  15.96      0
# ...      ...      ...     ...      ...    ...    ...
# 15145   0.00   948.60   21.49    13.11  12.28      0
# 15146   0.00  1000.62   15.81    10.98  12.66      0
# 15147   0.00     0.00    8.35     5.43   5.51      1
# 15148   0.00     0.00    6.91     4.24   4.52      1
# 15149   0.00     0.00    5.59     3.10  13.08      1
#
# [15150 rows x 54 columns]

# %%
a = df[df['부실기업1']==1]
b = a.drop_duplicates('회사명')
b
# Out:
#                     회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 2              (주)CMG제약   58820  13-Dec    0.70   -2.09    16.09   -18.89
# 10             (주)DB하이텍     990  12-Dec   -0.31   -3.44    -9.69    10.52
# 26              (주)ES큐브   50120  19-Dec   -0.68  312.66    14.02   696.75
# 27             (주)HJ중공업   97230  11-Dec    0.55   -6.49    -1.53   -13.26
# 36             (주)MH에탄올   23150  11-Dec    0.12   -0.49     2.92    -0.67
# ...                 ...     ...     ...     ...     ...      ...      ...
# 14981  현대일렉트릭앤에너지시스템(주)  267260  19-Dec   -4.66   -2.99    -2.10   -10.14
# 15016           현우산업(주)   92300  13-Dec   -1.29    7.54     4.22    14.79
# 15114           휴림로봇(주)   90710  13-Dec   -3.00   -8.68    -2.15   -17.87
# 15121           휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN
# 15147           흥아해운(주)    3280  17-Dec   -0.42  -11.43   -16.50    13.29
#
#        매출액증가율  재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 2       25.51    56.29    55.10  ...          12.09           14.12    58.50
# 10       6.98     2.79    -5.57  ...          25.64            0.00   -21.27
# 26      29.45   -17.20   -18.89  ...           2.13            5.93    27.78
# 27      -8.72    23.47    -4.59  ...          15.08            0.00    -1.29
# 36     -18.64    18.30    -8.46  ...          21.31            0.00   -24.28
# ...       ...      ...      ...  ...            ...             ...      ...
# 14981   -8.72    -7.99   -17.75  ...          26.33          108.41    15.97
# 15016   -3.69     3.74    -1.01  ...          27.36            0.00   -10.69
# 15114   36.45   -15.62   -20.84  ...          27.74          226.41     6.82
# 15121     NaN      NaN      NaN  ...            NaN             NaN      NaN
# 15147    0.56    11.18   -39.28  ...          17.27            0.00   -24.48
#
#         노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 2       66.01  17.77   411.48   77.91    12.51  34.29      1
# 10     287.76  95.01   498.73   37.03    21.22  41.58      1
# 26       0.00   0.00     0.00   -3.22    -0.12  -1.28      1
# 27     510.77  33.44  2103.09   15.81     7.02  17.09      1
# 36     689.66  18.92  2665.24   11.62     6.51  19.52      1
# ...       ...    ...      ...     ...      ...    ...    ...
# 14981    0.00   0.00     0.00   -5.42    -1.19  -1.52      1
# 15016  190.10  95.13   337.24   34.38    19.38  25.75      1
# 15114   62.61   1.19   283.56   75.91    16.06  16.97      1
# 15121     NaN    NaN      NaN     NaN      NaN    NaN      1
# 15147    0.00   0.00     0.00    8.35     5.43   5.51      1
#
# [835 rows x 54 columns]
