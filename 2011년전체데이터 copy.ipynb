# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
df = pd.read_csv('./비율/최종찐재무비율계산식.csv', encoding='utf-8')
# df = df.drop(columns=)
# df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  Dec-11    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  Dec-12   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  Dec-13    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  Dec-14    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  Dec-15  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  Dec-15    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  Dec-16    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  Dec-17   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  Dec-18   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  Dec-19   -0.55  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  \
# 0        -1.43    -2.02    0.00       0.00    41.83    -8.50     -8.28
# 1         7.73    75.17    0.00       0.00    28.34   -40.97    -26.84
# 2        56.29    55.10    0.00       0.00    38.70     1.45      0.74
# 3         6.37     0.01  -46.64     -44.10    37.07     0.69      0.32
# 4        11.04    -4.48    0.00       0.00    36.26   -13.50     -7.62
# ...        ...      ...     ...        ...      ...      ...       ...
# 15145   -12.92     3.39  -42.68      14.41     6.20     1.24      6.18
# 15146    56.39    11.22 -263.29     -72.25     4.49    -2.06     -9.40
# 15147    11.18   -39.28    0.00    -322.17     2.09    -8.79    -47.52
# 15148    -5.85   -37.42    0.00       0.00    -0.93   -11.48    -91.08
# 15149   -58.98   -57.73    0.00       0.00     5.54   -50.27    -98.70
#
#        총자본정상영업이익율  매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  \
# 0            2.37        3.61    -5.58    0.66     6.42     2.45     1.77
# 1           -9.96      -25.87   -15.78    0.39     5.71     1.85     1.71
# 2            1.40        3.88     0.52    0.36     5.39     2.07     2.03
# 3            0.78        1.94     0.28    0.40     4.77     1.86     1.54
# 4           -4.49       -9.51    -6.37    0.47     5.22     2.10     1.48
# ...           ...         ...      ...     ...      ...      ...      ...
# 15145        2.95        2.51     1.46    1.17    68.48    25.33     2.09
# 15146        0.67        0.71    -1.96    0.95    56.47    25.24     1.44
# 15147       -1.45       -1.57    -8.13    0.93    44.09    23.08     1.36
# 15148       -4.55       -4.99   -10.47    0.91    38.87    19.15     1.43
# 15149       -2.00      -12.10    -8.32    0.17     7.70     4.78     0.28
#
#        매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률    유동비율    당좌비율  \
# 0        11.95     0.97     2.01     1.25     1.55      0.86  200.97  165.03
# 1         7.83     0.66     0.93     0.52     0.57      0.42  693.49  649.98
# 2         6.20     0.51     1.26     0.48     0.52      0.42  694.71  610.74
# 3         5.27     0.46     2.85     0.68     0.80      0.56  324.58  268.23
# 4         5.66     0.56     2.88     0.99     1.22      0.75  296.85  235.21
# ...        ...      ...      ...      ...      ...       ...     ...     ...
# 15145    16.05     4.96     1.54     5.83     6.38      2.15   51.92   47.54
# 15146    16.26     4.55     1.20     6.98     7.96      2.19   39.46   32.52
# 15147    15.39     5.41     1.12     7.68     9.30      2.09   35.76   29.58
# 15148    11.87     7.93     1.03     6.73     8.14      1.75   34.67   28.66
# 15149     2.41     1.96     0.18     1.01     1.16      0.28   46.36   42.55
#
#          현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  \
# 0       15.10    51.41    9.08            -46.08             -24.07
# 1       68.81    80.77   30.58             -8.10             -12.71
# 2      394.63    14.11    2.53            -39.85             -13.51
# 3      101.24    18.50    2.66            -17.73              -7.06
# 4       29.00    20.78    0.01             16.12               5.80
# ...       ...      ...     ...               ...                ...
# 15145    7.76   357.39   32.82              2.78               2.03
# 15146    5.46   397.97   26.94              2.12               1.96
# 15147    6.17   626.32   31.84             -0.57              -0.50
# 15148    4.89   998.73   31.60             -2.78              -2.70
# 15149    6.75  1293.83   72.50             -5.73             -22.44
#
#        CASH_FLOW_대_차입금비율  자기자본구성비율    차입금비율  당좌자산구성비율  유동자산구성비율  \
# 0                -172.40     66.05    13.74     46.14     56.18
# 1                 -11.83     55.32    55.28     77.32     82.49
# 2                -194.73     87.63     2.89     60.08     68.34
# 3                -104.12     84.39     3.15     40.28     48.74
# 4               24988.82     82.80     0.01     36.82     46.47
# ...                  ...       ...      ...       ...       ...
# 15145               6.61     21.86   150.12     15.76     17.21
# 15146               6.30     20.08   134.16      8.78     10.65
# 15147              -1.53     13.77   231.23     11.27     13.63
# 15148              -8.01      9.10   347.18     11.14     13.48
# 15149              -7.34      7.17  1010.48     19.98     21.77
#
#        매출채권_대_매입채무비율  단기차입금_대_총차입금비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  \
# 0             602.31           80.71   42.33     33.95          17.88
# 1             323.41            0.57   21.50     44.68           6.27
# 2             282.72            0.00   11.23     12.37          12.09
# 3             285.31            0.00   17.79     15.61          17.36
# 4             254.69            0.00   18.91     17.20          20.77
# ...              ...             ...     ...       ...            ...
# 15145          60.44           69.35  151.66     78.14           8.43
# 15146          68.73           71.88  134.41     79.92          17.60
# 15147          65.00           82.75  276.77     86.23          17.27
# 15148          59.32           80.74  427.21     90.90          17.36
# 15149          15.30           41.02  654.44     92.83           8.22
#
#        재고자산_대_순운전자본비율  순운전자본비율   노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  \
# 0               35.59    28.23   71.32  19.75   204.06   35.86    12.72
# 1                7.33    70.60   69.14  18.64   425.29    2.89     0.47
# 2               14.12    58.50   66.01  17.77   411.48   77.91    12.51
# 3               25.09    33.72  113.90  32.60   354.43   37.80    12.16
# 4               31.32    30.82  114.25  30.43   362.77   24.21     7.63
# ...               ...      ...     ...    ...      ...     ...      ...
# 15145            0.00   -15.94  589.65   0.00   948.60   21.49    13.11
# 15146            0.00   -16.34  703.55   0.00  1000.62   15.81    10.98
# 15147            0.00   -24.48    0.00   0.00     0.00    8.35     5.43
# 15148            0.00   -25.40    0.00   0.00     0.00    6.91     4.24
# 15149            0.00   -25.18    0.00   0.00     0.00    5.59     3.10
#
#        부가가치율  직원감소율여부
# 0      19.56        0
# 1       1.66        0
# 2      34.29        0
# 3      31.04        1
# 4      15.96        0
# ...      ...      ...
# 15145  12.28        0
# 15146  12.66        0
# 15147   5.51        0
# 15148   4.52        0
# 15149  13.08        0
#
# [15150 rows x 54 columns]

# %%
# 분석 과정에서 NaN이 NaN이 아닌 다른 어떤 값인 것으로 판명되었습니다.
# 어쩔 수 없이 분석의 용이함을 위해 임의의 값을 채웠습니다
# df = df.fillna(77777.77)

# 이건 우리의 기준에 맞는 이자보상 배율을 저장하기 위한 컬럼입니다.
# df['이자보상배율'] = 0.0

# %%
# df_1 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS)']]
# df_2 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS연결)']]

# %%
# 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

f_company = [] # 한계기업을 저장하는 리스트
f_company_x = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
f_safe = []
fs_company = []
count = 0 # 한계기업 카운트용
s_count = 0
company = 'x' # 한계기업 기록용
s_company = 'o'

# 이거도 csv 한바퀴 돌립니다
for i in range(0, len(df)-1):

    # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
    if company == df.loc[i]['회사명']:
        # 다만 그 기업이 한계기업인데
        if count > 1:
            # 어머? 4년 연속이네요? 기록!!!
            if df.iloc[i]['이자보상배율'] < 1:
                f_company_x.append(company)
                count = 0
                # 반복문에서 볼일 다 끝났으니 통과합니다
            continue
        
        # 그게 아니라면 반복문을 통과합니다
        continue

    # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
    if df.iloc[i]['이자보상배율'] < 1:
            count += 1
    # 도중에 이자보상배율이 1 이상이면 탈출합니다
    else:
        count = 0
    # 한계 기업 클럽에 오셨습니다. 환영합니다.
    if count == 1:
        company = df.loc[i]['회사명']
        f_company.append(company)
        count += 1
        
    # else: 
    #     if count == 7:
    #         company == df.loc[i]['회사명']
    #         f_safe.append(company)
    #         count += 1

# %%
# f_company = [] # 한계기업을 저장하는 리스트
# f_safe = []
# fs_company = []
# s_count = 0
# s_company = 'o'

# for i in range(len(df)):
#     if s_company == df.loc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if s_count == 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df.iloc[i]['이자보상배율'] > 1:
#                 f_company_x.append(company)
#                 count = 0
#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#             continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue
    
#     if s_company == df.loc[i]['회사명']:
#         if s_count < 2:
#             f_safe.append(s_company)
#             s_count = 0
#         continue
    
#     if df.loc[i]['이자보상배율'] < 1:
#         s_count += 1
#     else:
#         s_count += 
        
#     if s_count == 2:
#         s_company = df.loc[i]['회사명']
#         f_company.append(s_company)
#         s_count += 1

# %%
# # 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

# f_company_1 = [] # 한계기업을 저장하는 리스트
# f_company_x_1 = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
# count_1 = 0 # 한계기업 카운트용
# company_1 = 'x' # 한계기업 기록용

# # 이거도 csv 한바퀴 돌립니다
# for i in range(0, len(df_2)-1):

#     # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
#     if company_1 == df_2.iloc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if count > 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#                 f_company_x_1.append(company_1)
#                 count = 0

#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#                 continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue

#     # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
#     if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#             count += 1
#     # 도중에 이자보상배율이 1 미만이면 탈출합니다
#     else:
#         count = 0

#     # 한계 기업 클럽에 오셨습니다. 환영합니다.
#     if count == 3:
#         company_1 = df_2.iloc[i]['회사명']
#         f_company_1.append(company_1)
#         count += 1

# %%
# 분명히 이거보다 더 좋은 방법이 있을건데
# 맷돌이 굴러가질 않네요

# 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
df_3 = df.isin(f_company)
df_3
# Out:
#         회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  재고자산증가율  \
# 0      True  False  False   False   False    False    False   False    False
# 1      True  False  False   False   False    False    False   False    False
# 2      True  False  False   False   False    False    False   False    False
# 3      True  False  False   False   False    False    False   False    False
# 4      True  False  False   False   False    False    False   False    False
# ...     ...    ...    ...     ...     ...      ...      ...     ...      ...
# 15145  True  False  False   False   False    False    False   False    False
# 15146  True  False  False   False   False    False    False   False    False
# 15147  True  False  False   False   False    False    False   False    False
# 15148  True  False  False   False   False    False    False   False    False
# 15149  True  False  False   False   False    False    False   False    False
#
#        자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본정상영업이익율  \
# 0        False   False      False    False    False     False       False
# 1        False   False      False    False    False     False       False
# 2        False   False      False    False    False     False       False
# 3        False   False      False    False    False     False       False
# 4        False   False      False    False    False     False       False
# ...        ...     ...        ...      ...      ...       ...         ...
# 15145    False   False      False    False    False     False       False
# 15146    False   False      False    False    False     False       False
# 15147    False   False      False    False    False     False       False
# 15148    False   False      False    False    False     False       False
# 15149    False   False      False    False    False     False       False
#
#        매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  \
# 0           False    False   False    False    False    False    False
# 1           False    False   False    False    False    False    False
# 2           False    False   False    False    False    False    False
# 3           False    False   False    False    False    False    False
# 4           False    False   False    False    False    False    False
# ...           ...      ...     ...      ...      ...      ...      ...
# 15145       False    False   False    False    False    False    False
# 15146       False    False   False    False    False    False    False
# 15147       False    False   False    False    False    False    False
# 15148       False    False   False    False    False    False    False
# 15149       False    False   False    False    False    False    False
#
#        자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률   유동비율   당좌비율   현금비율  \
# 0        False    False    False    False     False  False  False  False
# 1        False    False    False    False     False  False  False  False
# 2        False    False    False    False     False  False  False  False
# 3        False    False    False    False     False  False  False  False
# 4        False    False    False    False     False  False  False  False
# ...        ...      ...      ...      ...       ...    ...    ...    ...
# 15145    False    False    False    False     False  False  False  False
# 15146    False    False    False    False     False  False  False  False
# 15147    False    False    False    False     False  False  False  False
# 15148    False    False    False    False     False  False  False  False
# 15149    False    False    False    False     False  False  False  False
#
#         부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  \
# 0      False   False             False              False              False
# 1      False   False             False              False              False
# 2      False   False             False              False              False
# 3      False   False             False              False              False
# 4      False   False             False              False              False
# ...      ...     ...               ...                ...                ...
# 15145  False   False             False              False              False
# 15146  False   False             False              False              False
# 15147  False   False             False              False              False
# 15148  False   False             False              False              False
# 15149  False   False             False              False              False
#
#        자기자본구성비율  차입금비율  당좌자산구성비율  유동자산구성비율  매출채권_대_매입채무비율  단기차입금_대_총차입금비율  \
# 0         False  False     False     False          False           False
# 1         False  False     False     False          False           False
# 2         False  False     False     False          False           False
# 3         False  False     False     False          False           False
# 4         False  False     False     False          False           False
# ...         ...    ...       ...       ...            ...             ...
# 15145     False  False     False     False          False           False
# 15146     False  False     False     False          False           False
# 15147     False  False     False     False          False           False
# 15148     False  False     False     False          False           False
# 15149     False  False     False     False          False           False
#
#        유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  노동장비율  기계장비율  \
# 0       False     False          False           False    False  False  False
# 1       False     False          False           False    False  False  False
# 2       False     False          False           False    False  False  False
# 3       False     False          False           False    False  False  False
# 4       False     False          False           False    False  False  False
# ...       ...       ...            ...             ...      ...    ...    ...
# 15145   False     False          False           False    False  False  False
# 15146   False     False          False           False    False  False  False
# 15147   False     False          False           False    False  False  False
# 15148   False     False          False           False    False  False  False
# 15149   False     False          False           False    False  False  False
#
#        자본집약도  설비투자효율  총자본투자효율  부가가치율  직원감소율여부
# 0      False   False    False  False    False
# 1      False   False    False  False    False
# 2      False   False    False  False    False
# 3      False   False    False  False    False
# 4      False   False    False  False    False
# ...      ...     ...      ...    ...      ...
# 15145  False   False    False  False    False
# 15146  False   False    False  False    False
# 15147  False   False    False  False    False
# 15148  False   False    False  False    False
# 15149  False   False    False  False    False
#
# [15150 rows x 54 columns]

# %%
dd = df.isin(f_safe)
dd
# Out:
#          회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  재고자산증가율  \
# 0      False  False  False   False   False    False    False   False    False
# 1      False  False  False   False   False    False    False   False    False
# 2      False  False  False   False   False    False    False   False    False
# 3      False  False  False   False   False    False    False   False    False
# 4      False  False  False   False   False    False    False   False    False
# ...      ...    ...    ...     ...     ...      ...      ...     ...      ...
# 15145  False  False  False   False   False    False    False   False    False
# 15146  False  False  False   False   False    False    False   False    False
# 15147  False  False  False   False   False    False    False   False    False
# 15148  False  False  False   False   False    False    False   False    False
# 15149  False  False  False   False   False    False    False   False    False
#
#        자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본정상영업이익율  \
# 0        False   False      False    False    False     False       False
# 1        False   False      False    False    False     False       False
# 2        False   False      False    False    False     False       False
# 3        False   False      False    False    False     False       False
# 4        False   False      False    False    False     False       False
# ...        ...     ...        ...      ...      ...       ...         ...
# 15145    False   False      False    False    False     False       False
# 15146    False   False      False    False    False     False       False
# 15147    False   False      False    False    False     False       False
# 15148    False   False      False    False    False     False       False
# 15149    False   False      False    False    False     False       False
#
#        매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  \
# 0           False    False   False    False    False    False    False
# 1           False    False   False    False    False    False    False
# 2           False    False   False    False    False    False    False
# 3           False    False   False    False    False    False    False
# 4           False    False   False    False    False    False    False
# ...           ...      ...     ...      ...      ...      ...      ...
# 15145       False    False   False    False    False    False    False
# 15146       False    False   False    False    False    False    False
# 15147       False    False   False    False    False    False    False
# 15148       False    False   False    False    False    False    False
# 15149       False    False   False    False    False    False    False
#
#        자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률   유동비율   당좌비율   현금비율  \
# 0        False    False    False    False     False  False  False  False
# 1        False    False    False    False     False  False  False  False
# 2        False    False    False    False     False  False  False  False
# 3        False    False    False    False     False  False  False  False
# 4        False    False    False    False     False  False  False  False
# ...        ...      ...      ...      ...       ...    ...    ...    ...
# 15145    False    False    False    False     False  False  False  False
# 15146    False    False    False    False     False  False  False  False
# 15147    False    False    False    False     False  False  False  False
# 15148    False    False    False    False     False  False  False  False
# 15149    False    False    False    False     False  False  False  False
#
#         부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  \
# 0      False   False             False              False              False
# 1      False   False             False              False              False
# 2      False   False             False              False              False
# 3      False   False             False              False              False
# 4      False   False             False              False              False
# ...      ...     ...               ...                ...                ...
# 15145  False   False             False              False              False
# 15146  False   False             False              False              False
# 15147  False   False             False              False              False
# 15148  False   False             False              False              False
# 15149  False   False             False              False              False
#
#        자기자본구성비율  차입금비율  당좌자산구성비율  유동자산구성비율  매출채권_대_매입채무비율  단기차입금_대_총차입금비율  \
# 0         False  False     False     False          False           False
# 1         False  False     False     False          False           False
# 2         False  False     False     False          False           False
# 3         False  False     False     False          False           False
# 4         False  False     False     False          False           False
# ...         ...    ...       ...       ...            ...             ...
# 15145     False  False     False     False          False           False
# 15146     False  False     False     False          False           False
# 15147     False  False     False     False          False           False
# 15148     False  False     False     False          False           False
# 15149     False  False     False     False          False           False
#
#        유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  노동장비율  기계장비율  \
# 0       False     False          False           False    False  False  False
# 1       False     False          False           False    False  False  False
# 2       False     False          False           False    False  False  False
# 3       False     False          False           False    False  False  False
# 4       False     False          False           False    False  False  False
# ...       ...       ...            ...             ...      ...    ...    ...
# 15145   False     False          False           False    False  False  False
# 15146   False     False          False           False    False  False  False
# 15147   False     False          False           False    False  False  False
# 15148   False     False          False           False    False  False  False
# 15149   False     False          False           False    False  False  False
#
#        자본집약도  설비투자효율  총자본투자효율  부가가치율  직원감소율여부
# 0      False   False    False  False    False
# 1      False   False    False  False    False
# 2      False   False    False  False    False
# 3      False   False    False  False    False
# 4      False   False    False  False    False
# ...      ...     ...      ...    ...      ...
# 15145  False   False    False  False    False
# 15146  False   False    False  False    False
# 15147  False   False    False  False    False
# 15148  False   False    False  False    False
# 15149  False   False    False  False    False
#
# [15150 rows x 54 columns]

# %%
# # 분명히 이거보다 더 좋은 방법이 있을건데
# # 맷돌이 굴러가질 않네요

# # 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
# df_4 = df_2.isin(f_company_1)
# df_4

# %%
df_5 = [] # 임시 저장용 리스트

# 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
for i in range(0, len(df_3)-1):
    if df_3.iloc[i]["회사명"] == True:
        df_5.append(df.loc[i])
        
df_5_frame = pd.DataFrame(df_5).reset_index(drop=True)

# %%
# 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

df_6 = df.isin(f_company_x)
df_7 = []

for i in range(0, len(df_6)-1):
    if df_6.iloc[i]["회사명"] == True:
        df_7.append(df.loc[i])

df_7_frame = pd.DataFrame(df_7).reset_index(drop=True)

# %%
# df_8 = df_5_frame.isin()
# df_9 = []

# for i in range(0, len(dd)-1):
#     if dd.iloc[i]["회사명"] == False:
#         df_9.append(df.loc[i])

# df_9_frame = pd.DataFrame(df_9).reset_index(drop=True)

# %%
# df_8 = [] # 임시 저장용 리스트

# # 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
# for i in range(0, len(df_4)-1):
#     if df_4.iloc[i]["회사명"] == True:
#         df_8.append(df_2.loc[i])
        
# df_8_frame = pd.DataFrame(df_8).reset_index(drop=True)

# %%
# # 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

# df_9 = df_1.isin(f_company_x_1)
# df_10 = []

# for i in range(0, len(df_9)-1):
#     if df_9.iloc[i]["회사명"] == True:
#         df_10.append(df_2.loc[i])

# df_10_frame = pd.DataFrame(df_10).reset_index(drop=True)

# %%
c = df_5_frame.copy()
c['회계년도'] = pd.to_datetime(c['회계년도'], format='%b-%d').dt.strftime('20%d-%m')
# 거래소 코드 6자리가 아닌 것들은 6자리가 될 때까지 앞에 0 추가
c['거래소코드'] = c['거래소코드'].astype(str).str.zfill(6)

# %%
# 회계년도가 12월이 아닌 행 리스트 생성
not_dec_list = c[~c.loc[:,'회계년도'].str.endswith('12')].index.tolist()
not_dec_list
# Out:
# [86,
#  493,
#  494,
#  495,
#  496,
#  497,
#  498,
#  499,
#  1152,
#  1153,
#  1154,
#  1155,
#  1156,
#  1157,
#  1158,
#  1159,
#  1160,
#  1265,
#  1266,
#  1303,
#  1304,
#  1305,
#  1306,
#  1307,
#  1308,
#  1309,
#  1310,
#  1311,
#  1372,
#  1373,
#  1374,
#  1375,
#  1376,
#  1377,
#  1378,
#  1379,
#  1380,
#  1471,
#  1538,
#  1539,
#  1540,
#  1541,
#  1542,
#  1543,
#  1544,
#  1545,
#  1546,
#  1547,
#  1548,
#  1549,
#  1550,
#  1551,
#  1552,
#  1553,
#  1554,
#  1610,
#  1611,
#  1612,
#  1613,
#  1614,
#  1615,
#  1616,
#  1617,
#  1618,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1974,
#  1975,
#  2411,
#  2412,
#  2413,
#  2414,
#  2415,
#  2516,
#  2629,
#  2630,
#  2631,
#  2632,
#  2633,
#  2634,
#  2635,
#  2636,
#  2637,
#  3270,
#  3271,
#  3272,
#  3273,
#  3274,
#  3275,
#  3276,
#  3277,
#  3278,
#  3349,
#  3350,
#  3351,
#  3352,
#  3672,
#  4063,
#  4064,
#  4065,
#  4066,
#  4067,
#  4068,
#  4069,
#  4070,
#  4071,
#  4472,
#  4473,
#  4474,
#  4475,
#  4476,
#  4477,
#  4478,
#  4479,
#  4480,
#  5220,
#  5221,
#  5222,
#  5498,
#  5499,
#  5817,
#  5818,
#  5819,
#  5820,
#  5821,
#  5822,
#  5823,
#  5824,
#  5825,
#  6141,
#  6156,
#  6157,
#  6158,
#  6159,
#  6160,
#  6161,
#  6258,
#  6259,
#  6292,
#  6293,
#  6294,
#  6295,
#  6296,
#  6297,
#  6298,
#  6299,
#  6300,
#  6328,
#  6329,
#  6330,
#  6331,
#  6332,
#  6333,
#  6334,
#  6335,
#  6336,
#  6563,
#  6564,
#  6565,
#  6566,
#  6567,
#  6568,
#  6569,
#  6570,
#  6571,
#  6747,
#  6748,
#  6749,
#  6750,
#  6751,
#  6752,
#  6753,
#  6754,
#  6755,
#  6857,
#  6858,
#  6859,
#  6860,
#  7406,
#  7407,
#  7408,
#  7409,
#  7410,
#  7411,
#  7412,
#  7413,
#  7414,
#  7551,
#  7552,
#  7553,
#  7554,
#  7555,
#  7556,
#  7557,
#  7558,
#  7559,
#  7733,
#  7774,
#  7775,
#  8316,
#  8317,
#  8318,
#  8319,
#  8320,
#  8321,
#  8428,
#  8429,
#  8430,
#  8431,
#  8432,
#  9255,
#  9256,
#  9257,
#  9258,
#  9259,
#  9260,
#  9261,
#  9262,
#  9263,
#  9538,
#  9539,
#  9540,
#  9541,
#  9542,
#  9543,
#  9544,
#  9545,
#  9546]

# %%
# # 회계년도가 12월이 아닌 행 제거
print(c.shape)
c.drop(c.index[not_dec_list], inplace=True)
c.reset_index(drop=True, inplace=True)
print(c.shape)
# Out:
# (9633, 54)
# (9398, 54)

# %%
# # 거래소코드가 9로 시작하는 기업
code_nine_list = c['회사명'][c['거래소코드'].astype(str).str.startswith('9')].unique()
code_nine_list
# Out:
# array(['(주)엑세스바이오인코퍼레이션', '애머릿지코퍼레이션', '엘브이엠씨홀딩스(주)', '잉글우드랩(주)',
#        '코오롱티슈진(주)', '헝셩그룹유한회사'], dtype=object)

# %%
# # 거래소코드가 9로 시작하는 기업 제거
c = c[~c['회사명'].isin(code_nine_list)]
c.reset_index(drop=True, inplace=True)
print(c.shape)
# Out:
# (9361, 54)

# %%
# # 기업 기록이 하나인 기업
single_rows = c['회사명'].value_counts() < 2
single_rows[single_rows]
# Out:
# 씨제이바이오사이언스(주)     True
# 브릿지바이오테라퓨틱스(주)    True
# (주)나노브릭           True
# (주)플리토            True
# (주)세림비앤지          True
# (주)티움바이오          True
# (주)노랑풍선           True
# (주)캐리소프트          True
# (주)지노믹트리          True
# (주)제이엘케이          True
# (주)이노테라피          True
# (주)라닉스            True
# (주)라파스            True
# (주)마이크로디지탈        True
# (주)에이스토리          True
# (주)메드팩토           True
# (주)신테카바이오         True
# (주)수젠텍            True
# (주)비츠로테크          True
# 올리패스(주)           True
# Name: 회사명, dtype: bool

# %%
# # 기업 기록이 하나인 기업 제거
c = c[~c['회사명'].isin(single_rows[single_rows].index)]
c.reset_index(drop=True, inplace=True)
print(c.shape)
# Out:
# (9341, 54)

# %%
c.to_csv('찐low데이터.csv',encoding='cp949',index=False)

# %%
# c.isna().sum()

# %%
# df_5_frame.to_csv('3년연속성한계기업.csv',index=False,encoding='cp949')

# %%
# a.to_csv('3년연속한계기업.csv',index=False,encoding='cp949')

# %%
# df_7_frame.to_csv('4년째연속성나락간기업.csv',index=False,encoding='cp949')

# %%
# b.to_csv('4년째나락간기업.csv',index=False,encoding='cp949')

# %%
# pd.options.display.max_columns = None

# %%
# 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
a = df_5_frame.copy()
# a = a.reset_index(drop=True)
a
# Out:
#            회사명  거래소코드  회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0     (주)CMG제약  58820  2011    3.53    1.98    -5.90    17.64   56.40
# 1     (주)CMG제약  58820  2012   -7.75  109.15    -4.12   207.08   -8.43
# 2     (주)CMG제약  58820  2013    0.70   -2.09    16.09   -18.89   25.51
# 3     (주)CMG제약  58820  2014    3.60    3.86    74.30   -25.93   11.52
# 4     (주)CMG제약  58820  2015  -32.22   -2.64    -5.37    -7.17   18.85
# ...        ...    ...   ...     ...     ...      ...      ...     ...
# 9628   흥아해운(주)   3280  2014    1.12   13.69    45.19   -13.68    7.17
# 9629   흥아해운(주)   3280  2015    1.02   21.93    49.36   -11.18    2.42
# 9630   흥아해운(주)   3280  2016    0.21   21.08    38.84   -25.08   -1.58
# 9631   흥아해운(주)   3280  2017   -0.42  -11.43   -16.50    13.29    0.56
# 9632   흥아해운(주)   3280  2018   -1.16   -5.33   -12.07    -6.33   -9.87
#
#       재고자산증가율  자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  \
# 0       -1.43    -2.02    0.00       0.00    41.83    -8.50     -8.28
# 1        7.73    75.17    0.00       0.00    28.34   -40.97    -26.84
# 2       56.29    55.10    0.00       0.00    38.70     1.45      0.74
# 3        6.37     0.01  -46.64     -44.10    37.07     0.69      0.32
# 4       11.04    -4.48    0.00       0.00    36.26   -13.50     -7.62
# ...       ...      ...     ...        ...      ...      ...       ...
# 9628    -8.50     7.76    1.06      -3.91     5.61     2.22     11.37
# 9629   -12.92     3.39  -42.68      14.41     6.20     1.24      6.18
# 9630    56.39    11.22 -263.29     -72.25     4.49    -2.06     -9.40
# 9631    11.18   -39.28    0.00    -322.17     2.09    -8.79    -47.52
# 9632    -5.85   -37.42    0.00       0.00    -0.93   -11.48    -91.08
#
#       총자본정상영업이익율  매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  \
# 0           2.37        3.61    -5.58    0.66     6.42     2.45     1.77
# 1          -9.96      -25.87   -15.78    0.39     5.71     1.85     1.71
# 2           1.40        3.88     0.52    0.36     5.39     2.07     2.03
# 3           0.78        1.94     0.28    0.40     4.77     1.86     1.54
# 4          -4.49       -9.51    -6.37    0.47     5.22     2.10     1.48
# ...          ...         ...      ...     ...      ...      ...      ...
# 9628        3.04        2.25     3.01    1.35    59.77    26.03     3.02
# 9629        2.95        2.51     1.46    1.17    68.48    25.33     2.09
# 9630        0.67        0.71    -1.96    0.95    56.47    25.24     1.44
# 9631       -1.45       -1.57    -8.13    0.93    44.09    23.08     1.36
# 9632       -4.55       -4.99   -10.47    0.91    38.87    19.15     1.43
#
#       매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률    유동비율    당좌비율  \
# 0       11.95     0.97     2.01     1.25     1.55      0.86  200.97  165.03
# 1        7.83     0.66     0.93     0.52     0.57      0.42  693.49  649.98
# 2        6.20     0.51     1.26     0.48     0.52      0.42  694.71  610.74
# 3        5.27     0.46     2.85     0.68     0.80      0.56  324.58  268.23
# 4        5.66     0.56     2.88     0.99     1.22      0.75  296.85  235.21
# ...       ...      ...      ...      ...      ...       ...     ...     ...
# 9628    17.07     5.11     1.84     4.98     5.44      2.03   65.25   59.64
# 9629    16.05     4.96     1.54     5.83     6.38      2.15   51.92   47.54
# 9630    16.26     4.55     1.20     6.98     7.96      2.19   39.46   32.52
# 9631    15.39     5.41     1.12     7.68     9.30      2.09   35.76   29.58
# 9632    11.87     7.93     1.03     6.73     8.14      1.75   34.67   28.66
#
#         현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  \
# 0      15.10   51.41    9.08            -46.08             -24.07
# 1      68.81   80.77   30.58             -8.10             -12.71
# 2     394.63   14.11    2.53            -39.85             -13.51
# 3     101.24   18.50    2.66            -17.73              -7.06
# 4      29.00   20.78    0.01             16.12               5.80
# ...      ...     ...     ...               ...                ...
# 9628    8.09  287.83   36.72              2.84               1.66
# 9629    7.76  357.39   32.82              2.78               2.03
# 9630    5.46  397.97   26.94              2.12               1.96
# 9631    6.17  626.32   31.84             -0.57              -0.50
# 9632    4.89  998.73   31.60             -2.78              -2.70
#
#       CASH_FLOW_대_차입금비율  자기자본구성비율   차입금비율  당좌자산구성비율  유동자산구성비율  매출채권_대_매입채무비율  \
# 0               -172.40     66.05   13.74     46.14     56.18         602.31
# 1                -11.83     55.32   55.28     77.32     82.49         323.41
# 2               -194.73     87.63    2.89     60.08     68.34         282.72
# 3               -104.12     84.39    3.15     40.28     48.74         285.31
# 4              24988.82     82.80    0.01     36.82     46.47         254.69
# ...                 ...       ...     ...       ...       ...            ...
# 9628               5.73     25.78  142.41     21.60     23.63          66.36
# 9629               6.61     21.86  150.12     15.76     17.21          60.44
# 9630               6.30     20.08  134.16      8.78     10.65          68.73
# 9631              -1.53     13.77  231.23     11.27     13.63          65.00
# 9632              -8.01      9.10  347.18     11.14     13.48          59.32
#
#       단기차입금_대_총차입금비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0              80.71   42.33     33.95          17.88           35.59
# 1               0.57   21.50     44.68           6.27            7.33
# 2               0.00   11.23     12.37          12.09           14.12
# 3               0.00   17.79     15.61          17.36           25.09
# 4               0.00   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 9628           65.23  140.48     74.22           8.60            0.00
# 9629           69.35  151.66     78.14           8.43            0.00
# 9630           71.88  134.41     79.92          17.60            0.00
# 9631           82.75  276.77     86.23          17.27            0.00
# 9632           80.74  427.21     90.90          17.36            0.00
#
#       순운전자본비율   노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  직원감소율여부
# 0       28.23   71.32  19.75   204.06   35.86    12.72  19.56        0
# 1       70.60   69.14  18.64   425.29    2.89     0.47   1.66        0
# 2       58.50   66.01  17.77   411.48   77.91    12.51  34.29        0
# 3       33.72  113.90  32.60   354.43   37.80    12.16  31.04        1
# 4       30.82  114.25  30.43   362.77   24.21     7.63  15.96        0
# ...       ...     ...    ...      ...     ...      ...    ...      ...
# 9628   -12.59  423.67   0.00   831.53   27.88    13.89  10.93        0
# 9629   -15.94  589.65   0.00   948.60   21.49    13.11  12.28        0
# 9630   -16.34  703.55   0.00  1000.62   15.81    10.98  12.66        0
# 9631   -24.48    0.00   0.00     0.00    8.35     5.43   5.51        0
# 9632   -25.40    0.00   0.00     0.00    6.91     4.24   4.52        0
#
# [9633 rows x 54 columns]

# %%
a.to_csv('찐low데이터.csv',encoding='cp949',index=False)

# %%
# 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
b = df_7_frame.copy().drop_duplicates(['회사명'])
# b = b.reset_index(drop=True)
b
# Out:
#             회사명   거래소코드  회계년도   이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약   58820  2011     3.53    1.98    -5.90    17.64   56.40
# 9      (주)DB하이텍     990  2011    -0.75  -13.19    -7.89   -10.08  -10.94
# 18      (주)ES큐브   50120  2011  -245.99    0.00     0.00     0.00    0.00
# 27     (주)HJ중공업   97230  2011     0.55   -6.49    -1.53   -13.26   -8.72
# 36     (주)MH에탄올   23150  2011     0.12   -0.49     2.92    -0.67  -18.64
# ...         ...     ...   ...      ...     ...      ...      ...     ...
# 7360    화천기계(주)   10660  2011    68.14    8.08     0.86     6.13   32.84
# 7369  휴림네트웍스(주)  192410  2014  7777.00   14.27    11.41    15.88   47.11
# 7375    휴림로봇(주)   90710  2011     2.96   35.07    27.83    38.25   58.70
# 7384    휴마시스(주)  205470  2014    -0.76     NaN      NaN      NaN     NaN
# 7390    흥아해운(주)    3280  2011    -0.33   -3.13    -0.34   -15.59   12.78
#
#       재고자산증가율  자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  \
# 0       -1.43    -2.02    0.00       0.00    41.83    -8.50     -8.28
# 9       -3.28   -22.60    0.00       0.00    16.62   -17.74    -27.74
# 18       0.00     0.00    0.00       0.00    27.92    -8.99    -12.61
# 27      23.47    -4.59    0.00      -9.82     7.85    -3.35     -5.07
# 36      18.30    -8.46    0.00     -82.51    16.81    -9.73     -9.74
# ...       ...      ...     ...        ...      ...      ...       ...
# 7360     8.59    15.18   58.06      52.01    12.36     5.31     16.05
# 7369   -30.43    42.10   64.14      97.48    18.57    10.44     17.79
# 7375    17.70    37.53    6.71      33.90    25.26     2.63      6.24
# 7384      NaN      NaN     NaN        NaN      NaN      NaN       NaN
# 7390    49.62   -17.19    0.00       0.00     2.54    -2.95    -16.16
#
#       총자본정상영업이익율  매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  \
# 0           2.37        3.61    -5.58    0.66     6.42     2.45     1.77
# 9          -3.34       -7.81    -7.59    0.43     7.04     6.12     0.70
# 18         -6.58       -6.84    -8.65    0.96    10.05     4.27    12.37
# 27          1.48        3.73    -1.33    0.40     8.86    10.97     0.91
# 36          0.45        1.35    -3.24    0.33     4.99     4.83     0.60
# ...          ...         ...      ...     ...      ...      ...      ...
# 7360       10.46        6.61     8.40    1.58    14.50     4.90     5.07
# 7369       16.55       11.45    15.09    1.45    18.95    21.15    17.96
# 7375        4.12        3.82     2.84    1.08     6.23     3.34     5.75
# 7384         NaN         NaN      NaN     NaN      NaN      NaN      NaN
# 7390       -1.01       -0.80    -3.75    1.27    50.91    27.43     2.73
#
#       매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률     유동비율     당좌비율  \
# 0       11.95     0.97     2.01     1.25     1.55      0.86   200.97   165.03
# 9       20.51     1.56     0.59     1.87     2.54      0.72    35.20    25.50
# 18      19.72     1.36     3.29     1.57     1.86      1.09   230.24   194.35
# 27      10.41     1.51     0.54     1.12     1.29      0.52    96.33    81.81
# 36     148.03     1.00     0.50     0.98     1.22      0.36    58.36    45.92
# ...       ...      ...      ...      ...      ...       ...      ...      ...
# 7360     6.30     3.02     3.32     2.76     3.41      1.62   143.25   115.68
# 7369    14.79     1.70     9.51     1.70     1.86      1.44  1288.40  1200.26
# 7375     4.63     2.37     1.97     1.66     2.26      0.96   137.28   103.29
# 7384      NaN      NaN      NaN      NaN      NaN       NaN      NaN      NaN
# 7390    16.88     5.47     1.65     4.81     5.31      2.05    62.54    54.80
#
#         현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  \
# 0      15.10   51.41    9.08            -46.08             -24.07
# 9       5.04  289.22   59.00              5.87               9.47
# 18     21.35   41.36    0.18              6.82               2.08
# 27     34.40  276.93   48.42             -0.99              -1.77
# 36      5.22  214.54    8.89              2.62               5.35
# ...      ...     ...     ...               ...                ...
# 7360    2.71   85.39   11.87              5.19               1.57
# 7369  496.19    7.13    0.00            416.95              20.48
# 7375   15.15  118.23   31.76              1.77               1.03
# 7384     NaN     NaN     NaN               NaN                NaN
# 7390    4.96  368.79   47.74              3.15               1.92
#
#       CASH_FLOW_대_차입금비율  자기자본구성비율   차입금비율  당좌자산구성비율  유동자산구성비율  매출채권_대_매입채무비율  \
# 0               -172.40     66.05   13.74     46.14     56.18         602.31
# 9                  7.39     25.69  229.64     16.90     23.33         336.28
# 18              1107.72     70.74    0.25     51.85     61.43         461.69
# 27                -1.51     26.53  182.52     28.86     33.99         132.35
# 36                20.09     31.79   27.96     26.78     34.04       81716.41
# ...                 ...       ...     ...       ...       ...            ...
# 7360              20.13     53.94   22.01     45.92     56.86         135.09
# 7369               0.00     93.34    0.00     79.89     85.76         129.68
# 7375               3.03     45.82   69.30     49.41     65.67         200.54
# 7384                NaN       NaN     NaN       NaN       NaN            NaN
# 7390               5.19     21.33  223.82     21.48     24.52          65.47
#
#       단기차입금_대_총차입금비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0              80.71   42.33     33.95          17.88           35.59
# 9               0.00  257.97     74.31          27.57            0.00
# 18              0.00   37.71     29.26          15.59           27.56
# 27             32.69  132.98     73.47          15.08            0.00
# 36             32.19  183.43     68.21          21.31            0.00
# ...              ...     ...       ...            ...             ...
# 7360           50.39   73.59     46.06          19.25           63.75
# 7369            0.00    7.13      6.66           6.84            7.42
# 7375           82.38  104.40     54.18          24.76           91.17
# 7384             NaN     NaN       NaN            NaN             NaN
# 7390           52.41  183.78     78.67          12.38            0.00
#
#       순운전자본비율   노동장비율   기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  직원감소율여부
# 0       28.23   71.32   19.75   204.06   35.86    12.72  19.56        0
# 9      -42.95  284.94  107.56   461.22   29.75    18.17  39.45        0
# 18      34.75    5.94    0.00   190.86  279.20    21.71  22.56        0
# 27      -1.29  510.77   33.44  2103.09   15.81     7.02  17.09        0
# 36     -24.28  689.66   18.92  2665.24   11.62     6.51  19.52        0
# ...       ...     ...     ...      ...     ...      ...    ...      ...
# 7360    17.17  184.54   28.46   629.06   77.04    22.60  14.83        0
# 7369    79.10   30.99   23.14   391.33  504.70    39.96  29.49        0
# 7375    17.83   58.76    0.78   278.75  103.19    18.88  20.15        0
# 7384      NaN     NaN     NaN      NaN     NaN      NaN    NaN        0
# 7390   -14.68  357.93    0.00   752.66   14.67     6.92   5.37        0
#
# [899 rows x 54 columns]

# %%
c = a.columns - b.columns

# %%
# # 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
# df_8_frame.copy().drop_duplicates(['회사명'])

# %%
# # 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
# df_10_frame.copy().drop_duplicates(['회사명'])

# %%
# 회사명 리스트 생성
company_list = df['회사명'].unique()
company_list
# Out:
# array(['(주)CMG제약', '(주)DB하이텍', '(주)ES큐브', ..., '휴젤(주)', '흥구석유(주)',
#        '흥아해운(주)'], dtype=object)

# %%
# 행 개수가 3개 이상인 기업 리스트 및 수
over_three = []
for i in company_list:
    if len(df[df['회사명']==i]) >= 2:
        over_three.append(i)
print(len(over_three))
print(over_three)

# %%
# 행 개수가 3개 이상인 기업 인덱스
over_three_index = []
for i in over_three:
    over_three_index.append(df[df['회사명']==i].index)
over_three_index

# %%
# 3년 연속 이자보상배율이 1미만인 기업을 부실기업으로 정의
icr_count = 0
df['부실기업1'] = ''

for i in over_three_index:
    for j in i:
        if df.loc[j, '이자보상배율'] < 1:
            icr_count += 1
        else:
            icr_count = 0
                    
        if icr_count >= 2:
            df.loc[j, '부실기업1'] = 1
        else:
            df.loc[j, '부실기업1'] = 0

# %%
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율   노동장비율  \
# 0        -1.43    -2.02  ...          17.88           35.59    28.23   71.32
# 1         7.73    75.17  ...           6.27            7.33    70.60   69.14
# 2        56.29    55.10  ...          12.09           14.12    58.50   66.01
# 3         6.37     0.01  ...          17.36           25.09    33.72  113.90
# 4        11.04    -4.48  ...          20.77           31.32    30.82  114.25
# ...        ...      ...  ...            ...             ...      ...     ...
# 15145   -12.92     3.39  ...           8.43            0.00   -15.94  589.65
# 15146    56.39    11.22  ...          17.60            0.00   -16.34  703.55
# 15147    11.18   -39.28  ...          17.27            0.00   -24.48    0.00
# 15148    -5.85   -37.42  ...          17.36            0.00   -25.40    0.00
# 15149   -58.98   -57.73  ...           8.22            0.00   -25.18    0.00
#
#        기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 0      19.75   204.06   35.86    12.72  19.56      0
# 1      18.64   425.29    2.89     0.47   1.66      0
# 2      17.77   411.48   77.91    12.51  34.29      1
# 3      32.60   354.43   37.80    12.16  31.04      0
# 4      30.43   362.77   24.21     7.63  15.96      0
# ...      ...      ...     ...      ...    ...    ...
# 15145   0.00   948.60   21.49    13.11  12.28      0
# 15146   0.00  1000.62   15.81    10.98  12.66      0
# 15147   0.00     0.00    8.35     5.43   5.51      1
# 15148   0.00     0.00    6.91     4.24   4.52      1
# 15149   0.00     0.00    5.59     3.10  13.08      1
#
# [15150 rows x 54 columns]

# %%
a = df[df['부실기업1']==1]
b = a.drop_duplicates('회사명')
b
# Out:
#                     회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 2              (주)CMG제약   58820  13-Dec    0.70   -2.09    16.09   -18.89
# 10             (주)DB하이텍     990  12-Dec   -0.31   -3.44    -9.69    10.52
# 26              (주)ES큐브   50120  19-Dec   -0.68  312.66    14.02   696.75
# 27             (주)HJ중공업   97230  11-Dec    0.55   -6.49    -1.53   -13.26
# 36             (주)MH에탄올   23150  11-Dec    0.12   -0.49     2.92    -0.67
# ...                 ...     ...     ...     ...     ...      ...      ...
# 14981  현대일렉트릭앤에너지시스템(주)  267260  19-Dec   -4.66   -2.99    -2.10   -10.14
# 15016           현우산업(주)   92300  13-Dec   -1.29    7.54     4.22    14.79
# 15114           휴림로봇(주)   90710  13-Dec   -3.00   -8.68    -2.15   -17.87
# 15121           휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN
# 15147           흥아해운(주)    3280  17-Dec   -0.42  -11.43   -16.50    13.29
#
#        매출액증가율  재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 2       25.51    56.29    55.10  ...          12.09           14.12    58.50
# 10       6.98     2.79    -5.57  ...          25.64            0.00   -21.27
# 26      29.45   -17.20   -18.89  ...           2.13            5.93    27.78
# 27      -8.72    23.47    -4.59  ...          15.08            0.00    -1.29
# 36     -18.64    18.30    -8.46  ...          21.31            0.00   -24.28
# ...       ...      ...      ...  ...            ...             ...      ...
# 14981   -8.72    -7.99   -17.75  ...          26.33          108.41    15.97
# 15016   -3.69     3.74    -1.01  ...          27.36            0.00   -10.69
# 15114   36.45   -15.62   -20.84  ...          27.74          226.41     6.82
# 15121     NaN      NaN      NaN  ...            NaN             NaN      NaN
# 15147    0.56    11.18   -39.28  ...          17.27            0.00   -24.48
#
#         노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 2       66.01  17.77   411.48   77.91    12.51  34.29      1
# 10     287.76  95.01   498.73   37.03    21.22  41.58      1
# 26       0.00   0.00     0.00   -3.22    -0.12  -1.28      1
# 27     510.77  33.44  2103.09   15.81     7.02  17.09      1
# 36     689.66  18.92  2665.24   11.62     6.51  19.52      1
# ...       ...    ...      ...     ...      ...    ...    ...
# 14981    0.00   0.00     0.00   -5.42    -1.19  -1.52      1
# 15016  190.10  95.13   337.24   34.38    19.38  25.75      1
# 15114   62.61   1.19   283.56   75.91    16.06  16.97      1
# 15121     NaN    NaN      NaN     NaN      NaN    NaN      1
# 15147    0.00   0.00     0.00    8.35     5.43   5.51      1
#
# [835 rows x 54 columns]
