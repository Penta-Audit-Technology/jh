# %%
import pandas as pd
import numpy as np

df = pd.read_csv('레이블합친최종본v2.csv',encoding='cp949')
df1 = pd.read_csv('스탠다드라쏘데이터.csv',encoding='cp949')
df = df[['회생기업2','통계청 한국표준산업분류 10차(소분류)']]
df2 = pd.concat([df1,df],axis=1)
# df2 = df2.sort_values(['회사명','회계년도'])
df2
# Out:
#         회사명  거래소코드     회계년도   유동자산회전율   총자본투자효율  재고자산_대_유동자산비율  당좌자산구성비율  \
# 0     CMG제약  58820  2011-12 -0.579674  0.065883      -0.328854  0.473677
# 1     CMG제약  58820  2012-12 -1.184001 -0.633770      -1.013495  2.241422
# 2     CMG제약  58820  2013-12 -1.217114  0.053889      -0.670290  1.264003
# 3     CMG제약  58820  2014-12 -1.051546  0.033899      -0.359519  0.141445
# 4     CMG제약  58820  2015-12 -0.794914 -0.224830      -0.158431 -0.054719
# ...     ...    ...      ...       ...       ...            ...       ...
# 8780   흥아해운   3280  2015-12  2.317782  0.088158      -0.886120 -1.248712
# 8781   흥아해운   3280  2016-12  2.317782 -0.033496      -0.345366 -1.545793
# 8782   흥아해운   3280  2017-12  2.317782 -0.350482      -0.364826 -1.503272
# 8783   흥아해운   3280  2018-12  2.317782 -0.418448      -0.359519 -1.510642
# 8784   흥아해운   3280  2019-12 -0.778357 -0.483559      -0.898504 -1.009460
#
#         차입금의존도  총자본영업이익율  자기자본순이익율  매출원가감소율여부  배당금감소율여부  변화율여부  직원감소율여부  \
# 0    -0.544291  0.224478  0.021417          1         0      0        0
# 1    -0.977133 -1.454959 -0.174216          0         0      0        0
# 2    -0.988045  0.092356  0.116493          0         0      0        0
# 3    -0.987439  0.007908  0.112066          0         0      0        1
# 4    -0.987439 -0.709905  0.028374          0         0      0        0
# ...        ...       ...       ...        ...       ...    ...      ...
# 8780  0.498409  0.303478  0.173834          0         0      0        0
# 8781  0.165593 -0.007075  0.009612          0         1      0        0
# 8782  0.400201 -0.295834 -0.392194          0         0      0        0
# 8783  0.360190 -0.718077 -0.851341          0         1      0        0
# 8784  0.124977 -0.370749 -0.870841          0         0      0        0
#
#       자본증가율여부  투자활동감소율여부  회생기업2 통계청 한국표준산업분류 10차(소분류)
# 0           0          0      0               의약품 제조업
# 1           1          1      0               의약품 제조업
# 2           0          0      0               의약품 제조업
# 3           0          0      0               의약품 제조업
# 4           1          0      0               의약품 제조업
# ...       ...        ...    ...                   ...
# 8780        0          0      0                해상 운송업
# 8781        0          1      0                해상 운송업
# 8782        0          0      0                해상 운송업
# 8783        0          0      0                해상 운송업
# 8784        0          0      0                해상 운송업
#
# [8785 rows x 18 columns]

# %%
df2.to_csv('스탠라쏘레이블데이터.csv',encoding='cp949',index=False)

# %%
df2
# Out:
#         회사명  거래소코드     회계년도   유동자산회전율   총자본투자효율  재고자산_대_유동자산비율  당좌자산구성비율  \
# 0     CMG제약  58820  2011-12 -0.579674  0.065883      -0.328854  0.473677
# 1     CMG제약  58820  2012-12 -1.184001 -0.633770      -1.013495  2.241422
# 2     CMG제약  58820  2013-12 -1.217114  0.053889      -0.670290  1.264003
# 3     CMG제약  58820  2014-12 -1.051546  0.033899      -0.359519  0.141445
# 4     CMG제약  58820  2015-12 -0.794914 -0.224830      -0.158431 -0.054719
# ...     ...    ...      ...       ...       ...            ...       ...
# 8780   흥아해운   3280  2015-12  2.317782  0.088158      -0.886120 -1.248712
# 8781   흥아해운   3280  2016-12  2.317782 -0.033496      -0.345366 -1.545793
# 8782   흥아해운   3280  2017-12  2.317782 -0.350482      -0.364826 -1.503272
# 8783   흥아해운   3280  2018-12  2.317782 -0.418448      -0.359519 -1.510642
# 8784   흥아해운   3280  2019-12 -0.778357 -0.483559      -0.898504 -1.009460
#
#         차입금의존도  총자본영업이익율  자기자본순이익율  매출원가감소율여부  배당금감소율여부  변화율여부  직원감소율여부  \
# 0    -0.544291  0.224478  0.021417          1         0      0        0
# 1    -0.977133 -1.454959 -0.174216          0         0      0        0
# 2    -0.988045  0.092356  0.116493          0         0      0        0
# 3    -0.987439  0.007908  0.112066          0         0      0        1
# 4    -0.987439 -0.709905  0.028374          0         0      0        0
# ...        ...       ...       ...        ...       ...    ...      ...
# 8780  0.498409  0.303478  0.173834          0         0      0        0
# 8781  0.165593 -0.007075  0.009612          0         1      0        0
# 8782  0.400201 -0.295834 -0.392194          0         0      0        0
# 8783  0.360190 -0.718077 -0.851341          0         1      0        0
# 8784  0.124977 -0.370749 -0.870841          0         0      0        0
#
#       자본증가율여부  투자활동감소율여부  회생기업2 통계청 한국표준산업분류 10차(소분류)
# 0           0          0      0               의약품 제조업
# 1           1          1      0               의약품 제조업
# 2           0          0      0               의약품 제조업
# 3           0          0      0               의약품 제조업
# 4           1          0      0               의약품 제조업
# ...       ...        ...    ...                   ...
# 8780        0          0      0                해상 운송업
# 8781        0          1      0                해상 운송업
# 8782        0          0      0                해상 운송업
# 8783        0          0      0                해상 운송업
# 8784        0          0      0                해상 운송업
#
# [8785 rows x 18 columns]

# %%
import pandas as pd
import numpy as np

pp = pd.read_csv('../main/수명주기붙힌거공백제거.csv',encoding='cp949')
pp
# Out:
#            회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     (주)CMG제약  58820  201112    3.53    1.98    -5.90    17.64    -2.02
# 1     (주)CMG제약  58820  201212   -7.75  109.15    -4.12   207.08    75.17
# 2     (주)CMG제약  58820  201312    0.70   -2.09    16.09   -18.89    55.10
# 3     (주)CMG제약  58820  201412    3.60    3.86    74.30   -25.93     0.01
# 4     (주)CMG제약  58820  201512  -32.22   -2.64    -5.37    -7.17    -4.48
# ...        ...    ...     ...     ...     ...      ...      ...      ...
# 8743   흥아해운(주)   3280  201512    1.02   21.93    49.36   -11.18     3.39
# 8744   흥아해운(주)   3280  201612    0.21   21.08    38.84   -25.08    11.22
# 8745   흥아해운(주)   3280  201712   -0.42  -11.43   -16.50    13.29   -39.28
# 8746   흥아해운(주)   3280  201812   -1.16   -5.33   -12.07    -6.33   -37.42
# 8747   흥아해운(주)   3280  201912   -0.55  -46.38   -51.51   -13.42   -57.73
#
#       매출액증가율  매출액총이익율  ...  매출원가감소율여부  배당금감소율여부  변화율여부  직원감소율여부  자본증가율여부  \
# 0      56.40    41.83  ...          1         0      0        0        0
# 1      -8.43    28.34  ...          0         0      0        0        1
# 2      25.51    38.70  ...          0         0      0        0        0
# 3      11.52    37.07  ...          0         0      0        1        0
# 4      18.85    36.26  ...          0         0      0        0        1
# ...      ...      ...  ...        ...       ...    ...      ...      ...
# 8743    2.42     6.20  ...          0         0      0        0        0
# 8744   -1.58     4.49  ...          0         1      0        0        0
# 8745    0.56     2.09  ...          0         0      0        0        0
# 8746   -9.87    -0.93  ...          0         1      0        0        0
# 8747  -86.45     5.54  ...          0         0      0        0        0
#
#       투자활동감소율여부  기업수명주기  통계청한국표준산업분류10차(세세분류)  회생기업1  회생기업2
# 0             0       1                의약품제조업      0      0
# 1             1       1                의약품제조업      0      0
# 2             0       5                의약품제조업      0      0
# 3             0       2                의약품제조업      0      0
# 4             0       2                의약품제조업      0      0
# ...         ...     ...                   ...    ...    ...
# 8743          0       3               외항화물운송업      0      0
# 8744          1       1               외항화물운송업      0      0
# 8745          0       1               외항화물운송업      0      0
# 8746          0       5               외항화물운송업      0      0
# 8747          0       5               외항화물운송업      0      0
#
# [8748 rows x 59 columns]

# %%
f_djqwhd = []
djqwhd = 'x'
for i in range(len(pp)):
    if djqwhd == pp.loc[i]['통계청한국표준산업분류10차(세세분류)']:
        continue
    if pp.iloc[i]['회생기업2'] == 1:
        djqwhd = pp.loc[i]['통계청한국표준산업분류10차(세세분류)']
        f_djqwhd.append(djqwhd)

# %%
f_djqwhd
# Out:
# ['증류기,열교환기및가스발생기제조업',
#  '기타금융업',
#  '기타대형종합소매업',
#  '상품중개업',
#  '배전반및전기자동제어반제조업',
#  '자동차차체용신품부품제조업',
#  '남녀용겉옷및셔츠도매업',
#  '무점포소매업',
#  '그외기타분류안된화학제품제조업',
#  '산업처리공정제어장비제조업',
#  '플라스틱선,봉,관및호스제조업',
#  '유선통신장비제조업',
#  '농업및임업용기계제조업',
#  '그외기타1차철강제조업',
#  '기타종이및판지제품제조업',
#  '동물용의약품제조업',
#  '아파트건설업',
#  '의료기기도매업',
#  '플라스틱합성피혁제조업',
#  '구조용금속판제품및공작물제조업',
#  '기타비금속광물제품제조업',
#  '육상금속골조구조재제조업',
#  '경영컨설팅업',
#  '기초화학물질제조업',
#  '시외버스운송업',
#  '열간압연및압출제품제조업',
#  '가금류가공및저장처리업',
#  '제조업회사본부',
#  '게임소프트웨어개발및공급업',
#  '컴퓨터시스템통합자문및구축서비스업',
#  '디스플레이제조용기계제조업',
#  '애니메이션영화및비디오물제작업',
#  '산업용로봇제조업',
#  '의료용품및기타의약관련제품제조업',
#  '문구용품,회화용품,사무용품도매업',
#  '응용소프트웨어개발및공급업',
#  '다이오드,트랜지스터및유사반도체소자제조업',
#  '의료용기기제조업',
#  '전기통신업',
#  '고무의류및기타위생용비경화고무제품제조업',
#  '다이오드,트랜지스터및유사반도체소자제조업',
#  '디스플레이제조용기계제조업',
#  '인쇄회로기판용적층판제조업',
#  '기타신선식품및단순가공식품도매업',
#  '탭,밸브및유사장치제조업',
#  '설탕제조업',
#  '제조업회사본부',
#  '건반악기제조업',
#  '기타도로화물운송업',
#  '통신및방송장비제조업',
#  '그외기타전자부품제조업',
#  '상품종합중개업',
#  '배전반및전기자동제어반제조업',
#  '아파트건설업',
#  '영화,비디오물및방송프로그램배급업',
#  '그외기타전자부품제조업',
#  '시스템소프트웨어개발및공급업',
#  '그외기타1차철강제조업',
#  '전기공급및제어장치제조업',
#  '의료기기도매업',
#  '통신및방송장비제조업',
#  '냉간압연및압출제품제조업',
#  '방송및무선통신장비제조업',
#  '의약품제조업',
#  '그외기타전자부품제조업',
#  '디스플레이제조용기계제조업',
#  '항공기용부품제조업',
#  '컴퓨터시스템통합자문및구축서비스업',
#  '비디오및기타영상기기제조업',
#  '직물,편조원단및의복류염색가공업',
#  '방송및무선통신장비제조업',
#  '유선온라인게임소프트웨어개발및공급업',
#  '주방용및음식점용목재가구제조업',
#  '석탄광업',
#  '수송용운송장비도매업',
#  '기타물품취급장비제조업',
#  '방송및무선통신장비제조업',
#  '인쇄회로기판용적층판제조업',
#  '전자응용절삭기계제조업',
#  '방송및무선통신장비제조업',
#  '도배,실내장식및내장목공사업',
#  '소프트웨어개발및공급업',
#  '합성수지및기타플라스틱물질제조업',
#  '무선및위성통신업',
#  '비디오및기타영상기기제조업',
#  '금속캔및기타포장용기제조업',
#  '전자부품실장기판제조업',
#  '경영컨설팅업',
#  '자동차차체용신품부품제조업',
#  '기타전문도매업',
#  '산업처리공정제어장비제조업',
#  '전동기,발전기및전기변환ㆍ공급ㆍ제어장치제조업',
#  '남녀용겉옷및셔츠도매업',
#  '반도체제조용기계제조업',
#  '의약품제조업',
#  '전자부품제조업',
#  '전자집적회로제조업',
#  '석유화학계기초화학물질제조업',
#  '토목건설업',
#  '동물용사료및조제식품제조업',
#  '반도체및디스플레이제조용기계제조업',
#  '컴퓨터시스템통합자문및구축서비스업',
#  '반도체제조용기계제조업',
#  '의약품제조업',
#  '제조업회사본부',
#  '시외버스운송업',
#  '기계장비및관련물품도매업',
#  '그외기타전자부품제조업',
#  '시스템소프트웨어개발및공급업',
#  '방송및무선통신장비제조업',
#  '전기통신업',
#  '정형외과용및신체보정용기기제조업',
#  '육상금속골조구조재제조업',
#  '기타화학제품제조업',
#  '증류기,열교환기및가스발생기제조업',
#  '영화,비디오물및방송프로그램배급업',
#  '도로건설업',
#  '금속단조제품제조업',
#  '근무복,작업복및유사의복제조업',
#  '그외기타전자부품제조업',
#  '시스템소프트웨어개발및공급업',
#  '통신및방송장비제조업',
#  '반도체제조업',
#  '곡물가공품,전분및전분제품제조업',
#  '시스템소프트웨어개발및공급업',
#  '컴퓨터및주변장치,소프트웨어도매업',
#  '그외기타전자부품제조업',
#  '그외기타특수목적용기계제조업',
#  '생활용품도매업',
#  '완제의약품제조업',
#  '유선온라인게임소프트웨어개발및공급업',
#  '제재및목재가공업',
#  '기계장비및관련물품도매업',
#  '기타전문도매업',
#  '크라프트지및상자용판지제조업',
#  '플라스틱필름제조업',
#  '기타금융업',
#  '생활용품도매업',
#  '비디오및기타영상기기제조업',
#  '강관제조업',
#  '건축설계및관련서비스업',
#  '석유정제품제조업',
#  '통신및방송장비제조업',
#  '강관제조업',
#  '타이어및튜브제조업',
#  '복합비료및기타화학비료제조업',
#  '전자집적회로제조업',
#  '강주물주조업',
#  '기타종이및판지제조업',
#  '골판지및골판지가공제품제조업',
#  '기타전문도매업',
#  '석유화학계기초화학물질제조업',
#  '기타기관및터빈제조업',
#  '기타1차철강제조업',
#  '섬유,의복,신발및가죽제품중개업',
#  '철강선제조업',
#  '펄프제조업',
#  '기타1차철강제조업',
#  '소주제조업',
#  '시멘트,석회,플라스터및그제품제조업',
#  '전자축전기제조업',
#  '연료용가스제조및배관공급업',
#  '다이오드,트랜지스터및유사반도체소자제조업',
#  '그외기타분류안된화학제품제조업',
#  '원양어업',
#  '음ㆍ식료품및담배도매업',
#  '기타가정용전기기기제조업',
#  '사무·상업용및공공기관용건물건설업',
#  '아파트건설업',
#  '완제의약품제조업',
#  '플라스틱접착처리제품제조업',
#  '시멘트제조업',
#  '육상금속골조구조재제조업',
#  '골판지,종이상자및종이용기제조업',
#  '제조업및유사산업용건물건설업',
#  '소프트웨어개발및공급업',
#  '다이오드,트랜지스터및유사반도체소자제조업',
#  '원유정제처리업',
#  '기타금융업',
#  '사업시설유지·관리서비스업',
#  '디스플레이제조용기계제조업',
#  '유선온라인게임소프트웨어개발및공급업',
#  '무기및총포탄제조업',
#  '액정표시장치제조업',
#  '통신및방송장비제조업',
#  '석탄화학계화합물및기타기초유기화학물질제조업',
#  '골판지,종이상자및종이용기제조업',
#  '자동차엔진용신품부품제조업',
#  '토공사업',
#  '기타전자부품제조업',
#  '박판,합판및유사적층판제조업',
#  '금속절삭기계제조업',
#  '방송및무선통신장비제조업',
#  '전동기,발전기및전기변환장치제조업',
#  '그외기타분류안된화학제품제조업',
#  '컴퓨터및주변장치,소프트웨어도매업',
#  '그외기타전자부품제조업',
#  '내화요업제품제조업',
#  '광학렌즈및광학요소제조업',
#  '기타기계및장비도매업',
#  '그외자동차용신품부품제조업',
#  '합성수지및기타플라스틱물질제조업',
#  '기타기초무기화학물질제조업',
#  '봉제의복제조업',
#  '농업및임업용기계제조업',
#  '영상및음향기기제조업',
#  '통신및방송장비제조업',
#  '속도계및적산계기제조업',
#  '골판지및골판지가공제품제조업',
#  '제조업회사본부',
#  '특수목적용기계제조업',
#  '증기,냉·온수및공기조절공급업',
#  '제철,제강및합금철제조업',
#  '유인항공기,항공우주선및보조장치제조업',
#  '선박구성부분품제조업',
#  '수산동물훈제,조리및유사조제식품제조업',
#  '컴퓨터프로그래밍서비스업',
#  '인쇄용및필기용원지제조업',
#  '그외기타상품전문도매업',
#  '제조업회사본부',
#  '호스팅및관련서비스업',
#  '그외자동차용신품부품제조업',
#  '동물용사료및조제식품제조업',
#  '기타비철금속압연,압출및연신제품제조업',
#  '건설및채광용기계장비제조업',
#  '아파트건설업',
#  '액체연료및관련제품도매업',
#  '외항화물운송업']
