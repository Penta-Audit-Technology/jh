# %%
import pandas as pd
import numpy as np
# pd.options.display.max_columns = None
df = pd.read_csv('확인용입니다v2.csv', encoding='cp949')
# df = df.drop(columns=['Unnamed: 0'],axis=1)
# df = df.drop(df.iloc[:,4:],axis=1)
# df.drop(columns=['Unnamed: 0'], inplace=True)
# df['이자보상배율'] = df['이자보상배율'].astype(str)
df['이자보상배율'] = df['이자보상배율'].replace(0,1)
df['회계년도'] = pd.to_datetime(df['회계년도'], format='%d-%b').dt.strftime('20%d-%m')
df
# Out:
#             회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      (주)CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      (주)CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      (주)CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      (주)CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      (주)CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...         ...    ...      ...     ...     ...      ...      ...      ...
# 15145   흥아해운(주)   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 15146   흥아해운(주)   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 15147   흥아해운(주)   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 15148   흥아해운(주)   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 15149   흥아해운(주)   3280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  ...  순운전자본비율      노동장비율     기계장비율    자본집약도  \
# 0       56.40    41.83  ...    28.23   71726.36  29216.43   202.26
# 1       -8.43    28.34  ...    70.60   69458.82  32002.75   426.18
# 2       25.51    38.70  ...    58.50   66012.04  33789.62   411.12
# 3       11.52    37.07  ...    33.72  113899.65  48479.94   354.08
# 4       18.85    36.26  ...    30.82  114246.59  53386.77   362.39
# ...       ...      ...  ...      ...        ...       ...      ...
# 15145    2.42     6.20  ...   -15.94  593960.16     14.23   973.73
# 15146   -1.58     4.49  ...   -16.34  706868.14     12.28  1017.55
# 15147    0.56     2.09  ...   -24.48  599097.86     12.56   921.78
# 15148   -9.87    -0.93  ...   -25.40  618981.48     14.54  1009.67
# 15149  -86.45     5.54  ...   -25.18  704760.75     34.13  1271.28
#
#             설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치  R & D 투자효율  \
# 0      35.85819316    12.72  19.56    25719.78        0.13
# 1                0     0.47   1.66     2009.78        0.74
# 2      77.91470318    12.51  34.29    51433.09        0.66
# 3      37.80253285    12.16  31.04    43056.95        0.51
# 4                0     7.63  15.96    27662.63        3.08
# ...            ...      ...    ...         ...         ...
# 15145  21.49400366    13.11  12.28   127665.82        0.00
# 15146  15.81260955    10.98  12.66   111774.30        0.00
# 15147  8.349918093     5.43   5.51    50024.18        0.00
# 15148            0     4.24   4.52    42782.54        0.00
# 15149            0     3.10  13.08    39428.47        0.00
#
#        통계청 한국표준산업분류 10차(소분류)
# 0                    의약품 제조업
# 1                    의약품 제조업
# 2                    의약품 제조업
# 3                    의약품 제조업
# 4                    의약품 제조업
# ...                      ...
# 15145                 해상 운송업
# 15146                 해상 운송업
# 15147                 해상 운송업
# 15148                 해상 운송업
# 15149                 해상 운송업
#
# [15150 rows x 50 columns]

# %%
# df['회사명'] = df['회사명'].str.replace('\(','')
# df['회사명'] = df['회사명'].str.replace('주','')
# df['회사명'] = df['회사명'].str.replace('\)','')
# df

# %%
dd = df['회사명'].isin(['(주)고려시멘트','(주)국전약품','(주)나노','(주)나인테크','(주)넥슨게임즈','(주)넵튠','(주)누보','(주)다보링크',
                              '(주)더블유에스아이','(주)덴티스','(주)드림시큐리티','(주)디딤','(주)디알텍','(주)디와이디','(주)러셀','(주)레이크머티리얼즈',
                              '(주)로보로보','(주)모비스','(주)미래생명자원','(주)바이오로그디바이스','(주)베노홀딩스','(주)본느','(주)비올','(주)비투엔',
                              '(주)삼기','(주)서진오토모티브','(주)세림비앤지','(주)세토피아','(주)세화피앤씨','(주)셀바스헬스케어','(주)스튜디오산타클로스엔터테인먼트',
                              '(주)썸에이지','(주)쎄노텍','(주)아이비김영','(주)아이엘사이언스','(주)알로이스','(주)알톤스포츠','(주)애니플러스','(주)액션스퀘어',
                              '(주)에치에프알','(주)에프에스엔','(주)엑셈','(주)엔투텍','(주)엔피','(주)예선테크','(주)오하임아이엔티','(주)옵투스제약',
                              '(주)와이즈버즈','(주)우정바이오','(주)원바이오젠','(주)웨이버스','(주)위메이드플레이','(주)이노인스트루먼트','(주)이랜시스',
                              '(주)인산가','(주)일승','(주)자비스','(주)정다운','(주)제이시스메디칼','(주)지니틱스','(주)지란지교시큐리티','(주)카이노스메드',
                              '(주)켐온','(주)켐트로스','(주)코퍼스코리아','(주)큐브엔터테인먼트','(주)클래시스','(주)태성','(주)토박스코리아','(주)티에스트릴리온',
                              '(주)포인트엔지니어링','(주)프로스테믹스','(주)프로이천','(주)하이비젼시스템','(주)한국비엔씨','(주)한송네오텍','(주)한일진공',
                              '(주)화신정공','(주)휴센텍','글로벌텍스프리(주)','나무기술(주)','디와이씨(주)','미스터블루(주)','바디텍메드(주)','소프트캠프(주)',
                              '씨아이에스(주)','알서포트(주)','알에프에이치아이씨(주)','에스지에이솔루션즈(주)','엠에프엠코리아(주)','와이아이케이(주)','원텍(주)',
                              '윈텍(주)','줌인터넷(주)','지엔원에너지(주)','지엘팜텍(주)','케이에이치건설(주)','케이엠제약(주)','코리아에프티(주)','패션플랫폼(주)',
                              '현대무벡스(주)','휴마시스(주)','(주)네오셈','(주)라온테크','비플라이소프트(주)'])

# %%
# df.to_csv('전체이보배는이거인거같아요.csv',encoding='cp949',index=False)

# %%
dd = qw[~dd]
dd = dd.reset_index(drop=True)
dd
# Out:
#          회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약   58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약   58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약   58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약   58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약   58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...     ...      ...     ...     ...      ...      ...      ...
# 8498  테고사이언스  191420  2018-12   86.89   -1.71     0.05     3.04    27.70
# 8499  테고사이언스  191420  2019-12   49.16    2.12    -2.53     4.86     2.41
# 8500  테라사이언스   73640  2011-12    1.79    8.77     3.02    23.33     3.35
# 8501  테라사이언스   73640  2012-12    0.95   -2.07     1.80    -7.26     3.87
# 8502  테라사이언스   73640  2013-12   -1.28    3.25     6.95    -1.30    -7.98
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 1      -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78    0.39
# 2      25.51    38.70     1.45      0.74      1.40      3.88     0.52    0.36
# 3      11.52    37.07     0.69      0.32      0.78      1.94     0.28    0.40
# 4      18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37    0.47
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 8498   -9.16    76.22   -23.70     -4.47      1.82     11.12    -3.88    0.16
# 8499  -19.16    74.30    13.11      1.76      0.72      5.45     1.73    0.13
# 8500   39.62    23.02     2.34      2.26      5.71     14.49     0.92    0.39
# 8501  -13.43    23.46     6.17      4.98      2.78      8.41     2.04    0.33
# 8502  -30.89    17.90   -16.69     -9.52     -3.06    -13.45    -3.79    0.23
#
#       재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  순운전자본회전율  \
# 0        3.74     2.29     1.77    11.95     0.97     2.01     1.25      4.61
# 1        4.09     1.75     1.71     7.83     0.66     0.93     0.52      0.81
# 2        3.30     2.02     2.03     6.20     0.51     1.26     0.48      1.25
# 3        3.00     1.85     1.54     5.27     0.46     2.85     0.68      2.32
# 4        3.32     2.09     1.48     5.66     0.56     2.88     0.99      3.10
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 8498     2.36     2.70     0.41   401.05     0.19     1.24     0.32      0.65
# 8499     1.77     2.39     0.33   282.79     0.13     7.92     0.25      0.49
# 8500     2.47     3.29     0.77     7.66     0.97     0.67     1.11     -4.86
# 8501     1.49     3.36     0.65     7.75     0.81     0.56     0.90     -4.15
# 8502     0.95     3.24     0.43     9.08     0.57     0.38     0.65     -2.68
#
#          유동비율     당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0      200.97   165.03   15.10   51.41    7.32            -46.08
# 1      693.49   649.98   68.81   80.77    0.18             -8.10
# 2      694.71   610.74  394.63   14.11    0.00            -39.85
# 3      324.58   268.23  101.24   18.50    0.01            -17.73
# 4      296.85   235.21   29.00   20.78    0.01             16.12
# ...       ...      ...     ...     ...     ...               ...
# 8498  2922.82  2842.29  146.09    1.84    0.00            166.63
# 8499  3721.95  3559.87  229.88    1.55    0.00             59.06
# 8500    70.77    39.56    0.97  151.46   39.54              3.37
# 8501    68.91    35.12    5.01  137.06   44.74             -0.29
# 8502    67.16    24.17    1.08  166.00   46.62             -3.76
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 1                -12.71           -2066.51     55.32     77.32     82.49
# 2                -13.51               0.00     87.63     60.08     68.34
# 3                 -7.06          -29481.93     84.39     40.28     48.74
# 4                  5.80           24988.83     82.80     36.82     46.47
# ...                 ...                ...       ...       ...       ...
# 8498              18.29               0.00     98.19     51.48     52.94
# 8499               6.90               0.00     98.47     52.00     54.37
# 8500               5.36               5.13     39.77     21.06     37.67
# 8501              -0.51              -0.38     42.18     18.19     35.68
# 8502             -10.50              -5.04     37.59     12.27     34.11
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 1            323.41   21.50     44.68           6.27            7.33    70.60
# 2            282.72   11.23     12.37          12.09           14.12    58.50
# 3            285.31   17.79     15.61          17.36           25.09    33.72
# 4            254.69   18.91     17.20          20.77           31.32    30.82
# ...             ...     ...       ...            ...             ...      ...
# 8498        9693.80    1.84      1.81           2.76            2.85    51.13
# 8499       13043.83    1.48      1.53           4.35            4.47    52.90
# 8500         162.71  133.86     60.23          44.10         -106.78   -15.56
# 8501         274.42  122.75     57.82          49.02         -108.64   -16.10
# 8502         194.47  135.10     62.41          64.01         -130.88   -16.68
#
#           노동장비율      기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치  \
# 0      71726.36   29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 1      69458.82   32002.75   426.18            0     0.47   1.66     2009.78
# 2      66012.04   33789.62   411.12  77.91470318    12.51  34.29    51433.09
# 3     113899.65   48479.94   354.08  37.80253285    12.16  31.04    43056.95
# 4     114246.59   53386.77   362.39            0     7.63  15.96    27662.63
# ...         ...        ...      ...          ...      ...    ...         ...
# 8498  492356.51   77738.31  1219.54            0     6.42  38.92    78335.90
# 8499  467923.35   74933.25  1214.23            0     9.06  69.35   110030.75
# 8500  743702.11  198782.70  1493.10  15.84247658     7.89  20.87   117820.83
# 8501  719561.27   70076.92  1389.76    19.557228    10.13  30.29   140726.24
# 8502  726468.14  191786.33  1354.44  8.445186429     4.53  20.24    61351.59
#
#       R & D 투자효율    통계청 한국표준산업분류 10차(소분류)
# 0           0.13                  의약품 제조업
# 1           0.74                  의약품 제조업
# 2           0.66                  의약품 제조업
# 3           0.51                  의약품 제조업
# 4           3.08                  의약품 제조업
# ...          ...                      ...
# 8498       22.43    기초 의약물질 및 생물학적 제제 제조업
# 8499       27.09    기초 의약물질 및 생물학적 제제 제조업
# 8500        3.13           기타 금속 가공제품 제조업
# 8501        1.22           기타 금속 가공제품 제조업
# 8502        1.93           기타 금속 가공제품 제조업
#
# [8503 rows x 50 columns]

# %%
dd.isna().sum()
# Out:
# 회사명                       0
# 거래소코드                     0
# 회계년도                      0
# 이자보상배율                   10
# 총자산증가율                   20
# 유형자산증가율                  20
# 유동자산증가율                  20
# 자기자본증가율                  20
# 매출액증가율                   19
# 매출액총이익율                  10
# 매출액순이익율                  10
# 자기자본순이익율                 20
# 총자본영업이익율                  3
# 매출액영업이익률                  0
# 총자본순이익률                  20
# 총자본회전율                   19
# 재고자산회전율                  19
# 매출채권회전율                  19
# 유형자산회전율                  19
# 매입채무회전율                  19
# 자기자본회전율                  19
# 타인자본회전율                  19
# 유동자산회전율                  19
# 순운전자본회전율                 10
# 유동비율                     10
# 당좌비율                     10
# 현금비율                     10
# 부채비율                     10
# 차입금의존도                    0
# CASH_FLOW_대_부채비율          0
# CASH_FLOW_대_매출액비율         0
# CASH_FLOW_대_차입금비율         3
# 자기자본구성비율                 10
# 당좌자산구성비율                 10
# 유동자산구성비율                 10
# 매출채권_대_매입채무비율            10
# 유동부채비율                   10
# 타인자본구성비율                 10
# 재고자산_대_유동자산비율            10
# 재고자산_대_순운전자본비율            0
# 순운전자본비율                  10
# 노동장비율                    38
# 기계장비율                    38
# 자본집약도                     0
# 설비투자효율                    0
# 총자본투자효율                   0
# 부가가치율                     0
# 종업원1인당부가가치               13
# R & D 투자효율               60
# 통계청 한국표준산업분류 10차(소분류)     0
# dtype: int64

# %%
# 분석 과정에서 NaN이 NaN이 아닌 다른 어떤 값인 것으로 판명되었습니다.
# 어쩔 수 없이 분석의 용이함을 위해 임의의 값을 채웠습니다
# df = df.fillna(77777.77)

# 이건 우리의 기준에 맞는 이자보상 배율을 저장하기 위한 컬럼입니다.
# df['이자보상배율'] = 0.0

# %%
# df_1 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS)']]
# df_2 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS연결)']]

# %%
# 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

f_company = [] # 한계기업을 저장하는 리스트
f_company_x = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
f_safe = []
fs_company = []
count = 0 # 한계기업 카운트용
s_count = 0
company = 'x' # 한계기업 기록용
s_company = 'o'

# 이거도 csv 한바퀴 돌립니다
for i in range(0, len(df)-1):

    # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
    if company == df.loc[i]['회사명']:
        # 다만 그 기업이 한계기업인데
        if count > 1:
            # 어머? 4년 연속이네요? 기록!!!
            if df.iloc[i]['이자보상배율'] < 1:
                f_company_x.append(company)
                count = 0
                # 반복문에서 볼일 다 끝났으니 통과합니다
            continue
        
        # 그게 아니라면 반복문을 통과합니다
        continue

    # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
    if df.iloc[i]['이자보상배율'] < 1:
            count += 1
    # 도중에 이자보상배율이 1 이상이면 탈출합니다
    else:
        count = 0
    # 한계 기업 클럽에 오셨습니다. 환영합니다.
    if count == 1:
        company = df.loc[i]['회사명']
        f_company.append(company)
        count += 1
        
    # else: 
    #     if count == 7:
    #         company == df.loc[i]['회사명']
    #         f_safe.append(company)
    #         count += 1

# %%
# f_company = [] # 한계기업을 저장하는 리스트
# f_safe = []
# fs_company = []
# s_count = 0
# s_company = 'o'

# for i in range(len(df)):
#     if s_company == df.loc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if s_count == 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df.iloc[i]['이자보상배율'] > 1:
#                 f_company_x.append(company)
#                 count = 0
#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#             continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue
    
#     if s_company == df.loc[i]['회사명']:
#         if s_count < 2:
#             f_safe.append(s_company)
#             s_count = 0
#         continue
    
#     if df.loc[i]['이자보상배율'] < 1:
#         s_count += 1
#     else:
#         s_count += 
        
#     if s_count == 2:
#         s_company = df.loc[i]['회사명']
#         f_company.append(s_company)
#         s_count += 1

# %%
# # 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

# f_company_1 = [] # 한계기업을 저장하는 리스트
# f_company_x_1 = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
# count_1 = 0 # 한계기업 카운트용
# company_1 = 'x' # 한계기업 기록용

# # 이거도 csv 한바퀴 돌립니다
# for i in range(0, len(df_2)-1):

#     # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
#     if company_1 == df_2.iloc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if count > 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#                 f_company_x_1.append(company_1)
#                 count = 0

#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#                 continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue

#     # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
#     if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#             count += 1
#     # 도중에 이자보상배율이 1 미만이면 탈출합니다
#     else:
#         count = 0

#     # 한계 기업 클럽에 오셨습니다. 환영합니다.
#     if count == 3:
#         company_1 = df_2.iloc[i]['회사명']
#         f_company_1.append(company_1)
#         count += 1

# %%
# 분명히 이거보다 더 좋은 방법이 있을건데
# 맷돌이 굴러가질 않네요

# 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
df_3 = df.isin(f_company)
df_3
# Out:
#         회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  매출액증가율  \
# 0      True  False  False   False   False    False    False    False   False
# 1      True  False  False   False   False    False    False    False   False
# 2      True  False  False   False   False    False    False    False   False
# 3      True  False  False   False   False    False    False    False   False
# 4      True  False  False   False   False    False    False    False   False
# ...     ...    ...    ...     ...     ...      ...      ...      ...     ...
# 15145  True  False  False   False   False    False    False    False   False
# 15146  True  False  False   False   False    False    False    False   False
# 15147  True  False  False   False   False    False    False    False   False
# 15148  True  False  False   False   False    False    False    False   False
# 15149  True  False  False   False   False    False    False    False   False
#
#        매출액총이익율  ...  순운전자본비율  노동장비율  기계장비율  자본집약도  설비투자효율  총자본투자효율  부가가치율  \
# 0        False  ...    False  False  False  False   False    False  False
# 1        False  ...    False  False  False  False   False    False  False
# 2        False  ...    False  False  False  False   False    False  False
# 3        False  ...    False  False  False  False   False    False  False
# 4        False  ...    False  False  False  False   False    False  False
# ...        ...  ...      ...    ...    ...    ...     ...      ...    ...
# 15145    False  ...    False  False  False  False   False    False  False
# 15146    False  ...    False  False  False  False   False    False  False
# 15147    False  ...    False  False  False  False   False    False  False
# 15148    False  ...    False  False  False  False   False    False  False
# 15149    False  ...    False  False  False  False   False    False  False
#
#        종업원1인당부가가치  R & D 투자효율  통계청 한국표준산업분류 10차(소분류)
# 0           False       False                  False
# 1           False       False                  False
# 2           False       False                  False
# 3           False       False                  False
# 4           False       False                  False
# ...           ...         ...                    ...
# 15145       False       False                  False
# 15146       False       False                  False
# 15147       False       False                  False
# 15148       False       False                  False
# 15149       False       False                  False
#
# [15150 rows x 50 columns]

# %%
# # 분명히 이거보다 더 좋은 방법이 있을건데
# # 맷돌이 굴러가질 않네요

# # 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
# df_4 = df_2.isin(f_company_1)
# df_4

# %%
df_5 = [] # 임시 저장용 리스트

# 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
for i in range(0, len(df_3)-1):
    if df_3.iloc[i]["회사명"] == True:
        df_5.append(df.loc[i])
        
df_5_frame = pd.DataFrame(df_5).reset_index(drop=True)

# %%
# 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

df_6 = df.isin(f_company_x)
df_7 = []

for i in range(0, len(df_6)-1):
    if df_6.iloc[i]["회사명"] == True:
        df_7.append(df.loc[i])

df_7_frame = pd.DataFrame(df_7).reset_index(drop=True)

# %%
# df_8 = df_5_frame.isin()
# df_9 = []

# for i in range(0, len(dd)-1):
#     if dd.iloc[i]["회사명"] == False:
#         df_9.append(df.loc[i])

# df_9_frame = pd.DataFrame(df_9).reset_index(drop=True)

# %%
# df_8 = [] # 임시 저장용 리스트

# # 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
# for i in range(0, len(df_4)-1):
#     if df_4.iloc[i]["회사명"] == True:
#         df_8.append(df_2.loc[i])
        
# df_8_frame = pd.DataFrame(df_8).reset_index(drop=True)

# %%
# # 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

# df_9 = df_1.isin(f_company_x_1)
# df_10 = []

# for i in range(0, len(df_9)-1):
#     if df_9.iloc[i]["회사명"] == True:
#         df_10.append(df_2.loc[i])

# df_10_frame = pd.DataFrame(df_10).reset_index(drop=True)

# %%
# c = df_5_frame.copy()
# df['회계년도'] = pd.to_datetime(df['회계년도'], format='%d-%b').dt.strftime('20%d-%m')
# 거래소 코드 6자리가 아닌 것들은 6자리가 될 때까지 앞에 0 추가
dd['거래소코드'] = dd['거래소코드'].astype(str).str.zfill(6)

# %%
dd
# Out:
#          회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약  058820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약  058820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약  058820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약  058820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약  058820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...     ...      ...     ...     ...      ...      ...      ...
# 14688   흥아해운  003280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 14689   흥아해운  003280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 14690   흥아해운  003280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 14691   흥아해운  003280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 14692   흥아해운  003280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  \
# 0       56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58
# 1       -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78
# 2       25.51    38.70     1.45      0.74      1.40      3.88     0.52
# 3       11.52    37.07     0.69      0.32      0.78      1.94     0.28
# 4       18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37
# ...       ...      ...      ...       ...       ...       ...      ...
# 14688    2.42     6.20     1.24      6.18      2.95      2.51     1.46
# 14689   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96
# 14690    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13
# 14691   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47
# 14692  -86.45     5.54   -50.27    -98.70     -2.00    -12.10    -8.32
#
#        총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        0.66     3.74     2.29     1.77    11.95     0.97     2.01     1.25
# 1        0.39     4.09     1.75     1.71     7.83     0.66     0.93     0.52
# 2        0.36     3.30     2.02     2.03     6.20     0.51     1.26     0.48
# 3        0.40     3.00     1.85     1.54     5.27     0.46     2.85     0.68
# 4        0.47     3.32     2.09     1.48     5.66     0.56     2.88     0.99
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 14688    1.17    64.23    17.20     2.09    16.05     4.96     1.54     5.83
# 14689    0.95    53.94    17.35     1.44    16.26     4.55     1.20     6.98
# 14690    0.93    43.17    15.61     1.36    15.39     5.41     1.12     7.68
# 14691    0.91    39.24    12.79     1.43    11.87     7.93     1.03     6.73
# 14692    0.17     7.28     2.86     0.28     2.41     1.96     0.18     1.01
#
#        순운전자본회전율    유동비율    당좌비율    현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0          4.61  200.97  165.03   15.10    51.41    7.32            -46.08
# 1          0.81  693.49  649.98   68.81    80.77    0.18             -8.10
# 2          1.25  694.71  610.74  394.63    14.11    0.00            -39.85
# 3          2.32  324.58  268.23  101.24    18.50    0.01            -17.73
# 4          3.10  296.85  235.21   29.00    20.78    0.01             16.12
# ...         ...     ...     ...     ...      ...     ...               ...
# 14688    -13.39   51.92   47.54    7.76   357.39   24.52              2.78
# 14689    -10.62   39.46   32.52    5.46   397.97   19.03              2.12
# 14690     -8.05   35.76   29.58    6.17   626.32   22.90             -0.57
# 14691     -7.39   34.67   28.66    4.89   998.73   22.24             -2.78
# 14692     -1.88   46.36   42.55    6.75  1293.83   18.36             -5.73
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 14688               2.03               8.85     21.86     15.76     17.21
# 14689               1.96               8.92     20.08      8.78     10.65
# 14690              -0.50              -2.13     13.77     11.27     13.63
# 14691              -2.70             -11.38      9.10     11.14     13.48
# 14692             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 14688          60.44  151.66     78.14           8.43           -9.10
# 14689          68.73  134.41     79.92          17.60          -11.47
# 14690          65.00  276.77     86.23          17.27           -9.61
# 14691          59.32  427.21     90.90          17.36           -9.21
# 14692          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 14688   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 14689   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 14690   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 14691   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 14692   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인당부가가치  R & D 투자효율 통계청 한국표준산업분류 10차(소분류)
# 0        25719.78        0.13               의약품 제조업
# 1         2009.78        0.74               의약품 제조업
# 2        51433.09        0.66               의약품 제조업
# 3        43056.95        0.51               의약품 제조업
# 4        27662.63        3.08               의약품 제조업
# ...           ...         ...                   ...
# 14688   127665.82        0.00                해상 운송업
# 14689   111774.30        0.00                해상 운송업
# 14690    50024.18        0.00                해상 운송업
# 14691    42782.54        0.00                해상 운송업
# 14692    39428.47        0.00                해상 운송업
#
# [14693 rows x 50 columns]

# %%
# 회계년도가 12월이 아닌 행 리스트 생성
not_dec_list = df[~df.loc[:,'회계년도'].str.endswith('12')].index.tolist()
not_dec_list
# Out:
# [122,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  842,
#  843,
#  844,
#  845,
#  846,
#  847,
#  848,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1957,
#  1958,
#  2022,
#  2023,
#  2024,
#  2025,
#  2026,
#  2027,
#  2028,
#  2029,
#  2030,
#  2102,
#  2103,
#  2104,
#  2105,
#  2106,
#  2107,
#  2108,
#  2109,
#  2110,
#  2259,
#  2370,
#  2371,
#  2372,
#  2373,
#  2374,
#  2375,
#  2376,
#  2379,
#  2380,
#  2381,
#  2382,
#  2383,
#  2384,
#  2385,
#  2386,
#  2387,
#  2388,
#  2389,
#  2390,
#  2391,
#  2392,
#  2393,
#  2394,
#  2395,
#  2523,
#  2524,
#  2525,
#  2526,
#  2527,
#  2528,
#  2529,
#  2530,
#  2531,
#  2975,
#  2976,
#  2977,
#  2978,
#  2979,
#  2980,
#  2981,
#  2982,
#  2983,
#  3097,
#  3098,
#  3362,
#  3363,
#  3364,
#  3365,
#  3677,
#  3678,
#  3679,
#  3680,
#  3681,
#  3682,
#  3683,
#  3684,
#  3685,
#  3748,
#  3749,
#  3750,
#  3751,
#  3752,
#  3871,
#  4024,
#  4025,
#  4026,
#  4027,
#  4028,
#  4029,
#  4030,
#  4031,
#  4032,
#  5046,
#  5047,
#  5048,
#  5049,
#  5050,
#  5051,
#  5052,
#  5053,
#  5054,
#  5195,
#  5196,
#  5197,
#  5198,
#  5614,
#  5726,
#  5727,
#  5728,
#  5729,
#  5730,
#  5731,
#  5732,
#  5967,
#  5968,
#  5969,
#  5970,
#  5971,
#  5972,
#  5973,
#  5974,
#  5975,
#  6095,
#  6096,
#  6188,
#  6189,
#  6190,
#  6191,
#  6192,
#  6193,
#  6194,
#  6195,
#  6196,
#  6452,
#  6479,
#  6628,
#  6629,
#  6630,
#  6631,
#  6817,
#  6818,
#  6819,
#  6820,
#  6821,
#  6822,
#  6823,
#  6824,
#  6825,
#  7939,
#  7940,
#  7941,
#  8189,
#  8190,
#  8191,
#  8192,
#  8193,
#  8248,
#  8249,
#  8250,
#  8251,
#  8252,
#  8253,
#  8254,
#  8255,
#  8256,
#  8374,
#  8375,
#  8945,
#  8946,
#  8947,
#  8948,
#  8949,
#  8950,
#  8951,
#  8952,
#  8953,
#  9518,
#  9536,
#  9537,
#  9538,
#  9539,
#  9573,
#  9574,
#  9575,
#  9576,
#  9577,
#  9578,
#  9636,
#  9637,
#  9638,
#  9639,
#  9640,
#  9641,
#  9642,
#  9643,
#  9644,
#  9761,
#  9762,
#  9763,
#  9764,
#  9769,
#  9770,
#  9812,
#  9813,
#  9814,
#  9815,
#  9816,
#  9817,
#  9818,
#  9819,
#  9820,
#  9896,
#  9897,
#  9898,
#  9899,
#  9900,
#  9901,
#  9902,
#  9903,
#  9904,
#  10323,
#  10324,
#  10325,
#  10326,
#  10327,
#  10328,
#  10329,
#  10330,
#  10331,
#  10646,
#  10647,
#  10648,
#  10649,
#  10650,
#  10651,
#  10652,
#  10653,
#  10654,
#  10827,
#  10828,
#  10829,
#  10830,
#  10881,
#  11650,
#  11651,
#  11652,
#  11653,
#  11654,
#  11655,
#  11656,
#  11657,
#  11658,
#  11858,
#  11859,
#  11860,
#  11861,
#  11862,
#  11863,
#  11864,
#  11865,
#  11866,
#  12081,
#  12082,
#  12083,
#  12084,
#  12085,
#  12086,
#  12087,
#  12115,
#  12156,
#  12157,
#  12995,
#  13014,
#  13015,
#  13016,
#  13017,
#  13018,
#  13019,
#  13148,
#  13149,
#  13150,
#  13151,
#  13152,
#  14269,
#  14270,
#  14453,
#  14454,
#  14455,
#  14456,
#  14457,
#  14458,
#  14459,
#  14460,
#  14461,
#  14489,
#  14496,
#  14497,
#  14498,
#  14669,
#  14670,
#  14671,
#  14672,
#  14673,
#  14674,
#  14675,
#  14676,
#  14677,
#  14941,
#  14942,
#  14943,
#  14944,
#  14945,
#  14946,
#  14947,
#  14948,
#  14949,
#  15026,
#  15027,
#  15028,
#  15029,
#  15030,
#  15031,
#  15032,
#  15089,
#  15090,
#  15091,
#  15092,
#  15093,
#  15094,
#  15095,
#  15096,
#  15097]

# %%
# # 회계년도가 12월이 아닌 행 제거
print(df.shape)
df.drop(df.index[not_dec_list], inplace=True)
df.reset_index(drop=True, inplace=True)
print(df.shape)
# Out:
# (15150, 50)
# (14791, 50)

# %%
# # 거래소코드가 9로 시작하는 기업
code_nine_list = df['회사명'][df['거래소코드'].astype(str).str.startswith('9')].unique()
code_nine_list
# Out:
# array(['(주)DB하이텍', '(주)HJ중공업', '(주)SIMPAC', '(주)경동나비엔', '(주)고영테크놀러지',
#        '(주)네오리진', '(주)네오위즈', '(주)네오팜', '(주)노루페인트', '(주)대양금속', '(주)대창솔루션',
#        '(주)덕신하우징', '(주)동방선기', '(주)동운아나텍', '(주)디아이씨', '(주)디엔에프', '(주)로보스타',
#        '(주)마이크로컨텍솔루션', '(주)매커스', '(주)메타랩스', '(주)멜파스', '(주)모토닉', '(주)비에이치',
#        '(주)빅솔론', '(주)서원인텍', '(주)셀트리온헬스케어', '(주)슈프리마에이치큐', '(주)스맥',
#        '(주)신원', '(주)쎄트렉아이', '(주)씨젠', '(주)아모레퍼시픽', '(주)아이센스', '(주)아이에스시',
#        '(주)아이윈', '(주)아이티엑스에이아이', '(주)알에프세미', '(주)앤씨앤', '(주)에스에너지',
#        '(주)에스코넥', '(주)에스티오', '(주)에이루트', '(주)엑세스바이오인코퍼레이션', '(주)엑시콘',
#        '(주)엘디티', '(주)엘에프', '(주)엠씨넥스', '(주)엠에스씨', '(주)연이비앤티', '(주)영원무역홀딩스',
#        '(주)웅진씽크빅', '(주)웨이브일렉트로닉스', '(주)윈팩', '(주)유니온', '(주)이아이디', '(주)이엠텍',
#        '(주)이크레더블', '(주)일진파워', '(주)제넥신', '(주)제이스텍', '(주)칩스앤미디어',
#        '(주)케이씨티시', '(주)케이아이엔엑스', '(주)케이이씨', '(주)코센', '(주)크레버스', '(주)태영건설',
#        '(주)테스', '(주)텔레필드', '(주)티웨이항공', '(주)파트론', '(주)포스코엠텍', '(주)푸른기술',
#        '(주)플레이그램', '(주)한샘', '(주)한창제지', '(주)현대이지웰', '(주)후성', 'AJ네트웍스(주)',
#        'SK이노베이션(주)', '갤럭시아머니트리(주)', '경인전자(주)', '광동제약(주)', '글로벌에스엠테크리미티드',
#        '나노캠텍(주)', '남화토건(주)', '다믈멀티미디어(주)', '대우전자부품(주)', '동양피스톤(주)',
#        '로스웰인터내셔널유한회사', '무림페이퍼(주)', '무림피앤피(주)', '미래나노텍(주)', '삼보산업(주)',
#        '삼성전기(주)', '삼아제약(주)', '삼정펄프(주)', '삼화전기(주)', '상신이디피(주)', '세원이앤씨(주)',
#        '씨제이제일제당(주)', '아미코젠(주)', '애머릿지코퍼레이션', '에스디엔(주)', '에스맥(주)',
#        '에스엔케이폴리텍(주)', '엘브이엠씨홀딩스(주)', '오가닉티코스메틱스홀딩스컴퍼니리미티드', '윙입푸드홀딩스',
#        '이스트아시아홀딩스인베스트먼트리미티드', '이엠코리아(주)', '이트론(주)', '잉글우드랩(주)', '전방(주)',
#        '제이더블유홀딩스(주)', '제이엠티(주)', '차이나크리스탈신소재홀딩스', '참엔지니어링(주)', '참좋은여행(주)',
#        '컬러레이홀딩스', '케이만금세기차륜집단유한공사', '케이씨그린홀딩스(주)', '케이피엑스홀딩스(주)',
#        '코오롱티슈진(주)', '평화산업(주)', '한국조선해양(주)', '한라아이엠에스(주)', '한솔로지스틱스(주)',
#        '한올바이오파마(주)', '한화솔루션(주)', '헝셩그룹유한회사', '현우산업(주)', '효성아이티엑스(주)',
#        '휴림로봇(주)'], dtype=object)

# %%
# # 거래소코드가 9로 시작하는 기업 제거
dd = dd[~dd['회사명'].isin(code_nine_list)]
dd = dd.reset_index(drop=True)
print(dd.shape)
# Out:
# (13222, 50)

# %%
# # 기업 기록이 하나인 기업
single_rows = dd['회사명'].value_counts() <= 2
single_rows[single_rows]
# Out:
# 카나리아바이오    True
# 그리티        True
# 효성화학       True
# 대구백화점      True
# 케어랩스       True
#            ...
# 레이         True
# 에이스토리      True
# 네오크레마      True
# 라파스        True
# 미디어젠       True
# Name: 회사명, Length: 160, dtype: bool

# %%
# # 기업 기록이 하나인 기업 제거
dd = dd[~dd['회사명'].isin(single_rows[single_rows].index)]
dd = dd.reset_index(drop=True)
print(dd.shape)
# Out:
# (12976, 50)

# %%
df['이자보상배율'] = df['이자보상배율'].fillna(12547896.63)

# %%
df.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 이자보상배율                     0
# 총자산증가율                   296
# 유형자산증가율                  296
# 유동자산증가율                  296
# 자기자본증가율                  296
# 매출액증가율                   294
# 매출액총이익율                  204
# 매출액순이익율                  204
# 자기자본순이익율                 296
# 총자본영업이익율                  48
# 매출액영업이익률                   0
# 총자본순이익률                  296
# 총자본회전율                   295
# 재고자산회전율                  285
# 매출채권회전율                  295
# 유형자산회전율                  295
# 매입채무회전율                  295
# 자기자본회전율                  295
# 타인자본회전율                  295
# 유동자산회전율                  295
# 순운전자본회전율                 204
# 유동비율                     204
# 당좌비율                     204
# 현금비율                     204
# 부채비율                     204
# 차입금의존도                     0
# CASH_FLOW_대_부채비율           0
# CASH_FLOW_대_매출액비율          0
# CASH_FLOW_대_차입금비율         36
# 자기자본구성비율                 204
# 당좌자산구성비율                 204
# 유동자산구성비율                 204
# 매출채권_대_매입채무비율            206
# 유동부채비율                   204
# 타인자본구성비율                 204
# 재고자산_대_유동자산비율            204
# 재고자산_대_순운전자본비율             0
# 순운전자본비율                  204
# 노동장비율                    274
# 기계장비율                    267
# 자본집약도                      0
# 설비투자효율                     0
# 총자본투자효율                    0
# 부가가치율                      0
# 종업원1인당부가가치                19
# R & D 투자효율               329
# 통계청 한국표준산업분류 10차(소분류)      0
# dtype: int64

# %%
df['이자보상배율'] = df['이자보상배율'].replace(7777,np.nan)
maxi = lambda x: x.fillna(x.max())
df['이자보상배율'] = df['이자보상배율'].groupby(df['회사명']).apply(maxi)
df.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 이자보상배율                    79
# 총자산증가율                   296
# 유형자산증가율                  296
# 유동자산증가율                  296
# 자기자본증가율                  296
# 매출액증가율                   294
# 매출액총이익율                  204
# 매출액순이익율                  204
# 자기자본순이익율                 296
# 총자본영업이익율                  48
# 매출액영업이익률                   0
# 총자본순이익률                  296
# 총자본회전율                   295
# 재고자산회전율                  285
# 매출채권회전율                  295
# 유형자산회전율                  295
# 매입채무회전율                  295
# 자기자본회전율                  295
# 타인자본회전율                  295
# 유동자산회전율                  295
# 순운전자본회전율                 204
# 유동비율                     204
# 당좌비율                     204
# 현금비율                     204
# 부채비율                     204
# 차입금의존도                     0
# CASH_FLOW_대_부채비율           0
# CASH_FLOW_대_매출액비율          0
# CASH_FLOW_대_차입금비율         36
# 자기자본구성비율                 204
# 당좌자산구성비율                 204
# 유동자산구성비율                 204
# 매출채권_대_매입채무비율            206
# 유동부채비율                   204
# 타인자본구성비율                 204
# 재고자산_대_유동자산비율            204
# 재고자산_대_순운전자본비율             0
# 순운전자본비율                  204
# 노동장비율                    274
# 기계장비율                    267
# 자본집약도                      0
# 설비투자효율                     0
# 총자본투자효율                    0
# 부가가치율                      0
# 종업원1인당부가가치                19
# R & D 투자효율               329
# 통계청 한국표준산업분류 10차(소분류)      0
# dtype: int64

# %%
df['이자보상배율'] = df['이자보상배율'].fillna(12547896.63)

# %%
mins = lambda x: x.fillna(x.min())
df['이자보상배율'] = df['이자보상배율'].replace(-7777,np.nan)
df['이자보상배율'] = df['이자보상배율'].groupby(df['회사명']).apply(mins)
df.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 이자보상배율                    59
# 총자산증가율                   296
# 유형자산증가율                  296
# 유동자산증가율                  296
# 자기자본증가율                  296
# 매출액증가율                   294
# 매출액총이익율                  204
# 매출액순이익율                  204
# 자기자본순이익율                 296
# 총자본영업이익율                  48
# 매출액영업이익률                   0
# 총자본순이익률                  296
# 총자본회전율                   295
# 재고자산회전율                  285
# 매출채권회전율                  295
# 유형자산회전율                  295
# 매입채무회전율                  295
# 자기자본회전율                  295
# 타인자본회전율                  295
# 유동자산회전율                  295
# 순운전자본회전율                 204
# 유동비율                     204
# 당좌비율                     204
# 현금비율                     204
# 부채비율                     204
# 차입금의존도                     0
# CASH_FLOW_대_부채비율           0
# CASH_FLOW_대_매출액비율          0
# CASH_FLOW_대_차입금비율         36
# 자기자본구성비율                 204
# 당좌자산구성비율                 204
# 유동자산구성비율                 204
# 매출채권_대_매입채무비율            206
# 유동부채비율                   204
# 타인자본구성비율                 204
# 재고자산_대_유동자산비율            204
# 재고자산_대_순운전자본비율             0
# 순운전자본비율                  204
# 노동장비율                    274
# 기계장비율                    267
# 자본집약도                      0
# 설비투자효율                     0
# 총자본투자효율                    0
# 부가가치율                      0
# 종업원1인당부가가치                19
# R & D 투자효율               329
# 통계청 한국표준산업분류 10차(소분류)      0
# dtype: int64

# %%
df['이자보상배율'] = df['이자보상배율'].replace(12547896.63,np.nan)
df.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 이자보상배율                   246
# 총자산증가율                   296
# 유형자산증가율                  296
# 유동자산증가율                  296
# 자기자본증가율                  296
# 매출액증가율                   294
# 매출액총이익율                  204
# 매출액순이익율                  204
# 자기자본순이익율                 296
# 총자본영업이익율                  48
# 매출액영업이익률                   0
# 총자본순이익률                  296
# 총자본회전율                   295
# 재고자산회전율                  285
# 매출채권회전율                  295
# 유형자산회전율                  295
# 매입채무회전율                  295
# 자기자본회전율                  295
# 타인자본회전율                  295
# 유동자산회전율                  295
# 순운전자본회전율                 204
# 유동비율                     204
# 당좌비율                     204
# 현금비율                     204
# 부채비율                     204
# 차입금의존도                     0
# CASH_FLOW_대_부채비율           0
# CASH_FLOW_대_매출액비율          0
# CASH_FLOW_대_차입금비율         36
# 자기자본구성비율                 204
# 당좌자산구성비율                 204
# 유동자산구성비율                 204
# 매출채권_대_매입채무비율            206
# 유동부채비율                   204
# 타인자본구성비율                 204
# 재고자산_대_유동자산비율            204
# 재고자산_대_순운전자본비율             0
# 순운전자본비율                  204
# 노동장비율                    274
# 기계장비율                    267
# 자본집약도                      0
# 설비투자효율                     0
# 총자본투자효율                    0
# 부가가치율                      0
# 종업원1인당부가가치                19
# R & D 투자효율               329
# 통계청 한국표준산업분류 10차(소분류)      0
# dtype: int64

# %%
dd.to_csv('다제거후이보배결측치보기.csv',encoding='cp949',index=False)

# %%
# c.isna().sum()

# %%
# df_5_frame.to_csv('3년연속성한계기업.csv',index=False,encoding='cp949')

# %%
# a.to_csv('3년연속한계기업.csv',index=False,encoding='cp949')

# %%
# df_7_frame.to_csv('4년째연속성나락간기업.csv',index=False,encoding='cp949')

# %%
# b.to_csv('4년째나락간기업.csv',index=False,encoding='cp949')

# %%
# pd.options.display.max_columns = None

# %%
# 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
a = df_5_frame.copy()
# a = a.reset_index(drop=True)
a
# Out:
#            회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     (주)CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1     (주)CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2     (주)CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3     (주)CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4     (주)CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...        ...    ...      ...     ...     ...      ...      ...      ...
# 9387   흥아해운(주)   3280  2014-12    1.12   13.69    45.19   -13.68     7.76
# 9388   흥아해운(주)   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 9389   흥아해운(주)   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 9390   흥아해운(주)   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 9391   흥아해운(주)   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
#
#       매출액증가율  매출액총이익율  ...  순운전자본비율      노동장비율     기계장비율    자본집약도  \
# 0      56.40    41.83  ...    28.23   71726.36  29216.43   202.26
# 1      -8.43    28.34  ...    70.60   69458.82  32002.75   426.18
# 2      25.51    38.70  ...    58.50   66012.04  33789.62   411.12
# 3      11.52    37.07  ...    33.72  113899.65  48479.94   354.08
# 4      18.85    36.26  ...    30.82  114246.59  53386.77   362.39
# ...      ...      ...  ...      ...        ...       ...      ...
# 9387    7.17     5.61  ...   -12.59  428397.42     15.32   859.92
# 9388    2.42     6.20  ...   -15.94  593960.16     14.23   973.73
# 9389   -1.58     4.49  ...   -16.34  706868.14     12.28  1017.55
# 9390    0.56     2.09  ...   -24.48  599097.86     12.56   921.78
# 9391   -9.87    -0.93  ...   -25.40  618981.48     14.54  1009.67
#
#            설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치  R & D 투자효율  \
# 0     35.85819316    12.72  19.56    25719.78        0.13
# 1               0     0.47   1.66     2009.78        0.74
# 2     77.91470318    12.51  34.29    51433.09        0.66
# 3     37.80253285    12.16  31.04    43056.95        0.51
# 4               0     7.63  15.96    27662.63        3.08
# ...           ...      ...    ...         ...         ...
# 9387  27.87566308    13.89  10.93   119418.62        0.00
# 9388  21.49400366    13.11  12.28   127665.82        0.00
# 9389  15.81260955    10.98  12.66   111774.30        0.00
# 9390  8.349918093     5.43   5.51    50024.18        0.00
# 9391            0     4.24   4.52    42782.54        0.00
#
#       통계청 한국표준산업분류 10차(소분류)
# 0                   의약품 제조업
# 1                   의약품 제조업
# 2                   의약품 제조업
# 3                   의약품 제조업
# 4                   의약품 제조업
# ...                     ...
# 9387                 해상 운송업
# 9388                 해상 운송업
# 9389                 해상 운송업
# 9390                 해상 운송업
# 9391                 해상 운송업
#
# [9392 rows x 50 columns]

# %%
a.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 이자보상배율                    51
# 총자산증가율                   191
# 유형자산증가율                  191
# 유동자산증가율                  191
# 자기자본증가율                  191
# 매출액증가율                   189
# 매출액총이익율                  128
# 매출액순이익율                  128
# 자기자본순이익율                 191
# 총자본영업이익율                  36
# 매출액영업이익률                   0
# 총자본순이익률                  191
# 총자본회전율                   190
# 재고자산회전율                  181
# 매출채권회전율                  190
# 유형자산회전율                  190
# 매입채무회전율                  190
# 자기자본회전율                  190
# 타인자본회전율                  190
# 유동자산회전율                  190
# 순운전자본회전율                 128
# 유동비율                     128
# 당좌비율                     128
# 현금비율                     128
# 부채비율                     128
# 차입금의존도                     0
# CASH_FLOW_대_부채비율           0
# CASH_FLOW_대_매출액비율          0
# CASH_FLOW_대_차입금비율         28
# 자기자본구성비율                 128
# 당좌자산구성비율                 128
# 유동자산구성비율                 128
# 매출채권_대_매입채무비율            130
# 유동부채비율                   128
# 타인자본구성비율                 128
# 재고자산_대_유동자산비율            128
# 재고자산_대_순운전자본비율             0
# 순운전자본비율                  128
# 노동장비율                    159
# 기계장비율                    152
# 자본집약도                      0
# 설비투자효율                     0
# 총자본투자효율                    0
# 부가가치율                      0
# 종업원1인당부가가치                19
# R & D 투자효율               151
# 통계청 한국표준산업분류 10차(소분류)      0
# dtype: int64

# %%
a.drop_duplicates('회사명')
# Out:
#             회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      (주)CMG제약   58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 9      (주)DB하이텍     990  2011-12   -0.75  -13.19    -7.89   -10.08   -22.60
# 18      (주)ES큐브   50120  2011-12 -245.99   12.78    27.82     3.83    -7.92
# 27     (주)HJ중공업   97230  2011-12    0.55   -6.49    -1.53   -13.26    -4.55
# 36     (주)MH에탄올   23150  2011-12    0.12   -0.49     2.92    -0.67    -8.49
# ...         ...     ...      ...     ...     ...      ...      ...      ...
# 9354  휴림네트웍스(주)  192410  2014-12    3.38  -97.97   -99.71   -89.96   -93.71
# 9360    휴림로봇(주)   90710  2011-12    2.96   35.07    27.83    38.25    37.53
# 9369    휴마시스(주)  205470  2014-12   -0.76     NaN      NaN      NaN      NaN
# 9375    흥구석유(주)   24060  2011-12   10.35   -1.97    -5.85    -5.49     2.09
# 9384    흥아해운(주)    3280  2011-12   -0.33   -3.13    -0.34   -15.59   -17.19
#
#       매출액증가율  매출액총이익율  ...  순운전자본비율       노동장비율      기계장비율    자본집약도  \
# 0      56.40    41.83  ...    28.23    71726.36   29216.43   202.26
# 9     -10.94    16.62  ...   -42.95   284943.29  596524.90   467.10
# 18     21.63    27.92  ...    34.75    18201.83    3525.92   234.08
# 27     -8.72     7.85  ...    -1.29  1121928.55  179602.51  2526.64
# 36    -18.64    16.81  ...   -24.28  1474660.69  273673.90  2631.51
# ...      ...      ...  ...      ...         ...        ...      ...
# 9354  -97.39    18.57  ...    79.10    30985.94   52179.00   391.33
# 9360   58.70    25.26  ...    17.83    60938.35    2556.50   333.03
# 9369     NaN      NaN  ...      NaN         NaN        NaN     0.00
# 9375    8.12     3.71  ...     8.37   351367.02   16970.02   590.33
# 9384   12.78     2.54  ...   -14.68   364314.78      16.82   771.72
#
#            설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치  R & D 투자효율  \
# 0     35.85819316    12.72  19.56    25719.78        0.13
# 9      29.7816315    18.17  39.45    84860.76       11.34
# 18              0    21.71  22.56    50819.28        5.95
# 27     15.8107465     7.02  17.09   177385.28        0.06
# 36    11.62281333     6.51  19.52   171397.06        0.00
# ...           ...      ...    ...         ...         ...
# 9354            0     0.00   0.00        0.00        0.00
# 9360            0    18.88  20.15    62883.35        6.08
# 9369            0     0.00   0.00        0.00         NaN
# 9375            0     0.00   0.00        0.00        0.00
# 9384            0     6.92   5.37    53433.62        0.00
#
#         통계청 한국표준산업분류 10차(소분류)
# 0                     의약품 제조업
# 9                     반도체 제조업
# 18                   생활용품 도매업
# 27                     토목 건설업
# 36                  알코올음료 제조업
# ...                       ...
# 9354           통신 및 방송 장비 제조업
# 9360            특수 목적용 기계 제조업
# 9369    의료용품 및 기타 의약 관련제품 제조업
# 9375                기타 전문 도매업
# 9384                   해상 운송업
#
# [1177 rows x 50 columns]

# %%
a.to_csv('최종1년부실징후데이터(전)v2.csv',encoding='cp949',index=False)

# %%
df_7_frame.copy()
# Out:
#         회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1     CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2     CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3     CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4     CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...     ...    ...      ...     ...     ...      ...      ...      ...
# 6860   흥아해운   3280  2014-12    1.12   13.69    45.19   -13.68     7.76
# 6861   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 6862   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 6863   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 6864   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 1      -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78    0.39
# 2      25.51    38.70     1.45      0.74      1.40      3.88     0.52    0.36
# 3      11.52    37.07     0.69      0.32      0.78      1.94     0.28    0.40
# 4      18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37    0.47
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 6860    7.17     5.61     2.22     11.37      3.04      2.25     3.01    1.35
# 6861    2.42     6.20     1.24      6.18      2.95      2.51     1.46    1.17
# 6862   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96    0.95
# 6863    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13    0.93
# 6864   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47    0.91
#
#       재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  순운전자본회전율  \
# 0        3.74     2.29     1.77    11.95     0.97     2.01     1.25      4.61
# 1        4.09     1.75     1.71     7.83     0.66     0.93     0.52      0.81
# 2        3.30     2.02     2.03     6.20     0.51     1.26     0.48      1.25
# 3        3.00     1.85     1.54     5.27     0.46     2.85     0.68      2.32
# 4        3.32     2.09     1.48     5.66     0.56     2.88     0.99      3.10
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 6860    56.41    14.83     3.02    17.07     5.11     1.84     4.98    -20.19
# 6861    64.23    17.20     2.09    16.05     4.96     1.54     5.83    -13.39
# 6862    53.94    17.35     1.44    16.26     4.55     1.20     6.98    -10.62
# 6863    43.17    15.61     1.36    15.39     5.41     1.12     7.68     -8.05
# 6864    39.24    12.79     1.43    11.87     7.93     1.03     6.73     -7.39
#
#         유동비율    당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0     200.97  165.03   15.10   51.41    7.32            -46.08
# 1     693.49  649.98   68.81   80.77    0.18             -8.10
# 2     694.71  610.74  394.63   14.11    0.00            -39.85
# 3     324.58  268.23  101.24   18.50    0.01            -17.73
# 4     296.85  235.21   29.00   20.78    0.01             16.12
# ...      ...     ...     ...     ...     ...               ...
# 6860   65.25   59.64    8.09  287.83   29.09              2.84
# 6861   51.92   47.54    7.76  357.39   24.52              2.78
# 6862   39.46   32.52    5.46  397.97   19.03              2.12
# 6863   35.76   29.58    6.17  626.32   22.90             -0.57
# 6864   34.67   28.66    4.89  998.73   22.24             -2.78
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 1                -12.71           -2066.51     55.32     77.32     82.49
# 2                -13.51               0.00     87.63     60.08     68.34
# 3                 -7.06          -29481.93     84.39     40.28     48.74
# 4                  5.80           24988.83     82.80     36.82     46.47
# ...                 ...                ...       ...       ...       ...
# 6860               1.66               7.23     25.78     21.60     23.63
# 6861               2.03               8.85     21.86     15.76     17.21
# 6862               1.96               8.92     20.08      8.78     10.65
# 6863              -0.50              -2.13     13.77     11.27     13.63
# 6864              -2.70             -11.38      9.10     11.14     13.48
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 1            323.41   21.50     44.68           6.27            7.33    70.60
# 2            282.72   11.23     12.37          12.09           14.12    58.50
# 3            285.31   17.79     15.61          17.36           25.09    33.72
# 4            254.69   18.91     17.20          20.77           31.32    30.82
# ...             ...     ...       ...            ...             ...      ...
# 6860          66.36  140.48     74.22           8.60          -16.14   -12.59
# 6861          60.44  151.66     78.14           8.43           -9.10   -15.94
# 6862          68.73  134.41     79.92          17.60          -11.47   -16.34
# 6863          65.00  276.77     86.23          17.27           -9.61   -24.48
# 6864          59.32  427.21     90.90          17.36           -9.21   -25.40
#
#           노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0      71726.36  29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 1      69458.82  32002.75   426.18            0     0.47   1.66     2009.78
# 2      66012.04  33789.62   411.12  77.91470318    12.51  34.29    51433.09
# 3     113899.65  48479.94   354.08  37.80253285    12.16  31.04    43056.95
# 4     114246.59  53386.77   362.39            0     7.63  15.96    27662.63
# ...         ...       ...      ...          ...      ...    ...         ...
# 6860  428397.42     15.32   859.92  27.87566308    13.89  10.93   119418.62
# 6861  593960.16     14.23   973.73  21.49400366    13.11  12.28   127665.82
# 6862  706868.14     12.28  1017.55  15.81260955    10.98  12.66   111774.30
# 6863  599097.86     12.56   921.78  8.349918093     5.43   5.51    50024.18
# 6864  618981.48     14.54  1009.67            0     4.24   4.52    42782.54
#
# [6865 rows x 48 columns]

# %%
# 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
b = df_7_frame.copy().drop_duplicates(['회사명'])
# b = b.reset_index(drop=True)
b
# Out:
#          회사명   거래소코드     회계년도   이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약   58820  2011-12     3.53    1.98    -5.90    17.64    -2.02
# 9      DB하이텍     990  2011-12    -0.75  -13.19    -7.89   -10.08   -22.60
# 18      ES큐브   50120  2011-12  -245.99   12.78    27.82     3.83    -7.92
# 27     HJ중공업   97230  2011-12     0.55   -6.49    -1.53   -13.26    -4.55
# 36     MH에탄올   23150  2011-12     0.12   -0.49     2.92    -0.67    -8.49
# ...      ...     ...      ...      ...     ...      ...      ...      ...
# 6824    현우산업   92300  2011-12     2.86    6.48     8.40     4.77     0.42
# 6833    화천기계   10660  2011-12    68.14    8.08     0.86     6.13    15.18
# 6842  휴림네트웍스  192410  2014-12  7777.00  -97.97   -99.71   -89.96   -93.71
# 6848    휴림로봇   90710  2011-12     2.96   35.07    27.83    38.25    37.53
# 6857    흥아해운    3280  2011-12    -0.33   -3.13    -0.34   -15.59   -17.19
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 9     -10.94    16.62   -17.74    -27.74     -3.34     -7.81    -7.59    0.43
# 18     21.63    27.92    -8.99    -11.72     -6.98     -6.84    -9.17    1.02
# 27     -8.72     7.85    -3.35     -5.07      1.48      3.73    -1.33    0.40
# 36    -18.64    16.81    -9.73     -9.76      0.45      1.35    -3.24    0.33
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 6824    7.58     7.84     1.11      1.95      0.00      0.00     1.01    0.92
# 6833   32.84    12.36     5.31     16.05      0.00      0.00     8.40    1.58
# 6842  -97.39    18.57    10.44      1.79      0.00      0.00     0.56    0.05
# 6848   58.70    25.26     2.63      6.24      4.12      3.82     2.84    1.08
# 6857   12.78     2.54    -2.95    -16.16     -1.01     -0.80    -3.75    1.27
#
#       재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  순운전자본회전율  \
# 0        3.74     2.29     1.77    11.95     0.97     2.01     1.25      4.61
# 9        5.87     5.90     0.70    20.51     1.56     0.59     1.87     -2.14
# 18       8.12     5.26    13.89    18.08     1.30     4.68     1.60      5.54
# 27       8.17     2.95     0.91    10.41     1.51     0.54     1.12    -63.50
# 36       4.15     4.53     0.60   148.03     1.00     0.50     0.98     -2.75
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 6824     8.31     7.56     1.30     8.26     1.76     1.91     3.34    -14.01
# 6833    12.71     4.80     5.07     6.30     3.02     3.32     2.76     17.76
# 6842     0.64     0.57     0.10     0.70     0.17     0.08     0.29      3.43
# 6848     4.66     3.11     5.75     4.63     2.37     1.97     1.66     10.51
# 6857    49.62    15.13     2.73    16.88     5.47     1.65     4.81    -17.55
#
#          유동비율     당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0      200.97   165.03   15.10   51.41    7.32            -46.08
# 9       35.20    25.50    5.04  289.22   57.65              5.87
# 18     230.24   194.35   21.35   41.36    0.18             12.27
# 27      96.33    81.81   34.40  276.93   25.45             -0.99
# 36      58.36    45.92    5.22  214.54    8.89              2.62
# ...       ...      ...     ...     ...     ...               ...
# 6824    68.21    44.64   10.76   97.77    0.00             17.68
# 6833   143.25   115.68    2.71   85.39    0.00              5.19
# 6842  1288.40  1200.26  496.19    7.13    0.00           5345.94
# 6848   137.28   103.29   16.59  118.23   31.76              1.77
# 6857    62.54    54.80    4.96  368.79   45.86              3.15
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 9                  9.47               7.57     25.69     16.90     23.33
# 18                 3.73            1990.81     70.74     51.85     61.43
# 27                -1.77              -2.86     26.53     28.86     33.99
# 36                 5.35              20.09     31.79     26.78     34.04
# ...                 ...                ...       ...       ...       ...
# 6824               9.84               0.00     50.56     17.80     27.21
# 6833               1.57               0.00     53.94     45.92     56.86
# 6842             262.60               0.00     93.34     79.89     85.76
# 6848               1.03               3.03     45.82     49.41     65.67
# 6857               1.92               5.41     21.33     21.48     24.52
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 9            336.28  257.97     74.31          27.57          -14.97   -42.95
# 18           461.69   37.71     29.26          15.59           27.56    34.75
# 27           132.35  132.98     73.47          15.08         -395.95    -1.29
# 36         81716.41  183.43     68.21          21.31          -29.87   -24.28
# ...             ...     ...       ...            ...             ...      ...
# 6824          94.64   78.88     49.44          34.56          -74.17   -12.68
# 6833         135.09   73.59     46.06          19.25           63.75    17.17
# 6842         129.68    7.13      6.66           6.84            7.42    79.10
# 6848         200.54  104.40     54.18          24.76           91.17    17.83
# 6857          65.47  183.78     78.67          12.38          -20.67   -14.68
#
#            노동장비율      기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0       71726.36   29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 9      284943.29  596524.90   467.10   29.7816315    18.17  39.45    84860.76
# 18      18201.83    3525.92   234.08            0    21.71  22.56    50819.28
# 27    1121928.55  179602.51  2526.64   15.8107465     7.02  17.09   177385.28
# 36    1474660.69  273673.90  2631.51  11.62281333     6.51  19.52   171397.06
# ...          ...        ...      ...          ...      ...    ...         ...
# 6824   214268.12  170708.13   352.34            0     0.00   0.00        0.00
# 6833   184539.94   55727.89   629.06            0     0.00   0.00        0.00
# 6842    30985.94   52179.00   391.33            0     0.00   0.00        0.00
# 6848    60938.35    2556.50   333.03            0    18.88  20.15    62883.35
# 6857   364314.78      16.82   771.72            0     6.92   5.37    53433.62
#
# [808 rows x 48 columns]

# %%
c = a.columns - b.columns

# %%
# # 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
# df_8_frame.copy().drop_duplicates(['회사명'])

# %%
# # 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
# df_10_frame.copy().drop_duplicates(['회사명'])

# %%
# 회사명 리스트 생성
company_list = df['회사명'].unique()
company_list
# Out:
# array(['(주)CMG제약', '(주)DB하이텍', '(주)ES큐브', ..., '휴젤(주)', '흥구석유(주)',
#        '흥아해운(주)'], dtype=object)

# %%
# 행 개수가 3개 이상인 기업 리스트 및 수
over_three = []
for i in company_list:
    if len(df[df['회사명']==i]) >= 2:
        over_three.append(i)
print(len(over_three))
print(over_three)

# %%
# 행 개수가 3개 이상인 기업 인덱스
over_three_index = []
for i in over_three:
    over_three_index.append(df[df['회사명']==i].index)
over_three_index

# %%
# 3년 연속 이자보상배율이 1미만인 기업을 부실기업으로 정의
icr_count = 0
df['부실기업1'] = ''

for i in over_three_index:
    for j in i:
        if df.loc[j, '이자보상배율'] < 1:
            icr_count += 1
        else:
            icr_count = 0
                    
        if icr_count >= 2:
            df.loc[j, '부실기업1'] = 1
        else:
            df.loc[j, '부실기업1'] = 0

# %%
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율   노동장비율  \
# 0        -1.43    -2.02  ...          17.88           35.59    28.23   71.32
# 1         7.73    75.17  ...           6.27            7.33    70.60   69.14
# 2        56.29    55.10  ...          12.09           14.12    58.50   66.01
# 3         6.37     0.01  ...          17.36           25.09    33.72  113.90
# 4        11.04    -4.48  ...          20.77           31.32    30.82  114.25
# ...        ...      ...  ...            ...             ...      ...     ...
# 15145   -12.92     3.39  ...           8.43            0.00   -15.94  589.65
# 15146    56.39    11.22  ...          17.60            0.00   -16.34  703.55
# 15147    11.18   -39.28  ...          17.27            0.00   -24.48    0.00
# 15148    -5.85   -37.42  ...          17.36            0.00   -25.40    0.00
# 15149   -58.98   -57.73  ...           8.22            0.00   -25.18    0.00
#
#        기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 0      19.75   204.06   35.86    12.72  19.56      0
# 1      18.64   425.29    2.89     0.47   1.66      0
# 2      17.77   411.48   77.91    12.51  34.29      1
# 3      32.60   354.43   37.80    12.16  31.04      0
# 4      30.43   362.77   24.21     7.63  15.96      0
# ...      ...      ...     ...      ...    ...    ...
# 15145   0.00   948.60   21.49    13.11  12.28      0
# 15146   0.00  1000.62   15.81    10.98  12.66      0
# 15147   0.00     0.00    8.35     5.43   5.51      1
# 15148   0.00     0.00    6.91     4.24   4.52      1
# 15149   0.00     0.00    5.59     3.10  13.08      1
#
# [15150 rows x 54 columns]

# %%
a = df[df['부실기업1']==1]
b = a.drop_duplicates('회사명')
b
# Out:
#                     회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 2              (주)CMG제약   58820  13-Dec    0.70   -2.09    16.09   -18.89
# 10             (주)DB하이텍     990  12-Dec   -0.31   -3.44    -9.69    10.52
# 26              (주)ES큐브   50120  19-Dec   -0.68  312.66    14.02   696.75
# 27             (주)HJ중공업   97230  11-Dec    0.55   -6.49    -1.53   -13.26
# 36             (주)MH에탄올   23150  11-Dec    0.12   -0.49     2.92    -0.67
# ...                 ...     ...     ...     ...     ...      ...      ...
# 14981  현대일렉트릭앤에너지시스템(주)  267260  19-Dec   -4.66   -2.99    -2.10   -10.14
# 15016           현우산업(주)   92300  13-Dec   -1.29    7.54     4.22    14.79
# 15114           휴림로봇(주)   90710  13-Dec   -3.00   -8.68    -2.15   -17.87
# 15121           휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN
# 15147           흥아해운(주)    3280  17-Dec   -0.42  -11.43   -16.50    13.29
#
#        매출액증가율  재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 2       25.51    56.29    55.10  ...          12.09           14.12    58.50
# 10       6.98     2.79    -5.57  ...          25.64            0.00   -21.27
# 26      29.45   -17.20   -18.89  ...           2.13            5.93    27.78
# 27      -8.72    23.47    -4.59  ...          15.08            0.00    -1.29
# 36     -18.64    18.30    -8.46  ...          21.31            0.00   -24.28
# ...       ...      ...      ...  ...            ...             ...      ...
# 14981   -8.72    -7.99   -17.75  ...          26.33          108.41    15.97
# 15016   -3.69     3.74    -1.01  ...          27.36            0.00   -10.69
# 15114   36.45   -15.62   -20.84  ...          27.74          226.41     6.82
# 15121     NaN      NaN      NaN  ...            NaN             NaN      NaN
# 15147    0.56    11.18   -39.28  ...          17.27            0.00   -24.48
#
#         노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 2       66.01  17.77   411.48   77.91    12.51  34.29      1
# 10     287.76  95.01   498.73   37.03    21.22  41.58      1
# 26       0.00   0.00     0.00   -3.22    -0.12  -1.28      1
# 27     510.77  33.44  2103.09   15.81     7.02  17.09      1
# 36     689.66  18.92  2665.24   11.62     6.51  19.52      1
# ...       ...    ...      ...     ...      ...    ...    ...
# 14981    0.00   0.00     0.00   -5.42    -1.19  -1.52      1
# 15016  190.10  95.13   337.24   34.38    19.38  25.75      1
# 15114   62.61   1.19   283.56   75.91    16.06  16.97      1
# 15121     NaN    NaN      NaN     NaN      NaN    NaN      1
# 15147    0.00   0.00     0.00    8.35     5.43   5.51      1
#
# [835 rows x 54 columns]
