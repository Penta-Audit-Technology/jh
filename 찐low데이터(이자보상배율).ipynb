# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
df = pd.read_csv('다제거후이보배결측치보기1.csv', encoding='cp949')
# df = df.drop(columns=)
# df.drop(columns=['Unnamed: 0'], inplace=True)
df['회계년도'] = pd.to_datetime(df['회계년도'], format='%b-%d').dt.strftime('20%d-%m')
df
# Out:
#          회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...    ...      ...     ...     ...      ...      ...      ...
# 14175   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 14176   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 14177   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 14178   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 14179   흥아해운   3280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  \
# 0       56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58
# 1       -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78
# 2       25.51    38.70     1.45      0.74      1.40      3.88     0.52
# 3       11.52    37.07     0.69      0.32      0.78      1.94     0.28
# 4       18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37
# ...       ...      ...      ...       ...       ...       ...      ...
# 14175    2.42     6.20     1.24      6.18      2.95      2.51     1.46
# 14176   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96
# 14177    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13
# 14178   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47
# 14179  -86.45     5.54   -50.27    -98.70     -2.00    -12.10    -8.32
#
#        총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        0.66     3.74     2.29     1.77    11.95     0.97     2.01     1.25
# 1        0.39     4.09     1.75     1.71     7.83     0.66     0.93     0.52
# 2        0.36     3.30     2.02     2.03     6.20     0.51     1.26     0.48
# 3        0.40     3.00     1.85     1.54     5.27     0.46     2.85     0.68
# 4        0.47     3.32     2.09     1.48     5.66     0.56     2.88     0.99
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 14175    1.17    64.23    17.20     2.09    16.05     4.96     1.54     5.83
# 14176    0.95    53.94    17.35     1.44    16.26     4.55     1.20     6.98
# 14177    0.93    43.17    15.61     1.36    15.39     5.41     1.12     7.68
# 14178    0.91    39.24    12.79     1.43    11.87     7.93     1.03     6.73
# 14179    0.17     7.28     2.86     0.28     2.41     1.96     0.18     1.01
#
#        순운전자본회전율    유동비율    당좌비율    현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0          4.61  200.97  165.03   15.10    51.41    7.32            -46.08
# 1          0.81  693.49  649.98   68.81    80.77    0.18             -8.10
# 2          1.25  694.71  610.74  394.63    14.11    0.00            -39.85
# 3          2.32  324.58  268.23  101.24    18.50    0.01            -17.73
# 4          3.10  296.85  235.21   29.00    20.78    0.01             16.12
# ...         ...     ...     ...     ...      ...     ...               ...
# 14175    -13.39   51.92   47.54    7.76   357.39   24.52              2.78
# 14176    -10.62   39.46   32.52    5.46   397.97   19.03              2.12
# 14177     -8.05   35.76   29.58    6.17   626.32   22.90             -0.57
# 14178     -7.39   34.67   28.66    4.89   998.73   22.24             -2.78
# 14179     -1.88   46.36   42.55    6.75  1293.83   18.36             -5.73
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 14175               2.03               8.85     21.86     15.76     17.21
# 14176               1.96               8.92     20.08      8.78     10.65
# 14177              -0.50              -2.13     13.77     11.27     13.63
# 14178              -2.70             -11.38      9.10     11.14     13.48
# 14179             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 14175          60.44  151.66     78.14           8.43           -9.10
# 14176          68.73  134.41     79.92          17.60          -11.47
# 14177          65.00  276.77     86.23          17.27           -9.61
# 14178          59.32  427.21     90.90          17.36           -9.21
# 14179          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 14175   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 14176   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 14177   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 14178   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 14179   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인당부가가치
# 0        25719.78
# 1         2009.78
# 2        51433.09
# 3        43056.95
# 4        27662.63
# ...           ...
# 14175   127665.82
# 14176   111774.30
# 14177    50024.18
# 14178    42782.54
# 14179    39428.47
#
# [14180 rows x 48 columns]

# %%
df['회사명'] = df['회사명'].str.replace('\(','')
df['회사명'] = df['회사명'].str.replace('주','')
df['회사명'] = df['회사명'].str.replace('\)','')
df
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_17136\3284833777.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['회사명'] = df['회사명'].str.replace('\(','')
# C:\Users\82104\AppData\Local\Temp\ipykernel_17136\3284833777.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['회사명'] = df['회사명'].str.replace('\)','')
#          회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...    ...      ...     ...     ...      ...      ...      ...
# 15145   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 15146   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 15147   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 15148   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 15149   흥아해운   3280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  \
# 0       56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58
# 1       -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78
# 2       25.51    38.70     1.45      0.74      1.40      3.88     0.52
# 3       11.52    37.07     0.69      0.32      0.78      1.94     0.28
# 4       18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37
# ...       ...      ...      ...       ...       ...       ...      ...
# 15145    2.42     6.20     1.24      6.18      2.95      2.51     1.46
# 15146   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96
# 15147    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13
# 15148   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47
# 15149  -86.45     5.54   -50.27    -98.70     -2.00    -12.10    -8.32
#
#        총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        0.66     3.74     2.29     1.77    11.95     0.97     2.01     1.25
# 1        0.39     4.09     1.75     1.71     7.83     0.66     0.93     0.52
# 2        0.36     3.30     2.02     2.03     6.20     0.51     1.26     0.48
# 3        0.40     3.00     1.85     1.54     5.27     0.46     2.85     0.68
# 4        0.47     3.32     2.09     1.48     5.66     0.56     2.88     0.99
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 15145    1.17    64.23    17.20     2.09    16.05     4.96     1.54     5.83
# 15146    0.95    53.94    17.35     1.44    16.26     4.55     1.20     6.98
# 15147    0.93    43.17    15.61     1.36    15.39     5.41     1.12     7.68
# 15148    0.91    39.24    12.79     1.43    11.87     7.93     1.03     6.73
# 15149    0.17     7.28     2.86     0.28     2.41     1.96     0.18     1.01
#
#        순운전자본회전율    유동비율    당좌비율    현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0          4.61  200.97  165.03   15.10    51.41    7.32            -46.08
# 1          0.81  693.49  649.98   68.81    80.77    0.18             -8.10
# 2          1.25  694.71  610.74  394.63    14.11    0.00            -39.85
# 3          2.32  324.58  268.23  101.24    18.50    0.01            -17.73
# 4          3.10  296.85  235.21   29.00    20.78    0.01             16.12
# ...         ...     ...     ...     ...      ...     ...               ...
# 15145    -13.39   51.92   47.54    7.76   357.39   24.52              2.78
# 15146    -10.62   39.46   32.52    5.46   397.97   19.03              2.12
# 15147     -8.05   35.76   29.58    6.17   626.32   22.90             -0.57
# 15148     -7.39   34.67   28.66    4.89   998.73   22.24             -2.78
# 15149     -1.88   46.36   42.55    6.75  1293.83   18.36             -5.73
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 15145               2.03               8.85     21.86     15.76     17.21
# 15146               1.96               8.92     20.08      8.78     10.65
# 15147              -0.50              -2.13     13.77     11.27     13.63
# 15148              -2.70             -11.38      9.10     11.14     13.48
# 15149             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 15145          60.44  151.66     78.14           8.43           -9.10
# 15146          68.73  134.41     79.92          17.60          -11.47
# 15147          65.00  276.77     86.23          17.27           -9.61
# 15148          59.32  427.21     90.90          17.36           -9.21
# 15149          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 15145   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 15146   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 15147   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 15148   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 15149   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인당부가가치
# 0        25719.78
# 1         2009.78
# 2        51433.09
# 3        43056.95
# 4        27662.63
# ...           ...
# 15145   127665.82
# 15146   111774.30
# 15147    50024.18
# 15148    42782.54
# 15149    39428.47
#
# [15150 rows x 48 columns]

# %%
dd = df['회사명'].isin(['고려시멘트','국전약품','나노','나인테크','넥슨게임즈','넵튠','누보','다보링크',
                              '더블유에스아이','덴티스','드림시큐리티','디딤','디알텍','디와이디','러셀','레이크머티리얼즈',
                              '로보로보','모비스','미래생명자원','바이오로그디바이스','베노홀딩스','본느','비올','비투엔',
                              '삼기','서진오토모티브','세림비앤지','세토피아','세화피앤씨','셀바스헬스케어','스튜디오산타클로스엔터테인먼트',
                              '썸에이지','쎄노텍','아이비김영','아이엘사이언스','알로이스','알톤스포츠','애니플러스','액션스퀘어',
                              '에치에프알','에프에스엔','엑셈','엔투텍','엔피','예선테크','오하임아이엔티','옵투스제약',
                              '와이즈버즈','우정바이오','원바이오젠','웨이버스','위메이드플레이','이노인스트루먼트','이랜시스',
                              '인산가','일승','자비스','정다운','제이시스메디칼','지니틱스','지란지교시큐리티','카이노스메드',
                              '켐온','켐트로스','코퍼스코리아','큐브엔터테인먼트','클래시스','태성','토박스코리아','티에스트릴리온',
                              '포인트엔지니어링','프로스테믹스','프로이천','하이비젼시스템','한국비엔씨','한송네오텍','한일진공',
                              '화신정공','휴센텍','글로벌텍스프리','나무기술','디와이씨','미스터블루','바디텍메드','소프트캠프',
                              '씨아이에스','알서포트','알에프에이치아이씨','에스지에이솔루션즈','엠에프엠코리아','와이아이케이','원텍',
                              '윈텍','줌인터넷','지엔원에너지','지엘팜텍','케이에이치건설','케이엠제약','코리아에프티','패션플랫폼',
                              '현대무벡스','휴마시스','네오셈','라온테크','비플라이소프트'])

# %%
# df.to_csv('efs.csv',encoding='cp949')

# %%
dd = df[~dd]
dd = dd.reset_index(drop=True)
dd
# Out:
#          회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...    ...      ...     ...     ...      ...      ...      ...
# 14688   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 14689   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 14690   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 14691   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 14692   흥아해운   3280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  \
# 0       56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58
# 1       -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78
# 2       25.51    38.70     1.45      0.74      1.40      3.88     0.52
# 3       11.52    37.07     0.69      0.32      0.78      1.94     0.28
# 4       18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37
# ...       ...      ...      ...       ...       ...       ...      ...
# 14688    2.42     6.20     1.24      6.18      2.95      2.51     1.46
# 14689   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96
# 14690    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13
# 14691   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47
# 14692  -86.45     5.54   -50.27    -98.70     -2.00    -12.10    -8.32
#
#        총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        0.66     3.74     2.29     1.77    11.95     0.97     2.01     1.25
# 1        0.39     4.09     1.75     1.71     7.83     0.66     0.93     0.52
# 2        0.36     3.30     2.02     2.03     6.20     0.51     1.26     0.48
# 3        0.40     3.00     1.85     1.54     5.27     0.46     2.85     0.68
# 4        0.47     3.32     2.09     1.48     5.66     0.56     2.88     0.99
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 14688    1.17    64.23    17.20     2.09    16.05     4.96     1.54     5.83
# 14689    0.95    53.94    17.35     1.44    16.26     4.55     1.20     6.98
# 14690    0.93    43.17    15.61     1.36    15.39     5.41     1.12     7.68
# 14691    0.91    39.24    12.79     1.43    11.87     7.93     1.03     6.73
# 14692    0.17     7.28     2.86     0.28     2.41     1.96     0.18     1.01
#
#        순운전자본회전율    유동비율    당좌비율    현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0          4.61  200.97  165.03   15.10    51.41    7.32            -46.08
# 1          0.81  693.49  649.98   68.81    80.77    0.18             -8.10
# 2          1.25  694.71  610.74  394.63    14.11    0.00            -39.85
# 3          2.32  324.58  268.23  101.24    18.50    0.01            -17.73
# 4          3.10  296.85  235.21   29.00    20.78    0.01             16.12
# ...         ...     ...     ...     ...      ...     ...               ...
# 14688    -13.39   51.92   47.54    7.76   357.39   24.52              2.78
# 14689    -10.62   39.46   32.52    5.46   397.97   19.03              2.12
# 14690     -8.05   35.76   29.58    6.17   626.32   22.90             -0.57
# 14691     -7.39   34.67   28.66    4.89   998.73   22.24             -2.78
# 14692     -1.88   46.36   42.55    6.75  1293.83   18.36             -5.73
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 14688               2.03               8.85     21.86     15.76     17.21
# 14689               1.96               8.92     20.08      8.78     10.65
# 14690              -0.50              -2.13     13.77     11.27     13.63
# 14691              -2.70             -11.38      9.10     11.14     13.48
# 14692             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 14688          60.44  151.66     78.14           8.43           -9.10
# 14689          68.73  134.41     79.92          17.60          -11.47
# 14690          65.00  276.77     86.23          17.27           -9.61
# 14691          59.32  427.21     90.90          17.36           -9.21
# 14692          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 14688   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 14689   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 14690   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 14691   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 14692   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인당부가가치
# 0        25719.78
# 1         2009.78
# 2        51433.09
# 3        43056.95
# 4        27662.63
# ...           ...
# 14688   127665.82
# 14689   111774.30
# 14690    50024.18
# 14691    42782.54
# 14692    39428.47
#
# [14693 rows x 48 columns]

# %%
dd.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 이자보상배율               14
# 총자산증가율               35
# 유형자산증가율              35
# 유동자산증가율              35
# 자기자본증가율              35
# 매출액증가율               34
# 매출액총이익율              18
# 매출액순이익율              18
# 자기자본순이익율             35
# 총자본영업이익율              5
# 매출액영업이익률              0
# 총자본순이익률              35
# 총자본회전율               34
# 재고자산회전율              34
# 매출채권회전율              34
# 유형자산회전율              34
# 매입채무회전율              34
# 자기자본회전율              34
# 타인자본회전율              34
# 유동자산회전율              34
# 순운전자본회전율             18
# 유동비율                 18
# 당좌비율                 18
# 현금비율                 18
# 부채비율                 18
# 차입금의존도                0
# CASH_FLOW_대_부채비율      0
# CASH_FLOW_대_매출액비율     0
# CASH_FLOW_대_차입금비율     4
# 자기자본구성비율             18
# 당좌자산구성비율             18
# 유동자산구성비율             18
# 매출채권_대_매입채무비율        20
# 유동부채비율               18
# 타인자본구성비율             18
# 재고자산_대_유동자산비율        18
# 재고자산_대_순운전자본비율        0
# 순운전자본비율              18
# 노동장비율                88
# 기계장비율                81
# 자본집약도                 0
# 설비투자효율                0
# 총자본투자효율               0
# 부가가치율                 0
# 종업원1인당부가가치           19
# dtype: int64

# %%
# 분석 과정에서 NaN이 NaN이 아닌 다른 어떤 값인 것으로 판명되었습니다.
# 어쩔 수 없이 분석의 용이함을 위해 임의의 값을 채웠습니다
# df = df.fillna(77777.77)

# 이건 우리의 기준에 맞는 이자보상 배율을 저장하기 위한 컬럼입니다.
# df['이자보상배율'] = 0.0

# %%
# df_1 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS)']]
# df_2 = df[['회사명','거래소코드','회계년도','이자보상배율(이자비용)(IFRS연결)']]

# %%
# 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

f_company = [] # 한계기업을 저장하는 리스트
f_company_x = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
f_safe = []
fs_company = []
count = 0 # 한계기업 카운트용
s_count = 0
company = 'x' # 한계기업 기록용
s_company = 'o'

# 이거도 csv 한바퀴 돌립니다
for i in range(0, len(df)-1):

    # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
    if company == df.loc[i]['회사명']:
        # 다만 그 기업이 한계기업인데
        if count > 1:
            # 어머? 4년 연속이네요? 기록!!!
            if df.iloc[i]['이자보상배율'] < 1:
                f_company_x.append(company)
                count = 0
                # 반복문에서 볼일 다 끝났으니 통과합니다
            continue
        
        # 그게 아니라면 반복문을 통과합니다
        continue

    # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
    if df.iloc[i]['이자보상배율'] < 1:
            count += 1
    # 도중에 이자보상배율이 1 이상이면 탈출합니다
    else:
        count = 0
    # 한계 기업 클럽에 오셨습니다. 환영합니다.
    if count == 1:
        company = df.loc[i]['회사명']
        f_company.append(company)
        count += 1
        
    # else: 
    #     if count == 7:
    #         company == df.loc[i]['회사명']
    #         f_safe.append(company)
    #         count += 1

# %%
# f_company = [] # 한계기업을 저장하는 리스트
# f_safe = []
# fs_company = []
# s_count = 0
# s_company = 'o'

# for i in range(len(df)):
#     if s_company == df.loc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if s_count == 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df.iloc[i]['이자보상배율'] > 1:
#                 f_company_x.append(company)
#                 count = 0
#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#             continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue
    
#     if s_company == df.loc[i]['회사명']:
#         if s_count < 2:
#             f_safe.append(s_company)
#             s_count = 0
#         continue
    
#     if df.loc[i]['이자보상배율'] < 1:
#         s_count += 1
#     else:
#         s_count += 
        
#     if s_count == 2:
#         s_company = df.loc[i]['회사명']
#         f_company.append(s_company)
#         s_count += 1

# %%
# # 현재 데이터 기준으로 한계기업과 4년 연속 이.보.배 1 미만인 기업을 찾을 겁니다

# f_company_1 = [] # 한계기업을 저장하는 리스트
# f_company_x_1 = [] # 4년 연속 이자보상배율 1 미만인 기업 삽입
# count_1 = 0 # 한계기업 카운트용
# company_1 = 'x' # 한계기업 기록용

# # 이거도 csv 한바퀴 돌립니다
# for i in range(0, len(df_2)-1):

#     # 회사명이 이미 기록된 상태에서 또 중복으로 적을 필요는 없습니다
#     if company_1 == df_2.iloc[i]['회사명']:
#         # 다만 그 기업이 한계기업인데
#         if count > 3:
#             # 어머? 4년 연속이네요? 기록!!!
#             if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#                 f_company_x_1.append(company_1)
#                 count = 0

#                 # 반복문에서 볼일 다 끝났으니 통과합니다
#                 continue
        
#         # 그게 아니라면 반복문을 통과합니다
#         continue

#     # 이자보상배율이 1 미만인 경우 카운트를 늘립니다
#     if df_2.iloc[i]['이자보상배율(이자비용)(IFRS연결)'] < 1:
#             count += 1
#     # 도중에 이자보상배율이 1 미만이면 탈출합니다
#     else:
#         count = 0

#     # 한계 기업 클럽에 오셨습니다. 환영합니다.
#     if count == 3:
#         company_1 = df_2.iloc[i]['회사명']
#         f_company_1.append(company_1)
#         count += 1

# %%
# 분명히 이거보다 더 좋은 방법이 있을건데
# 맷돌이 굴러가질 않네요

# 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
df_3 = df.isin(f_company)
df_3
# Out:
#         회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  매출액증가율  \
# 0      True  False  False   False   False    False    False    False   False
# 1      True  False  False   False   False    False    False    False   False
# 2      True  False  False   False   False    False    False    False   False
# 3      True  False  False   False   False    False    False    False   False
# 4      True  False  False   False   False    False    False    False   False
# ...     ...    ...    ...     ...     ...      ...      ...      ...     ...
# 14175  True  False  False   False   False    False    False    False   False
# 14176  True  False  False   False   False    False    False    False   False
# 14177  True  False  False   False   False    False    False    False   False
# 14178  True  False  False   False   False    False    False    False   False
# 14179  True  False  False   False   False    False    False    False   False
#
#        매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0        False    False     False     False     False    False   False
# 1        False    False     False     False     False    False   False
# 2        False    False     False     False     False    False   False
# 3        False    False     False     False     False    False   False
# 4        False    False     False     False     False    False   False
# ...        ...      ...       ...       ...       ...      ...     ...
# 14175    False    False     False     False     False    False   False
# 14176    False    False     False     False     False    False   False
# 14177    False    False     False     False     False    False   False
# 14178    False    False     False     False     False    False   False
# 14179    False    False     False     False     False    False   False
#
#        재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        False    False    False    False    False    False    False
# 1        False    False    False    False    False    False    False
# 2        False    False    False    False    False    False    False
# 3        False    False    False    False    False    False    False
# 4        False    False    False    False    False    False    False
# ...        ...      ...      ...      ...      ...      ...      ...
# 14175    False    False    False    False    False    False    False
# 14176    False    False    False    False    False    False    False
# 14177    False    False    False    False    False    False    False
# 14178    False    False    False    False    False    False    False
# 14179    False    False    False    False    False    False    False
#
#        순운전자본회전율   유동비율   당좌비율   현금비율   부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0         False  False  False  False  False   False             False
# 1         False  False  False  False  False   False             False
# 2         False  False  False  False  False   False             False
# 3         False  False  False  False  False   False             False
# 4         False  False  False  False  False   False             False
# ...         ...    ...    ...    ...    ...     ...               ...
# 14175     False  False  False  False  False   False             False
# 14176     False  False  False  False  False   False             False
# 14177     False  False  False  False  False   False             False
# 14178     False  False  False  False  False   False             False
# 14179     False  False  False  False  False   False             False
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                  False              False     False     False     False
# 1                  False              False     False     False     False
# 2                  False              False     False     False     False
# 3                  False              False     False     False     False
# 4                  False              False     False     False     False
# ...                  ...                ...       ...       ...       ...
# 14175              False              False     False     False     False
# 14176              False              False     False     False     False
# 14177              False              False     False     False     False
# 14178              False              False     False     False     False
# 14179              False              False     False     False     False
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0              False   False     False          False           False
# 1              False   False     False          False           False
# 2              False   False     False          False           False
# 3              False   False     False          False           False
# 4              False   False     False          False           False
# ...              ...     ...       ...            ...             ...
# 14175          False   False     False          False           False
# 14176          False   False     False          False           False
# 14177          False   False     False          False           False
# 14178          False   False     False          False           False
# 14179          False   False     False          False           False
#
#        순운전자본비율  노동장비율  기계장비율  자본집약도  설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0        False  False  False  False   False    False  False       False
# 1        False  False  False  False   False    False  False       False
# 2        False  False  False  False   False    False  False       False
# 3        False  False  False  False   False    False  False       False
# 4        False  False  False  False   False    False  False       False
# ...        ...    ...    ...    ...     ...      ...    ...         ...
# 14175    False  False  False  False   False    False  False       False
# 14176    False  False  False  False   False    False  False       False
# 14177    False  False  False  False   False    False  False       False
# 14178    False  False  False  False   False    False  False       False
# 14179    False  False  False  False   False    False  False       False
#
# [14180 rows x 48 columns]

# %%
dd = df.isin(f_safe)
dd
# Out:
#          회사명  거래소코드   회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  매출액증가율  \
# 0      False  False  False   False   False    False    False    False   False
# 1      False  False  False   False   False    False    False    False   False
# 2      False  False  False   False   False    False    False    False   False
# 3      False  False  False   False   False    False    False    False   False
# 4      False  False  False   False   False    False    False    False   False
# ...      ...    ...    ...     ...     ...      ...      ...      ...     ...
# 14175  False  False  False   False   False    False    False    False   False
# 14176  False  False  False   False   False    False    False    False   False
# 14177  False  False  False   False   False    False    False    False   False
# 14178  False  False  False   False   False    False    False    False   False
# 14179  False  False  False   False   False    False    False    False   False
#
#        매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0        False    False     False     False     False    False   False
# 1        False    False     False     False     False    False   False
# 2        False    False     False     False     False    False   False
# 3        False    False     False     False     False    False   False
# 4        False    False     False     False     False    False   False
# ...        ...      ...       ...       ...       ...      ...     ...
# 14175    False    False     False     False     False    False   False
# 14176    False    False     False     False     False    False   False
# 14177    False    False     False     False     False    False   False
# 14178    False    False     False     False     False    False   False
# 14179    False    False     False     False     False    False   False
#
#        재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        False    False    False    False    False    False    False
# 1        False    False    False    False    False    False    False
# 2        False    False    False    False    False    False    False
# 3        False    False    False    False    False    False    False
# 4        False    False    False    False    False    False    False
# ...        ...      ...      ...      ...      ...      ...      ...
# 14175    False    False    False    False    False    False    False
# 14176    False    False    False    False    False    False    False
# 14177    False    False    False    False    False    False    False
# 14178    False    False    False    False    False    False    False
# 14179    False    False    False    False    False    False    False
#
#        순운전자본회전율   유동비율   당좌비율   현금비율   부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0         False  False  False  False  False   False             False
# 1         False  False  False  False  False   False             False
# 2         False  False  False  False  False   False             False
# 3         False  False  False  False  False   False             False
# 4         False  False  False  False  False   False             False
# ...         ...    ...    ...    ...    ...     ...               ...
# 14175     False  False  False  False  False   False             False
# 14176     False  False  False  False  False   False             False
# 14177     False  False  False  False  False   False             False
# 14178     False  False  False  False  False   False             False
# 14179     False  False  False  False  False   False             False
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                  False              False     False     False     False
# 1                  False              False     False     False     False
# 2                  False              False     False     False     False
# 3                  False              False     False     False     False
# 4                  False              False     False     False     False
# ...                  ...                ...       ...       ...       ...
# 14175              False              False     False     False     False
# 14176              False              False     False     False     False
# 14177              False              False     False     False     False
# 14178              False              False     False     False     False
# 14179              False              False     False     False     False
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0              False   False     False          False           False
# 1              False   False     False          False           False
# 2              False   False     False          False           False
# 3              False   False     False          False           False
# 4              False   False     False          False           False
# ...              ...     ...       ...            ...             ...
# 14175          False   False     False          False           False
# 14176          False   False     False          False           False
# 14177          False   False     False          False           False
# 14178          False   False     False          False           False
# 14179          False   False     False          False           False
#
#        순운전자본비율  노동장비율  기계장비율  자본집약도  설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0        False  False  False  False   False    False  False       False
# 1        False  False  False  False   False    False  False       False
# 2        False  False  False  False   False    False  False       False
# 3        False  False  False  False   False    False  False       False
# 4        False  False  False  False   False    False  False       False
# ...        ...    ...    ...    ...     ...      ...    ...         ...
# 14175    False  False  False  False   False    False  False       False
# 14176    False  False  False  False   False    False  False       False
# 14177    False  False  False  False   False    False  False       False
# 14178    False  False  False  False   False    False  False       False
# 14179    False  False  False  False   False    False  False       False
#
# [14180 rows x 48 columns]

# %%
# # 분명히 이거보다 더 좋은 방법이 있을건데
# # 맷돌이 굴러가질 않네요

# # 이건 f_company 리스트에 들어잇는 데이터와 일치하면 True, 아니면 False를 반환합니다
# df_4 = df_2.isin(f_company_1)
# df_4

# %%
df_5 = [] # 임시 저장용 리스트

# 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
for i in range(0, len(df_3)-1):
    if df_3.iloc[i]["회사명"] == True:
        df_5.append(df.loc[i])
        
df_5_frame = pd.DataFrame(df_5).reset_index(drop=True)

# %%
# 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

df_6 = df.isin(f_company_x)
df_7 = []

for i in range(0, len(df_6)-1):
    if df_6.iloc[i]["회사명"] == True:
        df_7.append(df.loc[i])

df_7_frame = pd.DataFrame(df_7).reset_index(drop=True)

# %%
# df_8 = df_5_frame.isin()
# df_9 = []

# for i in range(0, len(dd)-1):
#     if dd.iloc[i]["회사명"] == False:
#         df_9.append(df.loc[i])

# df_9_frame = pd.DataFrame(df_9).reset_index(drop=True)

# %%
# df_8 = [] # 임시 저장용 리스트

# # 그렇게 만든 데이터프레임을 기존과 비교해서 True인 애들만 뽑아옵니다
# for i in range(0, len(df_4)-1):
#     if df_4.iloc[i]["회사명"] == True:
#         df_8.append(df_2.loc[i])
        
# df_8_frame = pd.DataFrame(df_8).reset_index(drop=True)

# %%
# # 4년 연속 이자 보상 배율이 1 미만인 기업들도 똑같이 해봅니다

# df_9 = df_1.isin(f_company_x_1)
# df_10 = []

# for i in range(0, len(df_9)-1):
#     if df_9.iloc[i]["회사명"] == True:
#         df_10.append(df_2.loc[i])

# df_10_frame = pd.DataFrame(df_10).reset_index(drop=True)

# %%
# c = df_5_frame.copy()
# df['회계년도'] = pd.to_datetime(df['회계년도'], format='%d-%b').dt.strftime('20%d-%m')
# 거래소 코드 6자리가 아닌 것들은 6자리가 될 때까지 앞에 0 추가
dd['거래소코드'] = dd['거래소코드'].astype(str).str.zfill(6)

# %%
dd
# Out:
#          회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      CMG제약  058820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1      CMG제약  058820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2      CMG제약  058820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3      CMG제약  058820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4      CMG제약  058820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...      ...     ...      ...     ...     ...      ...      ...      ...
# 14688   흥아해운  003280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 14689   흥아해운  003280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 14690   흥아해운  003280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 14691   흥아해운  003280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
# 14692   흥아해운  003280  2019-12   -0.55  -46.38   -51.51   -13.42   -57.73
#
#        매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  \
# 0       56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58
# 1       -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78
# 2       25.51    38.70     1.45      0.74      1.40      3.88     0.52
# 3       11.52    37.07     0.69      0.32      0.78      1.94     0.28
# 4       18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37
# ...       ...      ...      ...       ...       ...       ...      ...
# 14688    2.42     6.20     1.24      6.18      2.95      2.51     1.46
# 14689   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96
# 14690    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13
# 14691   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47
# 14692  -86.45     5.54   -50.27    -98.70     -2.00    -12.10    -8.32
#
#        총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        0.66     3.74     2.29     1.77    11.95     0.97     2.01     1.25
# 1        0.39     4.09     1.75     1.71     7.83     0.66     0.93     0.52
# 2        0.36     3.30     2.02     2.03     6.20     0.51     1.26     0.48
# 3        0.40     3.00     1.85     1.54     5.27     0.46     2.85     0.68
# 4        0.47     3.32     2.09     1.48     5.66     0.56     2.88     0.99
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 14688    1.17    64.23    17.20     2.09    16.05     4.96     1.54     5.83
# 14689    0.95    53.94    17.35     1.44    16.26     4.55     1.20     6.98
# 14690    0.93    43.17    15.61     1.36    15.39     5.41     1.12     7.68
# 14691    0.91    39.24    12.79     1.43    11.87     7.93     1.03     6.73
# 14692    0.17     7.28     2.86     0.28     2.41     1.96     0.18     1.01
#
#        순운전자본회전율    유동비율    당좌비율    현금비율     부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0          4.61  200.97  165.03   15.10    51.41    7.32            -46.08
# 1          0.81  693.49  649.98   68.81    80.77    0.18             -8.10
# 2          1.25  694.71  610.74  394.63    14.11    0.00            -39.85
# 3          2.32  324.58  268.23  101.24    18.50    0.01            -17.73
# 4          3.10  296.85  235.21   29.00    20.78    0.01             16.12
# ...         ...     ...     ...     ...      ...     ...               ...
# 14688    -13.39   51.92   47.54    7.76   357.39   24.52              2.78
# 14689    -10.62   39.46   32.52    5.46   397.97   19.03              2.12
# 14690     -8.05   35.76   29.58    6.17   626.32   22.90             -0.57
# 14691     -7.39   34.67   28.66    4.89   998.73   22.24             -2.78
# 14692     -1.88   46.36   42.55    6.75  1293.83   18.36             -5.73
#
#        CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 14688               2.03               8.85     21.86     15.76     17.21
# 14689               1.96               8.92     20.08      8.78     10.65
# 14690              -0.50              -2.13     13.77     11.27     13.63
# 14691              -2.70             -11.38      9.10     11.14     13.48
# 14692             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 14688          60.44  151.66     78.14           8.43           -9.10
# 14689          68.73  134.41     79.92          17.60          -11.47
# 14690          65.00  276.77     86.23          17.27           -9.61
# 14691          59.32  427.21     90.90          17.36           -9.21
# 14692          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 14688   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 14689   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 14690   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 14691   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 14692   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인당부가가치
# 0        25719.78
# 1         2009.78
# 2        51433.09
# 3        43056.95
# 4        27662.63
# ...           ...
# 14688   127665.82
# 14689   111774.30
# 14690    50024.18
# 14691    42782.54
# 14692    39428.47
#
# [14693 rows x 48 columns]

# %%
# 회계년도가 12월이 아닌 행 리스트 생성
not_dec_list = dd[~dd.loc[:,'회계년도'].str.endswith('12')].index.tolist()
not_dec_list
# Out:
# [122,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  817,
#  1739,
#  1740,
#  1741,
#  1742,
#  1743,
#  1744,
#  1745,
#  1746,
#  1747,
#  1878,
#  1879,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2158,
#  2268,
#  2269,
#  2270,
#  2271,
#  2272,
#  2273,
#  2274,
#  2277,
#  2278,
#  2279,
#  2280,
#  2281,
#  2282,
#  2283,
#  2284,
#  2285,
#  2286,
#  2287,
#  2288,
#  2289,
#  2290,
#  2291,
#  2292,
#  2293,
#  2410,
#  2411,
#  2412,
#  2413,
#  2414,
#  2415,
#  2416,
#  2417,
#  2418,
#  2852,
#  2853,
#  2854,
#  2855,
#  2856,
#  2857,
#  2858,
#  2859,
#  2860,
#  2959,
#  2960,
#  3218,
#  3219,
#  3220,
#  3221,
#  3522,
#  3523,
#  3524,
#  3525,
#  3526,
#  3527,
#  3528,
#  3529,
#  3530,
#  3592,
#  3593,
#  3594,
#  3595,
#  3596,
#  3713,
#  3847,
#  3848,
#  3849,
#  3850,
#  3851,
#  3852,
#  3853,
#  3854,
#  3855,
#  4843,
#  4844,
#  4845,
#  4846,
#  4847,
#  4848,
#  4849,
#  4850,
#  4851,
#  4981,
#  4982,
#  4983,
#  4984,
#  5380,
#  5492,
#  5493,
#  5494,
#  5495,
#  5496,
#  5497,
#  5498,
#  5725,
#  5726,
#  5727,
#  5728,
#  5729,
#  5730,
#  5731,
#  5732,
#  5733,
#  5853,
#  5854,
#  5943,
#  5944,
#  5945,
#  5946,
#  5947,
#  5948,
#  5949,
#  5950,
#  5951,
#  6194,
#  6221,
#  6370,
#  6371,
#  6372,
#  6373,
#  6551,
#  6552,
#  6553,
#  6554,
#  6555,
#  6556,
#  6557,
#  6558,
#  6559,
#  7641,
#  7642,
#  7643,
#  7891,
#  7892,
#  7893,
#  7894,
#  7895,
#  7947,
#  7948,
#  7949,
#  7950,
#  7951,
#  7952,
#  7953,
#  7954,
#  7955,
#  8066,
#  8067,
#  8610,
#  8611,
#  8612,
#  8613,
#  8614,
#  8615,
#  8616,
#  8617,
#  8618,
#  9169,
#  9187,
#  9188,
#  9189,
#  9190,
#  9218,
#  9219,
#  9220,
#  9221,
#  9222,
#  9223,
#  9281,
#  9282,
#  9283,
#  9284,
#  9285,
#  9286,
#  9287,
#  9288,
#  9289,
#  9402,
#  9403,
#  9404,
#  9405,
#  9410,
#  9411,
#  9453,
#  9454,
#  9455,
#  9456,
#  9457,
#  9458,
#  9459,
#  9460,
#  9461,
#  9537,
#  9538,
#  9539,
#  9540,
#  9541,
#  9542,
#  9543,
#  9544,
#  9545,
#  9964,
#  9965,
#  9966,
#  9967,
#  9968,
#  9969,
#  9970,
#  9971,
#  9972,
#  10285,
#  10286,
#  10287,
#  10288,
#  10289,
#  10290,
#  10291,
#  10292,
#  10293,
#  10454,
#  10455,
#  10456,
#  10457,
#  10508,
#  11270,
#  11271,
#  11272,
#  11273,
#  11274,
#  11275,
#  11276,
#  11277,
#  11278,
#  11473,
#  11474,
#  11475,
#  11476,
#  11477,
#  11478,
#  11479,
#  11480,
#  11481,
#  11682,
#  11683,
#  11684,
#  11685,
#  11686,
#  11687,
#  11688,
#  11716,
#  12582,
#  12601,
#  12602,
#  12603,
#  12604,
#  12605,
#  12606,
#  12735,
#  12736,
#  12737,
#  12738,
#  12739,
#  13819,
#  13820,
#  14003,
#  14004,
#  14005,
#  14006,
#  14007,
#  14008,
#  14009,
#  14010,
#  14011,
#  14039,
#  14046,
#  14047,
#  14048,
#  14219,
#  14220,
#  14221,
#  14222,
#  14223,
#  14224,
#  14225,
#  14226,
#  14227,
#  14490,
#  14491,
#  14492,
#  14493,
#  14494,
#  14495,
#  14496,
#  14497,
#  14498,
#  14575,
#  14576,
#  14577,
#  14578,
#  14579,
#  14580,
#  14581,
#  14638,
#  14639,
#  14640,
#  14641,
#  14642,
#  14643,
#  14644,
#  14645,
#  14646]

# %%
# # 회계년도가 12월이 아닌 행 제거
print(dd.shape)
dd.drop(dd.index[not_dec_list], inplace=True)
dd.reset_index(drop=True, inplace=True)
print(dd.shape)
# Out:
# (14693, 48)
# (14336, 48)

# %%
# # 거래소코드가 9로 시작하는 기업
code_nine_list = dd['회사명'][dd['거래소코드'].astype(str).str.startswith('9')].unique()
code_nine_list
# Out:
# array(['엑세스바이오인코퍼레이션', '글로벌에스엠테크리미티드', '로스웰인터내셔널유한회사', '애머릿지코퍼레이션',
#        '엘브이엠씨홀딩스', '오가닉티코스메틱스홀딩스컴퍼니리미티드', '윙입푸드홀딩스',
#        '이스트아시아홀딩스인베스트먼트리미티드', '잉글우드랩', '차이나크리스탈신소재홀딩스', '컬러레이홀딩스',
#        '케이만금세기차륜집단유한공사', '코오롱티슈진', '헝셩그룹유한회사'], dtype=object)

# %%
# # 거래소코드가 9로 시작하는 기업 제거
dd = dd[~dd['회사명'].isin(code_nine_list)]
dd = dd.reset_index(drop=True)
print(dd.shape)
# Out:
# (14254, 48)

# %%
# # 기업 기록이 하나인 기업
single_rows = dd['회사명'].value_counts() < 2
single_rows[single_rows]
# Out:
# 한화시스템          True
# 그린플러스          True
# 현대에너지솔루션       True
# 현대오토에버         True
# 미디어젠           True
#                ...
# 센트랄모텍          True
# 브릿지바이오테라퓨틱스    True
# 수젠텍            True
# 슈프리마아이디        True
# 코윈테크           True
# Name: 회사명, Length: 74, dtype: bool

# %%
# # 기업 기록이 하나인 기업 제거
dd = dd[~dd['회사명'].isin(single_rows[single_rows].index)]
dd.reset_index(drop=True, inplace=True)
print(dd.shape)
# Out:
# (14180, 48)

# %%
dd['이자보상배율'] = dd['이자보상배율'].fillna(12547896.63)

# %%
dd.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 이자보상배율                0
# 총자산증가율               24
# 유형자산증가율              24
# 유동자산증가율              24
# 자기자본증가율              24
# 매출액증가율               23
# 매출액총이익율              10
# 매출액순이익율              10
# 자기자본순이익율             24
# 총자본영업이익율              5
# 매출액영업이익률              0
# 총자본순이익률              24
# 총자본회전율               23
# 재고자산회전율              23
# 매출채권회전율              23
# 유형자산회전율              23
# 매입채무회전율              23
# 자기자본회전율              23
# 타인자본회전율              23
# 유동자산회전율              23
# 순운전자본회전율             10
# 유동비율                 10
# 당좌비율                 10
# 현금비율                 10
# 부채비율                 10
# 차입금의존도                0
# CASH_FLOW_대_부채비율      0
# CASH_FLOW_대_매출액비율     0
# CASH_FLOW_대_차입금비율     4
# 자기자본구성비율             10
# 당좌자산구성비율             10
# 유동자산구성비율             10
# 매출채권_대_매입채무비율        12
# 유동부채비율               10
# 타인자본구성비율             10
# 재고자산_대_유동자산비율        10
# 재고자산_대_순운전자본비율        0
# 순운전자본비율              10
# 노동장비율                20
# 기계장비율                20
# 자본집약도                 0
# 설비투자효율                0
# 총자본투자효율               0
# 부가가치율                 0
# 종업원1인당부가가치           10
# dtype: int64

# %%
dd['이자보상배율'] = dd['이자보상배율'].replace(7777,np.nan)
maxi = lambda x: x.fillna(x.max())
dd['이자보상배율'] = dd['이자보상배율'].groupby(dd['회사명']).apply(maxi)
dd.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 이자보상배율               79
# 총자산증가율               24
# 유형자산증가율              24
# 유동자산증가율              24
# 자기자본증가율              24
# 매출액증가율               23
# 매출액총이익율              10
# 매출액순이익율              10
# 자기자본순이익율             24
# 총자본영업이익율              5
# 매출액영업이익률              0
# 총자본순이익률              24
# 총자본회전율               23
# 재고자산회전율              23
# 매출채권회전율              23
# 유형자산회전율              23
# 매입채무회전율              23
# 자기자본회전율              23
# 타인자본회전율              23
# 유동자산회전율              23
# 순운전자본회전율             10
# 유동비율                 10
# 당좌비율                 10
# 현금비율                 10
# 부채비율                 10
# 차입금의존도                0
# CASH_FLOW_대_부채비율      0
# CASH_FLOW_대_매출액비율     0
# CASH_FLOW_대_차입금비율     4
# 자기자본구성비율             10
# 당좌자산구성비율             10
# 유동자산구성비율             10
# 매출채권_대_매입채무비율        12
# 유동부채비율               10
# 타인자본구성비율             10
# 재고자산_대_유동자산비율        10
# 재고자산_대_순운전자본비율        0
# 순운전자본비율              10
# 노동장비율                20
# 기계장비율                20
# 자본집약도                 0
# 설비투자효율                0
# 총자본투자효율               0
# 부가가치율                 0
# 종업원1인당부가가치           10
# dtype: int64

# %%
dd['이자보상배율'] = dd['이자보상배율'].fillna(12547896.63)

# %%
mins = lambda x: x.fillna(x.min())
dd['이자보상배율'] = dd['이자보상배율'].replace(-7777,np.nan)
dd['이자보상배율'] = dd['이자보상배율'].groupby(dd['회사명']).apply(mins)
dd.isna().sum()
# Out:
# 회사명                   0
# 거래소코드                 0
# 회계년도                  0
# 이자보상배율               57
# 총자산증가율               24
# 유형자산증가율              24
# 유동자산증가율              24
# 자기자본증가율              24
# 매출액증가율               23
# 매출액총이익율              10
# 매출액순이익율              10
# 자기자본순이익율             24
# 총자본영업이익율              5
# 매출액영업이익률              0
# 총자본순이익률              24
# 총자본회전율               23
# 재고자산회전율              23
# 매출채권회전율              23
# 유형자산회전율              23
# 매입채무회전율              23
# 자기자본회전율              23
# 타인자본회전율              23
# 유동자산회전율              23
# 순운전자본회전율             10
# 유동비율                 10
# 당좌비율                 10
# 현금비율                 10
# 부채비율                 10
# 차입금의존도                0
# CASH_FLOW_대_부채비율      0
# CASH_FLOW_대_매출액비율     0
# CASH_FLOW_대_차입금비율     4
# 자기자본구성비율             10
# 당좌자산구성비율             10
# 유동자산구성비율             10
# 매출채권_대_매입채무비율        12
# 유동부채비율               10
# 타인자본구성비율             10
# 재고자산_대_유동자산비율        10
# 재고자산_대_순운전자본비율        0
# 순운전자본비율              10
# 노동장비율                20
# 기계장비율                20
# 자본집약도                 0
# 설비투자효율                0
# 총자본투자효율               0
# 부가가치율                 0
# 종업원1인당부가가치           10
# dtype: int64

# %%
dd['이자보상배율'] = dd['이자보상배율'].replace(12547896.63,np.nan)
dd.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 이자보상배율               142
# 총자산증가율                24
# 유형자산증가율               24
# 유동자산증가율               24
# 자기자본증가율               24
# 매출액증가율                23
# 매출액총이익율               10
# 매출액순이익율               10
# 자기자본순이익율              24
# 총자본영업이익율               5
# 매출액영업이익률               0
# 총자본순이익률               24
# 총자본회전율                23
# 재고자산회전율               23
# 매출채권회전율               23
# 유형자산회전율               23
# 매입채무회전율               23
# 자기자본회전율               23
# 타인자본회전율               23
# 유동자산회전율               23
# 순운전자본회전율              10
# 유동비율                  10
# 당좌비율                  10
# 현금비율                  10
# 부채비율                  10
# 차입금의존도                 0
# CASH_FLOW_대_부채비율       0
# CASH_FLOW_대_매출액비율      0
# CASH_FLOW_대_차입금비율      4
# 자기자본구성비율              10
# 당좌자산구성비율              10
# 유동자산구성비율              10
# 매출채권_대_매입채무비율         12
# 유동부채비율                10
# 타인자본구성비율              10
# 재고자산_대_유동자산비율         10
# 재고자산_대_순운전자본비율         0
# 순운전자본비율               10
# 노동장비율                 20
# 기계장비율                 20
# 자본집약도                  0
# 설비투자효율                 0
# 총자본투자효율                0
# 부가가치율                  0
# 종업원1인당부가가치            10
# dtype: int64

# %%
dd.to_csv('다제거후이보배결측치보기.csv',encoding='cp949',index=False)

# %%
# c.isna().sum()

# %%
# df_5_frame.to_csv('3년연속성한계기업.csv',index=False,encoding='cp949')

# %%
# a.to_csv('3년연속한계기업.csv',index=False,encoding='cp949')

# %%
# df_7_frame.to_csv('4년째연속성나락간기업.csv',index=False,encoding='cp949')

# %%
# b.to_csv('4년째나락간기업.csv',index=False,encoding='cp949')

# %%
# pd.options.display.max_columns = None

# %%
# 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
a = df_5_frame.copy()
# a = a.reset_index(drop=True)
a
# Out:
#         회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1     CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2     CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3     CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4     CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...     ...    ...      ...     ...     ...      ...      ...      ...
# 8853   흥아해운   3280  2014-12    1.12   13.69    45.19   -13.68     7.76
# 8854   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 8855   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 8856   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 8857   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 1      -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78    0.39
# 2      25.51    38.70     1.45      0.74      1.40      3.88     0.52    0.36
# 3      11.52    37.07     0.69      0.32      0.78      1.94     0.28    0.40
# 4      18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37    0.47
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 8853    7.17     5.61     2.22     11.37      3.04      2.25     3.01    1.35
# 8854    2.42     6.20     1.24      6.18      2.95      2.51     1.46    1.17
# 8855   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96    0.95
# 8856    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13    0.93
# 8857   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47    0.91
#
#       재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  순운전자본회전율  \
# 0        3.74     2.29     1.77    11.95     0.97     2.01     1.25      4.61
# 1        4.09     1.75     1.71     7.83     0.66     0.93     0.52      0.81
# 2        3.30     2.02     2.03     6.20     0.51     1.26     0.48      1.25
# 3        3.00     1.85     1.54     5.27     0.46     2.85     0.68      2.32
# 4        3.32     2.09     1.48     5.66     0.56     2.88     0.99      3.10
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 8853    56.41    14.83     3.02    17.07     5.11     1.84     4.98    -20.19
# 8854    64.23    17.20     2.09    16.05     4.96     1.54     5.83    -13.39
# 8855    53.94    17.35     1.44    16.26     4.55     1.20     6.98    -10.62
# 8856    43.17    15.61     1.36    15.39     5.41     1.12     7.68     -8.05
# 8857    39.24    12.79     1.43    11.87     7.93     1.03     6.73     -7.39
#
#         유동비율    당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0     200.97  165.03   15.10   51.41    7.32            -46.08
# 1     693.49  649.98   68.81   80.77    0.18             -8.10
# 2     694.71  610.74  394.63   14.11    0.00            -39.85
# 3     324.58  268.23  101.24   18.50    0.01            -17.73
# 4     296.85  235.21   29.00   20.78    0.01             16.12
# ...      ...     ...     ...     ...     ...               ...
# 8853   65.25   59.64    8.09  287.83   29.09              2.84
# 8854   51.92   47.54    7.76  357.39   24.52              2.78
# 8855   39.46   32.52    5.46  397.97   19.03              2.12
# 8856   35.76   29.58    6.17  626.32   22.90             -0.57
# 8857   34.67   28.66    4.89  998.73   22.24             -2.78
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 1                -12.71           -2066.51     55.32     77.32     82.49
# 2                -13.51               0.00     87.63     60.08     68.34
# 3                 -7.06          -29481.93     84.39     40.28     48.74
# 4                  5.80           24988.83     82.80     36.82     46.47
# ...                 ...                ...       ...       ...       ...
# 8853               1.66               7.23     25.78     21.60     23.63
# 8854               2.03               8.85     21.86     15.76     17.21
# 8855               1.96               8.92     20.08      8.78     10.65
# 8856              -0.50              -2.13     13.77     11.27     13.63
# 8857              -2.70             -11.38      9.10     11.14     13.48
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 1            323.41   21.50     44.68           6.27            7.33    70.60
# 2            282.72   11.23     12.37          12.09           14.12    58.50
# 3            285.31   17.79     15.61          17.36           25.09    33.72
# 4            254.69   18.91     17.20          20.77           31.32    30.82
# ...             ...     ...       ...            ...             ...      ...
# 8853          66.36  140.48     74.22           8.60          -16.14   -12.59
# 8854          60.44  151.66     78.14           8.43           -9.10   -15.94
# 8855          68.73  134.41     79.92          17.60          -11.47   -16.34
# 8856          65.00  276.77     86.23          17.27           -9.61   -24.48
# 8857          59.32  427.21     90.90          17.36           -9.21   -25.40
#
#           노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0      71726.36  29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 1      69458.82  32002.75   426.18            0     0.47   1.66     2009.78
# 2      66012.04  33789.62   411.12  77.91470318    12.51  34.29    51433.09
# 3     113899.65  48479.94   354.08  37.80253285    12.16  31.04    43056.95
# 4     114246.59  53386.77   362.39            0     7.63  15.96    27662.63
# ...         ...       ...      ...          ...      ...    ...         ...
# 8853  428397.42     15.32   859.92  27.87566308    13.89  10.93   119418.62
# 8854  593960.16     14.23   973.73  21.49400366    13.11  12.28   127665.82
# 8855  706868.14     12.28  1017.55  15.81260955    10.98  12.66   111774.30
# 8856  599097.86     12.56   921.78  8.349918093     5.43   5.51    50024.18
# 8857  618981.48     14.54  1009.67            0     4.24   4.52    42782.54
#
# [8858 rows x 48 columns]

# %%
a.drop_duplicates('회사명')
# Out:
#             회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0      (주)CMG제약  058820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 9      (주)DB하이텍  000990  2011-12   -0.75  -13.19    -7.89   -10.08   -22.60
# 18      (주)ES큐브  050120  2011-12 -245.99   12.78    27.82     3.83    -7.92
# 27     (주)HJ중공업  097230  2011-12    0.55   -6.49    -1.53   -13.26    -4.55
# 36     (주)MH에탄올  023150  2011-12    0.12   -0.49     2.92    -0.67    -8.49
# ...         ...     ...      ...     ...     ...      ...      ...      ...
# 9096  휴림네트웍스(주)  192410  2014-12    3.38  -97.97   -99.71   -89.96   -93.71
# 9102    휴림로봇(주)  090710  2011-12    2.96   35.07    27.83    38.25    37.53
# 9111    휴마시스(주)  205470  2014-12   -0.76     NaN      NaN      NaN      NaN
# 9117    흥구석유(주)  024060  2011-12   10.35   -1.97    -5.85    -5.49     2.09
# 9126    흥아해운(주)  003280  2011-12   -0.33   -3.13    -0.34   -15.59   -17.19
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 9     -10.94    16.62   -17.74    -27.74     -3.34     -7.81    -7.59    0.43
# 18     21.63    27.92    -8.99    -11.72     -6.98     -6.84    -9.17    1.02
# 27     -8.72     7.85    -3.35     -5.07      1.48      3.73    -1.33    0.40
# 36    -18.64    16.81    -9.73     -9.76      0.45      1.35    -3.24    0.33
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 9096  -97.39    18.57    10.44      1.79      0.00      0.00     0.56    0.05
# 9102   58.70    25.26     2.63      6.24      4.12      3.82     2.84    1.08
# 9111     NaN      NaN      NaN       NaN      0.00      0.00      NaN     NaN
# 9117    8.12     3.71     0.76      3.16      0.00      0.00     2.60    3.42
# 9126   12.78     2.54    -2.95    -16.16     -1.01     -0.80    -3.75    1.27
#
#       재고자산회전율  매출채권회전율  유형자산회전율    매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  \
# 0        3.74     2.29     1.77      11.95     0.97     2.01     1.25
# 9        5.87     5.90     0.70      20.51     1.56     0.59     1.87
# 18       8.12     5.26    13.89      18.08     1.30     4.68     1.60
# 27       8.17     2.95     0.91      10.41     1.51     0.54     1.12
# 36       4.15     4.53     0.60     148.03     1.00     0.50     0.98
# ...       ...      ...      ...        ...      ...      ...      ...
# 9096     0.64     0.57     0.10       0.70     0.17     0.08     0.29
# 9102     4.66     3.11     5.75       4.63     2.37     1.97     1.66
# 9111      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 9117    67.88    24.42     5.64  478766.75     4.17    19.18    15.84
# 9126    49.62    15.13     2.73      16.88     5.47     1.65     4.81
#
#       순운전자본회전율     유동비율     당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0         4.61   200.97   165.03   15.10   51.41    7.32            -46.08
# 9        -2.14    35.20    25.50    5.04  289.22   57.65              5.87
# 18        5.54   230.24   194.35   21.35   41.36    0.18             12.27
# 27      -63.50    96.33    81.81   34.40  276.93   25.45             -0.99
# 36       -2.75    58.36    45.92    5.22  214.54    8.89              2.62
# ...        ...      ...      ...     ...     ...     ...               ...
# 9096      3.43  1288.40  1200.26  496.19    7.13    0.00           5345.94
# 9102     10.51   137.28   103.29   16.59  118.23   31.76              1.77
# 9111       NaN      NaN      NaN     NaN     NaN    0.00              0.00
# 9117     82.69   165.07   132.22   10.82   19.29    0.00              9.95
# 9126    -17.55    62.54    54.80    4.96  368.79   45.86              3.15
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 9                  9.47               7.57     25.69     16.90     23.33
# 18                 3.73            1990.81     70.74     51.85     61.43
# 27                -1.77              -2.86     26.53     28.86     33.99
# 36                 5.35              20.09     31.79     26.78     34.04
# ...                 ...                ...       ...       ...       ...
# 9096             262.60               0.00     93.34     79.89     85.76
# 9102               1.03               3.03     45.82     49.41     65.67
# 9111               0.00               0.00       NaN       NaN       NaN
# 9117               0.47               0.00     83.83     17.00     21.22
# 9126               1.92               5.41     21.33     21.48     24.52
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 9            336.28  257.97     74.31          27.57          -14.97   -42.95
# 18           461.69   37.71     29.26          15.59           27.56    34.75
# 27           132.35  132.98     73.47          15.08         -395.95    -1.29
# 36         81716.41  183.43     68.21          21.31          -29.87   -24.28
# ...             ...     ...       ...            ...             ...      ...
# 9096         129.68    7.13      6.66           6.84            7.42    79.10
# 9102         200.54  104.40     54.18          24.76           91.17    17.83
# 9111            NaN     NaN       NaN            NaN            0.00      NaN
# 9117     1283650.89   15.34     16.17          19.90           50.48     8.37
# 9126          65.47  183.78     78.67          12.38          -20.67   -14.68
#
#            노동장비율      기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인딩부가가치
# 0       71726.36   29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 9      284943.29  596524.90   467.10   29.7816315    18.17  39.45    84860.76
# 18      18201.83    3525.92   234.08            0    21.71  22.56    50819.28
# 27    1121928.55  179602.51  2526.64   15.8107465     7.02  17.09   177385.28
# 36    1474660.69  273673.90  2631.51  11.62281333     6.51  19.52   171397.06
# ...          ...        ...      ...          ...      ...    ...         ...
# 9096    30985.94   52179.00   391.33            0     0.00   0.00        0.00
# 9102    60938.35    2556.50   333.03            0    18.88  20.15    62883.35
# 9111         NaN        NaN     0.00            0     0.00   0.00        0.00
# 9117   351367.02   16970.02   590.33            0     0.00   0.00        0.00
# 9126   364314.78      16.82   771.72            0     6.92   5.37    53433.62
#
# [1134 rows x 48 columns]

# %%
a.to_csv('확인용1년데이터v2.csv',encoding='cp949',index=False)

# %%
df_7_frame.copy()
# Out:
#         회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1     CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2     CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3     CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4     CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...     ...    ...      ...     ...     ...      ...      ...      ...
# 6889   흥아해운   3280  2014-12    1.12   13.69    45.19   -13.68     7.76
# 6890   흥아해운   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 6891   흥아해운   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 6892   흥아해운   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 6893   흥아해운   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# 0      56.40    41.83    -8.50     -8.28      2.37      3.61    -5.58    0.66
# 1      -8.43    28.34   -40.97    -26.84     -9.96    -25.87   -15.78    0.39
# 2      25.51    38.70     1.45      0.74      1.40      3.88     0.52    0.36
# 3      11.52    37.07     0.69      0.32      0.78      1.94     0.28    0.40
# 4      18.85    36.26   -13.50     -7.62     -4.49     -9.51    -6.37    0.47
# ...      ...      ...      ...       ...       ...       ...      ...     ...
# 6889    7.17     5.61     2.22     11.37      3.04      2.25     3.01    1.35
# 6890    2.42     6.20     1.24      6.18      2.95      2.51     1.46    1.17
# 6891   -1.58     4.49    -2.06     -9.40      0.67      0.71    -1.96    0.95
# 6892    0.56     2.09    -8.79    -47.52     -1.45     -1.57    -8.13    0.93
# 6893   -9.87    -0.93   -11.48    -91.08     -4.55     -4.99   -10.47    0.91
#
#       재고자산회전율  매출채권회전율  유형자산회전율  매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  순운전자본회전율  \
# 0        3.74     2.29     1.77    11.95     0.97     2.01     1.25      4.61
# 1        4.09     1.75     1.71     7.83     0.66     0.93     0.52      0.81
# 2        3.30     2.02     2.03     6.20     0.51     1.26     0.48      1.25
# 3        3.00     1.85     1.54     5.27     0.46     2.85     0.68      2.32
# 4        3.32     2.09     1.48     5.66     0.56     2.88     0.99      3.10
# ...       ...      ...      ...      ...      ...      ...      ...       ...
# 6889    56.41    14.83     3.02    17.07     5.11     1.84     4.98    -20.19
# 6890    64.23    17.20     2.09    16.05     4.96     1.54     5.83    -13.39
# 6891    53.94    17.35     1.44    16.26     4.55     1.20     6.98    -10.62
# 6892    43.17    15.61     1.36    15.39     5.41     1.12     7.68     -8.05
# 6893    39.24    12.79     1.43    11.87     7.93     1.03     6.73     -7.39
#
#         유동비율    당좌비율    현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  \
# 0     200.97  165.03   15.10   51.41    7.32            -46.08
# 1     693.49  649.98   68.81   80.77    0.18             -8.10
# 2     694.71  610.74  394.63   14.11    0.00            -39.85
# 3     324.58  268.23  101.24   18.50    0.01            -17.73
# 4     296.85  235.21   29.00   20.78    0.01             16.12
# ...      ...     ...     ...     ...     ...               ...
# 6889   65.25   59.64    8.09  287.83   29.09              2.84
# 6890   51.92   47.54    7.76  357.39   24.52              2.78
# 6891   39.46   32.52    5.46  397.97   19.03              2.12
# 6892   35.76   29.58    6.17  626.32   22.90             -0.57
# 6893   34.67   28.66    4.89  998.73   22.24             -2.78
#
#       CASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                -24.07            -213.61     66.05     46.14     56.18
# 1                -12.71           -2066.51     55.32     77.32     82.49
# 2                -13.51               0.00     87.63     60.08     68.34
# 3                 -7.06          -29481.93     84.39     40.28     48.74
# 4                  5.80           24988.83     82.80     36.82     46.47
# ...                 ...                ...       ...       ...       ...
# 6889               1.66               7.23     25.78     21.60     23.63
# 6890               2.03               8.85     21.86     15.76     17.21
# 6891               1.96               8.92     20.08      8.78     10.65
# 6892              -0.50              -2.13     13.77     11.27     13.63
# 6893              -2.70             -11.38      9.10     11.14     13.48
#
#       매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 0            602.31   42.33     33.95          17.88           35.59    28.23
# 1            323.41   21.50     44.68           6.27            7.33    70.60
# 2            282.72   11.23     12.37          12.09           14.12    58.50
# 3            285.31   17.79     15.61          17.36           25.09    33.72
# 4            254.69   18.91     17.20          20.77           31.32    30.82
# ...             ...     ...       ...            ...             ...      ...
# 6889          66.36  140.48     74.22           8.60          -16.14   -12.59
# 6890          60.44  151.66     78.14           8.43           -9.10   -15.94
# 6891          68.73  134.41     79.92          17.60          -11.47   -16.34
# 6892          65.00  276.77     86.23          17.27           -9.61   -24.48
# 6893          59.32  427.21     90.90          17.36           -9.21   -25.40
#
#           노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  종업원1인당부가가치
# 0      71726.36  29216.43   202.26  35.85819316    12.72  19.56    25719.78
# 1      69458.82  32002.75   426.18            0     0.47   1.66     2009.78
# 2      66012.04  33789.62   411.12  77.91470318    12.51  34.29    51433.09
# 3     113899.65  48479.94   354.08  37.80253285    12.16  31.04    43056.95
# 4     114246.59  53386.77   362.39            0     7.63  15.96    27662.63
# ...         ...       ...      ...          ...      ...    ...         ...
# 6889  428397.42     15.32   859.92  27.87566308    13.89  10.93   119418.62
# 6890  593960.16     14.23   973.73  21.49400366    13.11  12.28   127665.82
# 6891  706868.14     12.28  1017.55  15.81260955    10.98  12.66   111774.30
# 6892  599097.86     12.56   921.78  8.349918093     5.43   5.51    50024.18
# 6893  618981.48     14.54  1009.67            0     4.24   4.52    42782.54
#
# [6894 rows x 48 columns]

# %%
# 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
b = df_7_frame.copy().drop_duplicates(['회사명'])
# b = b.reset_index(drop=True)
b
# Out:
#             회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  058820  2011-12    3.53    1.98    -5.90    17.64   56.40
# 9      (주)DB하이텍  000990  2011-12   -0.75  -13.19    -7.89   -10.08  -10.94
# 18      (주)ES큐브  050120  2011-12 -245.99    0.00     0.00     0.00    0.00
# 27     (주)HJ중공업  097230  2011-12    0.55   -6.49    -1.53   -13.26   -8.72
# 36     (주)MH에탄올  023150  2011-12    0.12   -0.49     2.92    -0.67  -18.64
# ...         ...     ...      ...     ...     ...      ...      ...     ...
# 7042    화천기계(주)  010660  2011-12   68.14    8.08     0.86     6.13   32.84
# 7051  휴림네트웍스(주)  192410  2014-12    3.38   14.27    11.41    15.88   47.11
# 7057    휴림로봇(주)  090710  2011-12    2.96   35.07    27.83    38.25   58.70
# 7066    휴마시스(주)  205470  2014-12   -0.76     NaN      NaN      NaN     NaN
# 7072    흥아해운(주)  003280  2011-12   -0.33   -3.13    -0.34   -15.59   12.78
#
#       재고자산증가율  자기자본증가율  순이익증가율  정상영업이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  \
# 0       -1.43    -2.02    0.00       0.00    41.83    -8.50     -8.28
# 9       -3.28   -22.60    0.00       0.00    16.62   -17.74    -27.74
# 18       0.00     0.00    0.00       0.00    27.92    -8.99    -12.61
# 27      23.47    -4.59    0.00      -9.82     7.85    -3.35     -5.07
# 36      18.30    -8.46    0.00     -82.51    16.81    -9.73     -9.74
# ...       ...      ...     ...        ...      ...      ...       ...
# 7042     8.59    15.18   58.06      52.01    12.36     5.31     16.05
# 7051   -30.43    42.10   64.14      97.48    18.57    10.44     17.79
# 7057    17.70    37.53    6.71      33.90    25.26     2.63      6.24
# 7066      NaN      NaN     NaN        NaN      NaN      NaN       NaN
# 7072    49.62   -17.19    0.00       0.00     2.54    -2.95    -16.16
#
#       총자본정상영업이익율  매출액정상영업이익율  총자본순이익율  총자본회전율  재고자산회전율  매출채권회전율  유형자산회전율  \
# 0           2.37        3.61    -5.58    0.66     6.42     2.45     1.77
# 9          -3.34       -7.81    -7.59    0.43     7.04     6.12     0.70
# 18         -6.58       -6.84    -8.65    0.96    10.05     4.27    12.37
# 27          1.48        3.73    -1.33    0.40     8.86    10.97     0.91
# 36          0.45        1.35    -3.24    0.33     4.99     4.83     0.60
# ...          ...         ...      ...     ...      ...      ...      ...
# 7042       10.46        6.61     8.40    1.58    14.50     4.90     5.07
# 7051       16.55       11.45    15.09    1.45    18.95    21.15    17.96
# 7057        4.12        3.82     2.84    1.08     6.23     3.34     5.75
# 7066         NaN         NaN      NaN     NaN      NaN      NaN      NaN
# 7072       -1.01       -0.80    -3.75    1.27    50.91    27.43     2.73
#
#       매입채무회전율  자기자본회전율  타인자본회전율  유동자산회전율  당좌자산회전률  순운전자본회전률     유동비율     당좌비율  \
# 0       11.95     0.97     2.01     1.25     1.55      0.86   200.97   165.03
# 9       20.51     1.56     0.59     1.87     2.54      0.72    35.20    25.50
# 18      19.72     1.36     3.29     1.57     1.86      1.09   230.24   194.35
# 27      10.41     1.51     0.54     1.12     1.29      0.52    96.33    81.81
# 36     148.03     1.00     0.50     0.98     1.22      0.36    58.36    45.92
# ...       ...      ...      ...      ...      ...       ...      ...      ...
# 7042     6.30     3.02     3.32     2.76     3.41      1.62   143.25   115.68
# 7051    14.79     1.70     9.51     1.70     1.86      1.44  1288.40  1200.26
# 7057     4.63     2.37     1.97     1.66     2.26      0.96   137.28   103.29
# 7066      NaN      NaN      NaN      NaN      NaN       NaN      NaN      NaN
# 7072    16.88     5.47     1.65     4.81     5.31      2.05    62.54    54.80
#
#         현금비율    부채비율  차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율  \
# 0      15.10   51.41    9.08            -46.08             -24.07
# 9       5.04  289.22   59.00              5.87               9.47
# 18     21.35   41.36    0.18              6.82               2.08
# 27     34.40  276.93   48.42             -0.99              -1.77
# 36      5.22  214.54    8.89              2.62               5.35
# ...      ...     ...     ...               ...                ...
# 7042    2.71   85.39   11.87              5.19               1.57
# 7051  496.19    7.13    0.00            416.95              20.48
# 7057   15.15  118.23   31.76              1.77               1.03
# 7066     NaN     NaN     NaN               NaN                NaN
# 7072    4.96  368.79   47.74              3.15               1.92
#
#       CASH_FLOW_대_차입금비율  자기자본구성비율   차입금비율  당좌자산구성비율  유동자산구성비율  매출채권_대_매입채무비율  \
# 0               -172.40     66.05   13.74     46.14     56.18         602.31
# 9                  7.39     25.69  229.64     16.90     23.33         336.28
# 18              1107.72     70.74    0.25     51.85     61.43         461.69
# 27                -1.51     26.53  182.52     28.86     33.99         132.35
# 36                20.09     31.79   27.96     26.78     34.04       81716.41
# ...                 ...       ...     ...       ...       ...            ...
# 7042              20.13     53.94   22.01     45.92     56.86         135.09
# 7051               0.00     93.34    0.00     79.89     85.76         129.68
# 7057               3.03     45.82   69.30     49.41     65.67         200.54
# 7066                NaN       NaN     NaN       NaN       NaN            NaN
# 7072               5.19     21.33  223.82     21.48     24.52          65.47
#
#       단기차입금_대_총차입금비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0              80.71   42.33     33.95          17.88           35.59
# 9               0.00  257.97     74.31          27.57            0.00
# 18              0.00   37.71     29.26          15.59           27.56
# 27             32.69  132.98     73.47          15.08            0.00
# 36             32.19  183.43     68.21          21.31            0.00
# ...              ...     ...       ...            ...             ...
# 7042           50.39   73.59     46.06          19.25           63.75
# 7051            0.00    7.13      6.66           6.84            7.42
# 7057           82.38  104.40     54.18          24.76           91.17
# 7066             NaN     NaN       NaN            NaN             NaN
# 7072           52.41  183.78     78.67          12.38            0.00
#
#       순운전자본비율   노동장비율   기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  직원감소율여부
# 0       28.23   71.32   19.75   204.06   35.86    12.72  19.56        0
# 9      -42.95  284.94  107.56   461.22   29.75    18.17  39.45        0
# 18      34.75    5.94    0.00   190.86  279.20    21.71  22.56        0
# 27      -1.29  510.77   33.44  2103.09   15.81     7.02  17.09        0
# 36     -24.28  689.66   18.92  2665.24   11.62     6.51  19.52        0
# ...       ...     ...     ...      ...     ...      ...    ...      ...
# 7042    17.17  184.54   28.46   629.06   77.04    22.60  14.83        0
# 7051    79.10   30.99   23.14   391.33  504.70    39.96  29.49        0
# 7057    17.83   58.76    0.78   278.75  103.19    18.88  20.15        0
# 7066      NaN     NaN     NaN      NaN     NaN      NaN    NaN        0
# 7072   -14.68  357.93    0.00   752.66   14.67     6.92   5.37        0
#
# [866 rows x 54 columns]

# %%
c = a.columns - b.columns

# %%
# # 한계기업 후보 기업의 숫자는 밑에 카운트를 봅시다
# df_8_frame.copy().drop_duplicates(['회사명'])

# %%
# # 그래서 4년 연속인 애들이 얼마나 될까요? 밑에 숫자를 봅시다
# df_10_frame.copy().drop_duplicates(['회사명'])

# %%
# 회사명 리스트 생성
company_list = df['회사명'].unique()
company_list
# Out:
# array(['(주)CMG제약', '(주)DB하이텍', '(주)ES큐브', ..., '휴젤(주)', '흥구석유(주)',
#        '흥아해운(주)'], dtype=object)

# %%
# 행 개수가 3개 이상인 기업 리스트 및 수
over_three = []
for i in company_list:
    if len(df[df['회사명']==i]) >= 2:
        over_three.append(i)
print(len(over_three))
print(over_three)

# %%
# 행 개수가 3개 이상인 기업 인덱스
over_three_index = []
for i in over_three:
    over_three_index.append(df[df['회사명']==i].index)
over_three_index

# %%
# 3년 연속 이자보상배율이 1미만인 기업을 부실기업으로 정의
icr_count = 0
df['부실기업1'] = ''

for i in over_three_index:
    for j in i:
        if df.loc[j, '이자보상배율'] < 1:
            icr_count += 1
        else:
            icr_count = 0
                    
        if icr_count >= 2:
            df.loc[j, '부실기업1'] = 1
        else:
            df.loc[j, '부실기업1'] = 0

# %%
df
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  매출액증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64   56.40
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08   -8.43
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89   25.51
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93   11.52
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17   18.85
# ...         ...    ...     ...     ...     ...      ...      ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18    2.42
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08   -1.58
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    0.56
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33   -9.87
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42  -86.45
#
#        재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율   노동장비율  \
# 0        -1.43    -2.02  ...          17.88           35.59    28.23   71.32
# 1         7.73    75.17  ...           6.27            7.33    70.60   69.14
# 2        56.29    55.10  ...          12.09           14.12    58.50   66.01
# 3         6.37     0.01  ...          17.36           25.09    33.72  113.90
# 4        11.04    -4.48  ...          20.77           31.32    30.82  114.25
# ...        ...      ...  ...            ...             ...      ...     ...
# 15145   -12.92     3.39  ...           8.43            0.00   -15.94  589.65
# 15146    56.39    11.22  ...          17.60            0.00   -16.34  703.55
# 15147    11.18   -39.28  ...          17.27            0.00   -24.48    0.00
# 15148    -5.85   -37.42  ...          17.36            0.00   -25.40    0.00
# 15149   -58.98   -57.73  ...           8.22            0.00   -25.18    0.00
#
#        기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 0      19.75   204.06   35.86    12.72  19.56      0
# 1      18.64   425.29    2.89     0.47   1.66      0
# 2      17.77   411.48   77.91    12.51  34.29      1
# 3      32.60   354.43   37.80    12.16  31.04      0
# 4      30.43   362.77   24.21     7.63  15.96      0
# ...      ...      ...     ...      ...    ...    ...
# 15145   0.00   948.60   21.49    13.11  12.28      0
# 15146   0.00  1000.62   15.81    10.98  12.66      0
# 15147   0.00     0.00    8.35     5.43   5.51      1
# 15148   0.00     0.00    6.91     4.24   4.52      1
# 15149   0.00     0.00    5.59     3.10  13.08      1
#
# [15150 rows x 54 columns]

# %%
a = df[df['부실기업1']==1]
b = a.drop_duplicates('회사명')
b
# Out:
#                     회사명   거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 2              (주)CMG제약   58820  13-Dec    0.70   -2.09    16.09   -18.89
# 10             (주)DB하이텍     990  12-Dec   -0.31   -3.44    -9.69    10.52
# 26              (주)ES큐브   50120  19-Dec   -0.68  312.66    14.02   696.75
# 27             (주)HJ중공업   97230  11-Dec    0.55   -6.49    -1.53   -13.26
# 36             (주)MH에탄올   23150  11-Dec    0.12   -0.49     2.92    -0.67
# ...                 ...     ...     ...     ...     ...      ...      ...
# 14981  현대일렉트릭앤에너지시스템(주)  267260  19-Dec   -4.66   -2.99    -2.10   -10.14
# 15016           현우산업(주)   92300  13-Dec   -1.29    7.54     4.22    14.79
# 15114           휴림로봇(주)   90710  13-Dec   -3.00   -8.68    -2.15   -17.87
# 15121           휴마시스(주)  205470  14-Dec   -0.76     NaN      NaN      NaN
# 15147           흥아해운(주)    3280  17-Dec   -0.42  -11.43   -16.50    13.29
#
#        매출액증가율  재고자산증가율  자기자본증가율  ...  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  순운전자본비율  \
# 2       25.51    56.29    55.10  ...          12.09           14.12    58.50
# 10       6.98     2.79    -5.57  ...          25.64            0.00   -21.27
# 26      29.45   -17.20   -18.89  ...           2.13            5.93    27.78
# 27      -8.72    23.47    -4.59  ...          15.08            0.00    -1.29
# 36     -18.64    18.30    -8.46  ...          21.31            0.00   -24.28
# ...       ...      ...      ...  ...            ...             ...      ...
# 14981   -8.72    -7.99   -17.75  ...          26.33          108.41    15.97
# 15016   -3.69     3.74    -1.01  ...          27.36            0.00   -10.69
# 15114   36.45   -15.62   -20.84  ...          27.74          226.41     6.82
# 15121     NaN      NaN      NaN  ...            NaN             NaN      NaN
# 15147    0.56    11.18   -39.28  ...          17.27            0.00   -24.48
#
#         노동장비율  기계장비율    자본집약도  설비투자효율  총자본투자효율  부가가치율  부실기업1
# 2       66.01  17.77   411.48   77.91    12.51  34.29      1
# 10     287.76  95.01   498.73   37.03    21.22  41.58      1
# 26       0.00   0.00     0.00   -3.22    -0.12  -1.28      1
# 27     510.77  33.44  2103.09   15.81     7.02  17.09      1
# 36     689.66  18.92  2665.24   11.62     6.51  19.52      1
# ...       ...    ...      ...     ...      ...    ...    ...
# 14981    0.00   0.00     0.00   -5.42    -1.19  -1.52      1
# 15016  190.10  95.13   337.24   34.38    19.38  25.75      1
# 15114   62.61   1.19   283.56   75.91    16.06  16.97      1
# 15121     NaN    NaN      NaN     NaN      NaN    NaN      1
# 15147    0.00   0.00     0.00    8.35     5.43   5.51      1
#
# [835 rows x 54 columns]
