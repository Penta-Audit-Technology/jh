# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./비율/영업이익계산용.csv',encoding='cp949')
df.columns = df.columns.str.replace('\(', '')
df.columns = df.columns.str.replace('\)', '')
df.columns = df.columns.str.replace('\*', '')
df.columns = df.columns.str.replace('IFRS', '')
df.columns = df.columns.str.replace('천원', '')
df
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_21000\650883624.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('\(', '')
# C:\Users\82104\AppData\Local\Temp\ipykernel_21000\650883624.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('\)', '')
# C:\Users\82104\AppData\Local\Temp\ipykernel_21000\650883624.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('\*', '')
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결         매출원가  \
# 0      (주)CMG제약  58820  2010/12   11350419.0   11350419.0    8217627.0
# 1      (주)CMG제약  58820  2011/12   17751704.0   17751704.0   10325799.0
# 2      (주)CMG제약  58820  2012/12   16255389.0   16255389.0   11648690.0
# ...

# %%
for i in range(len(df)):
    df.iloc[i,'영업이익개별'] = df.iloc[i]['매출액수익'] - df.iloc[i]['매출원가'] - df.iloc[i]['판매비와 관리비물류원가 등 포함']

# %%
pd.options.display.max_columns = None
dd = pd.read_csv('확인스.csv',encoding='cp949')
dd
# Out:
#            회사명  거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 0     (주)CMG제약  58820  2011-12    3.53    1.98    -5.90    17.64    -2.02
# 1     (주)CMG제약  58820  2012-12   -7.75  109.15    -4.12   207.08    75.17
# 2     (주)CMG제약  58820  2013-12    0.70   -2.09    16.09   -18.89    55.10
# 3     (주)CMG제약  58820  2014-12    3.60    3.86    74.30   -25.93     0.01
# 4     (주)CMG제약  58820  2015-12  -32.22   -2.64    -5.37    -7.17    -4.48
# ...        ...    ...      ...     ...     ...      ...      ...      ...
# 8826   흥아해운(주)   3280  2014-12    1.12   13.69    45.19   -13.68     7.76
# 8827   흥아해운(주)   3280  2015-12    1.02   21.93    49.36   -11.18     3.39
# 8828   흥아해운(주)   3280  2016-12    0.21   21.08    38.84   -25.08    11.22
# 8829   흥아해운(주)   3280  2017-12   -0.42  -11.43   -16.50    13.29   -39.28
# 8830   흥아해운(주)   3280  2018-12   -1.16   -5.33   -12.07    -6.33   -37.42
#
#       매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  총자본순이익률  총자본회전율  \
# ...

# %%
dd[dd['재고자산_대_순운전자본비율'] == 0]
# Out:
#                  회사명   거래소코드     회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  \
# 99        (주)갤럭시아에스엠   11420  2016-12  -18.76  -14.91   -10.91   -14.62
# 100       (주)갤럭시아에스엠   11420  2017-12  -35.52  -14.74   -85.93   -24.20
# 101       (주)갤럭시아에스엠   11420  2018-12 -157.86  -33.27   -30.89   -50.43
# 102       (주)갤럭시아에스엠   11420  2019-12   -8.95  -15.07   103.49    -4.26
# 358   (주)넥스트엔터테인먼트월드  160550  2014-12   13.68    7.97   -90.67    22.20
# ...              ...     ...      ...     ...     ...      ...      ...
# 8224     크리스탈지노믹스(주)   83790  2013-12   -1.56   62.70    16.74   -51.85
# 8429       한국앤컴퍼니(주)     240  2012-12    0.24  -78.61   -97.80   -77.18
# 8430       한국앤컴퍼니(주)     240  2013-12  785.06  141.52    -0.91   -17.71
# 8431       한국앤컴퍼니(주)     240  2014-12  785.06    6.51    -2.69     6.09
# 8432       한국앤컴퍼니(주)     240  2015-12  785.06    6.40    -4.03     1.55
#
#       자기자본증가율  매출액증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본영업이익율  매출액영업이익률  \
# ...
