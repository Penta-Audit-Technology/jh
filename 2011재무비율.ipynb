# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./csv/00_증가율1차.csv',encoding='cp949')
df = df.fillna(11111111.11)
# df['회계년도'] = pd.to_datetime(df['회계년도'], format='%Y').dt.strftime('%b-%d')
df
# Out:
#             회사명  거래소코드  회계년도  총자본증가율  유형자산증가율  유동자산증가율  재고자산증가율  자기자본증가율  \
# 0      (주)CMG제약  58820  2011    1.98    -5.90    17.64    -1.43    -2.02
# 1      (주)CMG제약  58820  2012  109.15    -4.12   207.08     7.73    75.17
# 2      (주)CMG제약  58820  2013   -2.09    16.09   -18.89    56.29    55.10
# 3      (주)CMG제약  58820  2014    3.86    74.30   -25.93     6.37     0.01
# 4      (주)CMG제약  58820  2015   -2.64    -5.37    -7.17    11.04    -4.48
# ...         ...    ...   ...     ...      ...      ...      ...      ...
# 15145   흥아해운(주)   3280  2015   21.93    49.36   -11.18   -12.92     3.39
# 15146   흥아해운(주)   3280  2016   21.08    38.84   -25.08    56.39    11.22
# 15147   흥아해운(주)   3280  2017  -11.43   -16.50    13.29    11.18   -39.28
# 15148   흥아해운(주)   3280  2018   -5.33   -12.07    -6.33    -5.85   -37.42
# 15149   흥아해운(주)   3280  2019  -46.38   -51.51   -13.42   -58.98   -57.73
#
#        매출액증가율      순이익증가율  ...  유형자산회전율  순운전자본회전률  운전자본회전률   노동장비율  기계장비율  \
# ...

# %%
pd.set_option('display.max_columns',30)

# %%
# df[df['유형자산증가율']== 11111111.11]

# %%
# df[df['유형자산증가율']== 0]

# %%
dd = pd.read_csv('./비율/유형자산.csv', encoding='cp949')
dd = dd.fillna(15975328.46)
dd
# Out:
#             회사명  거래소코드     회계년도  유형자산(*)(IFRS)(천원)  유형자산(*)(IFRS연결)(천원)
# 0      (주)CMG제약  58820  2011/12          9652599.0            9707759.0
# 1      (주)CMG제약  58820  2012/12          9264142.0            9307482.0
# 2      (주)CMG제약  58820  2013/12         10805092.0           10805092.0
# 3      (주)CMG제약  58820  2014/12         18833775.0           18833775.0
# 4      (주)CMG제약  58820  2015/12         17822468.0           17822468.0
# ...         ...    ...      ...                ...                  ...
# 15145   흥아해운(주)   3280  2015/12        479816639.0          483319774.0
# 15146   흥아해운(주)   3280  2016/12        667913303.0          671042170.0
# 15147   흥아해운(주)   3280  2017/12        557578439.0          560312598.0
# 15148   흥아해운(주)   3280  2018/12        490215607.0          492709259.0
# 15149   흥아해운(주)   3280  2019/12        237825418.0          238913893.0
#
# [15150 rows x 5 columns]

# %%
# for i in range(len(dd)):
    
#     if dd.loc[i,'유형자산(*)(IFRS)(천원)'] != 15975328.46:
#         if dd.loc[i,'유형자산(*)(IFRS연결)(천원)'] != 15975328.46:
#             dd.loc[i,'유형자산'] = dd.loc[i,'유형자산(*)(IFRS연결)(천원)']
#         else:
#             dd.loc[i,'유형자산'] = dd.loc[i,'유형자산(*)(IFRS)(천원)']
#     else:
#         if dd.loc[i,'유형자산(*)(IFRS연결)(천원)'] != 15975328.46:
#             dd.loc[i,'유형자산'] = dd.loc[i,'유형자산(*)(IFRS연결)(천원)']
#         else:
#             dd.loc[i,'유형자산'] = 15151515.15
            
# dd

# %%
for i in range(len(dd)-1):
    if dd.loc[i,'회사명'] == dd.loc[i+1,'회사명']:
        if dd.loc[i,'유형자산(*)(IFRS)(천원)'] != 15975328.46:
            dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS)(천원)'] / dd.loc[i,'유형자산(*)(IFRS)(천원)'])*100)-100).round(2)
        else:
            if dd.loc[i,'유형자산(*)(IFRS)(천원)'] == 15975328.46:
                continue
    elif dd.loc[i,'회사명'] != dd.loc[i+1,'회사명']:
        if dd.loc[i,'회사명'] == dd.loc[i-1,'회사명']:
            dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS)(천원)'] / dd.loc[i,'유형자산(*)(IFRS)(천원)'])*100)-100).round(2)
        else:
            continue
dd
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2933163765.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS)(천원)'] / dd.loc[i,'유형자산(*)(IFRS)(천원)'])*100)-100).round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2933163765.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS)(천원)'] / dd.loc[i,'유형자산(*)(IFRS)(천원)'])*100)-100).round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2933163765.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS)(천원)'] / dd.loc[i,'유형자산(*)(IFRS)(천원)'])*100)-100).round(2)
#             회사명  거래소코드     회계년도  유형자산(*)(IFRS)(천원)  유형자산(*)(IFRS연결)(천원)      0
# 0      (주)CMG제약  58820  2011/12          9652599.0            9707759.0  -4.02
# 1      (주)CMG제약  58820  2012/12          9264142.0            9307482.0  16.63
# ...

# %%
for i in range(len(dd)-1):
    if dd.loc[i,'회사명'] == dd.loc[i+1,'회사명']:
        if dd.loc[i,'유형자산(*)(IFRS연결)(천원)'] != 15975328.46:
            dd.loc[i,'1'] = (((dd.loc[i+1,'유형자산(*)(IFRS연결)(천원)'] / dd.loc[i,'유형자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
        else:
            continue
    elif dd.loc[i,'회사명'] != dd.loc[i+1,'회사명']:
        if dd.loc[i,'회사명'] == dd.loc[i-1,'회사명']:
            dd.loc[i,'0'] = (((dd.loc[i+1,'유형자산(*)(IFRS연결)(천원)'] / dd.loc[i,'유형자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
        else:
            continue
dd
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\3353419528.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   dd.loc[i,'1'] = (((dd.loc[i+1,'유형자산(*)(IFRS연결)(천원)'] / dd.loc[i,'유형자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
#             회사명  거래소코드     회계년도  유형자산(*)(IFRS)(천원)  유형자산(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12          9652599.0            9707759.0
# 1      (주)CMG제약  58820  2012/12          9264142.0            9307482.0
# 2      (주)CMG제약  58820  2013/12         10805092.0           10805092.0
# 3      (주)CMG제약  58820  2014/12         18833775.0           18833775.0
# 4      (주)CMG제약  58820  2015/12         17822468.0           17822468.0
# ...         ...    ...      ...                ...                  ...
# 15145   흥아해운(주)   3280  2015/12        479816639.0          483319774.0
# 15146   흥아해운(주)   3280  2016/12        667913303.0          671042170.0
# 15147   흥아해운(주)   3280  2017/12        557578439.0          560312598.0
# ...

# %%
# dd.to_csv('유형자산증가율.csv',encoding='cp949')

# %%
dd[60:85]
# Out:
#           회사명   거래소코드     회계년도  유형자산(*)(IFRS)(천원)  유형자산(*)(IFRS연결)(천원)  \
# 60  (주)SIMPAC    9160  2017/12         70402759.0         1.726598e+08
# 61  (주)SIMPAC    9160  2018/12        156312739.0         3.573314e+08
# 62  (주)SIMPAC    9160  2019/12        153003014.0         2.636082e+08
# 63  (주)SNT에너지  100840  2011/12        122586108.0         1.597533e+07
# 64  (주)SNT에너지  100840  2012/12        122289502.0         1.597533e+07
# 65  (주)SNT에너지  100840  2013/12        120367341.0         1.597533e+07
# 66  (주)SNT에너지  100840  2014/12        120065551.0         1.597533e+07
# 67  (주)SNT에너지  100840  2015/12        118714558.0         1.597533e+07
# 68  (주)SNT에너지  100840  2016/12        118148046.0         1.597533e+07
# 69  (주)SNT에너지  100840  2017/12        116825424.0         1.597533e+07
# 70  (주)SNT에너지  100840  2018/12        115728393.0         1.597533e+07
# 71  (주)SNT에너지  100840  2019/12        116275557.0         1.232578e+08
# ...

# %%
qw = pd.read_csv('./비율/유형자산증가율.csv',encoding='cp949')
qw = qw.fillna(11111111.11)
qw = qw.drop(columns='유형자산증가율')
qw
# Out:
#        Unnamed: 0       회사명  회계년도            0            1
# 0               0  (주)CMG제약  2011  11111111.11  11111111.11
# 1               1  (주)CMG제약  2012        -4.02        -4.12
# 2               2  (주)CMG제약  2013        16.63        16.09
# 3               3  (주)CMG제약  2014        74.30        74.30
# 4               4  (주)CMG제약  2015        -5.37        -5.37
# ...           ...       ...   ...          ...          ...
# 15145       15145   흥아해운(주)  2015        49.93        49.36
# 15146       15146   흥아해운(주)  2016        39.20        38.84
# 15147       15147   흥아해운(주)  2017       -16.52       -16.50
# 15148       15148   흥아해운(주)  2018       -12.08       -12.07
# 15149       15149   흥아해운(주)  2019       -51.49       -51.51
#
# [15150 rows x 5 columns]

# %%
for i in range(len(qw)):
    if qw.loc[i,'0'] != 11111111.11:
        if qw.loc[i,'1'] != 11111111.11:
            qw.loc[i,'유형자산증가율'] = qw.loc[i,'1']
        else:
            qw.loc[i,'유형자산증가율'] = qw.loc[i,'0']
    elif qw.loc[i,'0'] == 11111111.11:
        if qw.loc[i,'1'] != 11111111.11:
            qw.loc[i,'유형자산증가율'] = qw.loc[i,'1']
        else:
            qw.loc[i,'유형자산증가율'] = 1254789.63

# %%
qw = qw.drop(columns=['Unnamed: 0','0','1'],axis=1)
qw
# Out:
#             회사명  회계년도     유형자산증가율
# 0      (주)CMG제약  2011  1254789.63
# 1      (주)CMG제약  2012       -4.12
# 2      (주)CMG제약  2013       16.09
# 3      (주)CMG제약  2014       74.30
# 4      (주)CMG제약  2015       -5.37
# ...         ...   ...         ...
# 15145   흥아해운(주)  2015       49.36
# 15146   흥아해운(주)  2016       38.84
# 15147   흥아해운(주)  2017      -16.50
# 15148   흥아해운(주)  2018      -12.07
# 15149   흥아해운(주)  2019      -51.51
#
# [15150 rows x 3 columns]

# %%
# qw.to_csv('qw.csv',encoding='cp949')

# %%
qq = pd.concat([df,qw],axis=1)
qq
# Out:
#             회사명  거래소코드  회계년도  총자본증가율  유형자산증가율  유동자산증가율  재고자산증가율  자기자본증가율  \
# 0      (주)CMG제약  58820  2011    1.98    -5.90    17.64    -1.43    -2.02
# 1      (주)CMG제약  58820  2012  109.15    -4.12   207.08     7.73    75.17
# 2      (주)CMG제약  58820  2013   -2.09    16.09   -18.89    56.29    55.10
# 3      (주)CMG제약  58820  2014    3.86    74.30   -25.93     6.37     0.01
# 4      (주)CMG제약  58820  2015   -2.64    -5.37    -7.17    11.04    -4.48
# ...         ...    ...   ...     ...      ...      ...      ...      ...
# 15145   흥아해운(주)   3280  2015   21.93    49.36   -11.18   -12.92     3.39
# 15146   흥아해운(주)   3280  2016   21.08    38.84   -25.08    56.39    11.22
# 15147   흥아해운(주)   3280  2017  -11.43   -16.50    13.29    11.18   -39.28
# 15148   흥아해운(주)   3280  2018   -5.33   -12.07    -6.33    -5.85   -37.42
# 15149   흥아해운(주)   3280  2019  -46.38   -51.51   -13.42   -58.98   -57.73
#
#        매출액증가율      순이익증가율  ...   노동장비율  기계장비율    자본집약도  총자본투자효율  설비투자효율  \
# ...

# %%
for i in range(len(qq)):
    if qq.loc[i,'유형자산증가율'] == 0:
        if qq.loc[i,'0'] != 11111111.11:
            if qq.loc[i,'1'] != 11111111.11:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'1']
            else:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'0']
        else:
            if qq.loc[i,'1'] != 11111111.11:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'1']
            else:
                qq.loc[i,'유형자산증가율'] = 1254789.63
        if qq.loc[i,'1'] == 0:
            qq.loc[i,'유형자산증가율'] = qq.loc[i,'0']
        if qq.loc[i,'1'] == 11111111.11:
            qq.loc[i,'유형자산증가율'] = 11111111.11
    if qq.loc[i,'유형자산증가율'] == 11111111.11:
        if qq.loc[i,'1'] != 11111111.11:
            if qq.loc[i,'0'] != 11111111.11:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'1']
            else:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'1']
        if qq.loc[i,'1'] == 11111111.11:
            if qq.loc[i,'0'] != 11111111.11:
                qq.loc[i,'유형자산증가율'] = qq.loc[i,'0']
            else:
                qq.loc[i,'유형자산증가율'] = 1254789.63
        
qq
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\82104\OneDrive\바탕 화면\vscode\프로젝트1\.git\jh\2011재무비율.ipynb 셀 15 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/82104/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/vscode/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/.git/jh/2011%EC%9E%AC%EB%AC%B4%EB%B9%84%EC%9C%A8.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> for i in range(len(qq)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/82104/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/vscode/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/.git/jh/2011%EC%9E%AC%EB%AC%B4%EB%B9%84%EC%9C%A8.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     if qq.loc[i,'유형자산증가율'] == 0:
# ...

# %%
qq[qq['유형자산증가율']==11111111.11]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 총자본증가율, 유형자산증가율, 유동자산증가율, 재고자산증가율, 자기자본증가율, 매출액증가율, 순이익증가율, 정상영업이익증가율, 매출액총이익률, 매출액순이익률, 총자본순이익률, 자기자본순이익률, 매출원가 대 매출액비율, 금융비용부담률, 금융비용 대 총비용비율, 이자부담률, 지급이자율, 차입금평균이자율, 매출액정상영업이익률, 유동자산구성비율, 재고자산 대 유동자산비율, 당좌자산구성비율, 자기자본구성비율, 타인자본구성비율, 자기자본배율, 유동비율, 당좌비율, 현금비율, 재고자산 대 순운전자본비율, 매출채권 대 매입채무비율, 부채비율, 유동부채비율, 단기차입금 대 총차입금비율, 순운전자본비율, 차입금비율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 매출액비율, 총자본회전률, 자기자본회전률, 타인자본회전률, 매입채무회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 유형자산회전율, 순운전자본회전률, 운전자본회전률, 노동장비율, 기계장비율, 자본집약도, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 0, 1]
# Index: []
#
# [0 rows x 61 columns]

# %%
# qq.to_csv('유형자산증가율.csv',encoding='cp949')

# %%
mm = pd.read_csv('./비율/총자산.csv',encoding='cp949')
mm = mm.fillna(11111111.11)
mm
# Out:
#             회사명  거래소코드     회계년도  자산(*)(IFRS)(천원)  자산(*)(IFRS연결)(천원)
# 0      (주)CMG제약  58820  2011/12       27548539.0         27305198.0
# 1      (주)CMG제약  58820  2012/12       56988604.0         57108035.0
# 2      (주)CMG제약  58820  2013/12       55961620.0         55912563.0
# 3      (주)CMG제약  58820  2014/12       58127098.0         58068326.0
# 4      (주)CMG제약  58820  2015/12       56591972.0         56532821.0
# ...         ...    ...      ...              ...                ...
# 15145   흥아해운(주)   3280  2015/12      771212062.0        791640802.0
# 15146   흥아해운(주)   3280  2016/12      942586770.0        958532259.0
# 15147   흥아해운(주)   3280  2017/12      834107402.0        848958520.0
# 15148   흥아해운(주)   3280  2018/12      782787041.0        803698457.0
# 15149   흥아해운(주)   3280  2019/12      386550839.0        430962722.0
#
# [15150 rows x 5 columns]

# %%
for i in range(len(mm)-1):
    if mm.loc[i,'회사명'] == mm.loc[i+1,'회사명']:
        if mm.loc[i,'자산(*)(IFRS)(천원)'] != 11111111.11:
            mm.loc[i,'0'] = (((mm.loc[i+1,'자산(*)(IFRS)(천원)'] - mm.loc[i,'자산(*)(IFRS)(천원)'])/mm.loc[i,'자산(*)(IFRS)(천원)'])*100).round(2)
        else:
            if mm.loc[i,'자산(*)(IFRS)(천원)'] == 11111111.11:
                continue
    elif mm.loc[i,'회사명'] != mm.loc[i+1,'회사명']:
        if mm.loc[i,'회사명'] == mm.loc[i-1,'회사명']:
            mm.loc[i,'0'] = (((mm.loc[i+1,'자산(*)(IFRS)(천원)'] - mm.loc[i,'자산(*)(IFRS)(천원)'])/mm.loc[i,'자산(*)(IFRS)(천원)'])*100).round(2)
        else:
            continue
mm
# Out:
#             회사명  거래소코드     회계년도  자산(*)(IFRS)(천원)  자산(*)(IFRS연결)(천원)       0
# 0      (주)CMG제약  58820  2011/12       27548539.0         27305198.0  106.87
# 1      (주)CMG제약  58820  2012/12       56988604.0         57108035.0   -1.80
# 2      (주)CMG제약  58820  2013/12       55961620.0         55912563.0    3.87
# 3      (주)CMG제약  58820  2014/12       58127098.0         58068326.0   -2.64
# 4      (주)CMG제약  58820  2015/12       56591972.0         56532821.0   96.11
# ...         ...    ...      ...              ...                ...     ...
# 15145   흥아해운(주)   3280  2015/12      771212062.0        791640802.0   22.22
# 15146   흥아해운(주)   3280  2016/12      942586770.0        958532259.0  -11.51
# 15147   흥아해운(주)   3280  2017/12      834107402.0        848958520.0   -6.15
# 15148   흥아해운(주)   3280  2018/12      782787041.0        803698457.0  -50.62
# 15149   흥아해운(주)   3280  2019/12      386550839.0        430962722.0     NaN
#
# [15150 rows x 6 columns]

# %%
for i in range(len(mm)-1):
    if mm.loc[i,'회사명'] == mm.loc[i+1,'회사명']:
        if mm.loc[i,'자산(*)(IFRS연결)(천원)'] != 11111111.11:
            mm.loc[i,'1'] = (((mm.loc[i+1,'자산(*)(IFRS연결)(천원)'] - mm.loc[i,'자산(*)(IFRS연결)(천원)'])/mm.loc[i,'자산(*)(IFRS연결)(천원)'])*100).round(2)
        else:
            if mm.loc[i,'자산(*)(IFRS연결)(천원)'] == 11111111.11:
                continue
    elif mm.loc[i,'회사명'] != mm.loc[i+1,'회사명']:
        if mm.loc[i,'회사명'] == mm.loc[i-1,'회사명']:
            mm.loc[i,'1'] = (((mm.loc[i+1,'자산(*)(IFRS연결)(천원)'] - mm.loc[i,'자산(*)(IFRS연결)(천원)'])/mm.loc[i,'자산(*)(IFRS연결)(천원)'])*100).round(2)
        else:
            continue
mm
# Out:
#             회사명  거래소코드     회계년도  자산(*)(IFRS)(천원)  자산(*)(IFRS연결)(천원)       0  \
# 0      (주)CMG제약  58820  2011/12       27548539.0         27305198.0  106.87
# 1      (주)CMG제약  58820  2012/12       56988604.0         57108035.0   -1.80
# 2      (주)CMG제약  58820  2013/12       55961620.0         55912563.0    3.87
# 3      (주)CMG제약  58820  2014/12       58127098.0         58068326.0   -2.64
# 4      (주)CMG제약  58820  2015/12       56591972.0         56532821.0   96.11
# ...         ...    ...      ...              ...                ...     ...
# 15145   흥아해운(주)   3280  2015/12      771212062.0        791640802.0   22.22
# 15146   흥아해운(주)   3280  2016/12      942586770.0        958532259.0  -11.51
# 15147   흥아해운(주)   3280  2017/12      834107402.0        848958520.0   -6.15
# 15148   흥아해운(주)   3280  2018/12      782787041.0        803698457.0  -50.62
# 15149   흥아해운(주)   3280  2019/12      386550839.0        430962722.0     NaN
#
#             1
# 0      109.15
# 1       -2.09
# ...

# %%
mm = pd.read_csv('./비율/총자산비율.csv',encoding='cp949')
mm = mm.fillna(11111111.11)
mm
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  자산(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11       27548539.0
# 1               1  (주)CMG제약  58820  Dec-12       56988604.0
# 2               2  (주)CMG제약  58820  Dec-13       55961620.0
# 3               3  (주)CMG제약  58820  Dec-14       58127098.0
# 4               4  (주)CMG제약  58820  Dec-15       56591972.0
# ...           ...       ...    ...     ...              ...
# 15145       15145   흥아해운(주)   3280  Dec-15      771212062.0
# 15146       15146   흥아해운(주)   3280  Dec-16      942586770.0
# 15147       15147   흥아해운(주)   3280  Dec-17      834107402.0
# 15148       15148   흥아해운(주)   3280  Dec-18      782787041.0
# 15149       15149   흥아해운(주)   3280  Dec-19      386550839.0
#
#        자산(*)(IFRS연결)(천원)            0            1
# 0             27305198.0  11111111.11  11111111.11
# 1             57108035.0       106.87       109.15
# 2             55912563.0        -1.80        -2.09
# ...

# %%
for i in range(len(mm)):
    if mm.loc[i,'0'] != 11111111.11:
        if mm.loc[i,'1'] != 11111111.11:
            mm.loc[i,'총자본증가율'] = mm.loc[i,'1']
        else:
            mm.loc[i,'총자본증가율'] = mm.loc[i,'0']
    elif mm.loc[i,'0'] == 11111111.11:
        if mm.loc[i,'1'] != 11111111.11:
            mm.loc[i,'총자본증가율'] = mm.loc[i,'1']
        else:
            mm.loc[i,'총자본증가율'] = 1254789.63

# %%
mm
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  자산(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11       27548539.0
# 1               1  (주)CMG제약  58820  Dec-12       56988604.0
# 2               2  (주)CMG제약  58820  Dec-13       55961620.0
# 3               3  (주)CMG제약  58820  Dec-14       58127098.0
# 4               4  (주)CMG제약  58820  Dec-15       56591972.0
# ...           ...       ...    ...     ...              ...
# 15145       15145   흥아해운(주)   3280  Dec-15      771212062.0
# 15146       15146   흥아해운(주)   3280  Dec-16      942586770.0
# 15147       15147   흥아해운(주)   3280  Dec-17      834107402.0
# 15148       15148   흥아해운(주)   3280  Dec-18      782787041.0
# 15149       15149   흥아해운(주)   3280  Dec-19      386550839.0
#
#        자산(*)(IFRS연결)(천원)            0            1      총자본증가율
# 0             27305198.0  11111111.11  11111111.11  1254789.63
# 1             57108035.0       106.87       109.15      109.15
# ...

# %%
# mm.to_csv('mm.csv',encoding='cp949')

# %%
m1 = pd.concat([df[['회사명','총자본증가율']],mm[['0','1']]],axis=1)
m1
# Out:
#             회사명  총자본증가율            0            1
# 0      (주)CMG제약    1.98  11111111.11  11111111.11
# 1      (주)CMG제약  109.15       106.87       109.15
# 2      (주)CMG제약   -2.09        -1.80        -2.09
# 3      (주)CMG제약    3.86         3.87         3.86
# 4      (주)CMG제약   -2.64        -2.64        -2.64
# ...         ...     ...          ...          ...
# 15145   흥아해운(주)   21.93        22.84        21.93
# 15146   흥아해운(주)   21.08        22.22        21.08
# 15147   흥아해운(주)  -11.43       -11.51       -11.43
# 15148   흥아해운(주)   -5.33        -6.15        -5.33
# 15149   흥아해운(주)  -46.38       -50.62       -46.38
#
# [15150 rows x 4 columns]

# %%
for i in range(len(m1)):
    if m1.loc[i,'총자본증가율'] == 0:
        if m1.loc[i,'0'] != 11111111.11:
            if m1.loc[i,'1'] != 11111111.11:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'1']
            else:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'0']
        else:
            if m1.loc[i,'1'] != 11111111.11:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'1']
            else:
                m1.loc[i,'총자본증가율'] = 1254789.63
        if m1.loc[i,'1'] == 0:
            m1.loc[i,'총자본증가율'] = m1.loc[i,'0']
        if m1.loc[i,'1'] == 11111111.11:
            m1.loc[i,'총자본증가율'] = 11111111.11
    if m1.loc[i,'총자본증가율'] == 11111111.11:
        if m1.loc[i,'1'] != 11111111.11:
            if m1.loc[i,'0'] != 11111111.11:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'1']
            else:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'1']
        if m1.loc[i,'1'] == 11111111.11:
            if m1.loc[i,'0'] != 11111111.11:
                m1.loc[i,'총자본증가율'] = m1.loc[i,'0']
            else:
                m1.loc[i,'총자본증가율'] = 1254789.63
        
m1
# Out:
#             회사명  총자본증가율            0            1
# 0      (주)CMG제약    1.98  11111111.11  11111111.11
# 1      (주)CMG제약  109.15       106.87       109.15
# 2      (주)CMG제약   -2.09        -1.80        -2.09
# 3      (주)CMG제약    3.86         3.87         3.86
# 4      (주)CMG제약   -2.64        -2.64        -2.64
# ...         ...     ...          ...          ...
# 15145   흥아해운(주)   21.93        22.84        21.93
# 15146   흥아해운(주)   21.08        22.22        21.08
# 15147   흥아해운(주)  -11.43       -11.51       -11.43
# 15148   흥아해운(주)   -5.33        -6.15        -5.33
# 15149   흥아해운(주)  -46.38       -50.62       -46.38
#
# [15150 rows x 4 columns]

# %%
# m1.to_csv('m1.csv',encoding='cp949')

# %%
q1 = pd.read_csv('./비율/재고,유동.csv',encoding='cp949')
q1 = q1.fillna(11111111.11)
q1
# Out:
#             회사명  거래소코드     회계년도  유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12         15264885.0           15341167.0
# 1      (주)CMG제약  58820  2012/12         47073443.0           47109213.0
# 2      (주)CMG제약  58820  2013/12         38258866.0           38209699.0
# 3      (주)CMG제약  58820  2014/12         28359823.0           28300941.0
# 4      (주)CMG제약  58820  2015/12         26330765.0           26271614.0
# ...         ...    ...      ...                ...                  ...
# 15145   흥아해운(주)   3280  2015/12        124478864.0          136280257.0
# 15146   흥아해운(주)   3280  2016/12         90973953.0          102103828.0
# 15147   흥아해운(주)   3280  2017/12        105819304.0          115675013.0
# 15148   흥아해운(주)   3280  2018/12        103181415.0          108354984.0
# 15149   흥아해운(주)   3280  2019/12         61182850.0           93810124.0
#
#        재고자산(*)(IFRS)(천원)  재고자산(*)(IFRS연결)(천원)
# 0              2743103.0            2743103.0
# ...

# %%
for i in range(len(q1)-1):
    if q1.loc[i,'회사명'] == q1.loc[i+1,'회사명']:
        if q1.loc[i,'유동자산(*)(IFRS연결)(천원)'] != 11111111.11:
            q1.loc[i,'1'] = (((q1.loc[i+1,'유동자산(*)(IFRS연결)(천원)'] - q1.loc[i,'유동자산(*)(IFRS연결)(천원)'])/q1.loc[i,'유동자산(*)(IFRS연결)(천원)'])*100).round(2)
        else:
            if q1.loc[i,'유동자산(*)(IFRS연결)(천원)'] == 11111111.11:
                continue
    elif q1.loc[i,'회사명'] != q1.loc[i+1,'회사명']:
        if q1.loc[i,'회사명'] == q1.loc[i-1,'회사명']:
            q1.loc[i,'1'] = (((q1.loc[i+1,'유동자산(*)(IFRS연결)(천원)'] - q1.loc[i,'유동자산(*)(IFRS연결)(천원)'])/q1.loc[i,'유동자산(*)(IFRS연결)(천원)'])*100).round(2)
        else:
            continue
q1
# Out:
#             회사명  거래소코드     회계년도  유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12         15264885.0           15341167.0
# 1      (주)CMG제약  58820  2012/12         47073443.0           47109213.0
# 2      (주)CMG제약  58820  2013/12         38258866.0           38209699.0
# 3      (주)CMG제약  58820  2014/12         28359823.0           28300941.0
# 4      (주)CMG제약  58820  2015/12         26330765.0           26271614.0
# ...         ...    ...      ...                ...                  ...
# 15145   흥아해운(주)   3280  2015/12        124478864.0          136280257.0
# 15146   흥아해운(주)   3280  2016/12         90973953.0          102103828.0
# 15147   흥아해운(주)   3280  2017/12        105819304.0          115675013.0
# 15148   흥아해운(주)   3280  2018/12        103181415.0          108354984.0
# 15149   흥아해운(주)   3280  2019/12         61182850.0           93810124.0
#
#        재고자산(*)(IFRS)(천원)  재고자산(*)(IFRS연결)(천원)       1
# ...

# %%
for i in range(len(q1)-1):
    if q1.loc[i,'회사명'] == q1.loc[i+1,'회사명']:
        if q1.loc[i,'재고자산(*)(IFRS연결)(천원)'] != 11111111.11:
            q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
        else:
            if q1.loc[i,'재고자산(*)(IFRS연결)(천원)'] == 11111111.11:
                continue
    elif q1.loc[i,'회사명'] != q1.loc[i+1,'회사명']:
        if q1.loc[i,'회사명'] == q1.loc[i-1,'회사명']:
            q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
        else:
            continue
q1
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2794307431.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2794307431.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2794307431.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
# C:\Users\82104\AppData\Local\Temp\ipykernel_19528\2794307431.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   q1.loc[i,'3'] = (((q1.loc[i+1,'재고자산(*)(IFRS연결)(천원)'] / q1.loc[i,'재고자산(*)(IFRS연결)(천원)'])*100)-100).round(2)
# ...

# %%
q2 = pd.read_csv('./비율/재고,유동증가율.csv',encoding='cp949')
q2 = q2.fillna(11111111.11)
q2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  유동자산(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11         15264885.0
# 1               1  (주)CMG제약  58820  Dec-12         47073443.0
# 2               2  (주)CMG제약  58820  Dec-13         38258866.0
# 3               3  (주)CMG제약  58820  Dec-14         28359823.0
# 4               4  (주)CMG제약  58820  Dec-15         26330765.0
# ...           ...       ...    ...     ...                ...
# 15145       15145   흥아해운(주)   3280  Dec-15        124478864.0
# 15146       15146   흥아해운(주)   3280  Dec-16         90973953.0
# 15147       15147   흥아해운(주)   3280  Dec-17        105819304.0
# 15148       15148   흥아해운(주)   3280  Dec-18        103181415.0
# 15149       15149   흥아해운(주)   3280  Dec-19         61182850.0
#
#        유동자산(*)(IFRS연결)(천원)  재고자산(*)(IFRS)(천원)  재고자산(*)(IFRS연결)(천원)  \
# 0               15341167.0          2743103.0            2743103.0
# 1               47109213.0          2955172.0            2955172.0
# ...

# %%
for i in range(len(q2)):
    if q2.loc[i,'0'] != 11111111.11:
        if q2.loc[i,'1'] != 11111111.11:
            q2.loc[i,'유동자산증가율'] = q2.loc[i,'1']
        else:
            q2.loc[i,'유동자산증가율'] = q2.loc[i,'0']
    elif q2.loc[i,'0'] == 11111111.11:
        if q2.loc[i,'1'] != 11111111.11:
            q2.loc[i,'유동자산증가율'] = q2.loc[i,'1']
        else:
            q2.loc[i,'유동자산증가율'] = 1254789.63

# %%
for i in range(len(q2)):
    if q2.loc[i,'2'] != 11111111.11:
        if q2.loc[i,'3'] != 11111111.11:
            q2.loc[i,'재고자산증가율'] = q2.loc[i,'3']
        else:
            q2.loc[i,'재고자산증가율'] = q2.loc[i,'2']
    elif q2.loc[i,'2'] == 11111111.11:
        if q2.loc[i,'3'] != 11111111.11:
            q2.loc[i,'재고자산증가율'] = q2.loc[i,'3']
        else:
            q2.loc[i,'재고자산증가율'] = 1254789.63

# %%
q2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  유동자산(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11         15264885.0
# 1               1  (주)CMG제약  58820  Dec-12         47073443.0
# 2               2  (주)CMG제약  58820  Dec-13         38258866.0
# 3               3  (주)CMG제약  58820  Dec-14         28359823.0
# 4               4  (주)CMG제약  58820  Dec-15         26330765.0
# ...           ...       ...    ...     ...                ...
# 15145       15145   흥아해운(주)   3280  Dec-15        124478864.0
# 15146       15146   흥아해운(주)   3280  Dec-16         90973953.0
# 15147       15147   흥아해운(주)   3280  Dec-17        105819304.0
# 15148       15148   흥아해운(주)   3280  Dec-18        103181415.0
# 15149       15149   흥아해운(주)   3280  Dec-19         61182850.0
#
#        유동자산(*)(IFRS연결)(천원)  재고자산(*)(IFRS)(천원)  재고자산(*)(IFRS연결)(천원)  \
# 0               15341167.0          2743103.0            2743103.0
# 1               47109213.0          2955172.0            2955172.0
# ...

# %%
# q2.to_csv('q2.csv',encoding='cp949')

# %%
q3 = pd.concat([df[['회사명','유동자산증가율','재고자산증가율']],q2[['0','1','2','3']]],axis=1)
q3
# Out:
#             회사명  유동자산증가율  재고자산증가율            0            1            2  \
# 0      (주)CMG제약    17.64    -1.43  11111111.11  11111111.11  11111111.11
# 1      (주)CMG제약   207.08     7.73       208.38       207.08         7.73
# 2      (주)CMG제약   -18.89    56.29       -18.73       -18.89        56.29
# 3      (주)CMG제약   -25.93     6.37       -25.87       -25.93         6.37
# 4      (주)CMG제약    -7.17    11.04        -7.15        -7.17        11.04
# ...         ...      ...      ...          ...          ...          ...
# 15145   흥아해운(주)   -11.18   -12.92       -14.23       -11.18       -12.92
# 15146   흥아해운(주)   -25.08    56.39       -26.92       -25.08        56.39
# 15147   흥아해운(주)    13.29    11.18        16.32        13.29        11.18
# 15148   흥아해운(주)    -6.33    -5.85        -2.49        -6.33        -5.92
# 15149   흥아해운(주)   -13.42   -58.98       -40.70       -13.42       -59.85
#
#                  3
# 0      11111111.11
# 1             7.73
# 2            56.29
# ...

# %%
for i in range(len(q3)):
    if q3.loc[i,'유동자산증가율'] == 0:
        if q3.loc[i,'0'] != 11111111.11:
            if q3.loc[i,'1'] != 11111111.11:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'1']
            else:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'0']
        else:
            if q3.loc[i,'1'] != 11111111.11:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'1']
            else:
                q3.loc[i,'유동자산증가율'] = 1254789.63
        if q3.loc[i,'1'] == 0:
            q3.loc[i,'유동자산증가율'] = q3.loc[i,'0']
        if q3.loc[i,'1'] == 11111111.11:
            q3.loc[i,'유동자산증가율'] = 11111111.11
    if q3.loc[i,'유동자산증가율'] == 11111111.11:
        if q3.loc[i,'1'] != 11111111.11:
            if q3.loc[i,'0'] != 11111111.11:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'1']
            else:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'1']
        if q3.loc[i,'1'] == 11111111.11:
            if q3.loc[i,'0'] != 11111111.11:
                q3.loc[i,'유동자산증가율'] = q3.loc[i,'0']
            else:
                q3.loc[i,'유동자산증가율'] = 1254789.63
        
q3
# Out:
#             회사명  유동자산증가율  재고자산증가율            0            1            2  \
# 0      (주)CMG제약    17.64    -1.43  11111111.11  11111111.11  11111111.11
# 1      (주)CMG제약   207.08     7.73       208.38       207.08         7.73
# 2      (주)CMG제약   -18.89    56.29       -18.73       -18.89        56.29
# 3      (주)CMG제약   -25.93     6.37       -25.87       -25.93         6.37
# 4      (주)CMG제약    -7.17    11.04        -7.15        -7.17        11.04
# ...         ...      ...      ...          ...          ...          ...
# 15145   흥아해운(주)   -11.18   -12.92       -14.23       -11.18       -12.92
# 15146   흥아해운(주)   -25.08    56.39       -26.92       -25.08        56.39
# 15147   흥아해운(주)    13.29    11.18        16.32        13.29        11.18
# 15148   흥아해운(주)    -6.33    -5.85        -2.49        -6.33        -5.92
# 15149   흥아해운(주)   -13.42   -58.98       -40.70       -13.42       -59.85
#
#                  3
# 0      11111111.11
# 1             7.73
# 2            56.29
# ...

# %%
for i in range(len(q3)):
    if q3.loc[i,'재고자산증가율'] == 0:
        if q3.loc[i,'2'] != 11111111.11:
            if q3.loc[i,'3'] != 11111111.11:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'3']
            else:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'2']
        else:
            if q3.loc[i,'3'] != 11111111.11:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'3']
            else:
                q3.loc[i,'재고자산증가율'] = 1254789.63
        if q3.loc[i,'3'] == 0:
            q3.loc[i,'재고자산증가율'] = q3.loc[i,'2']
        if q3.loc[i,'3'] == 11111111.11:
            q3.loc[i,'재고자산증가율'] = 11111111.11
    if q3.loc[i,'재고자산증가율'] == 11111111.11:
        if q3.loc[i,'3'] != 11111111.11:
            if q3.loc[i,'2'] != 11111111.11:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'3']
            else:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'3']
        if q3.loc[i,'3'] == 11111111.11:
            if q3.loc[i,'2'] != 11111111.11:
                q3.loc[i,'재고자산증가율'] = q3.loc[i,'2']
            else:
                q3.loc[i,'재고자산증가율'] = 1254789.63
        
q3
# Out:
#             회사명  유동자산증가율  재고자산증가율            0            1            2  \
# 0      (주)CMG제약    17.64    -1.43  11111111.11  11111111.11  11111111.11
# 1      (주)CMG제약   207.08     7.73       208.38       207.08         7.73
# 2      (주)CMG제약   -18.89    56.29       -18.73       -18.89        56.29
# 3      (주)CMG제약   -25.93     6.37       -25.87       -25.93         6.37
# 4      (주)CMG제약    -7.17    11.04        -7.15        -7.17        11.04
# ...         ...      ...      ...          ...          ...          ...
# 15145   흥아해운(주)   -11.18   -12.92       -14.23       -11.18       -12.92
# 15146   흥아해운(주)   -25.08    56.39       -26.92       -25.08        56.39
# 15147   흥아해운(주)    13.29    11.18        16.32        13.29        11.18
# 15148   흥아해운(주)    -6.33    -5.85        -2.49        -6.33        -5.92
# 15149   흥아해운(주)   -13.42   -58.98       -40.70       -13.42       -59.85
#
#                  3
# 0      11111111.11
# 1             7.73
# 2            56.29
# ...

# %%
e1 = pd.read_csv('./비율/자기자본.csv',encoding='cp949')
e1 = e1.fillna(11111111.11)
e1
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0
# ...         ...    ...      ...           ...             ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0
#
# [15150 rows x 5 columns]

# %%
for i in range(len(e1)-1):
    if e1.loc[i,'회사명'] == e1.loc[i+1,'회사명']:
        if e1.loc[i,'합계(IFRS)(천원)'] != 11111111.11:
            e1.loc[i,'0'] = (((e1.loc[i+1,'합계(IFRS)(천원)'] - e1.loc[i,'합계(IFRS)(천원)'])/e1.loc[i,'합계(IFRS)(천원)'])*100).round(2)
        else:
            if e1.loc[i,'합계(IFRS)(천원)'] == 11111111.11:
                continue
    elif e1.loc[i,'회사명'] != e1.loc[i+1,'회사명']:
        if e1.loc[i,'회사명'] == e1.loc[i-1,'회사명']:
            e1.loc[i,'0'] = (((e1.loc[i+1,'합계(IFRS)(천원)'] - e1.loc[i,'합계(IFRS)(천원)'])/e1.loc[i,'합계(IFRS)(천원)'])*100).round(2)
        else:
            continue
e1
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)       0
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0   72.78
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0   55.20
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0    0.04
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0   -4.47
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0  115.71
# ...         ...    ...      ...           ...             ...     ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0   13.60
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0  -41.46
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0  -47.28
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0  -68.92
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0     NaN
#
# [15150 rows x 6 columns]

# %%
for i in range(len(e1)-1):
    if e1.loc[i,'회사명'] == e1.loc[i+1,'회사명']:
        if e1.loc[i,'합계(IFRS연결)(천원)'] != 11111111.11:
            e1.loc[i,'1'] = (((e1.loc[i+1,'합계(IFRS연결)(천원)'] - e1.loc[i,'합계(IFRS연결)(천원)'])/e1.loc[i,'합계(IFRS연결)(천원)'])*100).round(2)
        else:
            if e1.loc[i,'합계(IFRS연결)(천원)'] == 11111111.11:
                continue
    elif e1.loc[i,'회사명'] != e1.loc[i+1,'회사명']:
        if e1.loc[i,'회사명'] == e1.loc[i-1,'회사명']:
            e1.loc[i,'1'] = (((e1.loc[i+1,'합계(IFRS연결)(천원)'] - e1.loc[i,'합계(IFRS연결)(천원)'])/e1.loc[i,'합계(IFRS연결)(천원)'])*100).round(2)
        else:
            continue
e1
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)       0       1
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0   72.78   75.17
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0   55.20   55.10
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0    0.04    0.01
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0   -4.47   -4.48
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0  115.71  116.01
# ...         ...    ...      ...           ...             ...     ...     ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0   13.60   11.22
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0  -41.46  -39.28
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0  -47.28  -37.42
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0  -68.92  -57.73
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0     NaN     NaN
#
# [15150 rows x 7 columns]

# %%
# e1.to_csv('자기자본증가율.csv',encoding='cp949')

# %%
e2 = pd.read_csv('./비율/자기자본증가율.csv',encoding='cp949')
e2 = e2.fillna(11111111.11)
e2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11    18290915.0      18034249.0
# 1               1  (주)CMG제약  58820  Dec-12    31602540.0      31590684.0
# 2               2  (주)CMG제약  58820  Dec-13    49048213.0      48997281.0
# 3               3  (주)CMG제약  58820  Dec-14    49067039.0      49002644.0
# 4               4  (주)CMG제약  58820  Dec-15    46872705.0      46806888.0
# ...           ...       ...    ...     ...           ...             ...
# 15145       15145   흥아해운(주)   3280  Dec-15   161824549.0     173076634.0
# 15146       15146   흥아해운(주)   3280  Dec-16   183829287.0     192487245.0
# 15147       15147   흥아해운(주)   3280  Dec-17   107614965.0     116884496.0
# 15148       15148   흥아해운(주)   3280  Dec-18    56731554.0      73148175.0
# 15149       15149   흥아해운(주)   3280  Dec-19    17632229.0      30919383.0
#
#                  0            1
# 0      11111111.11  11111111.11
# ...

# %%
for i in range(len(e2)):
    if e2.loc[i,'0'] != 11111111.11:
        if e2.loc[i,'1'] != 11111111.11:
            e2.loc[i,'자기자본증가율'] = e2.loc[i,'1']
        else:
            e2.loc[i,'자기자본증가율'] = e2.loc[i,'0']
    elif e2.loc[i,'0'] == 11111111.11:
        if e2.loc[i,'1'] != 11111111.11:
            e2.loc[i,'자기자본증가율'] = e2.loc[i,'1']
        else:
            e2.loc[i,'자기자본증가율'] = 1254789.63

# %%
e2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11    18290915.0      18034249.0
# 1               1  (주)CMG제약  58820  Dec-12    31602540.0      31590684.0
# 2               2  (주)CMG제약  58820  Dec-13    49048213.0      48997281.0
# 3               3  (주)CMG제약  58820  Dec-14    49067039.0      49002644.0
# 4               4  (주)CMG제약  58820  Dec-15    46872705.0      46806888.0
# ...           ...       ...    ...     ...           ...             ...
# 15145       15145   흥아해운(주)   3280  Dec-15   161824549.0     173076634.0
# 15146       15146   흥아해운(주)   3280  Dec-16   183829287.0     192487245.0
# 15147       15147   흥아해운(주)   3280  Dec-17   107614965.0     116884496.0
# 15148       15148   흥아해운(주)   3280  Dec-18    56731554.0      73148175.0
# 15149       15149   흥아해운(주)   3280  Dec-19    17632229.0      30919383.0
#
#                  0            1     자기자본증가율
# 0      11111111.11  11111111.11  1254789.63
# ...

# %%
# e2.to_csv('e2.csv',encoding='cp949')

# %%
e3 = pd.concat([df['자기자본증가율'],e2[['0','1']]],axis=1)
e3
# Out:
#        자기자본증가율            0            1
# 0        -2.02  11111111.11  11111111.11
# 1        75.17        72.78        75.17
# 2        55.10        55.20        55.10
# 3         0.01         0.04         0.01
# 4        -4.48        -4.47        -4.48
# ...        ...          ...          ...
# 15145     3.39         5.12         3.39
# 15146    11.22        13.60        11.22
# 15147   -39.28       -41.46       -39.28
# 15148   -37.42       -47.28       -37.42
# 15149   -57.73       -68.92       -57.73
#
# [15150 rows x 3 columns]

# %%
for i in range(len(e3)):
    if e3.loc[i,'자기자본증가율'] == 0:
        if e3.loc[i,'0'] != 11111111.11:
            if e3.loc[i,'1'] != 11111111.11:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'1']
            else:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'0']
        else:
            if e3.loc[i,'1'] != 11111111.11:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'1']
            else:
                e3.loc[i,'자기자본증가율'] = 1254789.63
        if e3.loc[i,'1'] == 0:
            e3.loc[i,'자기자본증가율'] = e3.loc[i,'0']
        if e3.loc[i,'1'] == 11111111.11:
            e3.loc[i,'자기자본증가율'] = 11111111.11
    if e3.loc[i,'자기자본증가율'] == 11111111.11:
        if e3.loc[i,'1'] != 11111111.11:
            if e3.loc[i,'0'] != 11111111.11:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'1']
            else:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'1']
        if e3.loc[i,'1'] == 11111111.11:
            if e3.loc[i,'0'] != 11111111.11:
                e3.loc[i,'자기자본증가율'] = e3.loc[i,'0']
            else:
                e3.loc[i,'자기자본증가율'] = 1254789.63
        
e3
# Out:
#        자기자본증가율            0            1
# 0        -2.02  11111111.11  11111111.11
# 1        75.17        72.78        75.17
# 2        55.10        55.20        55.10
# 3         0.01         0.04         0.01
# 4        -4.48        -4.47        -4.48
# ...        ...          ...          ...
# 15145     3.39         5.12         3.39
# 15146    11.22        13.60        11.22
# 15147   -39.28       -41.46       -39.28
# 15148   -37.42       -47.28       -37.42
# 15149   -57.73       -68.92       -57.73
#
# [15150 rows x 3 columns]

# %%
e3[e3['1']==11111111.11]
# Out:
#        자기자본증가율            0            1
# 0        -2.02  11111111.11  11111111.11
# 64       14.14        14.14  11111111.11
# 65        8.11         8.11  11111111.11
# 66        4.82         4.82  11111111.11
# 67       11.40        11.40  11111111.11
# ...        ...          ...          ...
# 15136     3.11         3.11  11111111.11
# 15137     1.39         1.39  11111111.11
# 15138     0.83         0.83  11111111.11
# 15139     0.99         0.99  11111111.11
# 15140     9.31         9.31  11111111.11
#
# [3156 rows x 3 columns]

# %%
# e3.to_csv('자기자본증가율최종.csv',encoding='cp949')

# %%
# w1[w1['기초자본금(IFRS연결)(천원)']==0]

# %%
# w1.to_csv('자기자본,매출증가율.csv',encoding='cp949')

# %%
w2 = pd.read_csv('./비율/자기자본,매출증가율.csv',encoding='cp949')
w2 = w2.fillna(11111111.11)
w2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  기말자본금(*)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11          21846600.0
# 1               1  (주)CMG제약  58820  Dec-12          33012770.0
# 2               2  (주)CMG제약  58820  Dec-13          43313433.0
# 3               3  (주)CMG제약  58820  Dec-14          43313433.0
# 4               4  (주)CMG제약  58820  Dec-15          44148622.0
# ...           ...       ...    ...     ...                 ...
# 15145       15145   흥아해운(주)   3280  Dec-15          42356715.0
# 15146       15146   흥아해운(주)   3280  Dec-16          63856715.0
# 15147       15147   흥아해운(주)   3280  Dec-17          63856715.0
# 15148       15148   흥아해운(주)   3280  Dec-18          87821715.0
# 15149       15149   흥아해운(주)   3280  Dec-19          56056196.0
#
#        기초자본금(IFRS)(천원)  기말자본금(*)(IFRS연결)(천원)  기초자본금(IFRS연결)(천원)  \
# 0           20588188.0            21846600.0         20588188.0
# 1           21846600.0            33012770.0         21846600.0
# ...

# %%
for i in range(len(w2)):
    if w2.loc[i,'2'] != 11111111.11:
        if w2.loc[i,'3'] != 11111111.11:
            w2.loc[i,'매출증가율'] = w2.loc[i,'3']
        else:
            w2.loc[i,'매출증가율'] = w2.loc[i,'2']
    elif w2.loc[i,'2'] == 11111111.11:
        if w2.loc[i,'3'] != 11111111.11:
            w2.loc[i,'매출증가율'] = w2.loc[i,'3']
        else:
            w2.loc[i,'매출증가율'] = 1254789.63

# %%
# w2.to_csv('w2.csv',encoding='cp949')

# %%
w3 = pd.concat([df['매출액증가율'],w2[['2','3']]], axis=1)
w3
# Out:
#        매출액증가율            2            3
# 0       56.40  11111111.11  11111111.11
# 1       -8.43        -8.43        -8.43
# 2       25.51        25.02        25.51
# 3       11.52        11.96        11.52
# 4       18.85        18.85        18.85
# ...       ...          ...          ...
# 15145    2.42         1.56         2.42
# 15146   -1.58        -2.69        -1.58
# 15147    0.56         0.11         0.56
# 15148   -9.87        -9.71        -9.87
# 15149  -86.45       -86.19       -86.45
#
# [15150 rows x 3 columns]

# %%
for i in range(len(w3)):
    if w3.loc[i,'매출액증가율'] == 0:
        if w3.loc[i,'2'] != 11111111.11:
            if w3.loc[i,'3'] != 11111111.11:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'3']
            else:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'2']
        else:
            if w3.loc[i,'3'] != 11111111.11:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'3']
            else:
                w3.loc[i,'매출액증가율'] = 1254789.63
        if w3.loc[i,'3'] == 0:
            w3.loc[i,'매출액증가율'] = w3.loc[i,'2']
        if w3.loc[i,'3'] == 11111111.11:
            w3.loc[i,'매출액증가율'] = 11111111.11
    if w3.loc[i,'매출액증가율'] == 11111111.11:
        if w3.loc[i,'3'] != 11111111.11:
            if w3.loc[i,'2'] != 11111111.11:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'3']
            else:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'3']
        if w3.loc[i,'3'] == 11111111.11:
            if w3.loc[i,'2'] != 11111111.11:
                w3.loc[i,'매출액증가율'] = w3.loc[i,'2']
            else:
                w3.loc[i,'매출액증가율'] = 1254789.63
        
w3
# Out:
#        매출액증가율            2            3
# 0       56.40  11111111.11  11111111.11
# 1       -8.43        -8.43        -8.43
# 2       25.51        25.02        25.51
# 3       11.52        11.96        11.52
# 4       18.85        18.85        18.85
# ...       ...          ...          ...
# 15145    2.42         1.56         2.42
# 15146   -1.58        -2.69        -1.58
# 15147    0.56         0.11         0.56
# 15148   -9.87        -9.71        -9.87
# 15149  -86.45       -86.19       -86.45
#
# [15150 rows x 3 columns]

# %%
# w3.to_csv('매출증가율최종.csv',encoding='cp949')

# %%
w3[w3['매출액증가율']==1254789.63]
# Out:
#            매출액증가율            2            3
# 194    1254789.63  11111111.11  11111111.11
# 195    1254789.63  11111111.11  11111111.11
# 196    1254789.63  11111111.11  11111111.11
# 331    1254789.63  11111111.11  11111111.11
# 411    1254789.63  11111111.11  11111111.11
# ...           ...          ...          ...
# 14094  1254789.63  11111111.11  11111111.11
# 14095  1254789.63  11111111.11  11111111.11
# 15122  1254789.63  11111111.11  11111111.11
# 15123  1254789.63  11111111.11  11111111.11
# 15124  1254789.63  11111111.11  11111111.11
#
# [192 rows x 3 columns]

# %%
test = pd.read_csv('./비율/자기자본.csv',encoding='cp949')
test
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0
# ...         ...    ...      ...           ...             ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0
#
# [15150 rows x 5 columns]

# %%
test['합계개별'] = test['합계(IFRS)(천원)'].shift().where(test.회사명.eq(test.회사명.shift()))
test
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)         합계개별
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0          NaN
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0   18290915.0
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0   31602540.0
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0   49048213.0
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0   49067039.0
# ...         ...    ...      ...           ...             ...          ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0  153935831.0
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0  161824549.0
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0  183829287.0
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0  107614965.0
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0   56731554.0
#
# [15150 rows x 6 columns]

# %%
test['합계개별율'] = (test['합계(IFRS)(천원)'] - test['합계개별'])/test['합계개별']
test
# Out:
#             회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)         합계개별  \
# 0      (주)CMG제약  58820  2011/12    18290915.0      18034249.0          NaN
# 1      (주)CMG제약  58820  2012/12    31602540.0      31590684.0   18290915.0
# 2      (주)CMG제약  58820  2013/12    49048213.0      48997281.0   31602540.0
# 3      (주)CMG제약  58820  2014/12    49067039.0      49002644.0   49048213.0
# 4      (주)CMG제약  58820  2015/12    46872705.0      46806888.0   49067039.0
# ...         ...    ...      ...           ...             ...          ...
# 15145   흥아해운(주)   3280  2015/12   161824549.0     173076634.0  153935831.0
# 15146   흥아해운(주)   3280  2016/12   183829287.0     192487245.0  161824549.0
# 15147   흥아해운(주)   3280  2017/12   107614965.0     116884496.0  183829287.0
# 15148   흥아해운(주)   3280  2018/12    56731554.0      73148175.0  107614965.0
# 15149   흥아해운(주)   3280  2019/12    17632229.0      30919383.0   56731554.0
#
#           합계개별율
# 0           NaN
# 1      0.727773
# ...

# %%
test[8:22]
# Out:
#          회사명  거래소코드     회계년도  합계(IFRS)(천원)  합계(IFRS연결)(천원)         합계개별  \
# 8   (주)CMG제약  58820  2019/12   180158283.0     180158283.0  103981846.0
# 9   (주)DB하이텍    990  2011/12   291709498.0     308061688.0          NaN
# 10  (주)DB하이텍    990  2012/12   274553219.0     290893335.0  291709498.0
# 11  (주)DB하이텍    990  2013/12   197287466.0     204756748.0  274553219.0
# 12  (주)DB하이텍    990  2014/12   136104062.0     120702734.0  197287466.0
# 13  (주)DB하이텍    990  2015/12   277662952.0     254057491.0  136104062.0
# 14  (주)DB하이텍    990  2016/12   364450453.0     341917315.0  277662952.0
# 15  (주)DB하이텍    990  2017/12   441546809.0     455797947.0  364450453.0
# 16  (주)DB하이텍    990  2018/12   542557222.0     558391531.0  441546809.0
# 17  (주)DB하이텍    990  2019/12   645305205.0     644650730.0  542557222.0
# 18   (주)ES큐브  50120  2011/12    39144414.0      39245830.0          NaN
# 19   (주)ES큐브  50120  2012/12    39881477.0      39859681.0   39144414.0
# ...

# %%
qq1 = pd.read_csv('./비율/영업이익진.csv',encoding='cp949')
# qq1 = qq1.fillna(11111111.11)
# qq1['영업이익개별스'] = qq1['영업이익(개별)'].shift().where(qq1.회사명.eq(qq1.회사명.shift()))
# qq1['영업이익연결스'] = qq1['영업이익(연결)'].shift().where(qq1.회사명.eq(qq1.회사명.shift()))
qq1['회계년도'] = pd.to_datetime(qq1['회계년도'], format='%b-%d').dt.strftime('20%d')
qq1 = qq1.sort_values('회계년도')
qq1 = qq1.reset_index(drop=True)
qq1 = qq1.loc[1353:]
qq1 = qq1.sort_values(by=['회사명','회계년도'])
qq1 = qq1.reset_index(drop=True)
qq1
# Out:
#             회사명  거래소코드  회계년도  영업이익(개별)  영업이익(연결)
# 0      (주)CMG제약  58820  2011    714950    640282
# 1      (주)CMG제약  58820  2012  -4045140  -4205504
# 2      (주)CMG제약  58820  2013    822547    791250
# 3      (주)CMG제약  58820  2014    446017    442322
# 4      (주)CMG제약  58820  2015  -2570878  -2572169
# ...         ...    ...   ...       ...       ...
# 15145   흥아해운(주)   3280  2015  16258441  21244278
# 15146   흥아해운(주)   3280  2016   1154122   5895873
# 15147   흥아해운(주)   3280  2017 -18649057 -13098624
# 15148   흥아해운(주)   3280  2018 -40598235 -37595967
# 15149   흥아해운(주)   3280  2019 -14756167 -12364292
#
# [15150 rows x 5 columns]

# %%
qq1.to_csv('영업이익.csv',encoding='cp949')

# %%
qq1[qq1['영업이익(개별)']==0]
# Out:
#             회사명   거래소코드  회계년도  영업이익(개별)  영업이익(연결)  영업이익개별스     영업이익연결스
# 213    (주)고려시멘트  198440  2014         0         0      NaN         NaN
# 214    (주)고려시멘트  198440  2015         0         0      0.0         0.0
# 215    (주)고려시멘트  198440  2016         0         0      0.0         0.0
# 363     (주)국전약품  307750  2018         0         0      NaN         NaN
# 364     (주)국전약품  307750  2019         0         0      0.0         0.0
# ...         ...     ...   ...       ...       ...      ...         ...
# 16204  헝셩그룹유한회사  900270  2019         0  43907646      0.0  34536637.0
# 16255  현대무벡스(주)  319400  2019         0         0      NaN         NaN
# 16472   휴마시스(주)  205470  2014         0         0      NaN         NaN
# 16473   휴마시스(주)  205470  2015         0         0      0.0         0.0
# 16474   휴마시스(주)  205470  2016         0         0      0.0         0.0
#
# [290 rows x 7 columns]

# %%
for i in range(0, len(qq1)-1):
    if qq1.loc[i,'회사명'] == qq1.loc[i+1,'회사명']:
        # 음수, 음수
        if qq1.iloc[i]["영업이익(개별)"] < 0 and qq1.iloc[i]["영업이익개별스"] < 0 :
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        # 양수, 음수
        elif qq1.iloc[i]["영업이익(개별)"] > 0 and qq1.iloc[i]["영업이익개별스"] < 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        # 음수, 양수
        elif qq1.iloc[i]["영업이익(개별)"] < 0 and qq1.iloc[i]["영업이익개별스"] > 0:
            qq1.loc[i, "영업이익증가률개별"] = (((qq1.iloc[i]["영업이익(개별)"]-qq1.iloc[i]["영업이익개별스"]) / qq1.iloc[i]["영업이익개별스"])*100).round(2)
        # 양수, 양수
        elif qq1.iloc[i]["영업이익(개별)"] > 0 and qq1.iloc[i]["영업이익개별스"] > 0:
            qq1.loc[i, "영업이익증가률개별"] = (((qq1.iloc[i]["영업이익(개별)"]-qq1.iloc[i]["영업이익개별스"]) / qq1.iloc[i]["영업이익개별스"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qq1.iloc[i]["영업이익(개별)"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 0
        elif qq1.iloc[i]["영업이익개별스"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qq1.loc[i, "영업이익증가률개별"] = 1254789.63
    elif qq1.loc[i,'회사명'] != qq1.loc[i-1,'회사명']:
        # 음수, 음수
        if qq1.iloc[i]["영업이익(개별)"] < 0 and qq1.iloc[i]["영업이익개별스"] < 0 :
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        # 양수, 음수
        elif qq1.iloc[i]["영업이익(개별)"] > 0 and qq1.iloc[i]["영업이익개별스"] < 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        # 음수, 양수
        elif qq1.iloc[i]["영업이익(개별)"] < 0 and qq1.iloc[i]["영업이익개별스"] > 0:
            qq1.loc[i, "영업이익증가률개별"] = (((qq1.iloc[i]["영업이익(개별)"]-qq1.iloc[i]["영업이익개별스"]) / qq1.iloc[i]["영업이익개별스"])*100).round(2)
        # 양수, 양수
        elif qq1.iloc[i]["영업이익(개별)"] > 0 and qq1.iloc[i]["영업이익개별스"] > 0:
            qq1.loc[i, "영업이익증가률개별"] = (((qq1.iloc[i]["영업이익(개별)"]-qq1.iloc[i]["영업이익개별스"]) / qq1.iloc[i]["영업이익개별스"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qq1.iloc[i]["영업이익(개별)"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 0
        elif qq1.iloc[i]["영업이익개별스"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qq1.loc[i, "영업이익증가률개별"] = 1254789.63
        
qq1.head(25)
# Out:
#          회사명  거래소코드  회계년도   영업이익(개별)   영업이익(연결)      영업이익개별스      영업이익연결스  \
# 0   (주)CMG제약  58820  2010   -7537070   -7537070          NaN          NaN
# 1   (주)CMG제약  58820  2011     714950     640282   -7537070.0   -7537070.0
# 2   (주)CMG제약  58820  2012   -4045140   -4205504     714950.0     640282.0
# 3   (주)CMG제약  58820  2013     822547     791250   -4045140.0   -4205504.0
# 4   (주)CMG제약  58820  2014     446017     442322     822547.0     791250.0
# 5   (주)CMG제약  58820  2015   -2570878   -2572169     446017.0     442322.0
# 6   (주)CMG제약  58820  2016    1730753    1730753   -2570878.0   -2572169.0
# 7   (주)CMG제약  58820  2017    1558607    1558607    1730753.0    1730753.0
# 8   (주)CMG제약  58820  2018    2567820    2567820    1558607.0    1558607.0
# 9   (주)CMG제약  58820  2019    2603774    2603774    2567820.0    2567820.0
# 10  (주)DB하이텍    990  2010 -362804082 -378471909          NaN          NaN
# 11  (주)DB하이텍    990  2011  -39983672  -43150444 -362804082.0 -378471909.0
# ...

# %%
for i in range(0, len(qq1)-1):
    if qq1.loc[i,'회사명'] == qq1.loc[i+1,'회사명']:
        # 음수, 음수
        if qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] < 0 :
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] < 0:
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 양수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qq1.iloc[i]["영업이익(연결)"] == 0 or qq1.iloc[i]["영업이익연결스"] == 0:
            qq1.loc[i, "영업이익증가률연결"] = 0
        elif qq1.iloc[i]["영업이익연결스"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qq1.loc[i, "영업이익증가률연결"] = 1254789.63
    elif qq1.loc[i,'회사명'] != qq1.loc[i-1,'회사명']:
        # 음수, 음수
        if qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] < 0 :
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] < 0:
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 양수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qq1.iloc[i]["영업이익(연결)"] == 0:
            qq1.loc[i, "영업이익증가률연결"] = 0
        elif qq1.iloc[i]["영업이익연결스"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qq1.loc[i, "영업이익증가률연결"] = 1254789.63
    elif qq1.loc[i,'회사명'] == qq1.loc[i-1,'회사명']:
        # 음수, 음수
        if qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] < 0 :
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] < 0:
            qq1.loc[i, "영업이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] < 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 양수, 양수
        elif qq1.iloc[i]["영업이익(연결)"] > 0 and qq1.iloc[i]["영업이익연결스"] > 0:
            qq1.loc[i, "영업이익증가률연결"] = (((qq1.iloc[i]["영업이익(연결)"]-qq1.iloc[i]["영업이익연결스"]) / qq1.iloc[i]["영업이익연결스"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qq1.iloc[i]["영업이익(연결)"] == 0:
            qq1.loc[i, "영업이익증가률연결"] = 0
        elif qq1.iloc[i]["영업이익연결스"] == 0:
            qq1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qq1.loc[i, "영업이익증가률연결"] = 1254789.63
        
qq1
# Out:
#             회사명  거래소코드  회계년도  영업이익(개별)  영업이익(연결)     영업이익개별스     영업이익연결스  \
# 0      (주)CMG제약  58820  2010  -7537070  -7537070         NaN         NaN
# 1      (주)CMG제약  58820  2011    714950    640282  -7537070.0  -7537070.0
# 2      (주)CMG제약  58820  2012  -4045140  -4205504    714950.0    640282.0
# 3      (주)CMG제약  58820  2013    822547    791250  -4045140.0  -4205504.0
# 4      (주)CMG제약  58820  2014    446017    442322    822547.0    791250.0
# ...         ...    ...   ...       ...       ...         ...         ...
# 16498   흥아해운(주)   3280  2015  16258441  21244278  15856524.0  18568741.0
# 16499   흥아해운(주)   3280  2016   1154122   5895873  16258441.0  21244278.0
# 16500   흥아해운(주)   3280  2017 -18649057 -13098624   1154122.0   5895873.0
# 16501   흥아해운(주)   3280  2018 -40598235 -37595967 -18649057.0 -13098624.0
# 16502   흥아해운(주)   3280  2019 -14756167 -12364292 -40598235.0 -37595967.0
#
#          영업이익증가률개별    영업이익증가률연결
# 0       1254789.63   1254789.63
# ...

# %%
qq1[qq1['영업이익증가률개별']==0]
# Out:
#             회사명   거래소코드  회계년도  영업이익(개별)  영업이익(연결)  영업이익개별스     영업이익연결스  \
# 213    (주)고려시멘트  198440  2014         0         0      NaN         NaN
# 214    (주)고려시멘트  198440  2015         0         0      0.0         0.0
# 215    (주)고려시멘트  198440  2016         0         0      0.0         0.0
# 363     (주)국전약품  307750  2018         0         0      NaN         NaN
# 451       (주)나노  187790  2014         0         0      NaN         NaN
# ...         ...     ...   ...       ...       ...      ...         ...
# 16203  헝셩그룹유한회사  900270  2018         0  34536637      0.0  39021752.0
# 16255  현대무벡스(주)  319400  2019         0         0      NaN         NaN
# 16472   휴마시스(주)  205470  2014         0         0      NaN         NaN
# 16473   휴마시스(주)  205470  2015         0         0      0.0         0.0
# 16474   휴마시스(주)  205470  2016         0         0      0.0         0.0
#
#        영업이익증가률개별  영업이익증가률연결
# 213          0.0       0.00
# 214          0.0       0.00
# ...

# %%
qq1 = qq1.sort_values('회계년도')
qq1 = qq1.reset_index(drop=True)
qq1 = qq1.loc[1353:]
qq1 = qq1.sort_values(by=['회사명','회계년도'])
qq1 = qq1.reset_index(drop=True)
qq1
# Out:
#             회사명  거래소코드  회계년도  영업이익(개별)  영업이익(연결)     영업이익개별스     영업이익연결스  \
# 0      (주)CMG제약  58820  2011    714950    640282  -7537070.0  -7537070.0
# 1      (주)CMG제약  58820  2012  -4045140  -4205504    714950.0    640282.0
# 2      (주)CMG제약  58820  2013    822547    791250  -4045140.0  -4205504.0
# 3      (주)CMG제약  58820  2014    446017    442322    822547.0    791250.0
# 4      (주)CMG제약  58820  2015  -2570878  -2572169    446017.0    442322.0
# ...         ...    ...   ...       ...       ...         ...         ...
# 15145   흥아해운(주)   3280  2015  16258441  21244278  15856524.0  18568741.0
# 15146   흥아해운(주)   3280  2016   1154122   5895873  16258441.0  21244278.0
# 15147   흥아해운(주)   3280  2017 -18649057 -13098624   1154122.0   5895873.0
# 15148   흥아해운(주)   3280  2018 -40598235 -37595967 -18649057.0 -13098624.0
# 15149   흥아해운(주)   3280  2019 -14756167 -12364292 -40598235.0 -37595967.0
#
#          영업이익증가률개별    영업이익증가률연결
# 0      11111111.11  11111111.11
# ...

# %%
for i in range(len(qq1)):
    if qq1.loc[i,'영업이익증가률개별'] != 11111111.11:
        if qq1.loc[i,'영업이익증가률연결'] != 11111111.11:
            qq1.loc[i,'영업이익증가률'] = qq1.loc[i,'영업이익증가률연결']
        else:
            qq1.loc[i,'영업이익증가률'] = qq1.loc[i,'영업이익증가률개별']
    elif qq1.loc[i,'영업이익증가률개별'] == 11111111.11:
        if qq1.loc[i,'영업이익증가률연결'] != 11111111.11:
            qq1.loc[i,'영업이익증가률'] = qq1.loc[i,'영업이익증가률연결']
        else:
            qq1.loc[i,'영업이익증가률'] = 1254789.63

# %%
# qq1.to_csv('qq1.csv',encoding='cp949')

# %%
qq2 = pd.concat([df['정상영업이익증가율'],qq1[['영업이익증가률개별','영업이익증가률연결']]],axis=1)
qq2 = qq2.fillna(11111111.11)

# %%
for i in range(len(qq2)):
    if qq2.loc[i,'정상영업이익증가율'] == 0:
        if qq2.loc[i,'영업이익증가률개별'] != 11111111.11:
            if qq2.loc[i,'영업이익증가률연결'] != 11111111.11:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률연결']
            else:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률개별']
        else:
            if qq2.loc[i,'영업이익증가률연결'] != 11111111.11:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률연결']
            else:
                qq2.loc[i,'정상영업이익증가율'] = 1254789.63
        if qq2.loc[i,'영업이익증가률연결'] == 0:
            qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률개별']
        if qq2.loc[i,'영업이익증가률연결'] == 11111111.11:
            qq2.loc[i,'정상영업이익증가율'] = 11111111.11
    if qq2.loc[i,'정상영업이익증가율'] == 11111111.11:
        if qq2.loc[i,'영업이익증가률연결'] != 11111111.11:
            if qq2.loc[i,'영업이익증가률개별'] != 11111111.11:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률연결']
            else:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률연결']
        if qq2.loc[i,'영업이익증가률연결'] == 11111111.11:
            if qq2.loc[i,'영업이익증가률개별'] != 11111111.11:
                qq2.loc[i,'정상영업이익증가율'] = qq2.loc[i,'영업이익증가률개별']
            else:
                qq2.loc[i,'정상영업이익증가율'] = 1254789.63
        
qq2
# Out:
#         정상영업이익증가율    영업이익증가률개별    영업이익증가률연결
# 0      1254789.63  11111111.11  11111111.11
# 1         -756.82      -665.79      -756.82
# 2      1254789.63  11111111.11  11111111.11
# 3          -44.10       -45.78       -44.10
# 4         -681.52      -676.41      -681.52
# ...           ...          ...          ...
# 15145       14.41         2.53        14.41
# 15146      -72.25       -92.90       -72.25
# 15147     -322.17     -1715.87      -322.17
# 15148  1254789.63  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11
#
# [15150 rows x 3 columns]

# %%
qq2.head(11)
# Out:
#      정상영업이익증가율    영업이익증가률개별    영업이익증가률연결
# 0   1254789.63  11111111.11  11111111.11
# 1      -756.82      -665.79      -756.82
# 2   1254789.63  11111111.11  11111111.11
# 3       -44.10       -45.78       -44.10
# 4      -681.52      -676.41      -681.52
# 5   1254789.63  11111111.11  11111111.11
# 6        -9.95        -9.95        -9.95
# 7        64.75        64.75        64.75
# 8         1.40  11111111.11         1.40
# 9   1254789.63  11111111.11  11111111.11
# 10  1254789.63  11111111.11  11111111.11

# %%
qq2[qq2['정상영업이익증가율']==1254789.63]
# Out:
#         정상영업이익증가율    영업이익증가률개별    영업이익증가률연결
# 0      1254789.63  11111111.11  11111111.11
# 2      1254789.63  11111111.11  11111111.11
# 5      1254789.63  11111111.11  11111111.11
# 9      1254789.63  11111111.11  11111111.11
# 10     1254789.63  11111111.11  11111111.11
# ...           ...          ...          ...
# 15116  1254789.63  11111111.11  11111111.11
# 15120  1254789.63  11111111.11  11111111.11
# 15142  1254789.63  11111111.11  11111111.11
# 15148  1254789.63  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11
#
# [2147 rows x 3 columns]

# %%
# qq2.to_csv('./비율/정상영업이익증가율최종.csv',encoding='cp949')

# %%
qw1 = pd.read_csv('./비율/당기순이익.csv',encoding='cp949')
qw1 = qw1.fillna(11111111.11)
# qw1['당기순이익개별스'] = qw1['당기순이익(손실)(IFRS)(천원)'].shift().where(qw1.회사명.eq(qw1.회사명.shift()))
# qw1['당기순이익연결스'] = qw1['당기순이익(손실)(IFRS연결)(천원)'].shift().where(qw1.회사명.eq(qw1.회사명.shift()))
# qw1['회계년도'] = pd.to_datetime(qw1['회계년도'], format='%Y/%m').dt.strftime('20%d')
qw1 = qw1[['회사명','거래소코드','회계년도','당기순이익(손실)(IFRS)(천원)','당기순이익(손실)(IFRS연결)(천원)']]
qw1
# Out:
#             회사명  거래소코드     회계년도  당기순이익(손실)(IFRS)(천원)  당기순이익(손실)(IFRS연결)(천원)
# 0      (주)CMG제약  58820  2011/12           -1264488.0             -1508282.0
# 1      (주)CMG제약  58820  2012/12           -6892739.0             -6660149.0
# 2      (주)CMG제약  58820  2013/12             335258.0               296181.0
# 3      (주)CMG제약  58820  2014/12             171502.0               158039.0
# 4      (주)CMG제약  58820  2015/12           -3648668.0             -3650091.0
# ...         ...    ...      ...                  ...                    ...
# 15145   흥아해운(주)   3280  2015/12            8827312.0             10517216.0
# 15146   흥아해운(주)   3280  2016/12          -16149442.0            -17173253.0
# 15147   흥아해운(주)   3280  2017/12          -67916740.0            -73500411.0
# 15148   흥아해운(주)   3280  2018/12          -96953501.0            -86540156.0
# 15149   흥아해운(주)   3280  2019/12          -52550693.0            -51356551.0
#
# [15150 rows x 5 columns]

# %%
for i in range(0, len(qw1)-1):
    if qw1.loc[i,'회사명'] == qw1.loc[i+1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0:
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0 or qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "순이익증가률개별"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률개별"] = 1254789.63
    elif qw1.loc[i,'회사명'] != qw1.loc[i-1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0:
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "순이익증가률개별"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률개별"] = 1254789.63
    elif qw1.loc[i,'회사명'] == qw1.loc[i-1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] < 0:
            qw1.loc[i, "순이익증가률개별"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"] > 0:
            qw1.loc[i, "순이익증가률개별"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "순이익증가률개별"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률개별"] = 1254789.63
        
qw1
# Out:
#             회사명  거래소코드     회계년도  당기순이익(손실)(IFRS)(천원)  당기순이익(손실)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12           -1264488.0             -1508282.0
# 1      (주)CMG제약  58820  2012/12           -6892739.0             -6660149.0
# 2      (주)CMG제약  58820  2013/12             335258.0               296181.0
# 3      (주)CMG제약  58820  2014/12             171502.0               158039.0
# 4      (주)CMG제약  58820  2015/12           -3648668.0             -3650091.0
# ...         ...    ...      ...                  ...                    ...
# 15145   흥아해운(주)   3280  2015/12            8827312.0             10517216.0
# 15146   흥아해운(주)   3280  2016/12          -16149442.0            -17173253.0
# 15147   흥아해운(주)   3280  2017/12          -67916740.0            -73500411.0
# 15148   흥아해운(주)   3280  2018/12          -96953501.0            -86540156.0
# 15149   흥아해운(주)   3280  2019/12          -52550693.0            -51356551.0
#
#           순이익증가률개별
# 0      11111111.11
# ...

# %%
for i in range(0, len(qw1)-1):
    if qw1.loc[i,'회사명'] == qw1.loc[i+1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0:
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0 or qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "순이익증가률연결"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률연결"] = 1254789.63
    elif qw1.loc[i,'회사명'] != qw1.loc[i-1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0:
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "순이익증가률연결"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률연결"] = 1254789.63
    elif qw1.loc[i,'회사명'] == qw1.loc[i-1,'회사명']:
        # 음수, 음수
        if qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0 :
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 양수, 음수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] < 0:
            qw1.loc[i, "순이익증가률연결"] = 11111111.11
        # 음수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] < 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 양수, 양수
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] > 0 and qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"] > 0:
            qw1.loc[i, "순이익증가률연결"] = (((qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"]-qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"]) / qw1.iloc[i]["당기순이익(손실)(IFRS연결)(천원)"])*100).round(2)
        # 두개 중 하나라도 0이 있으면
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "순이익증가률연결"] = 0
        elif qw1.iloc[i+1]["당기순이익(손실)(IFRS연결)(천원)"] == 0:
            qw1.loc[i, "영업이익증가률개별"] = 11111111.11
        else:
            qw1.loc[i, "순이익증가률연결"] = 1254789.63
        
qw1
# Out:
#             회사명  거래소코드     회계년도  당기순이익(손실)(IFRS)(천원)  당기순이익(손실)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12           -1264488.0             -1508282.0
# 1      (주)CMG제약  58820  2012/12           -6892739.0             -6660149.0
# 2      (주)CMG제약  58820  2013/12             335258.0               296181.0
# 3      (주)CMG제약  58820  2014/12             171502.0               158039.0
# 4      (주)CMG제약  58820  2015/12           -3648668.0             -3650091.0
# ...         ...    ...      ...                  ...                    ...
# 15145   흥아해운(주)   3280  2015/12            8827312.0             10517216.0
# 15146   흥아해운(주)   3280  2016/12          -16149442.0            -17173253.0
# 15147   흥아해운(주)   3280  2017/12          -67916740.0            -73500411.0
# 15148   흥아해운(주)   3280  2018/12          -96953501.0            -86540156.0
# 15149   흥아해운(주)   3280  2019/12          -52550693.0            -51356551.0
#
#           순이익증가률개별     순이익증가률연결
# ...

# %%
qw1.head(11)
# Out:
#          회사명  거래소코드     회계년도  당기순이익(손실)(IFRS)(천원)  당기순이익(손실)(IFRS연결)(천원)  \
# 0   (주)CMG제약  58820  2011/12           -1264488.0             -1508282.0
# 1   (주)CMG제약  58820  2012/12           -6892739.0             -6660149.0
# 2   (주)CMG제약  58820  2013/12             335258.0               296181.0
# 3   (주)CMG제약  58820  2014/12             171502.0               158039.0
# 4   (주)CMG제약  58820  2015/12           -3648668.0             -3650091.0
# 5   (주)CMG제약  58820  2016/12            1693463.0              1727895.0
# 6   (주)CMG제약  58820  2017/12            2834901.0              2834901.0
# 7   (주)CMG제약  58820  2018/12            6065026.0              6065026.0
# 8   (주)CMG제약  58820  2019/12            3051177.0              3051177.0
# 9   (주)DB하이텍    990  2011/12          -93084414.0            -97946584.0
# 10  (주)DB하이텍    990  2012/12          -32121504.0            -31341318.0
#
#        순이익증가률개별     순이익증가률연결
# 0   11111111.11  11111111.11
# 1   11111111.11  11111111.11
# ...

# %%
# qw1.to_csv('순이익증가율.csv',encoding='cp949')

# %%
qw2 = pd.read_csv('./비율/순이익증가율.csv',encoding='cp949')
qw2 = qw2.fillna(11111111.11)
qw2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  당기순이익(손실)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11           -1264488.0
# 1               1  (주)CMG제약  58820  Dec-12           -6892739.0
# 2               2  (주)CMG제약  58820  Dec-13             335258.0
# 3               3  (주)CMG제약  58820  Dec-14             171502.0
# 4               4  (주)CMG제약  58820  Dec-15           -3648668.0
# ...           ...       ...    ...     ...                  ...
# 15145       15145   흥아해운(주)   3280  Dec-15            8827312.0
# 15146       15146   흥아해운(주)   3280  Dec-16          -16149442.0
# 15147       15147   흥아해운(주)   3280  Dec-17          -67916740.0
# 15148       15148   흥아해운(주)   3280  Dec-18          -96953501.0
# 15149       15149   흥아해운(주)   3280  Dec-19          -52550693.0
#
#        당기순이익(손실)(IFRS연결)(천원)     순이익증가률개별     순이익증가률연결
# 0                 -1508282.0  11111111.11  11111111.11
# 1                 -6660149.0  11111111.11  11111111.11
# ...

# %%
for i in range(len(qw2)):
    if qw2.loc[i,'순이익증가률개별'] != 11111111.11:
        if qw2.loc[i,'순이익증가률연결'] != 11111111.11:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률연결']
        else:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률개별']
    elif qw2.loc[i,'순이익증가률개별'] == 11111111.11:
        if qw2.loc[i,'순이익증가률연결'] != 11111111.11:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률연결']
        else:
            qw2.loc[i,'순이익증가율'] = 1254789.63
            
    if qw2.loc[i,'순이익증가률개별'] != 0:
        if qw2.loc[i,'순이익증가률연결'] != 0:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률연결']
        else:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률개별']
    elif qw2.loc[i,'순이익증가률개별'] == 0:
        if qw2.loc[i,'순이익증가률연결'] != 0:
            qw2.loc[i,'순이익증가율'] = qw2.loc[i,'순이익증가률연결']
        else:
            qw2.loc[i,'순이익증가율'] = 1254789.63

# %%
qw2
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  당기순이익(손실)(IFRS)(천원)  \
# 0               0  (주)CMG제약  58820  Dec-11           -1264488.0
# 1               1  (주)CMG제약  58820  Dec-12           -6892739.0
# 2               2  (주)CMG제약  58820  Dec-13             335258.0
# 3               3  (주)CMG제약  58820  Dec-14             171502.0
# 4               4  (주)CMG제약  58820  Dec-15           -3648668.0
# ...           ...       ...    ...     ...                  ...
# 15145       15145   흥아해운(주)   3280  Dec-15            8827312.0
# 15146       15146   흥아해운(주)   3280  Dec-16          -16149442.0
# 15147       15147   흥아해운(주)   3280  Dec-17          -67916740.0
# 15148       15148   흥아해운(주)   3280  Dec-18          -96953501.0
# 15149       15149   흥아해운(주)   3280  Dec-19          -52550693.0
#
#        당기순이익(손실)(IFRS연결)(천원)     순이익증가률개별     순이익증가률연결       순이익증가율
# 0                 -1508282.0  11111111.11  11111111.11  11111111.11
# ...

# %%
import numpy as np
qw2 = qw2.replace(11111111.11,np.nan)

# %%
qw2 = qw2.replace(1254789.63,0)

# %%
# qw2.to_csv('qw2.csv',encoding='cp949')

# %%
qw3 = pd.concat([df['순이익증가율'],qw2[['순이익증가률개별','순이익증가률연결']]],axis=1)
qw3
# Out:
#            순이익증가율     순이익증가률개별     순이익증가률연결
# 0      1254789.63  11111111.11  11111111.11
# 1      1254789.63  11111111.11  11111111.11
# 2      1254789.63  11111111.11  11111111.11
# 3          -46.64       -48.84       -46.64
# 4        -2409.61     -2227.48     -2409.61
# ...           ...          ...          ...
# 15145      -42.68       -46.59       -42.68
# 15146     -263.29      -282.95      -263.29
# 15147  1254789.63  11111111.11  11111111.11
# 15148  1254789.63  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11
#
# [15150 rows x 3 columns]

# %%
for i in range(len(qw3)):
    if qw3.loc[i,'순이익증가율'] == 0:
        if qw3.loc[i,'순이익증가률개별'] != 11111111.11:
            if qw3.loc[i,'순이익증가률연결'] != 11111111.11:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률연결']
            else:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률개별']
        else:
            if qw3.loc[i,'순이익증가률연결'] != 11111111.11:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률연결']
            else:
                qw3.loc[i,'순이익증가율'] = 1254789.63
        if qw3.loc[i,'순이익증가률연결'] == 0:
            qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률개별']
        if qw3.loc[i,'순이익증가률연결'] == 11111111.11:
            qw3.loc[i,'순이익증가율'] = 11111111.11
    if qw3.loc[i,'순이익증가율'] == 11111111.11:
        if qw3.loc[i,'순이익증가률연결'] != 11111111.11:
            if qw3.loc[i,'순이익증가률개별'] != 11111111.11:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률연결']
            else:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률연결']
        if qw3.loc[i,'순이익증가률연결'] == 11111111.11:
            if qw3.loc[i,'순이익증가률개별'] != 11111111.11:
                qw3.loc[i,'순이익증가율'] = qw3.loc[i,'순이익증가률개별']
            else:
                qw3.loc[i,'순이익증가율'] = 1254789.63
        
qw3
# Out:
#            순이익증가율     순이익증가률개별     순이익증가률연결
# 0      1254789.63  11111111.11  11111111.11
# 1      1254789.63  11111111.11  11111111.11
# 2      1254789.63  11111111.11  11111111.11
# 3          -46.64       -48.84       -46.64
# 4        -2409.61     -2227.48     -2409.61
# ...           ...          ...          ...
# 15145      -42.68       -46.59       -42.68
# 15146     -263.29      -282.95      -263.29
# 15147  1254789.63  11111111.11  11111111.11
# 15148  1254789.63  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11
#
# [15150 rows x 3 columns]

# %%
for i in range(len(qw3)):
    if qw3.loc[i,'순이익증가률개별'] != 11111111.11:
        if qw3.loc[i,'순이익증가률연결'] != 11111111.11:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률연결']
        else:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률개별']
    elif qw3.loc[i,'순이익증가률개별'] == 11111111.11:
        if qw3.loc[i,'순이익증가률연결'] != 11111111.11:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률연결']
        else:
            qw3.loc[i,'순이익증가율1'] = 1254789.63
            
    if qw3.loc[i,'순이익증가률개별'] != 0:
        if qw3.loc[i,'순이익증가률연결'] != 0:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률연결']
        else:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률개별']
    elif qw3.loc[i,'순이익증가률개별'] == 0:
        if qw3.loc[i,'순이익증가률연결'] != 0:
            qw3.loc[i,'순이익증가율1'] = qw3.loc[i,'순이익증가률연결']
        else:
            qw3.loc[i,'순이익증가율1'] = 1254789.63
    else:
        qw3.loc[i,'순이익증가율1'] = 1254789.63

# %%
qw3
# Out:
#            순이익증가율     순이익증가률개별     순이익증가률연결      순이익증가율1
# 0      1254789.63  11111111.11  11111111.11  11111111.11
# 1      1254789.63  11111111.11  11111111.11  11111111.11
# 2      1254789.63  11111111.11  11111111.11  11111111.11
# 3          -46.64       -48.84       -46.64       -46.64
# 4        -2409.61     -2227.48     -2409.61     -2409.61
# ...           ...          ...          ...          ...
# 15145      -42.68       -46.59       -42.68       -42.68
# 15146     -263.29      -282.95      -263.29      -263.29
# 15147  1254789.63  11111111.11  11111111.11  11111111.11
# 15148  1254789.63  11111111.11  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11  11111111.11
#
# [15150 rows x 4 columns]

# %%
qw3[qw3['순이익증가율1']==11111111.11]
# Out:
#            순이익증가율     순이익증가률개별     순이익증가률연결      순이익증가율1
# 0      1254789.63  11111111.11  11111111.11  11111111.11
# 1      1254789.63  11111111.11  11111111.11  11111111.11
# 2      1254789.63  11111111.11  11111111.11  11111111.11
# 5      1254789.63  11111111.11  11111111.11  11111111.11
# 10     1254789.63  11111111.11  11111111.11  11111111.11
# ...           ...          ...          ...          ...
# 15126        0.00  11111111.11         0.00  11111111.11
# 15142  1254789.63  11111111.11  11111111.11  11111111.11
# 15147  1254789.63  11111111.11  11111111.11  11111111.11
# 15148  1254789.63  11111111.11  11111111.11  11111111.11
# 15149  1254789.63  11111111.11  11111111.11  11111111.11
#
# [4171 rows x 4 columns]

# %%
# qw3.to_csv('qw3.csv',encoding='cp949')

# %%
pp1 = pd.read_csv('./비율/비율입니다copy.csv',encoding='utf8')
pp1 = pp1.replace('#DIV/0!','')

# %%
# pp1.to_csv('재무비율계산.csv',encoding='cp949',index=False)
