# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./반정형데이터/배당금감소율여부.csv',encoding='cp949')
df['회계년도'] = pd.to_datetime(df['회계년도'], format='%d-%b').dt.strftime('20%d-%m')
df = df.sort_values('회계년도')
df = df.reset_index(drop=True)
df.loc[1500:]
# Out:
#        Unnamed: 0         회사명   거래소코드     회계년도  배당금감소율여부
# 1500        13288     동부건설(주)    5960  2010-12         0
# 1501        13048   대주전자재료(주)   78600  2010-12         0
# 1502        13028     대정화금(주)  120240  2010-12         0
# 1503        12810     대림통상(주)    6570  2010-12         0
# 1504        12825  대모엔지니어링(주)  317850  2010-12         0
# ...           ...         ...     ...      ...       ...
# 19487       12189   STX중공업(주)   71970  2019-12         0
# 19488       12199    가온미디어(주)   78890  2019-12         0
# 19489         657    (주)네오이뮨텍  950220  2019-12         0
# 19490       12489  글로벌텍스프리(주)  204620  2019-12         0
# 19491       19491     흥아해운(주)    3280  2019-12         0
#
# [17992 rows x 5 columns]

# %%
qq1 = qq1.sort_values('회계년도')
qq1 = qq1.reset_index(drop=True)
qq1 = qq1.loc[1353:]
qq1 = qq1.sort_values(by=['회사명','회계년도'])
qq1 = qq1.reset_index(drop=True)
qq1
