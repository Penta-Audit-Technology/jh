# %%
# 코스피 200 종목 가져오기

from bs4 import BeautifulSoup
import csv
import os
import re
import requests

stock_list = []
BaseUrl = 'http://finance.naver.com/sise/entryJongmok.nhn?&page='

for i in range(1, 21):
    url = BaseUrl + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'lxml')
    items = soup.find_all('td', {'class': 'ctg'})

    for item in items:
        #print(item)
        txt = item.a.get('href') # https://finance.naver.com/item/main.nhn?code=006390
        k = re.search('[\d]+', txt) ##정규표현식 사용. [\d] 숫자표현, + : 반복
        # print(k)
        if k:
            code = k.group()
            name = item.text
            data = code, name
            stock_list.append(data)
            print(data)

            with open ('KOSPI200.csv', 'a', newline='') as f: ## with 블록안에서 open, 블록밖에서 자동으로 close.
                writer = csv.writer(f)
                writer.writerow(data)

# 코스피 상위 200 종목 이름 가져오기
stock_name = []            
for i in range(len(stock_list)):
    print(stock_list[i][1])
    stock_name.append(stock_list[i][1])
    
stock_code = []
for i in range(len(stock_list)):
    print(stock_list[i][0])
    stock_code.append(stock_list[i][0])
    
print(stock_code)
# Out:
# ('005930', '삼성전자')
# ('373220', 'LG에너지솔루션')
# ('000660', 'SK하이닉스')
# ('207940', '삼성바이오로직스')
# ('051910', 'LG화학')
# ('006400', '삼성SDI')
# ('005380', '현대차')
# ('035420', 'NAVER')
# ('000270', '기아')
# ('035720', '카카오')
# ('068270', '셀트리온')
# ('028260', '삼성물산')
# ('005490', 'POSCO홀딩스')
# ('012330', '현대모비스')
# ('105560', 'KB금융')
# ('055550', '신한지주')
# ('034730', 'SK')
# ('096770', 'SK이노베이션')
# ('066570', 'LG전자')
# ('003670', '포스코케미칼')
# ('032830', '삼성생명')
# ('015760', '한국전력')
# ('003550', 'LG')
# ('323410', '카카오뱅크')
# ('010130', '고려아연')
# ('033780', 'KT&G')
# ('086790', '하나금융지주')
# ('017670', 'SK텔레콤')
# ('051900', 'LG생활건강')
# ('034020', '두산에너빌리티')
# ('259960', '크래프톤')
# ('329180', '현대중공업')
# ('010950', 'S-Oil')
# ('011200', 'HMM')
# ('030200', 'KT')
# ('003490', '대한항공')
# ('009830', '한화솔루션')
# ('009150', '삼성전기')
# ('018260', '삼성에스디에스')
# ('000810', '삼성화재')
# ('316140', '우리금융지주')
# ('011070', 'LG이노텍')
# ('377300', '카카오페이')
# ('036570', '엔씨소프트')
# ('024110', '기업은행')
# ('090430', '아모레퍼시픽')
# ('302440', 'SK바이오사이언스')
# ('086280', '현대글로비스')
# ('352820', '하이브')
# ('097950', 'CJ제일제당')
# ('009540', '한국조선해양')
# ('383220', 'F&F')
# ('011170', '롯데케미칼')
# ('402340', 'SK스퀘어')
# ('035250', '강원랜드')
# ('018880', '한온시스템')
# ('010140', '삼성중공업')
# ('361610', 'SK아이이테크놀로지')
# ('251270', '넷마블')
# ('032640', 'LG유플러스')
# ('034220', 'LG디스플레이')
# ('326030', 'SK바이오팜')
# ('047810', '한국항공우주')
# ('000720', '현대건설')
# ('161390', '한국타이어앤테크놀로지')
# ('267250', 'HD현대')
# ('028050', '삼성엔지니어링')
# ('004020', '현대제철')
# ('078930', 'GS')
# ('005830', 'DB손해보험')
# ('004990', '롯데지주')
# ('021240', '코웨이')
# ('010620', '현대미포조선')
# ('000100', '유한양행')
# ('271560', '오리온')
# ('000060', '메리츠화재')
# ('006800', '미래에셋증권')
# ('011790', 'SKC')
# ('011780', '금호석유')
# ('012450', '한화에어로스페이스')
# ('029780', '삼성카드')
# ('003410', '쌍용C&E')
# ('036460', '한국가스공사')
# ('005940', 'NH투자증권')
# ('241560', '두산밥캣')
# ('064350', '현대로템')
# ('138040', '메리츠금융지주')
# ('071050', '한국금융지주')
# ('137310', '에스디바이오센서')
# ('008770', '호텔신라')
# ('016360', '삼성증권')
# ('047050', '포스코인터내셔널')
# ('008560', '메리츠증권')
# ('028670', '팬오션')
# ('128940', '한미약품')
# ('020150', '일진머티리얼즈')
# ('007070', 'GS리테일')
# ('282330', 'BGF리테일')
# ('180640', '한진칼')
# ('002790', '아모레G')
# ('001450', '현대해상')
# ('023530', '롯데쇼핑')
# ('112610', '씨에스윈드')
# ('030000', '제일기획')
# ('272210', '한화시스템')
# ('139480', '이마트')
# ('004170', '신세계')
# ('010060', 'OCI')
# ('000120', 'CJ대한통운')
# ('002380', 'KCC')
# ('008930', '한미사이언스')
# ('204320', '만도')
# ('052690', '한전기술')
# ('006360', 'GS건설')
# ('042660', '대우조선해양')
# ('001040', 'CJ')
# ('026960', '동서')
# ('039490', '키움증권')
# ('000880', '한화')
# ('012750', '에스원')
# ('138930', 'BNK금융지주')
# ('014680', '한솔케미칼')
# ('111770', '영원무역')
# ('079550', 'LIG넥스원')
# ('336260', '두산퓨얼셀')
# ('006260', 'LS')
# ('088350', '한화생명')
# ('081660', '휠라홀딩스')
# ('000080', '하이트진로')
# ('001440', '대한전선')
# ('047040', '대우건설')
# ('011210', '현대위아')
# ('069620', '대웅제약')
# ('000990', 'DB하이텍')
# ('004370', '농심')
# ('285130', 'SK케미칼')
# ('298050', '효성첨단소재')
# ('005850', '에스엘')
# ('007310', '오뚜기')
# ('051600', '한전KPS')
# ('004000', '롯데정밀화학')
# ('006280', '녹십자')
# ('001120', 'LX인터내셔널')
# ('375500', 'DL이앤씨')
# ('004800', '효성')
# ('010120', 'LS ELECTRIC')
# ('005300', '롯데칠성')
# ('000150', '두산')
# ('014820', '동원시스템즈')
# ('000210', 'DL')
# ('120110', '코오롱인더')
# ('069960', '현대백화점')
# ('001230', '동국제강')
# ('093370', '후성')
# ('271940', '일진하이솔루스')
# ('003090', '대웅')
# ('000240', '한국앤컴퍼니')
# ('298020', '효성티앤씨')
# ('000670', '영풍')
# ('009900', '명신산업')
# ('019170', '신풍제약')
# ('009240', '한샘')
# ('178920', 'PI첨단소재')
# ('020560', '아시아나항공')
# ('017800', '현대엘리베이')
# ('073240', '금호타이어')
# ('001740', 'SK네트웍스')
# ('042670', '현대두산인프라코어')
# ('010780', '아이에스동서')
# ('031430', '신세계인터내셔날')
# ('039130', '하나투어')
# ('114090', 'GKL')
# ('185750', '종근당')
# ('016380', 'KG스틸')
# ('300720', '한일시멘트')
# ('161890', '한국콜마')
# ('001800', '오리온홀딩스')
# ('032350', '롯데관광개발')
# ('006040', '동원산업')
# ('003240', '태광산업')
# ('069260', 'TKG휴켐스')
# ('381970', '케이카')
# ('241590', '화승엔터프라이즈')
# ('005250', '녹십자홀딩스')
# ('192080', '더블유게임즈')
# ('009420', '한올바이오파마')
# ('001680', '대상')
# ('103140', '풍산')
# ('294870', 'HDC현대산업개발')
# ('006650', '대한유화')
# ('003850', '보령')
# ('192820', '코스맥스')
# ('004490', '세방전지')
# ('005440', '현대그린푸드')
# ('020000', '한섬')
# ('013890', '지누스')
# ('105630', '한세실업')
# ('284740', '쿠쿠홈시스')
# ('057050', '현대홈쇼핑')
# ('000070', '삼양홀딩스')
# 삼성전자
# LG에너지솔루션
# SK하이닉스
# 삼성바이오로직스
# LG화학
# 삼성SDI
# 현대차
# NAVER
# 기아
# 카카오
# 셀트리온
# 삼성물산
# POSCO홀딩스
# 현대모비스
# KB금융
# 신한지주
# SK
# SK이노베이션
# LG전자
# 포스코케미칼
# 삼성생명
# 한국전력
# LG
# 카카오뱅크
# 고려아연
# KT&G
# 하나금융지주
# SK텔레콤
# LG생활건강
# 두산에너빌리티
# 크래프톤
# 현대중공업
# S-Oil
# HMM
# KT
# 대한항공
# 한화솔루션
# 삼성전기
# 삼성에스디에스
# 삼성화재
# 우리금융지주
# LG이노텍
# 카카오페이
# 엔씨소프트
# 기업은행
# 아모레퍼시픽
# SK바이오사이언스
# 현대글로비스
# 하이브
# CJ제일제당
# 한국조선해양
# F&F
# 롯데케미칼
# SK스퀘어
# 강원랜드
# 한온시스템
# 삼성중공업
# SK아이이테크놀로지
# 넷마블
# LG유플러스
# LG디스플레이
# SK바이오팜
# 한국항공우주
# 현대건설
# 한국타이어앤테크놀로지
# HD현대
# 삼성엔지니어링
# 현대제철
# GS
# DB손해보험
# 롯데지주
# 코웨이
# 현대미포조선
# 유한양행
# 오리온
# 메리츠화재
# 미래에셋증권
# SKC
# 금호석유
# 한화에어로스페이스
# 삼성카드
# 쌍용C&E
# 한국가스공사
# NH투자증권
# 두산밥캣
# 현대로템
# 메리츠금융지주
# 한국금융지주
# 에스디바이오센서
# 호텔신라
# 삼성증권
# 포스코인터내셔널
# 메리츠증권
# 팬오션
# 한미약품
# 일진머티리얼즈
# GS리테일
# BGF리테일
# 한진칼
# 아모레G
# 현대해상
# 롯데쇼핑
# 씨에스윈드
# 제일기획
# 한화시스템
# 이마트
# 신세계
# OCI
# CJ대한통운
# KCC
# 한미사이언스
# 만도
# 한전기술
# GS건설
# 대우조선해양
# CJ
# 동서
# 키움증권
# 한화
# 에스원
# BNK금융지주
# 한솔케미칼
# 영원무역
# LIG넥스원
# 두산퓨얼셀
# LS
# 한화생명
# 휠라홀딩스
# 하이트진로
# 대한전선
# 대우건설
# 현대위아
# 대웅제약
# DB하이텍
# 농심
# SK케미칼
# 효성첨단소재
# 에스엘
# 오뚜기
# 한전KPS
# 롯데정밀화학
# 녹십자
# LX인터내셔널
# DL이앤씨
# 효성
# LS ELECTRIC
# 롯데칠성
# 두산
# 동원시스템즈
# DL
# 코오롱인더
# 현대백화점
# 동국제강
# 후성
# 일진하이솔루스
# 대웅
# 한국앤컴퍼니
# 효성티앤씨
# 영풍
# 명신산업
# 신풍제약
# 한샘
# PI첨단소재
# 아시아나항공
# 현대엘리베이
# 금호타이어
# SK네트웍스
# 현대두산인프라코어
# 아이에스동서
# 신세계인터내셔날
# 하나투어
# GKL
# 종근당
# KG스틸
# 한일시멘트
# 한국콜마
# 오리온홀딩스
# 롯데관광개발
# 동원산업
# 태광산업
# TKG휴켐스
# 케이카
# 화승엔터프라이즈
# 녹십자홀딩스
# 더블유게임즈
# 한올바이오파마
# 대상
# 풍산
# HDC현대산업개발
# 대한유화
# 보령
# 코스맥스
# 세방전지
# 현대그린푸드
# 한섬
# 지누스
# 한세실업
# 쿠쿠홈시스
# 현대홈쇼핑
# 삼양홀딩스
# 005930
# 373220
# 000660
# 207940
# 051910
# 006400
# 005380
# 035420
# 000270
# 035720
# 068270
# 028260
# 005490
# 012330
# 105560
# 055550
# 034730
# 096770
# 066570
# 003670
# 032830
# 015760
# 003550
# 323410
# 010130
# 033780
# 086790
# 017670
# 051900
# 034020
# 259960
# 329180
# 010950
# 011200
# 030200
# 003490
# 009830
# 009150
# 018260
# 000810
# 316140
# 011070
# 377300
# 036570
# 024110
# 090430
# 302440
# 086280
# 352820
# 097950
# 009540
# 383220
# 011170
# 402340
# 035250
# 018880
# 010140
# 361610
# 251270
# 032640
# 034220
# 326030
# 047810
# 000720
# 161390
# 267250
# 028050
# 004020
# 078930
# 005830
# 004990
# 021240
# 010620
# 000100
# 271560
# 000060
# 006800
# 011790
# 011780
# 012450
# 029780
# 003410
# 036460
# 005940
# 241560
# 064350
# 138040
# 071050
# 137310
# 008770
# 016360
# 047050
# 008560
# 028670
# 128940
# 020150
# 007070
# 282330
# 180640
# 002790
# 001450
# 023530
# 112610
# 030000
# 272210
# 139480
# 004170
# 010060
# 000120
# 002380
# 008930
# 204320
# 052690
# 006360
# 042660
# 001040
# 026960
# 039490
# 000880
# 012750
# 138930
# 014680
# 111770
# 079550
# 336260
# 006260
# 088350
# 081660
# 000080
# 001440
# 047040
# 011210
# 069620
# 000990
# 004370
# 285130
# 298050
# 005850
# 007310
# 051600
# 004000
# 006280
# 001120
# 375500
# 004800
# 010120
# 005300
# 000150
# 014820
# 000210
# 120110
# 069960
# 001230
# 093370
# 271940
# 003090
# 000240
# 298020
# 000670
# 009900
# 019170
# 009240
# 178920
# 020560
# 017800
# 073240
# 001740
# 042670
# 010780
# 031430
# 039130
# 114090
# 185750
# 016380
# 300720
# 161890
# 001800
# 032350
# 006040
# 003240
# 069260
# 381970
# 241590
# 005250
# 192080
# 009420
# 001680
# 103140
# 294870
# 006650
# 003850
# 192820
# 004490
# 005440
# 020000
# 013890
# 105630
# 284740
# 057050
# 000070
# ['005930', '373220', '000660', '207940', '051910', '006400', '005380', '035420', '000270', '035720', '068270', '028260', '005490', '012330', '105560', '055550', '034730', '096770', '066570', '003670', '032830', '015760', '003550', '323410', '010130', '033780', '086790', '017670', '051900', '034020', '259960', '329180', '010950', '011200', '030200', '003490', '009830', '009150', '018260', '000810', '316140', '011070', '377300', '036570', '024110', '090430', '302440', '086280', '352820', '097950', '009540', '383220', '011170', '402340', '035250', '018880', '010140', '361610', '251270', '032640', '034220', '326030', '047810', '000720', '161390', '267250', '028050', '004020', '078930', '005830', '004990', '021240', '010620', '000100', '271560', '000060', '006800', '011790', '011780', '012450', '029780', '003410', '036460', '005940', '241560', '064350', '138040', '071050', '137310', '008770', '016360', '047050', '008560', '028670', '128940', '020150', '007070', '282330', '180640', '002790', '001450', '023530', '112610', '030000', '272210', '139480', '004170', '010060', '000120', '002380', '008930', '204320', '052690', '006360', '042660', '001040', '026960', '039490', '000880', '012750', '138930', '014680', '111770', '079550', '336260', '006260', '088350', '081660', '000080', '001440', '047040', '011210', '069620', '000990', '004370', '285130', '298050', '005850', '007310', '051600', '004000', '006280', '001120', '375500', '004800', '010120', '005300', '000150', '014820', '000210', '120110', '069960', '001230', '093370', '271940', '003090', '000240', '298020', '000670', '009900', '019170', '009240', '178920', '020560', '017800', '073240', '001740', '042670', '010780', '031430', '039130', '114090', '185750', '016380', '300720', '161890', '001800', '032350', '006040', '003240', '069260', '381970', '241590', '005250', '192080', '009420', '001680', '103140', '294870', '006650', '003850', '192820', '004490', '005440', '020000', '013890', '105630', '284740', '057050', '000070']
