# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)
# pd.options.display.max_columns = None
df = pd.read_csv('4차테스트.csv',encoding='cp949')
df = df.replace(1254789.63,np.nan)
df = df.drop(columns=['무형자산개발비비율','경상개발비비율','통계청 한국표준산업분류 10차(소분류)'])
df
# Out:
#            회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0     (주)CMG제약  58820  11-Dec    3.53    1.98    -5.90    17.64    -1.43
# 1     (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2     (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3     (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# 4     (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17    11.04
# ...        ...    ...     ...     ...     ...      ...      ...      ...
# 9385   흥아해운(주)   3280  14-Dec    1.12   13.69    45.19   -13.68    -8.50
# 9386   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18   -12.92
# 9387   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08    56.39
# 9388   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    11.18
# 9389   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33    -5.85
#
#       자기자본증가율  매출액총이익율  ...  순운전자본비율      노동장비율  기계장비율       자본집약도  설비투자효율  \
# ...

# %%
plt.plot(df['순운전자본비율'])

# %%
# df.to_csv('확인용.csv',encoding='cp949')

# %%
df.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 이자보상배율                 0
# 총자산증가율               106
# 유형자산증가율              109
# 유동자산증가율              105
# 재고자산증가율              520
# 자기자본증가율              112
# 매출액총이익율              108
# 매출액순이익율              109
# 자기자본순이익율             116
# 총자본정상영업이익율           109
# 매출액정상영업이익율           109
# 총자본순이익율              109
# 총자본회전율               114
# 재고자산회전율              502
# 매출채권회전율              177
# 유형자산회전율              113
# 매입채무회전율              416
# 자기자본회전율              127
# 타인자본회전율              113
# 유동자산회전율              117
# 유동비율                 109
# 당좌비율                 109
# 현금비율                 109
# 부채비율                 115
# 차입금의존도               109
# CASH_FLOW_대_부채비율     109
# CASH_FLOW_대_매출액비율    109
# CASH_FLOW_대_차입금비율    109
# 자기자본구성비율             113
# 차입금비율                115
# 당좌자산구성비율             109
# 유동자산구성비율             109
# 매출채권_대_매입채무비율        109
# 단기차입금_대_총차입금비율       112
# ...

# %%
df.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
#        '재고자산증가율', '자기자본증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율', '총자본정상영업이익율',
#        '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율', '유형자산회전율',
#        '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율', '현금비율',
#        '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
#        'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
#        '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
#        '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
#        '설비투자효율', '총자본투자효율', '부가가치율', '종업원수증가율', 'R & D 투자효율', '직원감소율여부'],
#       dtype='object')

# %%
columns = df[['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율', '총자본정상영업이익율',
       '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율', '유형자산회전율',
       '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율', '현금비율',
       '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
       'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
       '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
       '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
       '설비투자효율', '총자본투자효율', '부가가치율', '종업원수증가율', 'R & D 투자효율', '직원감소율여부']]

# %%
medi = lambda x: x.fillna(x.median())
df = df.groupby('회사명').apply(medi)
df = df.dropna()
df = df.reset_index(drop=True)
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_10792\3510121016.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   medi = lambda x: x.fillna(x.median())
# C:\Users\82104\AppData\Local\Temp\ipykernel_10792\3510121016.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   medi = lambda x: x.fillna(x.median())
# C:\Users\82104\AppData\Local\Temp\ipykernel_10792\3510121016.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   medi = lambda x: x.fillna(x.median())
# ...

# %%
df.isna().sum()
# Out:
# 회사명                  0
# 거래소코드                0
# 회계년도                 0
# 이자보상배율               0
# 총자산증가율               0
# 유형자산증가율              0
# 유동자산증가율              0
# 재고자산증가율              0
# 자기자본증가율              0
# 매출액총이익율              0
# 매출액순이익율              0
# 자기자본순이익율             0
# 총자본정상영업이익율           0
# 매출액정상영업이익율           0
# 총자본순이익율              0
# 총자본회전율               0
# 재고자산회전율              0
# 매출채권회전율              0
# 유형자산회전율              0
# 매입채무회전율              0
# 자기자본회전율              0
# 타인자본회전율              0
# 유동자산회전율              0
# 유동비율                 0
# 당좌비율                 0
# 현금비율                 0
# 부채비율                 0
# 차입금의존도               0
# CASH_FLOW_대_부채비율     0
# CASH_FLOW_대_매출액비율    0
# CASH_FLOW_대_차입금비율    0
# 자기자본구성비율             0
# 차입금비율                0
# 당좌자산구성비율             0
# 유동자산구성비율             0
# 매출채권_대_매입채무비율        0
# 단기차입금_대_총차입금비율       0
# 유동부채비율               0
# 타인자본구성비율             0
# 재고자산_대_유동자산비율        0
# ...

# %%
from scipy import stats
from scipy.stats import shapiro

# 등락률 컬럼만 추출해서 pvalue 구하는 함수
def shap_pct(df_name):
    pct_colus = []
    pct_colus.append([col for col in df_name])
    for i in pct_colus:
        for j in i:
            shapiro_test = shapiro(df_name[j])
            print(j, "의 pvalue:", shapiro_test.pvalue)

# %%
shap_pct(df.iloc[:,3:])
# Out:
# 이자보상배율 의 pvalue: 0.0
# 총자산증가율 의 pvalue: 0.0
# 유형자산증가율 의 pvalue: 0.0
# 유동자산증가율 의 pvalue: 0.0
# 재고자산증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액총이익율 의 pvalue: 0.0
# 매출액순이익율 의 pvalue: 0.0
# 자기자본순이익율 의 pvalue: 0.0
# 총자본정상영업이익율 의 pvalue: 0.0
# 매출액정상영업이익율 의 pvalue: 0.0
# 총자본순이익율 의 pvalue: 0.0
# 총자본회전율 의 pvalue: 0.0
# 재고자산회전율 의 pvalue: 0.0
# 매출채권회전율 의 pvalue: 0.0
# 유형자산회전율 의 pvalue: 0.0
# 매입채무회전율 의 pvalue: 0.0
# 자기자본회전율 의 pvalue: 0.0
# 타인자본회전율 의 pvalue: 0.0
# 유동자산회전율 의 pvalue: 0.0
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 차입금의존도 의 pvalue: 0.0
# CASH_FLOW_대_부채비율 의 pvalue: 0.0
# CASH_FLOW_대_매출액비율 의 pvalue: 0.0
# CASH_FLOW_대_차입금비율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 1.6010471683552773e-31
# 차입금비율 의 pvalue: 0.0
# 당좌자산구성비율 의 pvalue: 1.4518347520123808e-38
# 유동자산구성비율 의 pvalue: 1.1716437282177639e-12
# 매출채권_대_매입채무비율 의 pvalue: 0.0
# 단기차입금_대_총차입금비율 의 pvalue: 0.0
# 유동부채비율 의 pvalue: 0.0
# 타인자본구성비율 의 pvalue: 0.0
# ...

# %%
sns.distplot(df['단기차입금_대_총차입금비율'])
# Out:
# c:\Users\82104\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='단기차입금_대_총차입금비율', ylabel='Density'>

# %%
fig, axes = plt.subplots(3, 5)
fig.set_size_inches((20,20))

stats.probplot(rs_sc2["단기차입금_대_총차입금비율"], dist=stats.norm, plot=axes[0,0])
# Out:
# ((array([-3.78616537, -3.55964471, -3.43521945, ...,  3.43521945,
#           3.55964471,  3.78616537]),
#   array([-0.71051983, -0.71051983, -0.71051983, ...,  0.52131067,
#           0.52131067,  0.52131067])),
#  (0.4135024552591293, -0.10110389876460506, 0.9352673823680798))

# %%
# df['재고자산회전율'][df['재고자산회전율'].isna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9061 entries, 0 to 9060
# Data columns (total 49 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   회사명                9061 non-null   object
#  1   거래소코드              9061 non-null   int64
#  2   회계년도               9061 non-null   object
#  3   이자보상배율             9061 non-null   float64
#  4   총자산증가율             9061 non-null   float64
#  5   유형자산증가율            9061 non-null   float64
#  6   유동자산증가율            9061 non-null   float64
#  7   재고자산증가율            9061 non-null   float64
#  8   자기자본증가율            9061 non-null   float64
#  9   순이익증가율             9061 non-null   float64
#  10  매출액총이익율            9061 non-null   float64
#  11  매출액순이익율            9061 non-null   float64
#  12  자기자본순이익율           9061 non-null   float64
#  13  총자본정상영업이익율         9061 non-null   float64
#  14  매출액정상영업이익율         9061 non-null   float64
# ...

# %%
# df.groupby('회사명')['무형자산처리무형자산개발비(천원)'].mean()

# %%
# df = df.where(pd.notnull(df), df.median(), axis='columns')
# df

# %%
# 이상치 박스플롯
from matplotlib.pyplot import imread

fig, axes = plt.subplots(10, 5)
fig.set_size_inches((40,35))

df.boxplot(column='총자산증가율', ax=axes[0,0])
df.boxplot(column='유형자산증가율', ax=axes[0,1])
df.boxplot(column='유동자산증가율', ax=axes[0,2])
df.boxplot(column='재고자산증가율', ax=axes[0,3])
df.boxplot(column='자기자본증가율', ax=axes[0,4])
df.boxplot(column='순이익증가율', ax=axes[1,0])
df.boxplot(column='매출액총이익율', ax=axes[1,1])
df.boxplot(column='매출액순이익율', ax=axes[1,2])
df.boxplot(column='자기자본순이익율', ax=axes[1,3])
df.boxplot(column='총자본정상영업이익율', ax=axes[1,4])
df.boxplot(column='매출액정상영업이익율', ax=axes[2,0])
df.boxplot(column='총자본순이익율', ax=axes[2,1])
df.boxplot(column='총자본회전율', ax=axes[2,2])
df.boxplot(column='재고자산회전율', ax=axes[2,3])
df.boxplot(column='매출채권회전율', ax=axes[2,4])
df.boxplot(column='유형자산회전율', ax=axes[3,0])
df.boxplot(column='매입채무회전율', ax=axes[3,1])
df.boxplot(column='자기자본회전율', ax=axes[3,2])
df.boxplot(column='타인자본회전율', ax=axes[3,3])
df.boxplot(column='유동자산회전율', ax=axes[3,4])
df.boxplot(column='유동비율', ax=axes[4,0])
df.boxplot(column='당좌비율', ax=axes[4,1])
df.boxplot(column='현금비율', ax=axes[4,2])
df.boxplot(column='부채비율', ax=axes[4,3])
df.boxplot(column='차입금의존도', ax=axes[4,4])
df.boxplot(column='CASH_FLOW_대_부채비율', ax=axes[5,0])
df.boxplot(column='CASH_FLOW_대_매출액비율', ax=axes[5,1])
df.boxplot(column='CASH_FLOW_대_차입금비율', ax=axes[5,2])
df.boxplot(column='자기자본구성비율', ax=axes[5,3])
df.boxplot(column='차입금비율', ax=axes[5,4])
df.boxplot(column='당좌자산구성비율', ax=axes[6,0])
df.boxplot(column='유동자산구성비율', ax=axes[6,1])
df.boxplot(column='매출채권_대_매입채무비율', ax=axes[6,2])
df.boxplot(column='단기차입금_대_총차입금비율', ax=axes[6,3])
df.boxplot(column='유동부채비율', ax=axes[6,4])
df.boxplot(column='타인자본구성비율', ax=axes[7,0])
df.boxplot(column='자기자본구성비율', ax=axes[7,1])
df.boxplot(column='재고자산_대_유동자산비율', ax=axes[7,2])
df.boxplot(column='재고자산_대_순운전자본비율', ax=axes[7,3])
df.boxplot(column='순운전자본비율', ax=axes[7,4])
df.boxplot(column='노동장비율', ax=axes[8,0])
df.boxplot(column='기계장비율', ax=axes[8,1])
df.boxplot(column='자본집약도', ax=axes[8,2])
df.boxplot(column='설비투자효율', ax=axes[8,3])
df.boxplot(column='총자본투자효율', ax=axes[8,4])
df.boxplot(column='부가가치율', ax=axes[9,0])
df.boxplot(column='이자보상배율', ax=axes[9,1])

plt.show()

# %%
df_se
# Out:
# 0         1.98
# 1       109.15
# 2        -2.09
# 3         3.86
# 4        -2.64
#          ...
# 9059     13.69
# 9060     21.93
# 9061     21.08
# 9062    -11.43
# 9063     -5.33
# Name: 총자산증가율, Length: 9064, dtype: float64

# %%
cols = []

total_df1_iqr = rs_sc2.copy()
total_df1_iqr = total_df1_iqr[['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '순이익증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율',
       '총자본정상영업이익율', '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율',
       '유형자산회전율', '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율',
       '현금비율', '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
       'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
       '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
       '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
       '설비투자효율', '총자본투자효율', '부가가치율']]
cols.append([col for col in total_df1_iqr])

Q1 = total_df1_iqr[['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '순이익증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율',
       '총자본정상영업이익율', '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율',
       '유형자산회전율', '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율',
       '현금비율', '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
       'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
       '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
       '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
       '설비투자효율', '총자본투자효율', '부가가치율']].quantile(q=0.25)

Q3 = total_df1_iqr[['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '순이익증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율',
       '총자본정상영업이익율', '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율',
       '유형자산회전율', '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율',
       '현금비율', '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
       'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
       '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
       '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
       '설비투자효율', '총자본투자효율', '부가가치율']].quantile(q=0.75)

IQR = Q3 - Q1
for i in cols:
    total_df1_iqr[i] = total_df1_iqr[i][(total_df1_iqr[i] <= Q3[i]+1.5*IQR[i]) & (total_df1_iqr[i] >= Q1[i]-1.5*IQR[i])]

# %%
# 이상치 박스플롯
from matplotlib.pyplot import imread

fig, axes = plt.subplots(10, 5)
fig.set_size_inches((40,35))

total_df1_iqr.boxplot(column='총자산증가율', ax=axes[0,0])
total_df1_iqr.boxplot(column='유형자산증가율', ax=axes[0,1])
total_df1_iqr.boxplot(column='유동자산증가율', ax=axes[0,2])
total_df1_iqr.boxplot(column='재고자산증가율', ax=axes[0,3])
total_df1_iqr.boxplot(column='자기자본증가율', ax=axes[0,4])
total_df1_iqr.boxplot(column='순이익증가율', ax=axes[1,0])
total_df1_iqr.boxplot(column='매출액총이익율', ax=axes[1,1])
total_df1_iqr.boxplot(column='매출액순이익율', ax=axes[1,2])
total_df1_iqr.boxplot(column='자기자본순이익율', ax=axes[1,3])
total_df1_iqr.boxplot(column='총자본정상영업이익율', ax=axes[1,4])
total_df1_iqr.boxplot(column='매출액정상영업이익율', ax=axes[2,0])
total_df1_iqr.boxplot(column='총자본순이익율', ax=axes[2,1])
total_df1_iqr.boxplot(column='총자본회전율', ax=axes[2,2])
total_df1_iqr.boxplot(column='재고자산회전율', ax=axes[2,3])
total_df1_iqr.boxplot(column='매출채권회전율', ax=axes[2,4])
total_df1_iqr.boxplot(column='유형자산회전율', ax=axes[3,0])
total_df1_iqr.boxplot(column='매입채무회전율', ax=axes[3,1])
total_df1_iqr.boxplot(column='자기자본회전율', ax=axes[3,2])
total_df1_iqr.boxplot(column='타인자본회전율', ax=axes[3,3])
total_df1_iqr.boxplot(column='유동자산회전율', ax=axes[3,4])
total_df1_iqr.boxplot(column='유동비율', ax=axes[4,0])
total_df1_iqr.boxplot(column='당좌비율', ax=axes[4,1])
total_df1_iqr.boxplot(column='현금비율', ax=axes[4,2])
total_df1_iqr.boxplot(column='부채비율', ax=axes[4,3])
total_df1_iqr.boxplot(column='차입금의존도', ax=axes[4,4])
total_df1_iqr.boxplot(column='CASH_FLOW_대_부채비율', ax=axes[5,0])
total_df1_iqr.boxplot(column='CASH_FLOW_대_매출액비율', ax=axes[5,1])
total_df1_iqr.boxplot(column='CASH_FLOW_대_차입금비율', ax=axes[5,2])
total_df1_iqr.boxplot(column='자기자본구성비율', ax=axes[5,3])
total_df1_iqr.boxplot(column='차입금비율', ax=axes[5,4])
total_df1_iqr.boxplot(column='당좌자산구성비율', ax=axes[6,0])
total_df1_iqr.boxplot(column='유동자산구성비율', ax=axes[6,1])
total_df1_iqr.boxplot(column='매출채권_대_매입채무비율', ax=axes[6,2])
total_df1_iqr.boxplot(column='단기차입금_대_총차입금비율', ax=axes[6,3])
total_df1_iqr.boxplot(column='유동부채비율', ax=axes[6,4])
total_df1_iqr.boxplot(column='타인자본구성비율', ax=axes[7,0])
total_df1_iqr.boxplot(column='자기자본구성비율', ax=axes[7,1])
total_df1_iqr.boxplot(column='재고자산_대_유동자산비율', ax=axes[7,2])
total_df1_iqr.boxplot(column='재고자산_대_순운전자본비율', ax=axes[7,3])
total_df1_iqr.boxplot(column='순운전자본비율', ax=axes[7,4])
total_df1_iqr.boxplot(column='노동장비율', ax=axes[8,0])
total_df1_iqr.boxplot(column='기계장비율', ax=axes[8,1])
total_df1_iqr.boxplot(column='자본집약도', ax=axes[8,2])
total_df1_iqr.boxplot(column='설비투자효율', ax=axes[8,3])
total_df1_iqr.boxplot(column='총자본투자효율', ax=axes[8,4])
total_df1_iqr.boxplot(column='부가가치율', ax=axes[9,0])
total_df1_iqr.boxplot(column='이자보상배율', ax=axes[9,1])

plt.show()

# %%
# 이상치 인덱스

q1 = total_df1_iqr['식료품'].quantile(0.25)
q3 = total_df1_iqr['식료품'].quantile(0.75)
iqr = q3-q1

condition1 = total_df1_iqr['식료품']>q3+1.5*iqr
condition2 = total_df1_iqr['식료품']<q1-1.5*iqr
a = total_df1_iqr[condition1].index
b = total_df1_iqr[condition2].index

print(a)
print(b)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
SS = StandardScaler()
RS = RobustScaler()

rs_sc = RS.fit_transform(df.iloc[:,3:])
rs_sc2 = pd.DataFrame(rs_sc)

# %%
rs_sc2.columns=['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율',
       '재고자산증가율', '자기자본증가율', '순이익증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율',
       '총자본정상영업이익율', '매출액정상영업이익율', '총자본순이익율', '총자본회전율', '재고자산회전율', '매출채권회전율',
       '유형자산회전율', '매입채무회전율', '자기자본회전율', '타인자본회전율', '유동자산회전율', '유동비율', '당좌비율',
       '현금비율', '부채비율', '차입금의존도', 'CASH_FLOW_대_부채비율', 'CASH_FLOW_대_매출액비율',
       'CASH_FLOW_대_차입금비율', '자기자본구성비율', '차입금비율', '당좌자산구성비율', '유동자산구성비율',
       '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '유동부채비율', '타인자본구성비율',
       '재고자산_대_유동자산비율', '재고자산_대_순운전자본비율', '순운전자본비율', '노동장비율', '기계장비율', '자본집약도',
       '설비투자효율', '총자본투자효율', '부가가치율']

# %%
# 이상치 박스플롯
from matplotlib.pyplot import imread

fig, axes = plt.subplots(10, 5)
fig.set_size_inches((40,35))

rs_sc2.boxplot(column='총자산증가율', ax=axes[0,0])
rs_sc2.boxplot(column='유형자산증가율', ax=axes[0,1])
rs_sc2.boxplot(column='유동자산증가율', ax=axes[0,2])
rs_sc2.boxplot(column='재고자산증가율', ax=axes[0,3])
rs_sc2.boxplot(column='자기자본증가율', ax=axes[0,4])
rs_sc2.boxplot(column='순이익증가율', ax=axes[1,0])
rs_sc2.boxplot(column='매출액총이익율', ax=axes[1,1])
rs_sc2.boxplot(column='매출액순이익율', ax=axes[1,2])
rs_sc2.boxplot(column='자기자본순이익율', ax=axes[1,3])
rs_sc2.boxplot(column='총자본정상영업이익율', ax=axes[1,4])
rs_sc2.boxplot(column='매출액정상영업이익율', ax=axes[2,0])
rs_sc2.boxplot(column='총자본순이익율', ax=axes[2,1])
rs_sc2.boxplot(column='총자본회전율', ax=axes[2,2])
rs_sc2.boxplot(column='재고자산회전율', ax=axes[2,3])
rs_sc2.boxplot(column='매출채권회전율', ax=axes[2,4])
rs_sc2.boxplot(column='유형자산회전율', ax=axes[3,0])
rs_sc2.boxplot(column='매입채무회전율', ax=axes[3,1])
rs_sc2.boxplot(column='자기자본회전율', ax=axes[3,2])
rs_sc2.boxplot(column='타인자본회전율', ax=axes[3,3])
rs_sc2.boxplot(column='유동자산회전율', ax=axes[3,4])
rs_sc2.boxplot(column='유동비율', ax=axes[4,0])
rs_sc2.boxplot(column='당좌비율', ax=axes[4,1])
rs_sc2.boxplot(column='현금비율', ax=axes[4,2])
rs_sc2.boxplot(column='부채비율', ax=axes[4,3])
rs_sc2.boxplot(column='차입금의존도', ax=axes[4,4])
rs_sc2.boxplot(column='CASH_FLOW_대_부채비율', ax=axes[5,0])
rs_sc2.boxplot(column='CASH_FLOW_대_매출액비율', ax=axes[5,1])
rs_sc2.boxplot(column='CASH_FLOW_대_차입금비율', ax=axes[5,2])
rs_sc2.boxplot(column='자기자본구성비율', ax=axes[5,3])
rs_sc2.boxplot(column='차입금비율', ax=axes[5,4])
rs_sc2.boxplot(column='당좌자산구성비율', ax=axes[6,0])
rs_sc2.boxplot(column='유동자산구성비율', ax=axes[6,1])
rs_sc2.boxplot(column='매출채권_대_매입채무비율', ax=axes[6,2])
rs_sc2.boxplot(column='단기차입금_대_총차입금비율', ax=axes[6,3])
rs_sc2.boxplot(column='유동부채비율', ax=axes[6,4])
rs_sc2.boxplot(column='타인자본구성비율', ax=axes[7,0])
rs_sc2.boxplot(column='자기자본구성비율', ax=axes[7,1])
rs_sc2.boxplot(column='재고자산_대_유동자산비율', ax=axes[7,2])
rs_sc2.boxplot(column='재고자산_대_순운전자본비율', ax=axes[7,3])
rs_sc2.boxplot(column='순운전자본비율', ax=axes[7,4])
rs_sc2.boxplot(column='노동장비율', ax=axes[8,0])
rs_sc2.boxplot(column='기계장비율', ax=axes[8,1])
rs_sc2.boxplot(column='자본집약도', ax=axes[8,2])
rs_sc2.boxplot(column='설비투자효율', ax=axes[8,3])
rs_sc2.boxplot(column='총자본투자효율', ax=axes[8,4])
rs_sc2.boxplot(column='부가가치율', ax=axes[9,0])
rs_sc2.boxplot(column='이자보상배율', ax=axes[9,1])

plt.show()

# %%
rs_sc2
# Out:
#         이자보상배율    총자산증가율   유형자산증가율   유동자산증가율   재고자산증가율   자기자본증가율     순이익증가율  \
# 0     0.216607 -0.040992 -0.342278  0.533967 -0.090271 -0.267780  -0.087430
# 1    -1.063757  5.739482 -0.244797  6.968750  0.139418  3.891164  -0.087430
# 2    -0.104619 -0.260518  0.861993 -0.706861  1.357071  2.809806  -0.087430
# 3     0.224552  0.060410  4.049836 -0.945992  0.105316 -0.158405  -0.087430
# 4    -3.841282 -0.290183 -0.313253 -0.308764  0.222417 -0.400323 -19.725660
# ...        ...       ...       ...       ...       ...       ...        ...
# 9056 -0.056946  0.590615  2.455641 -0.529891 -0.267553  0.259159   0.308996
# 9057 -0.068297  1.035059  2.684009 -0.444973 -0.378385  0.023707  -0.054519
# 9058 -0.160238  0.989213  2.107886 -0.917120  1.359579  0.445582  -1.887970
# 9059 -0.231748 -0.764293 -0.922782  0.386209  0.225928 -2.275323  -0.054519
# 9060 -0.315743 -0.435275 -0.680175 -0.280231 -0.201103 -2.175108  -0.054519
#
# ...

# %%
# from scipy.stats.mstats import winsorize

# def fences(df, variable_name):    
#     q1 = df[variable_name].quantile(0.25)
#     q3 = df[variable_name].quantile(0.75)
#     iqr = q3-q1
#     outer_fence = 3*iqr
#     outer_fence_le = q1-outer_fence
#     outer_fence_ue = q3+outer_fence
#     return outer_fence_le, outer_fence_ue

# outer_fence_le, outer_fence_ue = fences(df, '총자산증가율')
# print('Lower end outer fence: ', outer_fence_le)
# print('Upper end outer fence: ', outer_fence_ue)
# Out:
# Lower end outer fence:  -61.3
# Upper end outer fence:  69.79249999999999

# %%
# print('90% quantile:   ', df['총자산증가율'].quantile(0.90))       
# print('92.5% quantile: ', df['총자산증가율'].quantile(0.925))      
# print('95% quantile:   ', df['총자산증가율'].quantile(0.95))       
# print('97.5% quantile: ', df['총자산증가율'].quantile(0.975))      
# print('99% quantile:   ', df['총자산증가율'].quantile(0.99))       
# print('99.9% quantile: ', df['총자산증가율'].quantile(0.999))
# Out:
# 90% quantile:    34.12799999999999
# 92.5% quantile:  42.800750000000015
# 95% quantile:    58.77449999999996
# 97.5% quantile:  92.43700000000008
# 99% quantile:    165.83840000000004
# 99.9% quantile:  571.3518400000197

# %%
# from scipy.stats.mstats import winsorize
# winsor = lambda x: winsorize(x[columns],limits=[0.05,0.95])
# df.groupby('회사명').apply(winsor)

# %%
# from scipy.stats.mstats import winsorize

# for i in range(len(df)):
#     df.iloc[i][:,3:] = winsorize(df.iloc[i][:,3:],limits=[0.05,0.95])

# %%
# from scipy.stats.mstats import winsorize

# # option 1a:
# for v in range(len(df)):
#     df.loc[v]['총자산증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유형자산증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유동자산증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['재고자산증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자기자본증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['순이익증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매출액총이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매출액순이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자기자본순이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['총자본정상영업이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매출액정상영업이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['총자본순이익율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['총자본회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['재고자산회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매출채권회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유형자산회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매입채무회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자기자본회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['타인자본회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유동자산회전율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유동비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['당좌비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['현금비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['부채비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['차입금의존도'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['CASH_FLOW_대_부채비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['CASH_FLOW_대_매출액비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['CASH_FLOW_대_차입금비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자기자본구성비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['차입금비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['당좌자산구성비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유동자산구성비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['매출채권_대_매입채무비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['단기차입금_대_총차입금비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['유동부채비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['타인자본구성비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자기자본구성비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['재고자산_대_유동자산비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['재고자산_대_순운전자본비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['순운전자본비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['노동장비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['기계장비율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['자본집약도'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['설비투자효율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['총자본투자효율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['부가가치율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['종업원수증가율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['R & D 투자효율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['무형자산처리무형자산개발비(천원)'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['경상개발비(천원)'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])
#     df.loc[v]['이자보상배율'] = winsorize(df.loc[v]['총자산증가율'],limits=[.05,.95])

# %%
# from scipy.stats.mstats import winsorize
# winsor = lambda x: winsorize(x,limits=[0.01,0.99])
# df = df.groupby('회사명').apply(winsor)

# %%
df.boxplot(column='총자산증가율')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(40,30))
sns.heatmap(rs_sc2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['VIF_Factor'] = [variance_inflation_factor(df.iloc[:,3:],i)for i in range(df.iloc[:,3:].shape[1])]
vif['features'] = df.iloc[:,3:].columns
vif
# Out:
#     VIF_Factor           features
# 0     1.180052             이자보상배율
# 1     2.615733             총자산증가율
# 2     1.166815            유형자산증가율
# 3     2.345047            유동자산증가율
# 4     1.018942            재고자산증가율
# 5     1.142176            자기자본증가율
# 6     2.852018            매출액총이익율
# 7     2.999443            매출액순이익율
# 8     1.888208           자기자본순이익율
# 9     3.033702         총자본정상영업이익율
# 10   14.272820         매출액정상영업이익율
# 11    4.830834            총자본순이익율
# 12   27.056617             총자본회전율
# 13    1.023295            재고자산회전율
# 14    1.006970            매출채권회전율
# 15    1.455740            유형자산회전율
# 16    2.250885            매입채무회전율
# 17    2.778061            자기자본회전율
# 18    7.738022            타인자본회전율
# 19   20.707239            유동자산회전율
# 20  264.521444               유동비율
# 21  250.566692               당좌비율
# 22    4.746930               현금비율
# 23  172.155379               부채비율
# 24   12.914727             차입금의존도
# 25    1.579985   CASH_FLOW_대_부채비율
# ...

# %%
df = df.drop(columns=['매출액정상영업이익율','유동비율','당좌비율','부채비율','CASH_FLOW_대_매출액비율','자기자본구성비율','차입금비율',
                              '당좌자산구성비율','유동자산구성비율','유동부채비율','타인자본구성비율','순운전자본비율','노동장비율'],axis=1)

# %%
# df = df.drop(columns=['매출액정상영업이익율','총자본회전율','타인자본회전율','유동자산회전율','유동비율', '당좌비율','부채비율','차입금의존도','CASH_FLOW_대_매출액비율',
#                       '자기자본구성비율','차입금비율','당좌자산구성비율','유동자산구성비율','유동부채비율','타인자본구성비율','재고자산_대_유동자산비율','순운전자본비율'],axis=1)

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
rs_sc2.columns
# Out:
# Index(['이자보상배율', '총자산증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '자기자본증가율',
#        '순이익증가율', '매출액총이익율', '매출액순이익율', '자기자본순이익율', '총자본정상영업이익율', '총자본순이익율',
#        '총자본회전율', '재고자산회전율', '매출채권회전율', '유형자산회전율', '매입채무회전율', '자기자본회전율',
#        '타인자본회전율', '유동자산회전율', '현금비율', '차입금의존도', 'CASH_FLOW_대_부채비율',
#        'CASH_FLOW_대_차입금비율', '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '재고자산_대_유동자산비율',
#        '재고자산_대_순운전자본비율', '기계장비율', '자본집약도', '설비투자효율', '총자본투자효율', '부가가치율'],
#       dtype='object')

# %%
x = df[['회계년도','총자산증가율', '유형자산증가율', '유동자산증가율', '재고자산증가율', '자기자본증가율',
       '매출액총이익율', '매출액순이익율', '자기자본순이익율', '총자본정상영업이익율', '총자본순이익율',
       '총자본회전율', '재고자산회전율', '매출채권회전율', '유형자산회전율', '매입채무회전율', '자기자본회전율',
       '타인자본회전율', '유동자산회전율', '현금비율', '차입금의존도', 'CASH_FLOW_대_부채비율',
       'CASH_FLOW_대_차입금비율', '매출채권_대_매입채무비율', '단기차입금_대_총차입금비율', '재고자산_대_유동자산비율',
       '재고자산_대_순운전자본비율', '기계장비율', '자본집약도', '설비투자효율', '총자본투자효율', '부가가치율']]

# %%
x['회계년도'] = pd.to_datetime(x['회계년도'],format='%d-%b').dt.strftime("20%d-%m")
x
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_25832\133147366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['회계년도'] = pd.to_datetime(x['회계년도'],format='%d-%b').dt.strftime("20%d-%m")
#          회계년도  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  자기자본증가율  매출액총이익율  매출액순이익율  \
# 0     2011-12    1.98    -5.90    17.64    -1.43    -2.02    41.83    -8.50
# 1     2012-12  109.15    -4.12   207.08     7.73    75.17    28.34   -40.97
# 2     2013-12   -2.09    16.09   -18.89    56.29    55.10    38.70     1.45
# 3     2014-12    3.86    74.30   -25.93     6.37     0.01    37.07     0.69
# 4     2015-12   -2.64    -5.37    -7.17    11.04    -4.48    36.26   -13.50
# ...       ...     ...      ...      ...      ...      ...      ...      ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
ss_clf = SS.fit_transform(df['이자보상배율'].reshape(-1, 1))
y = df['이자보상배율']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\82104\OneDrive\바탕 화면\vscode\프로젝트1\.git\jh\3차테스트 copy.ipynb 셀 40 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/82104/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/vscode/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/.git/jh/3%EC%B0%A8%ED%85%8C%EC%8A%A4%ED%8A%B8%20copy.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import StandardScaler
#       <a href='vscode-notebook-cell:/c%3A/Users/82104/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/vscode/%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B81/.git/jh/3%EC%B0%A8%ED%85%8C%EC%8A%A4%ED%8A%B8%20copy.ipynb#X54sZmlsZQ%3D%3D?line=1'>2</a> SS = StandardScaler()
# ...

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import RobustScaler
# SS = StandardScaler()
# RS = RobustScaler()
# df_ss = SS.fit_transform(x)
# rs = RS.fit_transform(x)

# %%
# 훈련
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression(solver='liblinear', random_state=42)
log_reg.fit(x,y)

# %%
import statsmodels.api as sm
results = sm.OLS(endog=y, exog=x).fit()
results.summary()

# %%
import statsmodels.api as sm
results = sm.OLS(y, sm.add_constant(x)).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 이자보상배율   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.099
# Method:                 Least Squares   F-statistic:                     33.04
# Date:                Mon, 26 Sep 2022   Prob (F-statistic):          2.58e-184
# Time:                        18:26:21   Log-Likelihood:            -1.4450e+05
# No. Observations:                9064   AIC:                         2.891e+05
# Df Residuals:                    9032   BIC:                         2.893e+05
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
# 앞의 LinearRegression예제에서 분할한 feature 데이터 셋인 X_data과 Target 데이터 셋인 Y_target 데이터셋을 그대로 이용 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from sklearn.datasets import load_boston
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
# %matplotlib inline

ridge = Ridge(alpha = 10)
neg_mse_scores = cross_val_score(ridge, x, y, scoring="neg_mean_squared_error", cv = 5)
rmse_scores  = np.sqrt(-1 * neg_mse_scores)
avg_rmse = np.mean(rmse_scores)
print(' 5 folds 의 개별 Negative MSE scores: ', np.round(neg_mse_scores, 3))
print(' 5 folds 의 개별 RMSE scores : ', np.round(rmse_scores,3))
print(' 5 folds 의 평균 RMSE : {0:.3f} '.format(avg_rmse))
# Out:
#  5 folds 의 개별 Negative MSE scores:  [-5.78695020e+10 -5.81171844e+10 -5.72567442e+10 -6.94659845e+10
#  -7.05978214e+11]
#  5 folds 의 개별 RMSE scores :  [240560.807 241075.06  239283.815 263564.004 840225.097]
#  5 folds 의 평균 RMSE : 364941.757

# %%
# Ridge에 사용될 alpha 파라미터의 값들을 정의
alphas = [0, 0.1, 1, 10, 100]

# 각 alpha에 따른 회귀 계수 값을 시각화하기 위해 5개의 열로 된 맷플롯립 축 생성  
fig, axs = plt.subplots(figsize=(18,6), nrows=1, ncols=5)
# 각 alpha에 따른 회귀 계수 값을 데이터로 저장하기 위한 DataFrame 생성  
coeff_df = pd.DataFrame()

# alphas list 값을 iteration하면서 alpha에 따른 평균 rmse 구하고, 회귀 계수 값 시각화 및 데이터 저장. pos는 axis의 위치 지정
for pos, alpha in enumerate(alphas):
    ridge = Ridge(alpha = alpha)
    ridge.fit(x, y)
   
    #cross_val_score를 이용하여 5 fold의 평균 RMSE 계산
    neg_mse_scores = cross_val_score(ridge, x, y, scoring="neg_mean_squared_error", cv = 5)
    avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
    print('alpha {0} 일 때 5 folds 의 평균 RMSE : {1:.3f} '.format(alpha,avg_rmse))

     # alpha에 따른 피처별 회귀 계수를 Series로 변환하고 이를 DataFrame의 컬럼으로 추가.  
    coeff = pd.Series(data=ridge.coef_, index=x.columns )
    colname='alpha:'+str(alpha)
    coeff_df[colname] = coeff
    # 막대 그래프로 각 alpha 값에서의 회귀 계수를 시각화. 회귀 계수값이 높은 순으로 표현
    coeff = coeff.sort_values(ascending=False)
    axs[pos].set_title(colname)
    axs[pos].set_xlim(-3,6)
    sns.barplot(x=coeff.values, y=coeff.index, ax=axs[pos])

# for 문 바깥에서 맷플롯립의 show 호출 및 alpha에 따른 피처별 회귀 계수를 DataFrame으로 표시
plt.show()

# alpha 값에 따른 컬럼별 회귀계수 출력
sort_column = 'alpha:'+str(alphas[0])
coeff_df.sort_values(by=sort_column, ascending=False)
# Out:
# alpha 0 일 때 5 folds 의 평균 RMSE : 365091.983
# alpha 0.1 일 때 5 folds 의 평균 RMSE : 365090.475
# alpha 1 일 때 5 folds 의 평균 RMSE : 365076.907
# alpha 10 일 때 5 folds 의 평균 RMSE : 364941.757
# alpha 100 일 때 5 folds 의 평균 RMSE : 363638.499
#                         alpha:0     alpha:0.1       alpha:1      alpha:10  \
# 타인자본회전율            47581.803310  47580.925806  47573.031322  47494.387058
# 자기자본회전율             6779.513098   6779.068715   6775.070875   6735.251170
# 총자본투자효율             4811.452799   4811.018782   4807.115272   4768.340220
# 현금비율                2797.501612   2797.540738   2797.892759   2801.401633
# 자기자본순이익율            1167.620392   1167.520814   1166.625113   1157.717406
# 유동자산증가율             1087.223077   1087.218053   1087.172860   1086.723366
# 총자본정상영업이익율           701.818479    701.479985    698.435741    668.210543
# 유형자산회전율              250.059904    250.057041    250.031294    249.776176
# 부가가치율                235.829295    235.888664    236.422600    241.724089
# ...

# %%
from sklearn.linear_model import Lasso, ElasticNet

# alpha값에 따른 회귀 모델의 폴드 평균 RMSE를 출력하고 회귀 계수값들을 DataFrame으로 반환 
def get_linear_reg_eval(model_name, params=None, X_data_n=None, y_target_n=None, 
                        verbose=True, return_coeff=True):
    coeff_df = pd.DataFrame()
    if verbose : print('####### ', model_name , '#######')
    for param in params:
        if model_name =='Ridge': model = Ridge(alpha=param)
        elif model_name =='Lasso': model = Lasso(alpha=param)
        elif model_name =='ElasticNet': model = ElasticNet(alpha=param, l1_ratio=0.7)
        neg_mse_scores = cross_val_score(model, X_data_n, 
                                             y_target_n, scoring="neg_mean_squared_error", cv = 5)
        avg_rmse = np.mean(np.sqrt(-1 * neg_mse_scores))
        print('alpha {0}일 때 5 폴드 세트의 평균 RMSE: {1:.3f} '.format(param, avg_rmse))
        # cross_val_score는 evaluation metric만 반환하므로 모델을 다시 학습하여 회귀 계수 추출
       
        model.fit(X_data_n , y_target_n)
        if return_coeff:
            # alpha에 따른 피처별 회귀 계수를 Series로 변환하고 이를 DataFrame의 컬럼으로 추가. 
            coeff = pd.Series(data=model.coef_ , index=X_data_n.columns )
            colname='alpha:'+str(param)
            coeff_df[colname] = coeff

    return coeff_df

# 라쏘에 사용될 alpha 파라미터의 값들을 정의하고 get_linear_reg_eval() 함수 호출
lasso_alphas = [ 0.05,0.1,0.5,0.7,1.0]
coeff_lasso_df =get_linear_reg_eval('Lasso', params=lasso_alphas, X_data_n=x, y_target_n=y)

# 반환된 coeff_lasso_df를 첫번째 컬럼순으로 내림차순 정렬하여 회귀계수 DataFrame출력
sort_column = 'alpha:'+str(lasso_alphas[0])
coeff_lasso_df.sort_values(by=sort_column, ascending=False)
# Out:
# #######  Lasso #######
# alpha 0.05일 때 5 폴드 세트의 평균 RMSE: 365092.072
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 365092.161
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 365092.872
# alpha 0.7일 때 5 폴드 세트의 평균 RMSE: 365093.228
# alpha 1.0일 때 5 폴드 세트의 평균 RMSE: 365093.762
#                      alpha:0.05     alpha:0.1     alpha:0.5     alpha:0.7  \
# 타인자본회전율            47581.723943  47581.644576  47581.009630  47580.692188
# 자기자본회전율             6779.423812   6779.334525   6778.620229   6778.263095
# 총자본투자효율             4811.309086   4811.165373   4810.015646   4809.440860
# 현금비율                2797.505589   2797.509567   2797.541386   2797.557295
# 자기자본순이익율            1167.586794   1167.553197   1167.284416   1167.150035
# 유동자산증가율             1087.212811   1087.202545   1087.120422   1087.079353
# 총자본정상영업이익율           701.628026    701.437573    699.913889    699.152248
# 유형자산회전율              250.059832    250.059759    250.059179    250.058890
# ...

# %%
# 엘라스틱넷에 사용될 alpha 파라미터의 값들을 정의하고 get_linear_reg_eval() 함수 호출
# l1_ratio는 0.7로 고정
elastic_alphas = [ 0.07, 0.1, 0.5, 1, 3]
coeff_elastic_df =get_linear_reg_eval('ElasticNet', params=elastic_alphas,
                                      X_data_n=x, y_target_n=y)

# 반환된 coeff_elastic_df를 첫번째 컬럼순으로 내림차순 정렬하여 회귀계수 DataFrame출력
sort_column = 'alpha:'+str(elastic_alphas[0])
coeff_elastic_df.sort_values(by=sort_column, ascending=False)
# Out:
# #######  ElasticNet #######
# alpha 0.07일 때 5 폴드 세트의 평균 RMSE: 362917.675
# alpha 0.1일 때 5 폴드 세트의 평균 RMSE: 362048.221
# alpha 0.5일 때 5 폴드 세트의 평균 RMSE: 352415.300
# alpha 1일 때 5 폴드 세트의 평균 RMSE: 343025.756
# alpha 3일 때 5 폴드 세트의 평균 RMSE: 318226.679
#                      alpha:0.07     alpha:0.1     alpha:0.5       alpha:1  \
# 타인자본회전율            46023.778977  45416.135341  39380.839359  34522.542959
# 자기자본회전율             5993.599908   5689.463392   2816.066970    820.961522
# 총자본투자효율             4080.549152   3817.096591   1833.384330    952.834803
# 현금비율                2867.724601   2895.530283   3183.508034   3424.622031
# 유동자산증가율             1078.500309   1075.173632   1040.227794   1001.547181
# 자기자본순이익율             996.301535    932.543394    400.678818    116.589874
# 매출액총이익율              362.662478    541.203269   2022.172434   2778.641041
# 부가가치율                334.972865    370.233456    621.589288    715.048963
# ...
