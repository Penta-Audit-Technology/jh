# %%
import pandas as pd
import numpy as np

df = pd.read_csv('당좌순운전회전률.csv',encoding='cp949')
df
# Out:
#             회사명  거래소코드     회계년도  당좌자산회전률(IFRS)  당좌자산회전률(IFRS연결)  \
# 0      (주)CMG제약  58820  2011/12           1.56             1.55
# 1      (주)CMG제약  58820  2012/12           0.57             0.57
# 2      (주)CMG제약  58820  2013/12           0.52             0.52
# 3      (주)CMG제약  58820  2014/12           0.80             0.80
# 4      (주)CMG제약  58820  2015/12           1.22             1.22
# ...         ...    ...      ...            ...              ...
# 15145   흥아해운(주)   3280  2015/12           6.55             6.38
# 15146   흥아해운(주)   3280  2016/12           8.39             7.96
# 15147   흥아해운(주)   3280  2017/12           9.83             9.30
# 15148   흥아해운(주)   3280  2018/12           8.28             8.14
# 15149   흥아해운(주)   3280  2019/12           1.41             1.16
#
#        순운전자본회전률(IFRS)  순운전자본회전률(IFRS연결)
# 0                0.86              0.86
# 1                0.42              0.42
# 2                0.42              0.42
# ...

# %%
df['당좌자산회전률'] = df['당좌자산회전률(IFRS연결)'].fillna(df['당좌자산회전률(IFRS)'])
df['순운전자본회전률'] = df['순운전자본회전률(IFRS연결)'].fillna(df['순운전자본회전률(IFRS)'])

# %%
# df.to_csv('당좌순운전회전률.csv',encoding='cp949',index=False)
