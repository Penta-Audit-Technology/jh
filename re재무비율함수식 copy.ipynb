# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None

# %%
############################ WARNING ######################################
# 회사명 기준으로 shift 등의 조치가 필요한 경우 따로 취한 다음에 함수 적용하세요
# 안 그러면 터집니다...
###########################################################################


# 단순하게 나누는 함수
# df_name : raw_data 들어있는 데이터프레임
# a, b : 계산을 하고자하는 데이터프레임의 컬럼명을 입력 (a가 분자, b가 분모)
# c : 계산 결과를 저장하고자 하는 데이터프레임의 컬럼명을 입력

# 증가율 함수
def pct (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
                if 0 < (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
                if -0.01 < (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
                if 0.01 < (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
                if 0 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan

# 수익성 계산
def profit (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
# 매출액순이익률,현금비율,부채비율,유동자산구성비율,재고자산 대 유동자산비율,
# 자기자본구성비율, 타인자본구성비율, 유동부채비율, 차입금비율
def profit_tns(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
            
def profit_chddud(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모,분자가 - 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
            
# 활동성 계산
def activity(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모,분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모,분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
            
def activity_tnsdns(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모,분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # a(-), b(+), c(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모,분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
            
# 생산성 계산
def produce (df_name,a,b,c,d):
    for i in range(len(df_name)):
        # (-a) - (-b) 일때
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i,d] = ((abs(df_name.iloc[i][a]) - abs(df_name.iloc[i][b]))/df_name.iloc[i][c])
        # a - (-b) 일때
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i,d] = ((df_name.iloc[i][a] - abs(df_name.iloc[i][b]))/df_name.iloc[i][c]) # b 절대값 변환
        # (-a) - b 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i,d] = ((df_name.iloc[i][a] - df_name.iloc[i][b])/df_name.iloc[i][c]) # a 아무대나 절대값 하나
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i,d] = ((df_name.iloc[i][a] - df_name.iloc[i][b])/df_name.iloc[i][c])
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i,d] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i,d] = np.nan
            
# 안정성 계산
def stability(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan

# %%
# # 증가율 함수
# def pct1 (df_name,a,b,c,d):
#     for i in range(len(df_name)-1):
#         if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
#             # 분모,분자가 - 인 상황
#             if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
#                 df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
#             #분모 +, 분자 - 인 상황
#             elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
#                 df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
#             # 분모 -, 분자 + 인 상황
#             elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
#                 df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
#             # 분모, 분자가 + 인 상황
#             elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
#                 df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
#             # 분모 또는 분자가 0인 경우
#             elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
#                 df_name.loc[i,d] = 0
#             # 둘다 결측치인 경우
#             else:
#                 df_name.loc[i,d] = np.nan
                
#         elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
#             # 분모,분자가 - 인 상황
#             if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
#                 df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
#             #분모 +, 분자 - 인 상황
#             elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
#                 df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
#             # 분모 -, 분자 + 인 상황
#             elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
#                 df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
#             # 분모, 분자가 + 인 상황
#             elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
#                 df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
#             # 분모 또는 분자가 0인 경우
#             elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
#                 df_name.loc[i,d] = 0
#             # 둘다 결측치인 경우
#             else:
#                 df_name.loc[i,d] = np.nan

# %%
# def pct2 (df_name,a,b,c,d):
#     for i in range(len(df_name)-1):
#         if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
#             df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
#         elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
#             df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)

# %%
df1 = pd.read_csv('./비율/성장성비율.csv',encoding='cp949')
df1.columns = df1.columns.str.replace('\(', '')
df1.columns = df1.columns.str.replace('\)', '')
df1.columns = df1.columns.str.replace('\*', '')
df1.columns = df1.columns.str.replace('IFRS', '')
df1.columns = df1.columns.str.replace('천원', '')
df1
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\557423526.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1.columns = df1.columns.str.replace('\(', '')
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\557423526.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1.columns = df1.columns.str.replace('\)', '')
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\557423526.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1.columns = df1.columns.str.replace('\*', '')
#             회사명  거래소코드     회계년도           자산         자산연결         유형자산  \
# 0      (주)CMG제약  58820  2011/12   27548539.0   27305198.0    9652599.0
# 1      (주)CMG제약  58820  2012/12   56988604.0   57108035.0    9264142.0
# 2      (주)CMG제약  58820  2013/12   55961620.0   55912563.0   10805092.0
# 3      (주)CMG제약  58820  2014/12   58127098.0   58068326.0   18833775.0
# 4      (주)CMG제약  58820  2015/12   56591972.0   56532821.0   17822468.0
# ...         ...    ...      ...          ...          ...          ...
# 15145   흥아해운(주)   3280  2015/12  771212062.0  791640802.0  479816639.0
# 15146   흥아해운(주)   3280  2016/12  942586770.0  958532259.0  667913303.0
# 15147   흥아해운(주)   3280  2017/12  834107402.0  848958520.0  557578439.0
# 15148   흥아해운(주)   3280  2018/12  782787041.0  803698457.0  490215607.0
# 15149   흥아해운(주)   3280  2019/12  386550839.0  430962722.0  237825418.0
#
#             유형자산연결         유동자산       유동자산연결           자본         자본연결
# 0        9707759.0   15264885.0   15341167.0   18290915.0   18034249.0
# 1        9307482.0   47073443.0   47109213.0   31602540.0   31590685.0
# 2       10805092.0   38258866.0   38209699.0   49048213.0   48997281.0
# 3       18833775.0   28359823.0   28300941.0   49067039.0   49002644.0
# 4       17822468.0   26330765.0   26271614.0   46872705.0   46806888.0
# ...            ...          ...          ...          ...          ...
# 15145  483319774.0  124478864.0  136280257.0  161824549.0  173076634.0
# 15146  671042170.0   90973953.0  102103828.0  183829287.0  192487245.0
# 15147  560312598.0  105819304.0  115675013.0  107614965.0  116884496.0
# 15148  492709259.0  103181415.0  108354984.0   56731554.0   73148175.0
# 15149  238913893.0   61182850.0   93810124.0   17632229.0   30919383.0
#
# [15150 rows x 11 columns]

# %%
df1['자산개별'] = df1['자산'].shift(1)
df1['자산연결_'] = df1['자산연결'].shift(1)
df1['유형자산개별'] = df1['유형자산'].shift(1)
df1['유형자산연결_'] = df1['유형자산연결'].shift(1)
df1['유동자산개별'] = df1['유동자산'].shift(1)
df1['유동자산연결_'] = df1['유동자산연결'].shift(1)
df1['자본개별'] = df1['자본'].shift(1)
df1['자본연결_'] = df1['자본연결'].shift(1)
# df1['총자산개별율'] = ''
pct2(df1,'회사명','자산','자산개별','총자산개별율1')
pct2(df1,'회사명','자산연결','자산연결_','총자산개별율2')
pct2(df1,'회사명','유형자산','유형자산개별','유형자산개별율1')
pct2(df1,'회사명','유형자산연결','유형자산연결_','유형자산개별율2')
pct2(df1,'회사명','유동자산','유동자산개별','유동자산개별율1')
pct2(df1,'회사명','유동자산연결','유동자산연결_','유동자산개별율2')
pct2(df1,'회사명','자본','자본개별','자본개별율1')
pct2(df1,'회사명','자본연결','자본연결_','자본개별율2')
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\484843349.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\484843349.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\484843349.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#   df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\484843349.py:6: RuntimeWarning: invalid value encountered in double_scalars
#   df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
# C:\Users\82104\AppData\Local\Temp\ipykernel_21436\484843349.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)

# %%
df1['총자산증가율'] = df1['총자산개별율2'].fillna(df1['총자산개별율1'])
df1['유형자산증가율'] = df1['유형자산개별율2'].fillna(df1['유형자산개별율1'])
df1['유동자산증가율'] = df1['유동자산개별율2'].fillna(df1['유동자산개별율1'])
df1['자본증가율'] = df1['자본개별율2'].fillna(df1['자본개별율1'])

# %%
# df1.to_csv('성장성계산식비율.csv',encoding='cp949',index=False)

# %%
df2 = pd.read_csv('./비율/수익성비율.csv',encoding='cp949')
df2.columns = df2.columns.str.replace('\(', '')
df2.columns = df2.columns.str.replace('\)', '')
df2.columns = df2.columns.str.replace('\*', '')
df2.columns = df2.columns.str.replace('IFRS', '')
df2.columns = df2.columns.str.replace('천원', '')
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결
# 0       18034249.0   27548539.0   27305198.0
# 1       31590685.0   56988604.0   57108035.0
# 2       48997281.0   55961620.0   55912563.0
# 3       49002644.0   58127098.0   58068326.0
# 4       46806888.0   56591972.0   56532821.0
# ...            ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0
# 15146  192487245.0  942586770.0  958532259.0
# 15147  116884496.0  834107402.0  848958520.0
# 15148   73148175.0  782787041.0  803698457.0
# 15149   30919383.0  386550839.0  430962722.0
#
# [15150 rows x 15 columns]

# %%
df2['자본개별'] = df2['자본'].shift(1)
df2['자본연결_'] = df2['자본연결'].shift(1)
df2['자산개별'] = df2['자산'].shift(1)
df2['자산연결_'] = df2['자산연결'].shift(1)
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결         자본개별        자본연결_  \
# 0       18034249.0   27548539.0   27305198.0          NaN          NaN
# 1       31590685.0   56988604.0   57108035.0   18290915.0   18034249.0
# 2       48997281.0   55961620.0   55912563.0   31602540.0   31590685.0
# 3       49002644.0   58127098.0   58068326.0   49048213.0   48997281.0
# 4       46806888.0   56591972.0   56532821.0   49067039.0   49002644.0
# ...            ...          ...          ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0  153935831.0  167402807.0
# 15146  192487245.0  942586770.0  958532259.0  161824549.0  173076634.0
# 15147  116884496.0  834107402.0  848958520.0  183829287.0  192487245.0
# 15148   73148175.0  782787041.0  803698457.0  107614965.0  116884496.0
# 15149   30919383.0  386550839.0  430962722.0   56731554.0   73148175.0
#
#               자산개별        자산연결_
# 0              NaN          NaN
# 1       27548539.0   27305198.0
# 2       56988604.0   57108035.0
# 3       55961620.0   55912563.0
# 4       58127098.0   58068326.0
# ...            ...          ...
# 15145  627805252.0  649240003.0
# 15146  771212062.0  791640802.0
# 15147  942586770.0  958532259.0
# 15148  834107402.0  848958520.0
# 15149  782787041.0  803698457.0
#
# [15150 rows x 19 columns]

# %%
profit(df2,'회사명','매출액수익','매출원가','매출액총익율1')
profit(df2,'회사명','매출액수익연결','매출원가연결','매출액총익율2')
profit_tns(df2,'회사명','당기순이익손실','매출액수익','매출액순이익율1')
profit_tns(df2,'회사명','당기순이익손실연결','매출액수익연결','매출액순이익율2')
profit_chddud(df2,'회사명','당기순이익손실','자본','자본개별','자기자본순이익율1')
profit_chddud(df2,'회사명','당기순이익손실연결','자본연결','자본연결_','자기자본순이익율2')

# %%
profit_chddud(df2,'회사명','영업이익개별','자본','자본개별','총자본영업이익율1')
profit_chddud(df2,'회사명','영업이익연결','자본연결','자본연결_','총자본영업이익율2')
profit(df2,'회사명','영업이익개별','매출액수익','매출액영업이익률1')
profit(df2,'회사명','영업이익연결','매출액수익연결','매출액영업이익률2')
profit_chddud(df2,'회사명','당기순이익손실','자산','자산개별','총자본순이익률1')
profit_chddud(df2,'회사명','당기순이익손실연결','자산연결','자산연결_','총자본순이익률2')

# %%
# df2.to_csv('수익성계산식비율.csv',encoding='cp949',index=False)

# %%
df2['매출액총익율'] = df2['매출액총익율2'].fillna(df2['매출액총익율1'])
df2['매출액순이익율'] = df2['매출액순이익율2'].fillna(df2['매출액순이익율1'])
df2['자기자본순이익율'] = df2['자기자본순이익율2'].fillna(df2['자기자본순이익율1'])
df2['총자본영업이익율'] = df2['총자본영업이익율2'].fillna(df2['총자본영업이익율1'])
df2['매출액영업이익률'] = df2['매출액영업이익률2'].fillna(df2['매출액영업이익률1'])
df2['총자본순이익률'] = df2['총자본순이익률2'].fillna(df2['총자본순이익률1'])

# %%
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결         자본개별        자본연결_  \
# 0       18034249.0   27548539.0   27305198.0          NaN          NaN
# 1       31590685.0   56988604.0   57108035.0   18290915.0   18034249.0
# 2       48997281.0   55961620.0   55912563.0   31602540.0   31590685.0
# 3       49002644.0   58127098.0   58068326.0   49048213.0   48997281.0
# 4       46806888.0   56591972.0   56532821.0   49067039.0   49002644.0
# ...            ...          ...          ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0  153935831.0  167402807.0
# 15146  192487245.0  942586770.0  958532259.0  161824549.0  173076634.0
# 15147  116884496.0  834107402.0  848958520.0  183829287.0  192487245.0
# 15148   73148175.0  782787041.0  803698457.0  107614965.0  116884496.0
# 15149   30919383.0  386550839.0  430962722.0   56731554.0   73148175.0
#
#               자산개별        자산연결_    매출액총익율1    매출액총익율2   매출액순이익율1   매출액순이익율2  \
# 0              NaN          NaN  41.832069  41.832069  -7.123192  -8.496548
# 1       27548539.0   27305198.0  28.339519  28.339519 -42.402793 -40.971945
# 2       56988604.0   57108035.0  38.457185  38.698504   1.649718   1.451715
# 3       55961620.0   55912563.0  37.070673  37.070673   0.753769   0.694598
# 4       58127098.0   58068326.0  36.255153  36.255153 -13.492650 -13.497912
# ...            ...          ...        ...        ...        ...        ...
# 15145  627805252.0  649240003.0   4.730554   6.203323   1.101265   1.244471
# 15146  771212062.0  791640802.0   2.949451   4.493679  -2.070467  -2.064723
# 15147  942586770.0  958532259.0   0.358741   2.088563  -8.697640  -8.787422
# 15148  834107402.0  848958520.0  -2.768912  -0.928795 -13.752129 -11.479521
# 15149  782787041.0  803698457.0        NaN        NaN        NaN        NaN
#
#        자기자본순이익율1  자기자본순이익율2  총자본영업이익율1  총자본영업이익율2     매출액영업이익률1     매출액영업이익률2  \
# 0            NaN        NaN        NaN        NaN  -2382.929436  -2672.482125
# 1            NaN        NaN        NaN        NaN    301.849849    286.526538
# 2       0.831382   0.735050   2.039775   1.963693  -2370.635721  -2478.469510
# 3       0.349593   0.322529   0.909170   0.902699  -5001.281790  -5043.896076
# 4            NaN        NaN        NaN        NaN    951.854425    951.326487
# ...          ...        ...        ...        ...           ...           ...
# 15145   5.591146   6.177886  10.297961  12.479037  -4830.121806  -3878.084635
# 15146        NaN        NaN   0.667791   3.225632 -67483.006823 -14007.259112
# 15147        NaN        NaN        NaN        NaN   4087.149903   6285.613451
# 15148        NaN        NaN        NaN        NaN   1636.546424   1905.176696
# 15149        NaN        NaN        NaN        NaN           NaN           NaN
#
#        총자본순이익률1  총자본순이익률2     매출액총익율    매출액순이익율  자기자본순이익율   총자본영업이익율  \
# 0           NaN       NaN  41.832069  -8.496548       NaN        NaN
# 1           NaN       NaN  28.339519 -40.971945       NaN        NaN
# 2      0.593638  0.524119  38.698504   1.451715  0.735050   1.963693
# 3      0.300647  0.277308  37.070673   0.694598  0.322529   0.902699
# 4           NaN       NaN  36.255153 -13.497912       NaN        NaN
# ...         ...       ...        ...        ...       ...        ...
# 15145  1.261930  1.459832   6.203323   1.244471  6.177886  12.479037
# 15146       NaN       NaN   4.493679  -2.064723       NaN   3.225632
# 15147       NaN       NaN   2.088563  -8.787422       NaN        NaN
# 15148       NaN       NaN  -0.928795 -11.479521       NaN        NaN
# 15149       NaN       NaN        NaN        NaN       NaN        NaN
#
#            매출액영업이익률   총자본순이익률
# 0      -2672.482125       NaN
# 1        286.526538       NaN
# 2      -2478.469510  0.524119
# 3      -5043.896076  0.277308
# 4        951.326487       NaN
# ...             ...       ...
# 15145  -3878.084635  1.459832
# 15146 -14007.259112       NaN
# 15147   6285.613451       NaN
# 15148   1905.176696       NaN
# 15149           NaN       NaN
#
# [15150 rows x 37 columns]

# %%
df3 = pd.read_csv('./비율/활동성비율1.csv',encoding='cp949')
df3.columns = df3.columns.str.replace('\(', '')
df3.columns = df3.columns.str.replace('\)', '')
df3.columns = df3.columns.str.replace('\*', '')
df3.columns = df3.columns.str.replace('IFRS', '')
df3.columns = df3.columns.str.replace('천원', '')
df3
# Out:
#             회사명  거래소코드     회계년도  매출액(수익)(*)(IFRS)(천원)  매출액(수익)(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12            17751704.0              17751704.0
# 1      (주)CMG제약  58820  2012/12            16255389.0              16255389.0
# 2      (주)CMG제약  58820  2013/12            20322140.0              20402140.0
# 3      (주)CMG제약  58820  2014/12            22752584.0              22752584.0
# 4      (주)CMG제약  58820  2015/12            27041894.0              27041894.0
# ...         ...    ...      ...                   ...                     ...
# 15145   흥아해운(주)   3280  2015/12           801560945.0             845115359.0
# 15146   흥아해운(주)   3280  2016/12           779990350.0             831746081.0
# 15147   흥아해운(주)   3280  2017/12           780863972.0             836427496.0
# 15148   흥아해운(주)   3280  2018/12           705007198.0             753865569.0
# 15149   흥아해운(주)   3280  2019/12            97376909.0             102166838.0
#
#        자산(*)(IFRS)(천원)  자산(*)(IFRS연결)(천원)  매출원가(*)(IFRS)(천원)  \
# 0           27548539.0         27305198.0         10325799.0
# 1           56988604.0         57108035.0         11648690.0
# 2           55961620.0         55912563.0         12506817.0
# 3           58127098.0         58068326.0         14318048.0
# 4           56591972.0         56532821.0         17237814.0
# ...                ...                ...                ...
# 15145      771212062.0        791640802.0        763642673.0
# 15146      942586770.0        958532259.0        756984914.0
# 15147      834107402.0        848958520.0        778062692.0
# 15148      782787041.0        803698457.0        724528226.0
# 15149      386550839.0        430962722.0         98752599.0
#
#        매출원가(*)(IFRS연결)(천원)  재고자산(*)(IFRS)(천원)  ...  유형자산(*)(IFRS)(천원)  \
# 0               10325799.0          2743103.0  ...          9652599.0
# 1               11648690.0          2955172.0  ...          9264142.0
# 2               12506817.0          4618718.0  ...         10805092.0
# 3               14318048.0          4913103.0  ...         18833775.0
# 4               17237814.0          5455617.0  ...         17822468.0
# ...                    ...                ...  ...                ...
# 15145          792690121.0         11488626.0  ...        479816639.0
# 15146          794370084.0         17967554.0  ...        667913303.0
# 15147          818958179.0         19976759.0  ...        557578439.0
# 15148          760867431.0         18794127.0  ...        490215607.0
# 15149           96504366.0          7544969.0  ...        237825418.0
#
#        유형자산(*)(IFRS연결)(천원)  매입채무 및 기타유동채무(*)(IFRS)(천원)  \
# 0                9707759.0                   3372462.0
# 1                9307482.0                   4386179.0
# 2               10805092.0                   5421230.0
# 3               18833775.0                   7033905.0
# 4               17822468.0                   8667461.0
# ...                    ...                         ...
# 15145          483319774.0                  77008135.0
# 15146          671042170.0                  71355785.0
# 15147          560312598.0                  98602844.0
# 15148          492709259.0                 105402970.0
# 15149          238913893.0                  27077037.0
#
#        매입채무 및 기타유동채무(*)(IFRS연결)(천원)  자본(*)(IFRS)(천원)  자본(*)(IFRS연결)(천원)  \
# 0                         3385786.0       18290915.0         18034249.0
# 1                         4414147.0       31602540.0         31590685.0
# 2                         5423103.0       49048213.0         48997281.0
# 3                         7034077.0       49067039.0         49002644.0
# 4                         8667854.0       46872705.0         46806888.0
# ...                             ...              ...                ...
# 15145                    79182852.0      161824549.0        173076634.0
# 15146                    70849617.0      183829287.0        192487245.0
# 15147                    97335526.0      107614965.0        116884496.0
# 15148                   100450854.0       56731554.0         73148175.0
# 15149                    40896024.0       17632229.0         30919383.0
#
#        유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS연결)(천원)  유동부채(*)(IFRS)(천원)  \
# 0             15264885.0           15341167.0          7620349.0
# 1             47073443.0           47109213.0          6665126.0
# 2             38258866.0           38209699.0          5498201.0
# 3             28359823.0           28300941.0          8713579.0
# 4             26330765.0           26271614.0          8843328.0
# ...                  ...                  ...                ...
# 15145        124478864.0          136280257.0        256595137.0
# 15146         90973953.0          102103828.0        254811943.0
# 15147        105819304.0          115675013.0        321975170.0
# 15148        103181415.0          108354984.0        314936957.0
# 15149         61182850.0           93810124.0        178068106.0
#
#        유동부채(*)(IFRS연결)(천원)
# 0                7633673.0
# 1                6793095.0
# 2                5500075.0
# 3                8719202.0
# 4                8849994.0
# ...                    ...
# 15145          262487550.0
# 15146          258729193.0
# 15147          323503225.0
# 15148          312494268.0
# 15149          202347422.0
#
# [15150 rows x 23 columns]

# %%
df3['자본개별'] = df3['자본'].shift(1)
df3['자본연결_'] = df3['자본연결'].shift(1)
df3['재고자산개별'] = df3['재고자산'].shift(1)
df3['재고자산연결_'] = df3['재고자산연결'].shift(1)
df3['매출채권개별'] = df3['매출채권'].shift(1)
df3['매출채권연결_'] = df3['매출채권연결'].shift(1)
df3['유형자산개별'] = df3['유형자산'].shift(1)
df3['유형자산연결_'] = df3['유형자산연결'].shift(1)
df3['매입채무'] = df3['매입채무 및 기타유동채무'].shift(1)
df3['매입채무연결'] = df3['매입채무 및 기타유동채무연결'].shift(1)
df3['부채개별'] = df3['부채'].shift(1)
df3['부채연결_'] = df3['부채연결'].shift(1)
df3['유동자산개별'] = df3['유동자산'].shift(1)
df3['유동자산연결_'] = df3['유동자산연결'].shift(1)

# %%
activity(df3,'회사명','매출액수익','자본개별','자본','총자본회전율1')
activity(df3,'회사명','매출액수익연결','자본연결_','자본연결','총자본회전율2')

activity(df3,'회사명','매출원가','재고자산개별','재고자산','재고자산회전율1')
activity(df3,'회사명','매출원가연결','매출채권연결_','재고자산연결','재고자산회전율2')

activity(df3,'회사명','매출액수익','매출채권개별','매출채권','매출채권회전율1')
activity(df3,'회사명','매출액수익연결','매출채권연결_','매출채권연결','매출채권회전율2')

activity(df3,'회사명','매출액수익','유형자산개별','유형자산','유형자산회전율1')
activity(df3,'회사명','매출액수익연결','매출채권연결_','매출채권연결','유형자산회전율2')

activity(df3,'회사명','매출액수익','매입채무','매입채무 및 기타유동채무','매입채무회전율1')
activity(df3,'회사명','매출액수익연결','매입채무연결','매입채무 및 기타유동채무연결','매입채무회전율2')

activity(df3,'회사명','매출액수익','자본개별','자본','자기자본회전율1')
activity(df3,'회사명','매출액수익연결','자본연결_','자본연결','자기자본회전율2')

activity(df3,'회사명','매출액수익','부채개별','부채','타인자본회전율1')
activity(df3,'회사명','매출액수익연결','부채연결_','부채연결','타인자본회전율1')

activity(df3,'회사명','매출액수익','유동자산개별','유동자산','유동자산회전율1')
activity(df3,'회사명','매출액수익연결','유동자산연결_','유동자산연결','유동자산회전율2')

activity_tnsdns(df3,'회사명','매출액수익','유동자산','유동부채','순운전자본회전율1')
activity_tnsdns(df3,'회사명','매출액수익연결','유동자산연결','유동부채연결','순운전자본회전율2')

# %%
df3.to_csv('활동성계산식비율.csv',encoding='cp949')

# %%
df4 = pd.read_csv('./비율/안정성비율.csv',encoding='cp949')
df4
# Out:
#             회사명  거래소코드     회계년도  유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12         15264885.0           15341167.0
# 1      (주)CMG제약  58820  2012/12         47073443.0           47109213.0
# 2      (주)CMG제약  58820  2013/12         38258866.0           38209699.0
# 3      (주)CMG제약  58820  2014/12         28359823.0           28300941.0
# 4      (주)CMG제약  58820  2015/12         26330765.0           26271614.0
# ...         ...    ...      ...                ...                  ...
# 15145   흥아해운(주)   3280  2015/12        124478864.0          136280257.0
# 15146   흥아해운(주)   3280  2016/12         90973953.0          102103828.0
# 15147   흥아해운(주)   3280  2017/12        105819304.0          115675013.0
# 15148   흥아해운(주)   3280  2018/12        103181415.0          108354984.0
# 15149   흥아해운(주)   3280  2019/12         61182850.0           93810124.0
#
#        유동부채(*)(IFRS)(천원)  유동부채(*)(IFRS연결)(천원)  재고자산(*)(IFRS)(천원)  \
# 0              7620349.0            7633673.0          2743103.0
# 1              6665126.0            6793095.0          2955172.0
# 2              5498201.0            5500075.0          4618718.0
# 3              8713579.0            8719202.0          4913103.0
# 4              8843328.0            8849994.0          5455617.0
# ...                  ...                  ...                ...
# 15145        256595137.0          262487550.0         11488626.0
# 15146        254811943.0          258729193.0         17967554.0
# 15147        321975170.0          323503225.0         19976759.0
# 15148        314936957.0          312494268.0         18794127.0
# 15149        178068106.0          202347422.0          7544969.0
#
#        재고자산(*)(IFRS연결)(천원)  현금및현금성자산(*)(IFRS)(천원)  ...  \
# 0                2743103.0              1152489.0  ...
# 1                2955172.0              4673134.0  ...
# 2                4618718.0             21704962.0  ...
# 3                4913103.0              8826926.0  ...
# 4                5455617.0              2566164.0  ...
# ...                    ...                    ...  ...
# 15145           11488626.0              9908430.0  ...
# 15146           17967554.0              2384823.0  ...
# 15147           19976759.0             10380560.0  ...
# 15148           18807927.0              9560545.0  ...
# 15149            7715548.0              7559325.0  ...
#
#        매입채무 및 기타유동채무(*)(IFRS)(천원)  매입채무 및 기타유동채무(*)(IFRS연결)(천원)  \
# 0                       3372462.0                     3385786.0
# 1                       4386179.0                     4414147.0
# 2                       5421230.0                     5423103.0
# 3                       7033905.0                     7034077.0
# 4                       8667461.0                     8667854.0
# ...                           ...                           ...
# 15145                  77008135.0                    79182852.0
# 15146                  71355785.0                    70849617.0
# 15147                  98602844.0                    97335526.0
# 15148                 105402970.0                   100450854.0
# 15149                  27077037.0                    40896024.0
#
#        장기차입금(*)(IFRS)(천원)  장기차입금(*)(IFRS연결)(천원)  단기차입금(*)(IFRS)(천원)  \
# 0                     0.0                   0.0           2134049.0
# 1                     0.0                   0.0           2132612.0
# 2                     0.0                   0.0                 0.0
# 3                     0.0                   0.0                 0.0
# 4                     0.0                   0.0                 0.0
# ...                   ...                   ...                 ...
# 15145          64641000.0            64641000.0         105777748.0
# 15146          46829458.0            46829458.0         113942285.0
# 15147          37958229.0            37958229.0         141774467.0
# 15148          25794042.0            25794042.0         146990180.0
# 15149                 0.0                   0.0          44292628.0
#
#        단기차입금(*)(IFRS연결)(천원)  회사채(IFRS)(천원)  회사채(IFRS연결)(천원)  \
# 0                       0.0            0.0              0.0
# 1                  100000.0            0.0              0.0
# 2                       0.0            0.0              0.0
# 3                    5451.0            0.0              0.0
# 4                    6273.0            0.0              0.0
# ...                     ...            ...              ...
# 15145           107562548.0            0.0              0.0
# 15146           115674885.0            0.0              0.0
# 15147           143410967.0            0.0              0.0
# 15148           148617784.0            0.0              0.0
# 15149            44292628.0            0.0              0.0
#
#        영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)
# 0                            -2488268.0                          -2560438.0
# 1                            -1453276.0                          -1572581.0
# 2                            -3891420.0                          -3939013.0
# 3                              730447.0                            724893.0
# 4                             2411254.0                           2410205.0
# ...                                 ...                                 ...
# 15145                        34042933.0                          33913401.0
# 15146                        -4725664.0                          -1389623.0
# 15147                        -5348563.0                          -6892102.0
# 15148                       -30464257.0                         -33794586.0
# 15149                       -16943933.0                         -12048291.0
#
# [15150 rows x 31 columns]

# %%
df5 = pd.read_csv('./비율/생산성지표.csv',encoding='cp949')
df5
# Out:
#             회사명  거래소코드     회계년도  유형자산(*)(IFRS연결)(천원)  유형자산(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12            9707759.0          9652599.0
# 1      (주)CMG제약  58820  2012/12            9307482.0          9264142.0
# 2      (주)CMG제약  58820  2013/12           10805092.0         10805092.0
# 3      (주)CMG제약  58820  2014/12           18833775.0         18833775.0
# 4      (주)CMG제약  58820  2015/12           17822468.0         17822468.0
# ...         ...    ...      ...                  ...                ...
# 15145   흥아해운(주)   3280  2015/12          483319774.0        479816639.0
# 15146   흥아해운(주)   3280  2016/12          671042170.0        667913303.0
# 15147   흥아해운(주)   3280  2017/12          560312598.0        557578439.0
# 15148   흥아해운(주)   3280  2018/12          492709259.0        490215607.0
# 15149   흥아해운(주)   3280  2019/12          238913893.0        237825418.0
#
#        건설중인자산(IFRS연결)(천원)  건설중인자산(IFRS)(천원)  합계_기말인원(명)  기계장치(IFRS연결)(천원)  \
# 0                 24700.0           24700.0       135.0         3944218.0
# 1                     0.0               0.0       134.0         4288368.0
# 2               1827454.0         1827454.0       136.0         4595388.0
# 3                154233.0          154233.0       164.0         7950710.0
# 4                     0.0               0.0       156.0         8328336.0
# ...                   ...               ...         ...               ...
# 15145            430166.0          430166.0       813.0           11570.0
# 15146           5172380.0         5172380.0       942.0           11570.0
# 15147           8543473.0         8543473.0       921.0           11570.0
# 15148                 0.0               0.0       796.0           11570.0
# 15149                 0.0               0.0       339.0           11570.0
#
#        기계장치(IFRS)(천원)  자산(*)(IFRS연결)(천원)  자산(*)(IFRS)(천원)  부가가치(IFRS연결)(백만원)  \
# 0           3944218.0         27305198.0       27548539.0            3472.17
# 1           4288368.0         57108035.0       56988604.0             269.31
# 2           4595388.0         55912563.0       55961620.0            6994.90
# 3           7950710.0         58068326.0       58127098.0            7061.34
# 4           8328336.0         56532821.0       56591972.0            4315.37
# ...               ...                ...              ...                ...
# 15145             0.0        791640802.0      771212062.0          103792.31
# 15146             0.0        958532259.0      942586770.0          105291.39
# 15147             0.0        848958520.0      834107402.0           46072.27
# 15148             0.0        803698457.0      782787041.0           34054.90
# 15149             0.0        430962722.0      386550839.0           13366.25
#
#        부가가치(IFRS)(백만원)  매출액(수익)(*)(IFRS연결)(천원)  매출액(수익)(*)(IFRS)(천원)
# 0              3669.25              17751704.0            17751704.0
# 1               -88.04              16255389.0            16255389.0
# 2              6952.08              20402140.0            20322140.0
# 3              7065.04              22752584.0            22752584.0
# 4              4316.80              27041894.0            27041894.0
# ...                ...                     ...                   ...
# 15145         88375.30             845115359.0           801560945.0
# 15146         81449.56             831746081.0           779990350.0
# 15147         41240.98             836427496.0           780863972.0
# 15148          1920.69             753865569.0           705007198.0
# 15149          3363.37             102166838.0            97376909.0
#
# [15150 rows x 16 columns]
