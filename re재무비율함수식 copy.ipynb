# %%
import pandas as pd
import numpy as np
import warnings
import guro
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
gu = guro.pat()

# %%
############################ WARNING ######################################
# 회사명 기준으로 shift 등의 조치가 필요한 경우 따로 취한 다음에 함수 적용하세요
# 안 그러면 터집니다...
###########################################################################


# 단순하게 나누는 함수
# df_name : raw_data 들어있는 데이터프레임
# a, b : 계산을 하고자하는 데이터프레임의 컬럼명을 입력 (a가 분자, b가 분모)
# c : 계산 결과를 저장하고자 하는 데이터프레임의 컬럼명을 입력
 # b / ((c + d)/2) * 100
def profit_chddud(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                    
# 증가율 함수
def pct (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan

# 수익성 계산
def profit (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,d] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,d] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def profit_tns(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
# b / ((c + d)/2) * 100
def profit_chddud(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
def activiti(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
# b / ((c - d)/2)
def activity_tnsdns(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
# 생산성 계산
def produce (df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d]))
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d]))
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
            
# 안정성 계산
def stability(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def robo(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c])))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c])))) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c]))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c])))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c])))) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c]))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def sulbi(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))* -1 
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d])))*-1 
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        
def ekdwhk (df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = ((((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = ((((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
def ckdlq (df_name,a,b,c,d,e,f):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            if df_name.iloc[i][b] > 0 or df_name.iloc[i][c] > 0 or df_name.iloc[i][d] > 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = 0
            elif df_name.iloc[i][e] == 0:
                df_name.loc[i,f] = 0
            else:
                df_name.loc[i,f] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            if df_name.iloc[i][b] > 0 or df_name.iloc[i][c] > 0 or df_name.iloc[i][d] > 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = 0
            elif df_name.iloc[i][e] == 0:
                df_name.loc[i,f] = 0
            else:
                df_name.loc[i,f] = np.nan
            
def cash(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # - - -
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) + abs(df_name.iloc[i][c]))/2)/df_name.iloc[i][d])
            # - + -
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*-1
            # - - +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # - + +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + - -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*-1
            # + + -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + - +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + + +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # - - -
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) + abs(df_name.iloc[i][c]))/2)/df_name.iloc[i][d])
            # - + -
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*-1
            # - - +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # - + +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + - -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*-1
            # + + -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + - +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            # + + +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            else:
                df_name.loc[i,e] = np.nan

# %%
df1 = pd.read_csv('./비율/성장성비율.csv',encoding='cp949')
df1.columns = df1.columns.str.replace('\(', '')
df1.columns = df1.columns.str.replace('\)', '')
df1.columns = df1.columns.str.replace('\*', '')
df1.columns = df1.columns.str.replace('IFRS', '')
df1.columns = df1.columns.str.replace('천원', '')
df1
# Out:
#             회사명  거래소코드     회계년도           자산         자산연결         유형자산  \
# 0      (주)CMG제약  58820  2011/12   27548539.0   27305198.0    9652599.0
# 1      (주)CMG제약  58820  2012/12   56988604.0   57108035.0    9264142.0
# 2      (주)CMG제약  58820  2013/12   55961620.0   55912563.0   10805092.0
# 3      (주)CMG제약  58820  2014/12   58127098.0   58068326.0   18833775.0
# 4      (주)CMG제약  58820  2015/12   56591972.0   56532821.0   17822468.0
# ...         ...    ...      ...          ...          ...          ...
# 15145   흥아해운(주)   3280  2015/12  771212062.0  791640802.0  479816639.0
# 15146   흥아해운(주)   3280  2016/12  942586770.0  958532259.0  667913303.0
# 15147   흥아해운(주)   3280  2017/12  834107402.0  848958520.0  557578439.0
# 15148   흥아해운(주)   3280  2018/12  782787041.0  803698457.0  490215607.0
# 15149   흥아해운(주)   3280  2019/12  386550839.0  430962722.0  237825418.0
#
#             유형자산연결         유동자산       유동자산연결           자본         자본연결
# 0        9707759.0   15264885.0   15341167.0   18290915.0   18034249.0
# 1        9307482.0   47073443.0   47109213.0   31602540.0   31590685.0
# 2       10805092.0   38258866.0   38209699.0   49048213.0   48997281.0
# 3       18833775.0   28359823.0   28300941.0   49067039.0   49002644.0
# 4       17822468.0   26330765.0   26271614.0   46872705.0   46806888.0
# ...            ...          ...          ...          ...          ...
# 15145  483319774.0  124478864.0  136280257.0  161824549.0  173076634.0
# 15146  671042170.0   90973953.0  102103828.0  183829287.0  192487245.0
# 15147  560312598.0  105819304.0  115675013.0  107614965.0  116884496.0
# 15148  492709259.0  103181415.0  108354984.0   56731554.0   73148175.0
# 15149  238913893.0   61182850.0   93810124.0   17632229.0   30919383.0
#
# [15150 rows x 11 columns]

# %%
df1['자산개별'] = df1['자산'].shift(1)
df1['자산연결_'] = df1['자산연결'].shift(1)
df1['유형자산개별'] = df1['유형자산'].shift(1)
df1['유형자산연결_'] = df1['유형자산연결'].shift(1)
df1['유동자산개별'] = df1['유동자산'].shift(1)
df1['유동자산연결_'] = df1['유동자산연결'].shift(1)
df1['자본개별'] = df1['자본'].shift(1)
df1['자본연결_'] = df1['자본연결'].shift(1)
# df1['총자산개별율'] = ''
pct(df1,'회사명','자산','자산개별','총자산개별율1')
pct(df1,'회사명','자산연결','자산연결_','총자산개별율2')
pct(df1,'회사명','유형자산','유형자산개별','유형자산개별율1')
pct(df1,'회사명','유형자산연결','유형자산연결_','유형자산개별율2')
pct(df1,'회사명','유동자산','유동자산개별','유동자산개별율1')
pct(df1,'회사명','유동자산연결','유동자산연결_','유동자산개별율2')
pct(df1,'회사명','자본','자본개별','자본개별율1')
pct(df1,'회사명','자본연결','자본연결_','자본개별율2')

# %%
df1['총자산증가율'] = df1['총자산개별율2'].fillna(df1['총자산개별율1'])
df1['유형자산증가율'] = df1['유형자산개별율2'].fillna(df1['유형자산개별율1'])
df1['유동자산증가율'] = df1['유동자산개별율2'].fillna(df1['유동자산개별율1'])
df1['자본증가율'] = df1['자본개별율2'].fillna(df1['자본개별율1'])

# %%
df1.to_csv('성장성계산식비율.csv',encoding='cp949',index=False)

# %%
df2 = pd.read_csv('./비율/수익성비율.csv',encoding='cp949')
df2.columns = df2.columns.str.replace('\(', '')
df2.columns = df2.columns.str.replace('\)', '')
df2.columns = df2.columns.str.replace('\*', '')
df2.columns = df2.columns.str.replace('IFRS', '')
df2.columns = df2.columns.str.replace('천원', '')
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결
# 0       18034249.0   27548539.0   27305198.0
# 1       31590685.0   56988604.0   57108035.0
# 2       48997281.0   55961620.0   55912563.0
# 3       49002644.0   58127098.0   58068326.0
# 4       46806888.0   56591972.0   56532821.0
# ...            ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0
# 15146  192487245.0  942586770.0  958532259.0
# 15147  116884496.0  834107402.0  848958520.0
# 15148   73148175.0  782787041.0  803698457.0
# 15149   30919383.0  386550839.0  430962722.0
#
# [15150 rows x 15 columns]

# %%
df2['자본개별'] = df2['자본'].shift(1)
df2['자본연결_'] = df2['자본연결'].shift(1)
df2['자산개별'] = df2['자산'].shift(1)
df2['자산연결_'] = df2['자산연결'].shift(1)
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결         자본개별        자본연결_  \
# 0       18034249.0   27548539.0   27305198.0          NaN          NaN
# 1       31590685.0   56988604.0   57108035.0   18290915.0   18034249.0
# 2       48997281.0   55961620.0   55912563.0   31602540.0   31590685.0
# 3       49002644.0   58127098.0   58068326.0   49048213.0   48997281.0
# 4       46806888.0   56591972.0   56532821.0   49067039.0   49002644.0
# ...            ...          ...          ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0  153935831.0  167402807.0
# 15146  192487245.0  942586770.0  958532259.0  161824549.0  173076634.0
# 15147  116884496.0  834107402.0  848958520.0  183829287.0  192487245.0
# 15148   73148175.0  782787041.0  803698457.0  107614965.0  116884496.0
# 15149   30919383.0  386550839.0  430962722.0   56731554.0   73148175.0
#
#               자산개별        자산연결_
# 0              NaN          NaN
# 1       27548539.0   27305198.0
# 2       56988604.0   57108035.0
# 3       55961620.0   55912563.0
# 4       58127098.0   58068326.0
# ...            ...          ...
# 15145  627805252.0  649240003.0
# 15146  771212062.0  791640802.0
# 15147  942586770.0  958532259.0
# 15148  834107402.0  848958520.0
# 15149  782787041.0  803698457.0
#
# [15150 rows x 19 columns]

# %%
profit(df2,'회사명','매출액수익','매출원가','매출액총익율1')
profit(df2,'회사명','매출액수익연결','매출원가연결','매출액총익율2')
profit_tns(df2,'회사명','당기순이익손실','매출액수익','매출액순이익율1')
profit_tns(df2,'회사명','당기순이익손실연결','매출액수익연결','매출액순이익율2')
profit_chddud(df2,'회사명','당기순이익손실','자본','자본개별','자기자본순이익율1')
profit_chddud(df2,'회사명','당기순이익손실연결','자본연결','자본연결_','자기자본순이익율2')

# %%
profit_chddud(df2,'회사명','영업이익개별','자본','자본개별','총자본영업이익율1')
profit_chddud(df2,'회사명','영업이익연결','자본연결','자본연결_','총자본영업이익율2')
profit(df2,'회사명','영업이익개별','매출액수익','매출액영업이익률1')
profit(df2,'회사명','영업이익연결','매출액수익연결','매출액영업이익률2')
profit_chddud(df2,'회사명','당기순이익손실','자산','자산개별','총자본순이익률1')
profit_chddud(df2,'회사명','당기순이익손실연결','자산연결','자산연결_','총자본순이익률2')

# %%
df2.to_csv('수익성계산식비율.csv',encoding='cp949',index=False)

# %%
df2['매출액총익율'] = df2['매출액총익율2'].fillna(df2['매출액총익율1'])
df2['매출액순이익율'] = df2['매출액순이익율2'].fillna(df2['매출액순이익율1'])
df2['자기자본순이익율'] = df2['자기자본순이익율2'].fillna(df2['자기자본순이익율1'])
df2['총자본영업이익율'] = df2['총자본영업이익율2'].fillna(df2['총자본영업이익율1'])
df2['매출액영업이익률'] = df2['매출액영업이익률2'].fillna(df2['매출액영업이익률1'])
df2['총자본순이익률'] = df2['총자본순이익률2'].fillna(df2['총자본순이익률1'])

# %%
df2
# Out:
#             회사명  거래소코드    회계년도        매출액수익         매출원가      매출액수익연결  \
# 0      (주)CMG제약  58820  11-Dec   17751704.0   10325799.0   17751704.0
# 1      (주)CMG제약  58820  12-Dec   16255389.0   11648690.0   16255389.0
# 2      (주)CMG제약  58820  13-Dec   20322140.0   12506817.0   20402140.0
# 3      (주)CMG제약  58820  14-Dec   22752584.0   14318048.0   22752584.0
# 4      (주)CMG제약  58820  15-Dec   27041894.0   17237814.0   27041894.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  801560945.0  763642673.0  845115359.0
# 15146   흥아해운(주)   3280  16-Dec  779990350.0  756984914.0  831746081.0
# 15147   흥아해운(주)   3280  17-Dec  780863972.0  778062692.0  836427496.0
# 15148   흥아해운(주)   3280  18-Dec  705007198.0  724528226.0  753865569.0
# 15149   흥아해운(주)   3280  19-Dec   97376909.0   98752599.0  102166838.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결    영업이익개별    영업이익연결           자본  \
# 0       10325799.0  -1264488.0  -1508282.0    714950    640282   18290915.0
# 1       11648690.0  -6892739.0  -6660149.0  -4045140  -4205504   31602540.0
# 2       12506817.0    335258.0    296181.0    822547    791250   49048213.0
# 3       14318048.0    171502.0    158039.0    446017    442322   49067039.0
# 4       17237814.0  -3648668.0  -3650091.0  -2570878  -2572169   46872705.0
# ...            ...         ...         ...       ...       ...          ...
# 15145  792690121.0   8827312.0  10517216.0  16258441  21244278  161824549.0
# 15146  794370084.0 -16149442.0 -17173253.0   1154122   5895873  183829287.0
# 15147  818958179.0 -67916740.0 -73500411.0 -18649057 -13098624  107614965.0
# 15148  760867431.0 -96953501.0 -86540156.0 -40598235 -37595967   56731554.0
# 15149   96504366.0 -52550693.0 -51356551.0 -14756167 -12364292   17632229.0
#
#               자본연결           자산         자산연결         자본개별        자본연결_  \
# 0       18034249.0   27548539.0   27305198.0          NaN          NaN
# 1       31590685.0   56988604.0   57108035.0   18290915.0   18034249.0
# 2       48997281.0   55961620.0   55912563.0   31602540.0   31590685.0
# 3       49002644.0   58127098.0   58068326.0   49048213.0   48997281.0
# 4       46806888.0   56591972.0   56532821.0   49067039.0   49002644.0
# ...            ...          ...          ...          ...          ...
# 15145  173076634.0  771212062.0  791640802.0  153935831.0  167402807.0
# 15146  192487245.0  942586770.0  958532259.0  161824549.0  173076634.0
# 15147  116884496.0  834107402.0  848958520.0  183829287.0  192487245.0
# 15148   73148175.0  782787041.0  803698457.0  107614965.0  116884496.0
# 15149   30919383.0  386550839.0  430962722.0   56731554.0   73148175.0
#
#               자산개별        자산연결_    매출액총익율1    매출액총익율2   매출액순이익율1   매출액순이익율2  \
# 0              NaN          NaN  41.832069  41.832069  -7.123192  -8.496548
df3.columns = df3.columns.str.replace('\(', '')
df3.columns = df3.columns.str.replace('\)', '')
df3.columns = df3.columns.str.replace('\*', '')
df3.columns = df3.columns.str.replace('IFRS', '')
df3.columns = df3.columns.str.replace('천원', '')
df3
# Out:
#             회사명  거래소코드    회계년도        매출액수익      매출액수익연결           자산  \
# 0      (주)CMG제약  58820  Dec-11   17751704.0   17751704.0   27548539.0
# 1      (주)CMG제약  58820  Dec-12   16255389.0   16255389.0   56988604.0
# 2      (주)CMG제약  58820  Dec-13   20322140.0   20402140.0   55961620.0
# 3      (주)CMG제약  58820  Dec-14   22752584.0   22752584.0   58127098.0
# 4      (주)CMG제약  58820  Dec-15   27041894.0   27041894.0   56591972.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  Dec-15  801560945.0  845115359.0  771212062.0
# 15146   흥아해운(주)   3280  Dec-16  779990350.0  831746081.0  942586770.0
# 15147   흥아해운(주)   3280  Dec-17  780863972.0  836427496.0  834107402.0
# 15148   흥아해운(주)   3280  Dec-18  705007198.0  753865569.0  782787041.0
# 15149   흥아해운(주)   3280  Dec-19   97376909.0  102166838.0  386550839.0
#
#               자산연결         매출원가       매출원가연결        재고자산      재고자산연결  \
# 0       27305198.0   10325799.0   10325799.0   2743103.0   2743103.0
# 1       57108035.0   11648690.0   11648690.0   2955172.0   2955172.0
# 2       55912563.0   12506817.0   12506817.0   4618718.0   4618718.0
# 3       58068326.0   14318048.0   14318048.0   4913103.0   4913103.0
# 4       56532821.0   17237814.0   17237814.0   5455617.0   5455617.0
# ...            ...          ...          ...         ...         ...
# 15145  791640802.0  763642673.0  792690121.0  11488626.0  11488626.0
# 15146  958532259.0  756984914.0  794370084.0  17967554.0  17967554.0
# 15147  848958520.0  778062692.0  818958179.0  19976759.0  19976759.0
# 15148  803698457.0  724528226.0  760867431.0  18794127.0  18807927.0
# 15149  430962722.0   98752599.0   96504366.0   7544969.0   7715548.0
#
#        매출채권 및 기타유동채권  매출채권 및 기타유동채권연결         유형자산       유형자산연결  \
# 0          9527407.0        9533102.0    9652599.0    9707759.0
# 1          9089645.0        9084190.0    9264142.0    9307482.0
# 2         11109760.0       11089670.0   10805092.0   10805092.0
# 3         13533700.0       13503998.0   18833775.0   18833775.0
# 4         12405117.0       12375263.0   17822468.0   17822468.0
# ...              ...              ...          ...          ...
# 15145     45635972.0       46513910.0  479816639.0  483319774.0
# 15146     50314914.0       49357034.0  667913303.0  671042170.0
# 15147     58014242.0       57834010.0  557578439.0  560312598.0
# 15148     61151622.0       60060449.0  490215607.0  492709259.0
# 15149      4342600.0       11480074.0  237825418.0  238913893.0
#
#        매입채무 및 기타유동채무  매입채무 및 기타유동채무연결           자본         자본연결         유동자산  \
# 0          3372462.0        3385786.0   18290915.0   18034249.0   15264885.0
# 1          4386179.0        4414147.0   31602540.0   31590685.0   47073443.0
# 2          5421230.0        5423103.0   49048213.0   48997281.0   38258866.0
# 3          7033905.0        7034077.0   49067039.0   49002644.0   28359823.0
# 4          8667461.0        8667854.0   46872705.0   46806888.0   26330765.0
# ...              ...              ...          ...          ...          ...
# 15145     77008135.0       79182852.0  161824549.0  173076634.0  124478864.0
# 15146     71355785.0       70849617.0  183829287.0  192487245.0   90973953.0
# 15147     98602844.0       97335526.0  107614965.0  116884496.0  105819304.0
# 15148    105402970.0      100450854.0   56731554.0   73148175.0  103181415.0
# 15149     27077037.0       40896024.0   17632229.0   30919383.0   61182850.0
#
#             유동자산연결         유동부채       유동부채연결           부채         부채연결
# 0       15341167.0    7620349.0    7633673.0    9257624.0    9270949.0
# 1       47109213.0    6665126.0    6793095.0   25386064.0   25517350.0
# 2       38209699.0    5498201.0    5500075.0    6913407.0    6915281.0
# 3       28300941.0    8713579.0    8719202.0    9060059.0    9065682.0
# 4       26271614.0    8843328.0    8849994.0    9719267.0    9725933.0
# ...            ...          ...          ...          ...          ...
# 15145  136280257.0  256595137.0  262487550.0  609387512.0  618564168.0
# 15146  102103828.0  254811943.0  258729193.0  758757483.0  766045015.0
# 15147  115675013.0  321975170.0  323503225.0  726492437.0  732074025.0
# 15148  108354984.0  314936957.0  312494268.0  726055487.0  730550282.0
# 15149   93810124.0  178068106.0  202347422.0  368918610.0  400043339.0
#
# [15150 rows x 25 columns]

# %%
df3['자본개별'] = df3['자본'].shift(1)
df3['자본연결_'] = df3['자본연결'].shift(1)
df3['재고자산개별'] = df3['재고자산'].shift(1)
df3['재고자산연결_'] = df3['재고자산연결'].shift(1)
df3['매출채권개별'] = df3['매출채권 및 기타유동채권'].shift(1)
df3['매출채권연결_'] = df3['매출채권 및 기타유동채권연결'].shift(1)
df3['유형자산개별'] = df3['유형자산'].shift(1)
df3['유형자산연결_'] = df3['유형자산연결'].shift(1)
df3['매입채무'] = df3['매입채무 및 기타유동채무'].shift(1)
df3['매입채무연결'] = df3['매입채무 및 기타유동채무연결'].shift(1)
df3['부채개별'] = df3['부채'].shift(1)
df3['부채연결_'] = df3['부채연결'].shift(1)
df3['유동자산개별'] = df3['유동자산'].shift(1)
df3['유동자산연결_'] = df3['유동자산연결'].shift(1)

# %%
activiti(df3,'회사명','매출액수익','자본개별','자본','총자본회전율1')
activiti(df3,'회사명','매출액수익연결','자본연결_','자본연결','총자본회전율2')

activiti(df3,'회사명','매출원가','재고자산개별','재고자산','재고자산회전율1')
activiti(df3,'회사명','매출원가연결','매출채권연결_','재고자산연결','재고자산회전율2')

activiti(df3,'회사명','매출액수익','매출채권개별','매출채권 및 기타유동채권','매출채권회전율1')
activiti(df3,'회사명','매출액수익연결','매출채권연결_','매출채권 및 기타유동채권연결','매출채권회전율2')

activiti(df3,'회사명','매출액수익','유형자산개별','유형자산','유형자산회전율1')
activiti(df3,'회사명','매출액수익연결','유형자산연결_','유형자산연결','유형자산회전율2')

activiti(df3,'회사명','매출액수익','매입채무','매입채무 및 기타유동채무','매입채무회전율1')
activiti(df3,'회사명','매출액수익연결','매입채무연결','매입채무 및 기타유동채무연결','매입채무회전율2')

activiti(df3,'회사명','매출액수익','자본개별','자본','자기자본회전율1')
activiti(df3,'회사명','매출액수익연결','자본연결_','자본연결','자기자본회전율2')

activiti(df3,'회사명','매출액수익','부채개별','부채','타인자본회전율1')
activiti(df3,'회사명','매출액수익연결','부채연결_','부채연결','타인자본회전율2')

activiti(df3,'회사명','매출액수익','유동자산개별','유동자산','유동자산회전율1')
activiti(df3,'회사명','매출액수익연결','유동자산연결_','유동자산연결','유동자산회전율2')

activity_tnsdns(df3,'회사명','매출액수익','유동자산','유동부채','순운전자본회전율1')
activity_tnsdns(df3,'회사명','매출액수익연결','유동자산연결','유동부채연결','순운전자본회전율2')

# %%
df3
# Out:
#             회사명  거래소코드    회계년도        매출액수익      매출액수익연결           자산  \
# 0      (주)CMG제약  58820  Dec-11   17751704.0   17751704.0   27548539.0
# 1      (주)CMG제약  58820  Dec-12   16255389.0   16255389.0   56988604.0
# 2      (주)CMG제약  58820  Dec-13   20322140.0   20402140.0   55961620.0
# 3      (주)CMG제약  58820  Dec-14   22752584.0   22752584.0   58127098.0
# 4      (주)CMG제약  58820  Dec-15   27041894.0   27041894.0   56591972.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  Dec-15  801560945.0  845115359.0  771212062.0
# 15146   흥아해운(주)   3280  Dec-16  779990350.0  831746081.0  942586770.0
# 15147   흥아해운(주)   3280  Dec-17  780863972.0  836427496.0  834107402.0
# 15148   흥아해운(주)   3280  Dec-18  705007198.0  753865569.0  782787041.0
# 15149   흥아해운(주)   3280  Dec-19   97376909.0  102166838.0  386550839.0
#
#               자산연결         매출원가       매출원가연결        재고자산      재고자산연결  \
# 0       27305198.0   10325799.0   10325799.0   2743103.0   2743103.0
# 1       57108035.0   11648690.0   11648690.0   2955172.0   2955172.0
# 2       55912563.0   12506817.0   12506817.0   4618718.0   4618718.0
# 3       58068326.0   14318048.0   14318048.0   4913103.0   4913103.0
# 4       56532821.0   17237814.0   17237814.0   5455617.0   5455617.0
# ...            ...          ...          ...         ...         ...
# 15145  791640802.0  763642673.0  792690121.0  11488626.0  11488626.0
# 15146  958532259.0  756984914.0  794370084.0  17967554.0  17967554.0
# 15147  848958520.0  778062692.0  818958179.0  19976759.0  19976759.0
# 15148  803698457.0  724528226.0  760867431.0  18794127.0  18807927.0
# 15149  430962722.0   98752599.0   96504366.0   7544969.0   7715548.0
#
#        매출채권 및 기타유동채권  매출채권 및 기타유동채권연결         유형자산       유형자산연결  \
# 0          9527407.0        9533102.0    9652599.0    9707759.0
# 1          9089645.0        9084190.0    9264142.0    9307482.0
# 2         11109760.0       11089670.0   10805092.0   10805092.0
# 3         13533700.0       13503998.0   18833775.0   18833775.0
# 4         12405117.0       12375263.0   17822468.0   17822468.0
# ...              ...              ...          ...          ...
# 15145     45635972.0       46513910.0  479816639.0  483319774.0
# 15146     50314914.0       49357034.0  667913303.0  671042170.0
# 15147     58014242.0       57834010.0  557578439.0  560312598.0
# 15148     61151622.0       60060449.0  490215607.0  492709259.0
# 4      0.991044   3.092722   3.104406
# ...         ...        ...        ...
# 15145  5.833991 -12.134174 -13.392496
# 15146  6.978201  -9.521483 -10.620835
# 15147  7.681440  -7.225008  -8.049220
# 15148  6.730041  -6.658689  -7.385796
# 15149       NaN        NaN        NaN
#
# [15150 rows x 57 columns]

# %%
df3['총자본회전율'] = df3['총자본회전율2'].fillna(df3['총자본회전율1'])
df3['재고자산회전율'] = df3['재고자산회전율2'].fillna(df3['재고자산회전율1'])
df3['매출채권회전율'] = df3['매출채권회전율2'].fillna(df3['매출채권회전율1'])
df3['유형자산회전율'] = df3['유형자산회전율2'].fillna(df3['유형자산회전율1'])
df3['매입채무회전율'] = df3['매입채무회전율2'].fillna(df3['매입채무회전율1'])
df3['자기자본회전율'] = df3['자기자본회전율2'].fillna(df3['자기자본회전율1'])
df3['타인자본회전율'] = df3['타인자본회전율2'].fillna(df3['타인자본회전율1'])
df3['유동자산회전율'] = df3['유동자산회전율2'].fillna(df3['유동자산회전율1'])
df3['순운전자본회전율'] = df3['순운전자본회전율2'].fillna(df3['순운전자본회전율1'])

# %%
df3.to_csv('활동성계산식비율.csv',encoding='cp949')

# %%
df4 = pd.read_csv('./비율/생산성지표.csv',encoding='cp949')
df4.columns = df4.columns.str.replace('\(', '')
df4.columns = df4.columns.str.replace('\)', '')
df4.columns = df4.columns.str.replace('\*', '')
df4.columns = df4.columns.str.replace('IFRS', '')
df4.columns = df4.columns.str.replace('천원', '')
df4
# Out:
#             회사명  거래소코드    회계년도       유형자산연결         유형자산   건설중인자산연결  \
# 0      (주)CMG제약  58820  11-Dec    9707759.0    9652599.0    24700.0
# 1      (주)CMG제약  58820  12-Dec    9307482.0    9264142.0        0.0
# 2      (주)CMG제약  58820  13-Dec   10805092.0   10805092.0  1827454.0
# 3      (주)CMG제약  58820  14-Dec   18833775.0   18833775.0   154233.0
# 4      (주)CMG제약  58820  15-Dec   17822468.0   17822468.0        0.0
# ...         ...    ...     ...          ...          ...        ...
# 15145   흥아해운(주)   3280  15-Dec  483319774.0  479816639.0   430166.0
# 15146   흥아해운(주)   3280  16-Dec  671042170.0  667913303.0  5172380.0
# 15147   흥아해운(주)   3280  17-Dec  560312598.0  557578439.0  8543473.0
# 15148   흥아해운(주)   3280  18-Dec  492709259.0  490215607.0        0.0
# 15149   흥아해운(주)   3280  19-Dec  238913893.0  237825418.0        0.0
#
#           건설중인자산  합계_기말인원명     기계장치연결       기계장치         자산연결           자산  \
# 0        24700.0     135.0  3944218.0  3944218.0   27305198.0   27548539.0
# 1            0.0     134.0  4288368.0  4288368.0   57108035.0   56988604.0
# 2      1827454.0     136.0  4595388.0  4595388.0   55912563.0   55961620.0
# 3       154233.0     164.0  7950710.0  7950710.0   58068326.0   58127098.0
# 4            0.0     156.0  8328336.0  8328336.0   56532821.0   56591972.0
# ...          ...       ...        ...        ...          ...          ...
# 15145   430166.0     813.0    11570.0        0.0  791640802.0  771212062.0
# 15146  5172380.0     942.0    11570.0        0.0  958532259.0  942586770.0
# 15147  8543473.0     921.0    11570.0        0.0  848958520.0  834107402.0
# 15148        0.0     796.0    11570.0        0.0  803698457.0  782787041.0
# 15149        0.0     339.0    11570.0        0.0  430962722.0  386550839.0
#
#        부가가치연결백만원   부가가치백만원      매출액수익연결        매출액수익       부가가치연결      부가가치  \
# 0        3472.17   3669.25   17751704.0   17751704.0    3472170.0   3669250
# 1         269.31    -88.04   16255389.0   16255389.0     269310.0    -88040
# 2        6994.90   6952.08   20402140.0   20322140.0    6994900.0   6952080
# 3        7061.34   7065.04   22752584.0   22752584.0    7061340.0   7065040
# 4        4315.37   4316.80   27041894.0   27041894.0    4315370.0   4316800
# ...          ...       ...          ...          ...          ...       ...
# 15145  103792.31  88375.30  845115359.0  801560945.0  103792310.0  88375300
# 15146  105291.39  81449.56  831746081.0  779990350.0  105291390.0  81449560
# 15147   46072.27  41240.98  836427496.0  780863972.0   46072270.0  41240980
# 15148   34054.90   1920.69  753865569.0  705007198.0   34054900.0   1920690
# 15149   13366.25   3363.37  102166838.0   97376909.0   13366250.0   3363370
#
#        종업원
# 0      250
# 1      250
# 2      250
# 3      250
# 4      250
# ...    ...
# 15145  381
# 15146  381
# 15147  381
# 15148  381
# 15149  381
#
# [15150 rows x 19 columns]

# %%
produce(df4,'회사명','유형자산','건설중인자산','합계_기말인원명','노동장비율1')
produce(df4,'회사명','유형자산연결','건설중인자산연결','합계_기말인원명','노동장비율2')

robo(df4,'회사명','기계장치','합계_기말인원명','기계장비율1')
robo(df4,'회사명','기계장치연결','합계_기말인원명','기계장비율2')

robo(df4,'회사명','자산','합계_기말인원명','자본집약도1')
robo(df4,'회사명','자산연결','합계_기말인원명','자본집약도2')

sulbi(df4,'회사명','부가가치','유형자산','건설중인자산','설비투자효율1')
sulbi(df4,'회사명','부가가치연결','유형자산연결','건설중인자산연결','설비투자효율2')

profit_tns(df4,'회사명','부가가치','자산','총자본투자효율1')
profit_tns(df4,'회사명','부가가치연결','자산연결','총자본투자효율2')

profit_tns(df4,'회사명','부가가치','매출액수익','부가가치율1')
profit_tns(df4,'회사명','부가가치연결','매출액수익연결','부가가치율2')

robo(df4,'회사명','부가가치','합계_기말인원명','종업원1인딩부가가치1')
robo(df4,'회사명','부가가치연결','합계_기말인원명','종업원1인딩부가가치2')

# %%
df4['노동장비율'] = df4['노동장비율2'].fillna(df4['노동장비율1'])
df4['기계장비율'] = df4['기계장비율2'].fillna(df4['기계장비율1'])
df4['자본집약도'] = df4['자본집약도2'].fillna(df4['자본집약도1'])
df4['설비투자효율'] = df4['설비투자효율2'].fillna(df4['설비투자효율1'])
df4['총자본투자효율'] = df4['총자본투자효율2'].fillna(df4['총자본투자효율1'])
df4['부가가치율'] = df4['부가가치율2'].fillna(df4['부가가치율1'])
df4['종업원1인딩부가가치'] = df4['종업원1인딩부가가치2'].fillna(df4['종업원1인딩부가가치1'])

# %%
df4.to_csv('생산성계산식비율.csv',encoding='cp949',index=False)

# %%
df5 = pd.read_csv('./비율/안정성비율.csv',encoding='cp949')
df5.columns = df5.columns.str.replace('\(', '')
df5.columns = df5.columns.str.replace('\)', '')
df5.columns = df5.columns.str.replace('\*', '')
df5.columns = df5.columns.str.replace('IFRS', '')
df5.columns = df5.columns.str.replace('천원', '')
df5
# Out:
#             회사명  거래소코드    회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  11-Dec   15264885.0   15341167.0    7620349.0
# 1      (주)CMG제약  58820  12-Dec   47073443.0   47109213.0    6665126.0
# 2      (주)CMG제약  58820  13-Dec   38258866.0   38209699.0    5498201.0
# 3      (주)CMG제약  58820  14-Dec   28359823.0   28300941.0    8713579.0
# 4      (주)CMG제약  58820  15-Dec   26330765.0   26271614.0    8843328.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  124478864.0  136280257.0  256595137.0
# 15146   흥아해운(주)   3280  16-Dec   90973953.0  102103828.0  254811943.0
# 15147   흥아해운(주)   3280  17-Dec  105819304.0  115675013.0  321975170.0
# 15148   흥아해운(주)   3280  18-Dec  103181415.0  108354984.0  314936957.0
# 15149   흥아해운(주)   3280  19-Dec   61182850.0   93810124.0  178068106.0
#
#             유동부채연결        재고자산      재고자산연결    현금및현금성자산  현금및현금성자산연결  \
# 0        7633673.0   2743103.0   2743103.0   1152489.0   1152489.0
# 1        6793095.0   2955172.0   2955172.0   4673134.0   4674359.0
# 2        5500075.0   4618718.0   4618718.0  21704962.0  21705184.0
# 3        8719202.0   4913103.0   4913103.0   8826926.0   8827046.0
# 4        8849994.0   5455617.0   5455617.0   2566164.0   2566167.0
# ...            ...         ...         ...         ...         ...
# 15145  262487550.0  11488626.0  11488626.0   9908430.0  20371285.0
# 15146  258729193.0  17967554.0  17967554.0   2384823.0  14116233.0
# 15147  323503225.0  19976759.0  19976759.0  10380560.0  19969877.0
# 15148  312494268.0  18794127.0  18807927.0   9560545.0  15272818.0
# 15149  202347422.0   7544969.0   7715548.0   7559325.0  13657451.0
#
#                 부채         부채연결           자본         자본연결           자산  \
# 0        9257624.0    9270949.0   18290915.0   18034249.0   27548539.0
# 1       25386064.0   25517350.0   31602540.0   31590685.0   56988604.0
# 2        6913407.0    6915281.0   49048213.0   48997281.0   55961620.0
# 3        9060059.0    9065682.0   49067039.0   49002644.0   58127098.0
# 4        9719267.0    9725933.0   46872705.0   46806888.0   56591972.0
# ...            ...          ...          ...          ...          ...
# 15145  609387512.0  618564168.0  161824549.0  173076634.0  771212062.0
# 15146  758757483.0  766045015.0  183829287.0  192487245.0  942586770.0
# 15147  726492437.0  732074025.0  107614965.0  116884496.0  834107402.0
# 15148  726055487.0  730550282.0   56731554.0   73148175.0  782787041.0
# 15149  368918610.0  400043339.0   17632229.0   30919383.0  386550839.0
#
#               자산연결        매출채권      매출채권연결      대손충당금    대손충당금연결  \
# 0       27305198.0  11050219.0  11050219.0  2127119.0  2127119.0
# 1       57108035.0  11362566.0  11362566.0  2724749.0  2724749.0
# 2       55912563.0  13999415.0  13999415.0  2939659.0  2939659.0
# 3       58068326.0  16787073.0  16787073.0  3321706.0  3321706.0
# 4       56532821.0  15838056.0  15838057.0  3500558.0  3500558.0
# ...            ...         ...         ...        ...        ...
# 15145  791640802.0  29612998.0  33337383.0  1220252.0  1248751.0
# 15146  958532259.0  30865776.0  35120758.0  1260865.0  1289363.0
# 15147  848958520.0  37228549.0  40288664.0  1619351.0  1647850.0
# 15148  803698457.0  40164987.0  42695421.0  2209169.0  2604931.0
# 15149  430962722.0   2673427.0   4681942.0  1143894.0  2037528.0
#
#        매입채무 및 기타유동채무  매입채무 및 기타유동채무연결       장기차입금     장기차입금연결        단기차입금  \
# 0          3372462.0        3385786.0         0.0         0.0    2134049.0
# 1          4386179.0        4414147.0         0.0         0.0    2132612.0
# 2          5421230.0        5423103.0         0.0         0.0          0.0
# 3          7033905.0        7034077.0         0.0         0.0          0.0
# 4          8667461.0        8667854.0         0.0         0.0          0.0
# ...              ...              ...         ...         ...          ...
# 15145     77008135.0       79182852.0  64641000.0  64641000.0  105777748.0
# 15146     71355785.0       70849617.0  46829458.0  46829458.0  113942285.0
# 15147     98602844.0       97335526.0  37958229.0  37958229.0  141774467.0
# 15148    105402970.0      100450854.0  25794042.0  25794042.0  146990180.0
# 15149     27077037.0       40896024.0         0.0         0.0   44292628.0
#
#            단기차입금연결  회사채  회사채연결  영업활동으로 인한 현금흐름간접법  영업활동으로 인한 현금흐름간접법연결  \
# 0              0.0  0.0    0.0         -2488268.0           -2560438.0
# 1         100000.0  0.0    0.0         -1453276.0           -1572581.0
# 2              0.0  0.0    0.0         -3891420.0           -3939013.0
# 3           5451.0  0.0    0.0           730447.0             724893.0
# 4           6273.0  0.0    0.0          2411254.0            2410205.0
# ...            ...  ...    ...                ...                  ...
# 15145  107562548.0  0.0    0.0         34042933.0           33913401.0
# 15146  115674885.0  0.0    0.0         -4725664.0           -1389623.0
# 15147  143410967.0  0.0    0.0         -5348563.0           -6892102.0
# 15148  148617784.0  0.0    0.0        -30464257.0          -33794586.0
# 15149   44292628.0  0.0    0.0        -16943933.0          -12048291.0
#
#              매출액수익      매출액수익연결
# 0       17751704.0   17751704.0
# 1       16255389.0   16255389.0
# 2       20322140.0   20402140.0
# 3       22752584.0   22752584.0
# 4       27041894.0   27041894.0
# ...            ...          ...
# 15145  801560945.0  845115359.0
# 15146  779990350.0  831746081.0
# 15147  780863972.0  836427496.0
# 15148  705007198.0  753865569.0
# 15149   97376909.0  102166838.0
#
# [15150 rows x 33 columns]

# %%
df5['영업활동으로_인한_현금흐름간접법게별'] = df5['영업활동으로 인한 현금흐름간접법'].shift(1)
df5['영업활동으로_인한_현금흐름간접법연결'] = df5['영업활동으로 인한 현금흐름간접법연결'].shift(1)
df5
# Out:
#             회사명  거래소코드    회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  11-Dec   15264885.0   15341167.0    7620349.0
# 1      (주)CMG제약  58820  12-Dec   47073443.0   47109213.0    6665126.0
# 15149  430962722.0   2673427.0   4681942.0  1143894.0  2037528.0
#
#        매입채무 및 기타유동채무  매입채무 및 기타유동채무연결       장기차입금     장기차입금연결        단기차입금  \
# 0          3372462.0        3385786.0         0.0         0.0    2134049.0
# 1          4386179.0        4414147.0         0.0         0.0    2132612.0
# 2          5421230.0        5423103.0         0.0         0.0          0.0
# 3          7033905.0        7034077.0         0.0         0.0          0.0
# 4          8667461.0        8667854.0         0.0         0.0          0.0
# ...              ...              ...         ...         ...          ...
# 15145     77008135.0       79182852.0  64641000.0  64641000.0  105777748.0
# 15146     71355785.0       70849617.0  46829458.0  46829458.0  113942285.0
# 15147     98602844.0       97335526.0  37958229.0  37958229.0  141774467.0
# 15148    105402970.0      100450854.0  25794042.0  25794042.0  146990180.0
# 15149     27077037.0       40896024.0         0.0         0.0   44292628.0
#
#            단기차입금연결  회사채  회사채연결  영업활동으로 인한 현금흐름간접법  영업활동으로 인한 현금흐름간접법연결  \
# 0              0.0  0.0    0.0         -2488268.0           -2560438.0
# 1         100000.0  0.0    0.0         -1453276.0           -1572581.0
# 2              0.0  0.0    0.0         -3891420.0           -3939013.0
# 3           5451.0  0.0    0.0           730447.0             724893.0
# 4           6273.0  0.0    0.0          2411254.0            2410205.0
# ...            ...  ...    ...                ...                  ...
# 15145  107562548.0  0.0    0.0         34042933.0           33913401.0
# 15146  115674885.0  0.0    0.0         -4725664.0           -1389623.0
# 15147  143410967.0  0.0    0.0         -5348563.0           -6892102.0
# 15148  148617784.0  0.0    0.0        -30464257.0          -33794586.0
# 15149   44292628.0  0.0    0.0        -16943933.0          -12048291.0
#
#              매출액수익      매출액수익연결  영업활동으로_인한_현금흐름간접법게별  영업활동으로_인한_현금흐름간접법연결
# 0       17751704.0   17751704.0                  NaN                  NaN
# 1       16255389.0   16255389.0           -2488268.0           -2560438.0
# 2       20322140.0   20402140.0           -1453276.0           -1572581.0
# 3       22752584.0   22752584.0           -3891420.0           -3939013.0
# 4       27041894.0   27041894.0             730447.0             724893.0
# ...            ...          ...                  ...                  ...
# 15145  801560945.0  845115359.0            -446094.0             436601.0
# 15146  779990350.0  831746081.0           34042933.0           33913401.0
# 15147  780863972.0  836427496.0           -4725664.0           -1389623.0
# 15148  705007198.0  753865569.0           -5348563.0           -6892102.0
# 15149   97376909.0  102166838.0          -30464257.0          -33794586.0
#
# [15150 rows x 35 columns]

# %%
profit_tns(df5,'회사명','유동자산','유동부채','유동비율1')
profit_tns(df5,'회사명','유동자산연결','유동부채연결','유동비율2')

ekdwhk(df5,'회사명','유동자산','재고자산','유동부채','당좌비율1')
ekdwhk(df5,'회사명','유동자산연결','재고자산연결','유동부채연결','당좌비율2')

profit_tns(df5,'회사명','현금및현금성자산','유동부채','현금비율1')
profit_tns(df5,'회사명','현금및현금성자산연결','유동부채연결','현금비율2')

profit_tns(df5,'회사명','부채','자본','부채비율1')
profit_tns(df5,'회사명','부채연결','자본연결','부채비율2')

profit_tns(df5,'회사명','유동자산','자산','유동자산구성비율1')
profit_tns(df5,'회사명','유동자산연결','자산연결','유동자산구성비율2')

# %%
profit_tns(df5,'회사명','재고자산','유동자산','재고자산_대_유동자산비율1')
profit_tns(df5,'회사명','재고자산연결','유동자산연결','재고자산_대_유동자산비율2')

ekdwhk(df5,'회사명','유동자산','재고자산','유동부채','당좌자산구성비율1')
ekdwhk(df5,'회사명','유동자산연결','재고자산연결','유동부채연결','당좌자산구성비율2')

profit_tns(df5,'회사명','자본','자산','자기자본구성비율1')
profit_tns(df5,'회사명','자본연결','자산연결','자기자본구성비율2')

profit_tns(df5,'회사명','부채','자산','타인자본구성비율1')
profit_tns(df5,'회사명','부채연결','자산연결','타인자본구성비율2')

sulbi(df5,'회사명','재고자산','유동자산','유동부채','재고자산_대_순운전자본비율1')
sulbi(df5,'회사명','재고자산연결','유동자산연결','유동부채연결','재고자산_대_순운전자본비율2')

# %%
ekdwhk(df5,'회사명','매출채권','대손충당금','매입채무 및 기타유동채무','매출채권_대_매입채무비율1')
ekdwhk(df5,'회사명','매출채권연결','대손충당금연결','매입채무 및 기타유동채무연결','매출채권_대_매입채무비율2')

profit_tns(df5,'회사명','유동부채','자본','유동부채비율1')
profit_tns(df5,'회사명','유동부채연결','자본연결','유동부채비율2')

ckdlq(df5,'회사명','장기차입금','단기차입금','회사채','자산','차입금의존도1')
ckdlq(df5,'회사명','장기차입금연결','단기차입금연결','회사채연결','자산연결','차입금의존도2')

cash(df5,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법게별','부채','CASH_FLOW_대_부채비율1')
cash(df5,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','부채연결','CASH_FLOW_대_부채비율2')

cash(df5,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법게별','매출액수익','CASH_FLOW_대_매출액비율1')
cash(df5,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','매출액수익연결','CASH_FLOW_대_매출액비율2')

ekdwhk(df5,'회사명','유동자산','유동부채','자산','순운전자본비율1')
ekdwhk(df5,'회사명','유동자산연결','유동부채연결','자산연결','순운전자본비율2')

# %%
df5
# Out:
#             회사명  거래소코드    회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  11-Dec   15264885.0   15341167.0    7620349.0
# 1      (주)CMG제약  58820  12-Dec   47073443.0   47109213.0    6665126.0
# 2      (주)CMG제약  58820  13-Dec   38258866.0   38209699.0    5498201.0
# 3      (주)CMG제약  58820  14-Dec   28359823.0   28300941.0    8713579.0
# 4      (주)CMG제약  58820  15-Dec   26330765.0   26271614.0    8843328.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  124478864.0  136280257.0  256595137.0
# 15146   흥아해운(주)   3280  16-Dec   90973953.0  102103828.0  254811943.0
# 15147   흥아해운(주)   3280  17-Dec  105819304.0  115675013.0  321975170.0
# 15148          -0.024663          -0.027847           -0.025399
# 15149                NaN                NaN                 NaN
#
#        CASH_FLOW_대_매출액비율2   순운전자본비율1   순운전자본비율2
# 0                     NaN  27.749334  28.227204
# 1               -0.127128  70.905960  70.596227
# 2               -0.135074  58.541309  58.501385
# 3               -0.070632  33.798770  33.721893
# 4                0.057967  30.900915  30.816824
# ...                   ...        ...        ...
# 15145            0.020323 -17.130992 -15.942495
# 15146            0.019552 -17.381741 -16.340125
# 15147           -0.004951 -25.914632 -24.480373
# 15148           -0.026985 -27.051488 -25.399985
# 15149                 NaN        NaN        NaN
#
# [15150 rows x 67 columns]

# %%
df5['유동비율'] = df5['유동비율2'].fillna(df5['유동비율1'])
df5['당좌비율'] = df5['당좌비율2'].fillna(df5['당좌비율1'])
df5['현금비율'] = df5['현금비율2'].fillna(df5['현금비율1'])
df5['부채비율'] = df5['부채비율2'].fillna(df5['부채비율1'])
df5['유동자산구성비율'] = df5['유동자산구성비율2'].fillna(df5['유동자산구성비율1'])
df5['재고자산_대_유동자산비율'] = df5['재고자산_대_유동자산비율2'].fillna(df5['재고자산_대_유동자산비율1'])
df5['당좌자산구성비율'] = df5['당좌자산구성비율2'].fillna(df5['당좌자산구성비율1'])
df5['자기자본구성비율'] = df5['자기자본구성비율2'].fillna(df5['자기자본구성비율1'])
df5['타인자본구성비율'] = df5['타인자본구성비율2'].fillna(df5['타인자본구성비율1'])
df5['재고자산_대_순운전자본비율'] = df5['재고자산_대_순운전자본비율2'].fillna(df5['재고자산_대_순운전자본비율1'])
df5['매출채권_대_매입채무비율'] = df5['매출채권_대_매입채무비율2'].fillna(df5['매출채권_대_매입채무비율1'])
df5['유동부채비율'] = df5['유동부채비율2'].fillna(df5['유동부채비율1'])
df5['차입금의존도'] = df5['차입금의존도2'].fillna(df5['차입금의존도1'])
df5['CASH_FLOW_대_부채비율'] = df5['CASH_FLOW_대_부채비율2'].fillna(df5['CASH_FLOW_대_부채비율1'])
df5['CASH_FLOW_대_매출액비율'] = df5['CASH_FLOW_대_매출액비율2'].fillna(df5['CASH_FLOW_대_매출액비율1'])
df5['순운전자본비율'] = df5['순운전자본비율2'].fillna(df5['순운전자본비율1'])

# %%
df5
# Out:
#             회사명  거래소코드    회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  11-Dec   15264885.0   15341167.0    7620349.0
# 1      (주)CMG제약  58820  12-Dec   47073443.0   47109213.0    6665126.0
# 2      (주)CMG제약  58820  13-Dec   38258866.0   38209699.0    5498201.0
# 3      (주)CMG제약  58820  14-Dec   28359823.0   28300941.0    8713579.0
# 4      (주)CMG제약  58820  15-Dec   26330765.0   26271614.0    8843328.0
# ...         ...    ...     ...          ...          ...          ...
# 15145   흥아해운(주)   3280  15-Dec  124478864.0  136280257.0  256595137.0
# 15146   흥아해운(주)   3280  16-Dec   90973953.0  102103828.0  254811943.0
# 15147   흥아해운(주)   3280  17-Dec  105819304.0  115675013.0  321975170.0
# 15148          -0.024663          -0.027847           -0.025399
# 15149                NaN                NaN                 NaN
#
#        CASH_FLOW_대_매출액비율2   순운전자본비율1   순운전자본비율2        유동비율        당좌비율  \
# 0                     NaN  27.749334  28.227204  200.967044  165.032796
# 1               -0.127128  70.905960  70.596227  693.486739  649.984153
# 2               -0.135074  58.541309  58.501385  694.712327  610.736781
# 3               -0.070632  33.798770  33.721893  324.581779  268.233698
# 4                0.057967  30.900915  30.816824  296.854597  235.209165
# ...                   ...        ...        ...         ...         ...
# 15145            0.020323 -17.130992 -15.942495   51.918751   47.541924
# 15146            0.019552 -17.381741 -16.340125   39.463590   32.519049
# 15147           -0.004951 -25.914632 -24.480373   35.756989   29.581855
# 15148           -0.026985 -27.051488 -25.399985   34.674231   28.655584
# 15149                 NaN        NaN        NaN         NaN         NaN
#
#              현금비율        부채비율   유동자산구성비율  재고자산_대_유동자산비율    당좌자산구성비율  \
# 0       15.097437   51.407458  56.184053      17.880667  165.032796
# 1       68.810446   80.774918  82.491392       6.273023  649.984153
# 2      394.634328   14.113602  68.338307      12.087816  610.736781
# 3      101.236856   18.500394  48.737312      17.360211  268.233698
# 4       28.996257   20.778850  46.471436      20.766204  235.209165
# ...           ...         ...        ...            ...         ...
# 15145    7.760858  357.393227  17.214911       8.430147   47.541924
# 15146    5.455988  397.971832  10.652101      17.597336   32.519049
# 15147    6.173007  626.322609  13.625520      17.269727   29.581855
# 15148    4.887391  998.726601  13.482045      17.357694   28.655584
# 15149         NaN         NaN        NaN            NaN         NaN
#
#         자기자본구성비율   타인자본구성비율  재고자산_대_순운전자본비율  매출채권_대_매입채무비율      유동부채비율  \
# 0      66.046945  33.953055        0.355901     263.545895   42.328755
# 1      55.317408  44.682592        0.073300     195.684851   21.503475
# 2      87.631971  12.368027        0.141204     203.937782   11.225266
# 3      84.387905  15.612095        0.250902     191.430475   17.793330
# 4      82.795953  17.204047        0.313152     142.336258   18.907461
# ...          ...        ...             ...            ...         ...
# 15145  21.863026  78.136974       -0.091030      40.524724  151.659727
# 15146  20.081457  79.918543       -0.114717      47.750992  134.413682
# 15147  13.767987  86.232013       -0.096121      39.698572  276.771716
# 15148   9.101445  90.898555       -0.092133      39.910552  427.207197
# 15149        NaN        NaN             NaN            NaN         NaN
#
#           차입금의존도  CASH_FLOW_대_부채비율  CASH_FLOW_대_매출액비율    순운전자본비율
# 0       0.000000               NaN                NaN  28.227204
# 1       0.175107         -0.080984          -0.127128  70.596227
# 2       0.000000         -0.398508          -0.135074  58.501385
# 3       0.009387         -0.177269          -0.070632  33.721893
# 4       0.011096          0.161172           0.057967  30.816824
# ...          ...               ...                ...        ...
# 15145  21.752738          0.027766           0.020323 -15.942495
# 15146  16.953456          0.021228           0.019552 -16.340125
# 15147  21.363729         -0.005656          -0.004951 -24.480373
# 15148  21.701152         -0.027847          -0.026985 -25.399985
# 15149        NaN               NaN                NaN        NaN
#
# [15150 rows x 83 columns]

# %%
df5.to_csv('안정성계산식비율.csv',encoding='cp949',index=False)
