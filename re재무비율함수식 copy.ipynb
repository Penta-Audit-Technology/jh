# %%
import pandas as pd
import numpy as np
import warnings
import guro
warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
gu = guro.pat()

# %%
############################ WARNING ######################################
# 회사명 기준으로 shift 등의 조치가 필요한 경우 따로 취한 다음에 함수 적용하세요
# 안 그러면 터집니다...
###########################################################################


# 단순하게 나누는 함수
# df_name : raw_data 들어있는 데이터프레임
# a, b : 계산을 하고자하는 데이터프레임의 컬럼명을 입력 (a가 분자, b가 분모)
# c : 계산 결과를 저장하고자 하는 데이터프레임의 컬럼명을 입력
 # b / ((c + d)/2) * 100
def profit_chddud(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                    
# 증가율 함수
def pct (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)-100)
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)-100)*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)-100)
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)-100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan

# 수익성 계산
def profit (df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,d] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # 분모 -
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][b])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((abs(df_name.iloc[i][b]) - df_name.iloc[i][c])/df_name.iloc[i][b])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,d] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][b])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def profit_tns(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))*-1
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100)) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))*100))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
# b / ((c + d)/2) * 100
def profit_chddud(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2))*100)*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2))*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
def activiti(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-)
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])+abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # b(-), c(+), d(+)
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))*-1
            # a(+), b(+), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(-), c(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # a(+), b(+), c(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]+df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
# b / ((c - d)/2)
def activity_tnsdns(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))/2)))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))* -1 
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
                else:
                    df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])/2)))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
                else:
                    df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))/2)))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = ((df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])/2)))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
# 생산성 계산
def produce (df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d]))
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d]))
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d]))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
            
# 안정성 계산
def stability(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))*100)*-1)
            #분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100))
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if -0.01 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0:
                    df_name.loc[i,d] = -0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])*100)) 
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c])*100)) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])*100))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def robo(df_name,a,b,c,d):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c])))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c])))) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c]))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모,분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if 0 < (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c])))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/abs(df_name.iloc[i][c]))))
            #분모 +, 분자 - 인 상황
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                if -0.01 < (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((abs(df_name.iloc[i][b])/df_name.iloc[i][c])))*-1
            # 분모 -, 분자 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                if 0.01 < (((df_name.iloc[i][b]/abs(df_name.iloc[i][c])))) < 0:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/abs(df_name.iloc[i][c]))))
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                if 0 < (((df_name.iloc[i][b]/df_name.iloc[i][c]))) < 0.01:
                    df_name.loc[i,d] = 0.01
                else:
                    df_name.loc[i,d] = (((df_name.iloc[i][b]/df_name.iloc[i][c])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,d] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,d] = np.nan
                
def sulbi(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))* -1 
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # b(-), c(-), d(-) 일때
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-abs(df_name.iloc[i][d]))))*-1 # 절대값 변환
            # b(-), c(+), d(-) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d])))*-1 
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(-), c(-), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                # 절대값 변환 후 음수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
                else:
                    df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(-), c(+), d(+) 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (abs(df_name.iloc[i][b])/((abs(df_name.iloc[i][c])-df_name.iloc[i][d])))*-1
            # b(+), c(+), d(-) 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                # 절대값 변환 후 양수일 때
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(-), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # b(+), c(-), d(-)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][c]) > abs(df_name.iloc[i][d]):
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
                else:
                    df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-abs(df_name.iloc[i][d]))))
            # b(+), c(+), d(+)
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][b] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (df_name.iloc[i][b]/((df_name.iloc[i][c]-df_name.iloc[i][d])))
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        
def ekdwhk (df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = ((((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # 분모, 분자가 - 인 상황
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = ((((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)*-1) # 분모 -
                else:
                    df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100)
            # a - (-b) / a 일때
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - abs(df_name.iloc[i][c]))/df_name.iloc[i][d])*100) # b 절대값 변환
            # -a - b / -a 일때
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100) # a 아무대나 절대값 하나
            # 분모, 분자가 + 인 상황
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            # 분모 또는 분자가 0인 경우
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] - df_name.iloc[i][c])/df_name.iloc[i][d])*100)
            elif df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            # 둘다 결측치인 경우
            else:
                df_name.loc[i,e] = np.nan
                
def ckdlq (df_name,a,b,c,d,e,f):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            if df_name.iloc[i][b] > 0 or df_name.iloc[i][c] > 0 or df_name.iloc[i][d] > 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = 0
            elif df_name.iloc[i][e] == 0:
                df_name.loc[i,f] = 0
            else:
                df_name.loc[i,f] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            if df_name.iloc[i][b] > 0 or df_name.iloc[i][c] > 0 or df_name.iloc[i][d] > 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0 or df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = ((df_name.iloc[i][b] + df_name.iloc[i][c] + df_name.iloc[i][d])/df_name.iloc[i][e]) * 100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0 and df_name.iloc[i][d] == 0:
                df_name.loc[i,f] = 0
            elif df_name.iloc[i][e] == 0:
                df_name.loc[i,f] = 0
            else:
                df_name.loc[i,f] = np.nan
            
def cash(df_name,a,b,c,d,e):
    for i in range(len(df_name)-1):
        if df_name.iloc[i][a] == df_name.iloc[i+1][a]:
            # - - -
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) + abs(df_name.iloc[i][c]))/2)/df_name.iloc[i][d])*100
            # - + -
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*100
                else:
                    df_name.loc[i,e] = ((((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*-1)*100
            # - - +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # - + +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + - -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = ((((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*-1)*100
            # + + -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + - +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + + +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            else:
                df_name.loc[i,e] = np.nan
        elif df_name.iloc[i][a] == df_name.iloc[i-1][a]:
            # - - -
            if df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((abs(df_name.iloc[i][b]) + abs(df_name.iloc[i][c]))/2)/df_name.iloc[i][d])*100
            # - + -
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*100
                else:
                    df_name.loc[i,e] = ((((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/abs(df_name.iloc[i][d]))*-1)*100
            # - - +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # - + +
            elif df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + - -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] < 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = ((((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*-1)*100
            # + + -
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] < 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + - +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0 and df_name.iloc[i][d] > 0:
                if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
                else:
                    df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            # + + +
            elif df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0 and df_name.iloc[i][d] > 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            elif df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = (((df_name.iloc[i][b] + df_name.iloc[i][c])/2)/df_name.iloc[i][d])*100
            elif df_name.iloc[i][b] == 0 and df_name.iloc[i][c] == 0:
                df_name.loc[i,e] = 0
            elif df_name.iloc[i][d] == 0:
                df_name.loc[i,e] = 0
            else:
                df_name.loc[i,e] = np.nan

# %%
df1 = pd.read_csv('./비율/성장성비율2020.csv',encoding='cp949')
df1.columns = df1.columns.str.replace('\(', '')
df1.columns = df1.columns.str.replace('\)', '')
df1.columns = df1.columns.str.replace('\*', '')
df1.columns = df1.columns.str.replace('IFRS', '')
df1.columns = df1.columns.str.replace('천원', '')
# df1.columns = df1.columns.str.replace('\[', '')
# df1.columns = df1.columns.str.replace('\]', '')
# df1.columns = df1.columns.str.replace('제조', '')
df1['회계년도'] = pd.to_datetime(df1['회계년도'],format='%b-%d').dt.strftime('20%d-%m')
df1
# Out:
#             회사명  거래소코드     회계년도           자산         자산연결         유형자산  \
# 0      (주)CMG제약  58820  2010-12   26775627.0   26775627.0   10316860.0
# 1      (주)CMG제약  58820  2011-12   27548539.0   27305198.0    9652599.0
# 2      (주)CMG제약  58820  2012-12   56988604.0   57108035.0    9264142.0
# 3      (주)CMG제약  58820  2013-12   55961620.0   55912563.0   10805092.0
# 4      (주)CMG제약  58820  2014-12   58127098.0   58068326.0   18833775.0
# ...         ...    ...      ...          ...          ...          ...
# 18596   흥아해운(주)   3280  2016-12  942586770.0  958532259.0  667913303.0
# 18597   흥아해운(주)   3280  2017-12  834107402.0  848958520.0  557578439.0
# 18598   흥아해운(주)   3280  2018-12  782787041.0  803698457.0  490215607.0
# 18599   흥아해운(주)   3280  2019-12  386550839.0  430962722.0  237825418.0
# 18600   흥아해운(주)   3280  2020-12  284767347.0  286775958.0  179476647.0
#
#             유형자산연결         유동자산       유동자산연결           자본         자본연결  \
# 0       10316860.0   13041215.0   13041215.0   18405116.0   18405116.0
# 1        9707759.0   15264885.0   15341167.0   18290915.0   18034249.0
# 2        9307482.0   47073443.0   47109213.0   31602540.0   31590685.0
# 3       10805092.0   38258866.0   38209699.0   49048213.0   48997281.0
# 4       18833775.0   28359823.0   28300941.0   49067039.0   49002644.0
# ...            ...          ...          ...          ...          ...
# 18596  671042170.0   90973953.0  102103828.0  183829287.0  192487245.0
# 18597  560312598.0  105819304.0  115675013.0  107614965.0  116884496.0
# 18598  492709259.0  103181415.0  108354984.0   56731554.0   73148175.0
# 18599  238913893.0   61182850.0   93810124.0   17632229.0   30919383.0
# 18600  179753596.0   51275586.0   59094649.0  -20161176.0  -26283865.0
#
#              재고자산      재고자산연결
# 0       2782759.0   2782759.0
# 1       2743103.0   2743103.0
# 2       2955172.0   2955172.0
# 3       4618718.0   4618718.0
# 4       4913103.0   4913103.0
# ...           ...         ...
# 18596  17967554.0  17967554.0
# 18597  19976759.0  19976759.0
# 18598  18794127.0  18807927.0
# 18599   7544969.0   7715548.0
# 18600   7553365.0   7553389.0
#
# [18601 rows x 13 columns]

# %%
df1['자산개별'] = df1['자산'].shift(1)
df1['자산연결_'] = df1['자산연결'].shift(1)
df1['유형자산개별'] = df1['유형자산'].shift(1)
df1['유형자산연결_'] = df1['유형자산연결'].shift(1)
df1['유동자산개별'] = df1['유동자산'].shift(1)
df1['유동자산연결_'] = df1['유동자산연결'].shift(1)
df1['자본개별'] = df1['자본'].shift(1)
df1['자본연결_'] = df1['자본연결'].shift(1)
df1['재고자산개별'] = df1['재고자산'].shift(1)
df1['재고자산연결_'] = df1['재고자산연결'].shift(1)
# df1['총자산개별율'] = ''
pct(df1,'회사명','자산','자산개별','총자산개별율1')
pct(df1,'회사명','자산연결','자산연결_','총자산개별율2')
pct(df1,'회사명','유형자산','유형자산개별','유형자산개별율1')
pct(df1,'회사명','유형자산연결','유형자산연결_','유형자산개별율2')
pct(df1,'회사명','유동자산','유동자산개별','유동자산개별율1')
pct(df1,'회사명','유동자산연결','유동자산연결_','유동자산개별율2')
pct(df1,'회사명','자본','자본개별','자본개별율1')
pct(df1,'회사명','자본연결','자본연결_','자본개별율2')
pct(df1,'회사명','재고자산','재고자산개별','재고자산개별율1')
pct(df1,'회사명','재고자산연결','재고자산연결_','재고자산개별율2')

# %%
df1['총자산증가율'] = df1['총자산개별율2'].fillna(df1['총자산개별율1'])
df1['유형자산증가율'] = df1['유형자산개별율2'].fillna(df1['유형자산개별율1'])
df1['유동자산증가율'] = df1['유동자산개별율2'].fillna(df1['유동자산개별율1'])
df1['자본증가율'] = df1['자본개별율2'].fillna(df1['자본개별율1'])
df1['재고자산증가율'] = df1['재고자산개별율2'].fillna(df1['재고자산개별율1'])
t1 = df1[df1['회계년도'].str.contains('2010')].index
r1 = df1[df1['회계년도'].str.contains('2020')].index
df1 = df1.drop(t1)
df1 = df1.drop(r1)

# %%
df1.to_csv('성장성계산식비율.csv',encoding='cp949',index=False)

# %%
df2 = pd.read_csv('./비율/수익성비율2020.csv',encoding='cp949')
df2.columns = df2.columns.str.replace('\(', '')
df2.columns = df2.columns.str.replace('\)', '')
df2.columns = df2.columns.str.replace('\*', '')
df2.columns = df2.columns.str.replace('IFRS', '')
df2.columns = df2.columns.str.replace('천원', '')
df2['회계년도'] = pd.to_datetime(df2['회계년도'],format='%b-%d').dt.strftime('20%d-%m')
df2
# Out:
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결         매출원가  \
# 0      (주)CMG제약  58820  2010-12   11350419.0   11350419.0    8217627.0
# 1      (주)CMG제약  58820  2011-12   17751704.0   17751704.0   10325799.0
# 2      (주)CMG제약  58820  2012-12   16255389.0   16255389.0   11648690.0
# 3      (주)CMG제약  58820  2013-12   20322140.0   20402140.0   12506817.0
# 4      (주)CMG제약  58820  2014-12   22752584.0   22752584.0   14318048.0
# ...         ...    ...      ...          ...          ...          ...
# 18596   흥아해운(주)   3280  2016-12  779990350.0  831746081.0  756984914.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0  836427496.0  778062692.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0  753865569.0  724528226.0
# 18599   흥아해운(주)   3280  2019-12   97376909.0  102166838.0   98752599.0
# 18600   흥아해운(주)   3280  2020-12   85455349.0   88938838.0   80473859.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결           자본         자본연결  \
# 0        8217627.0  -6945220.0  -6945220.0   18405116.0   18405116.0
# 1       10325799.0  -1264488.0  -1508282.0   18290915.0   18034249.0
# 2       11648690.0  -6892739.0  -6660149.0   31602540.0   31590685.0
# 3       12506817.0    335258.0    296181.0   49048213.0   48997281.0
# 4       14318048.0    171502.0    158039.0   49067039.0   49002644.0
# ...            ...         ...         ...          ...          ...
# 18596  794370084.0 -16149442.0 -17173253.0  183829287.0  192487245.0
# 18597  818958179.0 -67916740.0 -73500411.0  107614965.0  116884496.0
# 18598  760867431.0 -96953501.0 -86540156.0   56731554.0   73148175.0
# 18599   96504366.0 -52550693.0 -51356551.0   17632229.0   30919383.0
# 18600   81592856.0 -37397763.0 -50876456.0  -20161176.0  -26283865.0
#
#                 자산         자산연결    영업이익개별    영업이익연결
# 0       26775627.0   26775627.0  -7537070  -7537070
# 1       27548539.0   27305198.0    714950    640282
# 2       56988604.0   57108035.0  -4045139  -4205503
# 3       55961620.0   55912563.0    822547    791250
# 4       58127098.0   58068326.0    446018    442323
# ...            ...          ...       ...       ...
# 18596  942586770.0  958532259.0   1154122   5895874
# 18597  834107402.0  848958520.0 -18649057 -13098623
# 18598  782787041.0  803698457.0 -40598236 -37595967
# 18599  386550839.0  430962722.0 -14756167 -12364292
# 18600  284767347.0  286775958.0  -4227716  -5797544
#
# [18601 rows x 15 columns]

# %%
df2['자본개별'] = df2['자본'].shift(1)
df2['자본연결_'] = df2['자본연결'].shift(1)
df2['자산개별'] = df2['자산'].shift(1)
df2['자산연결_'] = df2['자산연결'].shift(1)
df2['매출액개별'] = df2['매출액수익'].shift(1)
df2['매출액연결_'] = df2['매출액수익연결'].shift(1)
df2
# Out:
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결         매출원가  \
# 0      (주)CMG제약  58820  2010-12   11350419.0   11350419.0    8217627.0
# 1      (주)CMG제약  58820  2011-12   17751704.0   17751704.0   10325799.0
# 2      (주)CMG제약  58820  2012-12   16255389.0   16255389.0   11648690.0
# 3      (주)CMG제약  58820  2013-12   20322140.0   20402140.0   12506817.0
# 4      (주)CMG제약  58820  2014-12   22752584.0   22752584.0   14318048.0
# ...         ...    ...      ...          ...          ...          ...
# 18596   흥아해운(주)   3280  2016-12  779990350.0  831746081.0  756984914.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0  836427496.0  778062692.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0  753865569.0  724528226.0
# 18599   흥아해운(주)   3280  2019-12   97376909.0  102166838.0   98752599.0
# 18600   흥아해운(주)   3280  2020-12   85455349.0   88938838.0   80473859.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결           자본         자본연결  \
# 0        8217627.0  -6945220.0  -6945220.0   18405116.0   18405116.0
# 1       10325799.0  -1264488.0  -1508282.0   18290915.0   18034249.0
# 2       11648690.0  -6892739.0  -6660149.0   31602540.0   31590685.0
# 3       12506817.0    335258.0    296181.0   49048213.0   48997281.0
# 4       14318048.0    171502.0    158039.0   49067039.0   49002644.0
# ...            ...         ...         ...          ...          ...
# 18596  794370084.0 -16149442.0 -17173253.0  183829287.0  192487245.0
# 18597  818958179.0 -67916740.0 -73500411.0  107614965.0  116884496.0
# 18598  760867431.0 -96953501.0 -86540156.0   56731554.0   73148175.0
# 18599   96504366.0 -52550693.0 -51356551.0   17632229.0   30919383.0
# 18600   81592856.0 -37397763.0 -50876456.0  -20161176.0  -26283865.0
#
#                 자산         자산연결    영업이익개별    영업이익연결         자본개별        자본연결_  \
# 0       26775627.0   26775627.0  -7537070  -7537070          NaN          NaN
# 1       27548539.0   27305198.0    714950    640282   18405116.0   18405116.0
# 2       56988604.0   57108035.0  -4045139  -4205503   18290915.0   18034249.0
# 3       55961620.0   55912563.0    822547    791250   31602540.0   31590685.0
# 4       58127098.0   58068326.0    446018    442323   49048213.0   48997281.0
# ...            ...          ...       ...       ...          ...          ...
# 18596  942586770.0  958532259.0   1154122   5895874  161824549.0  173076634.0
# 18597  834107402.0  848958520.0 -18649057 -13098623  183829287.0  192487245.0
# 18598  782787041.0  803698457.0 -40598236 -37595967  107614965.0  116884496.0
# 18599  386550839.0  430962722.0 -14756167 -12364292   56731554.0   73148175.0
# 18600  284767347.0  286775958.0  -4227716  -5797544   17632229.0   30919383.0
#
#               자산개별        자산연결_        매출액개별       매출액연결_
# 0              NaN          NaN          NaN          NaN
# 1       26775627.0   26775627.0   11350419.0   11350419.0
# 2       27548539.0   27305198.0   17751704.0   17751704.0
# 3       56988604.0   57108035.0   16255389.0   16255389.0
# 4       55961620.0   55912563.0   20322140.0   20402140.0
# ...            ...          ...          ...          ...
# 18596  771212062.0  791640802.0  801560945.0  845115359.0
# 18597  942586770.0  958532259.0  779990350.0  831746081.0
# 18598  834107402.0  848958520.0  780863972.0  836427496.0
# 18599  782787041.0  803698457.0  705007198.0  753865569.0
# 18600  386550839.0  430962722.0   97376909.0  102166838.0
#
# [18601 rows x 21 columns]

# %%
profit(df2,'회사명','매출액수익','매출원가','매출액총이익율1')
profit(df2,'회사명','매출액수익연결','매출원가연결','매출액총이익율2')
profit_tns(df2,'회사명','당기순이익손실','매출액수익','매출액순이익율1')
profit_tns(df2,'회사명','당기순이익손실연결','매출액수익연결','매출액순이익율2')
profit_chddud(df2,'회사명','당기순이익손실','자본개별','자본','자기자본순이익율1')
profit_chddud(df2,'회사명','당기순이익손실연결','자본연결_','자본연결','자기자본순이익율2')

# %%
profit_chddud(df2,'회사명','영업이익개별','자산개별','자산','총자본영업이익율1')
profit_chddud(df2,'회사명','영업이익연결','자산연결_','자산연결','총자본영업이익율2')
profit_tns(df2,'회사명','영업이익개별','매출액수익','매출액영업이익률1')
profit_tns(df2,'회사명','영업이익연결','매출액수익연결','매출액영업이익률2')
profit_chddud(df2,'회사명','당기순이익손실','자산','자산개별','총자본순이익률1')
profit_chddud(df2,'회사명','당기순이익손실연결','자산연결','자산연결_','총자본순이익률2')

# %%
profit_tns(df2,'회사명','영업이익개별','매출액수익','매출액영업이익률1')
profit_tns(df2,'회사명','영업이익연결','매출액수익연결','매출액영업이익률2')

# %%
profit_chddud(df2,'회사명','영업이익개별','자산개별','자산','총자본영업이익율1')
profit_chddud(df2,'회사명','영업이익연결','자산연결_','자산연결','총자본영업이익율2')

# %%
pct(df2,'회사명','매출액수익','매출액개별','매출액증가율1')
pct(df2,'회사명','매출액수익연결','매출액연결_','매출액증가율2')

# %%
df2
# Out:
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결         매출원가  \
# 0      (주)CMG제약  58820  2010-12   11350419.0   11350419.0    8217627.0
# 1      (주)CMG제약  58820  2011-12   17751704.0   17751704.0   10325799.0
# 2      (주)CMG제약  58820  2012-12   16255389.0   16255389.0   11648690.0
# 3      (주)CMG제약  58820  2013-12   20322140.0   20402140.0   12506817.0
# 4      (주)CMG제약  58820  2014-12   22752584.0   22752584.0   14318048.0
# ...         ...    ...      ...          ...          ...          ...
# 18596   흥아해운(주)   3280  2016-12  779990350.0  831746081.0  756984914.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0  836427496.0  778062692.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0  753865569.0  724528226.0
# 18599   흥아해운(주)   3280  2019-12   97376909.0  102166838.0   98752599.0
# 18600   흥아해운(주)   3280  2020-12   85455349.0   88938838.0   80473859.0
#
#             매출원가연결     당기순이익손실   당기순이익손실연결           자본         자본연결  \
# 0        8217627.0  -6945220.0  -6945220.0   18405116.0   18405116.0
# 1       10325799.0  -1264488.0  -1508282.0   18290915.0   18034249.0
# 2       11648690.0  -6892739.0  -6660149.0   31602540.0   31590685.0
# 3       12506817.0    335258.0    296181.0   49048213.0   48997281.0
# 4       14318048.0    171502.0    158039.0   49067039.0   49002644.0
# ...            ...         ...         ...          ...          ...
# 18596  794370084.0 -16149442.0 -17173253.0  183829287.0  192487245.0
# 18597  818958179.0 -67916740.0 -73500411.0  107614965.0  116884496.0
# 18598  760867431.0 -96953501.0 -86540156.0   56731554.0   73148175.0
# 18599   96504366.0 -52550693.0 -51356551.0   17632229.0   30919383.0
# 18600   81592856.0 -37397763.0 -50876456.0  -20161176.0  -26283865.0
#
#                 자산         자산연결    영업이익개별    영업이익연결         자본개별        자본연결_  \
# 0       26775627.0   26775627.0  -7537070  -7537070          NaN          NaN
# 1       27548539.0   27305198.0    714950    640282   18405116.0   18405116.0
# 2       56988604.0   57108035.0  -4045139  -4205503   18290915.0   18034249.0
# 3       55961620.0   55912563.0    822547    791250   31602540.0   31590685.0
# 4       58127098.0   58068326.0    446018    442323   49048213.0   48997281.0
# ...            ...          ...       ...       ...          ...          ...
# 18596  942586770.0  958532259.0   1154122   5895874  161824549.0  173076634.0
# 18597  834107402.0  848958520.0 -18649057 -13098623  183829287.0  192487245.0
# 18598  782787041.0  803698457.0 -40598236 -37595967  107614965.0  116884496.0
# 18599  386550839.0  430962722.0 -14756167 -12364292   56731554.0   73148175.0
# 18600  284767347.0  286775958.0  -4227716  -5797544   17632229.0   30919383.0
#
#               자산개별        자산연결_        매출액개별       매출액연결_    매출액증가율1  \
# 0              NaN          NaN          NaN          NaN        NaN
# 1       26775627.0   26775627.0   11350419.0   11350419.0  56.396905
# 2       27548539.0   27305198.0   17751704.0   17751704.0  -8.429134
# 3       56988604.0   57108035.0   16255389.0   16255389.0  25.017863
# 4       55961620.0   55912563.0   20322140.0   20402140.0  11.959587
# ...            ...          ...          ...          ...        ...
# 18596  771212062.0  791640802.0  801560945.0  845115359.0  -2.691074
# 18597  942586770.0  958532259.0  779990350.0  831746081.0   0.112004
# 18598  834107402.0  848958520.0  780863972.0  836427496.0  -9.714467
# 18599  782787041.0  803698457.0  705007198.0  753865569.0 -86.187814
# 18600  386550839.0  430962722.0   97376909.0  102166838.0        NaN
#
#          매출액증가율2
# 0            NaN
# 1      56.396905
# 2      -8.429134
# 3      25.510008
# 4      11.520576
# ...          ...
# 18596  -1.581947
# 18597   0.562842
# 18598  -9.870781
# 18599 -86.447605
# 18600        NaN
#
# [18601 rows x 23 columns]

# %%
# df2['매출액총이익율'] = df2['매출액총이익율2'].fillna(df2['매출액총이익율1'])
# df2['매출액순이익율'] = df2['매출액순이익율2'].fillna(df2['매출액순이익율1'])
# df2['자기자본순이익율'] = df2['자기자본순이익율2'].fillna(df2['자기자본순이익율1'])
# df2['총자본영업이익율'] = df2['총자본영업이익율2'].fillna(df2['총자본영업이익율1'])
# df2['매출액영업이익률'] = df2['매출액영업이익률2'].fillna(df2['매출액영업이익률1'])
# df2['총자본순이익률'] = df2['총자본순이익률2'].fillna(df2['총자본순이익률1'])
df2['매출액증가율'] = df2['매출액증가율2'].fillna(df2['매출액증가율1'])
t2 = df2[df2['회계년도'].str.contains('2010')].index
r2 = df2[df2['회계년도'].str.contains('2020')].index
df2 = df2.drop(t2)
df2 = df2.drop(r2)
df2
# Out:
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결         매출원가  \
# 1      (주)CMG제약  58820  2011-12   17751704.0   17751704.0   10325799.0
# 2      (주)CMG제약  58820  2012-12   16255389.0   16255389.0   11648690.0
# 3      (주)CMG제약  58820  2013-12   20322140.0   20402140.0   12506817.0
# 4      (주)CMG제약  58820  2014-12   22752584.0   22752584.0   14318048.0
# 5      (주)CMG제약  58820  2015-12   27041894.0   27041894.0   17237814.0
# ...         ...    ...      ...          ...          ...          ...
# 18595   흥아해운(주)   3280  2015-12  801560945.0  845115359.0  763642673.0
# 18596   흥아해운(주)   3280  2016-12  779990350.0  831746081.0  756984914.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0  836427496.0  778062692.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0  753865569.0  724528226.0
# ...            ...          ...        ...        ...        ...        ...
# 15145  627805252.0  649240003.0   4.730554   6.203323   1.101265   1.244471
# 15146  771212062.0  791640802.0   2.949451   4.493679  -2.070467  -2.064723
# 15147  942586770.0  958532259.0   0.358741   2.088563  -8.697640  -8.787422
# 15148  834107402.0  848958520.0  -2.768912  -0.928795 -13.752129 -11.479521
# 15149  782787041.0  803698457.0        NaN        NaN        NaN        NaN
#
#         자기자본순이익율1  자기자본순이익율2  총자본영업이익율1  총자본영업이익율2     매출액영업이익률1  \
# 0             NaN        NaN        NaN        NaN  -2382.929436
# 1      -27.629832 -26.841946 -16.215113 -16.949157    301.849849
# 2        0.831382   0.735050   2.039775   1.963693  -2370.635721
# 3        0.349593   0.322529   0.909170   0.902699  -5001.281790
# 4       -7.606166  -7.619474  -5.359360  -5.369338    951.854425
# ...           ...        ...        ...        ...           ...
# 15145    5.591146   6.177886  10.297961  12.479037  -4830.121806
# 15146   -9.344286  -9.395487   0.667791   3.225632 -67483.006823
# 15147  -46.607020 -47.515918 -12.797684  -8.467887   4087.149903
# 15148 -117.986680 -91.079240 -49.405652 -39.567898   1636.546424
# 15149         NaN        NaN        NaN        NaN           NaN
#
#           매출액영업이익률2   총자본순이익률1   총자본순이익률2     매출액총익율    매출액순이익율   자기자본순이익율  \
# 0      -2672.482125        NaN        NaN  41.832069  -8.496548        NaN
# 1        286.526538 -16.307007 -15.779869  28.339519 -40.971945 -26.841946
# 2      -2478.469510   0.593638   0.524119  38.698504   1.451715   0.735050
# 3      -5043.896076   0.300647   0.277308  37.070673   0.694598   0.322529
# 4        951.326487  -6.361049  -6.370078  36.255153 -13.497912  -7.619474
# ...             ...        ...        ...        ...        ...        ...
# 15145  -3878.084635   1.261930   1.459832   6.203323   1.244471   6.177886
# 15146 -14007.259112  -1.884637  -1.962463   4.493679  -2.064723  -9.395487
# 15147   6285.613451  -7.645293  -8.132867   2.088563  -8.787422 -47.515918
# 15148   1905.176696 -11.992558 -10.472852  -0.928795 -11.479521 -91.079240
# 15149           NaN        NaN        NaN        NaN        NaN        NaN
#
#         총자본영업이익율      매출액영업이익률    총자본순이익률
# 0            NaN  -2672.482125        NaN
# 1     -16.949157    286.526538 -15.779869
# 2       1.963693  -2478.469510   0.524119
# 3       0.902699  -5043.896076   0.277308
# 4      -5.369338    951.326487  -6.370078
# ...          ...           ...        ...
# 15145  12.479037  -3878.084635   1.459832
# 15146   3.225632 -14007.259112  -1.962463
# 15147  -8.467887   6285.613451  -8.132867
# 15148 -39.567898   1905.176696 -10.472852
# 15149        NaN           NaN        NaN
#
# [15150 rows x 37 columns]

# %%
df3 = pd.read_csv('./비율/활동성비율2020.csv',encoding='cp949')
df3.columns = df3.columns.str.replace('\(', '')
df3.columns = df3.columns.str.replace('\)', '')
df3.columns = df3.columns.str.replace('\*', '')
df3.columns = df3.columns.str.replace('IFRS', '')
df3.columns = df3.columns.str.replace('천원', '')
df3['회계년도'] = pd.to_datetime(df3['회계년도'],format='%Y/%m').dt.strftime('%Y-%m')
df3
# Out:
# 18598  108354984.0  314936957.0  312494268.0  40164987.0  42695421.0
# 18599   93810124.0  178068106.0  202347422.0   2673427.0   4681942.0
# 18600   59094649.0  146027933.0  152820982.0   2731019.0   3825652.0
#
#            매입채무연결        매입채무           부채         부채연결
# 0       1488643.0   1488643.0    8370511.0    8370511.0
# 1       1481481.0   1481481.0    9257624.0    9270949.0
# 2       2670886.0   2670886.0   25386064.0   25517350.0
# 3       3911851.0   3911851.0    6913407.0    6915281.0
# 4       4719504.0   4719504.0    9060059.0    9065682.0
# ...           ...         ...          ...          ...
# 18596  49227200.0  46875781.0  758757483.0  766045015.0
# 18597  59451213.0  57971363.0  726492437.0  732074025.0
# 18598  67579783.0  68383653.0  726055487.0  730550282.0
# 18599  17283443.0  17852986.0  368918610.0  400043339.0
# 18600  11344824.0  12612875.0  304928523.0  313059823.0
#
# [18601 rows x 25 columns]

# %%
df3['자산개별'] = df3['자산'].shift(1)
df3['자산연결_'] = df3['자산연결'].shift(1)
df3['재고자산개별'] = df3['재고자산'].shift(1)
df3['재고자산연결_'] = df3['재고자산연결'].shift(1)
df3['매출채권개별'] = df3['매출채권'].shift(1)
df3['매출채권연결_'] = df3['매출채권연결'].shift(1)
df3['유형자산개별'] = df3['유형자산'].shift(1)
df3['유형자산연결_'] = df3['유형자산연결'].shift(1)
df3['매입채무개별'] = df3['매입채무'].shift(1)
df3['매입채무연결_'] = df3['매입채무연결'].shift(1)
df3['부채개별'] = df3['부채'].shift(1)
df3['부채연결_'] = df3['부채연결'].shift(1)
df3['유동자산개별'] = df3['유동자산'].shift(1)
df3['유동자산연결_'] = df3['유동자산연결'].shift(1)
df3['자본개별'] = df3['자본'].shift(1)
df3['자본연결_'] = df3['자본연결'].shift(1)

# %%
activiti(df3,'회사명','매출액수익','자산개별','자산','총자본회전율1')
activiti(df3,'회사명','매출액수익연결','자산연결_','자산연결','총자본회전율2')

activiti(df3,'회사명','매출원가','재고자산개별','재고자산','재고자산회전율1')
activiti(df3,'회사명','매출원가연결','재고자산연결_','재고자산연결','재고자산회전율2')

activiti(df3,'회사명','매출액수익','매출채권개별','매출채권','매출채권회전율1')
activiti(df3,'회사명','매출액수익연결','매출채권연결_','매출채권연결','매출채권회전율2')

activiti(df3,'회사명','매출액수익','유형자산개별','유형자산','유형자산회전율1')
activiti(df3,'회사명','매출액수익연결','유형자산연결_','유형자산연결','유형자산회전율2')

activiti(df3,'회사명','매출액수익','매입채무개별','매입채무','매입채무회전율1')
activiti(df3,'회사명','매출액수익연결','매입채무연결_','매입채무연결','매입채무회전율2')

activiti(df3,'회사명','매출액수익','자본개별','자본','자기자본회전율1')
activiti(df3,'회사명','매출액수익연결','자본연결_','자본연결','자기자본회전율2')

activiti(df3,'회사명','매출액수익','부채개별','부채','타인자본회전율1')
activiti(df3,'회사명','매출액수익연결','부채연결_','부채연결','타인자본회전율2')

activiti(df3,'회사명','매출액수익','유동자산개별','유동자산','유동자산회전율1')
activiti(df3,'회사명','매출액수익연결','유동자산연결_','유동자산연결','유동자산회전율2')

# 18597  1.116637  7.935881  7.681440  -7.225008  -8.049220  0.925512
# 18598  1.030840  6.746457  6.730041  -6.658689  -7.385796  0.912307
# 18599  0.180731  1.184891  1.010727  -1.666197  -1.882613  0.165498
#
#          재고자산회전율    매출채권회전율   유형자산회전율    매입채무회전율   자기자본회전율   타인자본회전율  \
# 1       3.737263   1.901091  1.772988  11.953510  0.974315  2.012498
# 2       4.088497   1.450546  1.709722   7.829457  0.655130  0.934532
# 3       3.302614   1.608876  2.028795   6.198680  0.506332  1.258124
# 4       3.004263   1.478089  1.535321   5.272077  0.464339  2.847461
# 5       3.324965   1.657734  1.475432   5.655170  0.564493  2.878081
# ...          ...        ...       ...        ...       ...       ...
# 18595  64.233139  24.382231  2.094676  16.050269  4.964267  1.536013
# 18596  53.935716  24.299406  1.441049  16.257836  4.550483  1.201416
# 18597  43.166320  22.183634  1.358548  15.392707  5.407265  1.116637
# 18598  39.235457  18.168919  1.431814  11.869002  7.934063  1.030840
# 18599   7.276902   4.312897  0.279288   2.407800  1.963471  0.180731
#
#         유동자산회전율   순운전자본회전율
# 1      1.250896   4.606349
# 2      0.520586   0.806397
# 3      0.478256   1.247470
# 4      0.684179   2.323857
# 5      0.991044   3.104406
# ...         ...        ...
# 18595  5.833991 -13.392496
# 18596  6.978201 -10.620835
# 18597  7.681440  -8.049220
# 18598  6.730041  -7.385796
# 18599  1.010727  -1.882613
#
# [15150 rows x 68 columns]

# %%
df3['총자본회전율'] = df3['총자본회전율2'].fillna(df3['총자본회전율1'])
df3['재고자산회전율'] = df3['재고자산회전율2'].fillna(df3['재고자산회전율1'])
df3['매출채권회전율'] = df3['매출채권회전율2'].fillna(df3['매출채권회전율1'])
df3['유형자산회전율'] = df3['유형자산회전율2'].fillna(df3['유형자산회전율1'])
df3['매입채무회전율'] = df3['매입채무회전율2'].fillna(df3['매입채무회전율1'])
df3['자기자본회전율'] = df3['자기자본회전율2'].fillna(df3['자기자본회전율1'])
df3['타인자본회전율'] = df3['타인자본회전율2'].fillna(df3['타인자본회전율1'])
df3['유동자산회전율'] = df3['유동자산회전율2'].fillna(df3['유동자산회전율1'])
df3['순운전자본회전율'] = df3['순운전자본회전율2'].fillna(df3['순운전자본회전율1'])
t3 = df3[df3['회계년도'].str.contains('2010')].index
r3 = df3[df3['회계년도'].str.contains('2020')].index
df3 = df3.drop(t3)
df3 = df3.drop(r3)

# %%
df3
# Out:
#             회사명  거래소코드     회계년도        매출액수익      매출액수익연결           자산  \
# 1      (주)CMG제약  58820  2011-12   17751704.0   17751704.0   27548539.0
# 2      (주)CMG제약  58820  2012-12   16255389.0   16255389.0   56988604.0
# 3      (주)CMG제약  58820  2013-12   20322140.0   20402140.0   55961620.0
# 4      (주)CMG제약  58820  2014-12   22752584.0   22752584.0   58127098.0
# 5      (주)CMG제약  58820  2015-12   27041894.0   27041894.0   56591972.0
# ...         ...    ...      ...          ...          ...          ...
# 18595   흥아해운(주)   3280  2015-12  801560945.0  845115359.0  771212062.0
# 18596   흥아해운(주)   3280  2016-12  779990350.0  831746081.0  942586770.0
#        순운전자본회전율1  순운전자본회전율2    총자본회전율     재고자산회전율  매출채권회전율     유형자산회전율  \
# 842     9.883429  11.421040  1.425938   28.906714      inf    5.124465
# 1501    7.079164   7.116115  1.330148  115.547117      inf    6.337957
# 1835   11.225565  11.773628  0.567090   10.402896      inf    2.313727
# 1836   -9.432134 -22.720289  0.271542    6.675351      inf    1.002757
# 1837  -54.222114 -21.113601  0.392270   10.097459      inf    1.443610
# ...          ...        ...       ...         ...      ...         ...
# 16127  22.521124  27.064185  1.068515    7.196128      inf  108.267828
# 16128  16.132717  16.766474  1.444287   14.000786      inf  179.021517
# 16129  20.781400  21.932665  1.185639   15.698306      inf  139.062612
# 16130  30.193257  33.537882  1.139520   20.009455      inf  138.318718
# 18460   7.899717   7.896677  0.723219    3.346043      inf   10.256191
#
#          매입채무회전율   자기자본회전율   타인자본회전율   유동자산회전율   순운전자본회전율
# 842    12.956444  3.577573  2.370941  2.642526  11.421040
# 1501   62.604547  2.179686  3.412804  1.870825   7.116115
# 1835    9.611455  1.450048  0.931310  1.043192  11.773628
# 1836    7.551344  0.670014  0.456585  0.582284 -22.720289
# 1837    5.134901  0.995883  0.647193  0.936955 -21.113601
# ...          ...       ...       ...       ...        ...
# 16127  26.694069  3.047500  1.645440  1.703544  27.064185
# 16128  15.512769  4.634190  2.098214  2.203517  16.766474
# 16129   9.364865  4.177073  1.655561  1.735962  21.932665
# 16130   9.080987  4.148444  1.571071  1.668931  33.537882
# 18460   7.527027  1.612152  1.311617  1.147741   7.896677
#
# [83 rows x 68 columns]

# %%
df3.to_csv('활동성계산식비율.csv',encoding='cp949')

# %%
df4 = pd.read_csv('./비율/생산성비율2020.csv',encoding='cp949')
df4.columns = df4.columns.str.replace('\(', '')
df4.columns = df4.columns.str.replace('\)', '')
df4.columns = df4.columns.str.replace('\*', '')
df4.columns = df4.columns.str.replace('IFRS', '')
df4.columns = df4.columns.str.replace('천원', '')
df4['회계년도'] = pd.to_datetime(df4['회계년도'],format='%b-%d').dt.strftime('20%d-%m')
df4
# Out:
#             회사명  거래소코드     회계년도         유형자산       유형자산연결     건설중인자산  \
# 0      (주)CMG제약  58820  2010-12   10316860.0   10316860.0    20000.0
# 1      (주)CMG제약  58820  2011-12    9652599.0    9707759.0    24700.0
# 2      (주)CMG제약  58820  2012-12    9264142.0    9307482.0        0.0
# 3      (주)CMG제약  58820  2013-12   10805092.0   10805092.0  1827454.0
# 4      (주)CMG제약  58820  2014-12   18833775.0   18833775.0   154233.0
# ...         ...    ...      ...          ...          ...        ...
# 18596   흥아해운(주)   3280  2016-12  667913303.0  671042170.0  5172380.0
# 18597   흥아해운(주)   3280  2017-12  557578439.0  560312598.0  8543473.0
# 18598   흥아해운(주)   3280  2018-12  490215607.0  492709259.0        0.0
# 18599   흥아해운(주)   3280  2019-12  237825418.0  238913893.0        0.0
# 18600   흥아해운(주)   3280  2020-12  179476647.0  179753596.0        0.0
#
#         건설중인자산연결       기계장치     기계장치연결           자산         자산연결        매출액수익  \
# 0        20000.0  4008773.0  4008773.0   26775627.0   26775627.0   11350419.0
# 1        24700.0  3944218.0  3944218.0   27548539.0   27305198.0   17751704.0
# 2            0.0  4288368.0  4288368.0   56988604.0   57108035.0   16255389.0
# 3      1827454.0  4595388.0  4595388.0   55961620.0   55912563.0   20322140.0
# 4       154233.0  7950710.0  7950710.0   58127098.0   58068326.0   22752584.0
# ...          ...        ...        ...          ...          ...          ...
# 18596  5172380.0        0.0    11570.0  942586770.0  958532259.0  779990350.0
# 18597  8543473.0        0.0    11570.0  834107402.0  848958520.0  780863972.0
# 18598        0.0        0.0    11570.0  782787041.0  803698457.0  705007198.0
# 18599        0.0        0.0    11570.0  386550839.0  430962722.0   97376909.0
# 18600        0.0        0.0        0.0  284767347.0  286775958.0   85455349.0
#
#            매출액수익연결  합계_기말인원      부가가치       부가가치연결
# 0       11350419.0    129.0    796710     771120.0
# 1       17751704.0    135.0   3669250    3472170.0
# 2       16255389.0    134.0    -88040     269310.0
# 3       20402140.0    136.0   6952080    6994900.0
# 4       22752584.0    164.0   7065040    7061340.0
# ...            ...      ...       ...          ...
# 18596  831746081.0    942.0  81449560  105291390.0
# 18597  836427496.0    921.0  41240980   46072270.0
# 18598  753865569.0    796.0   1920690   34054900.0
# 18599  102166838.0    339.0   3363370   13366250.0
# 18600   88938838.0    307.0  11992070   -1108190.0
#
# [18601 rows x 16 columns]

# %%
produce(df4,'회사명','유형자산','건설중인자산','합계_기말인원','노동장비율1')
produce(df4,'회사명','유형자산연결','건설중인자산연결','합계_기말인원','노동장비율2')

robo(df4,'회사명','기계장치','합계_기말인원','기계장비율1')
robo(df4,'회사명','기계장치연결','합계_기말인원','기계장비율2')

robo(df4,'회사명','자산','합계_기말인원','자본집약도1')
robo(df4,'회사명','자산연결','합계_기말인원','자본집약도2')

sulbi(df4,'회사명','부가가치','유형자산','건설중인자산','설비투자효율1')
sulbi(df4,'회사명','부가가치연결','유형자산연결','건설중인자산연결','설비투자효율2')

profit_tns(df4,'회사명','부가가치','자산','총자본투자효율1')
profit_tns(df4,'회사명','부가가치연결','자산연결','총자본투자효율2')

profit_tns(df4,'회사명','부가가치','매출액수익','부가가치율1')
profit_tns(df4,'회사명','부가가치연결','매출액수익연결','부가가치율2')

robo(df4,'회사명','부가가치','합계_기말인원','종업원1인딩부가가치1')
robo(df4,'회사명','부가가치연결','합계_기말인원','종업원1인딩부가가치2')

# %%
df4['노동장비율'] = df4['노동장비율2'].fillna(df4['노동장비율1'])
df4['기계장비율'] = df4['기계장비율2'].fillna(df4['기계장비율1'])
df4['자본집약도'] = df4['자본집약도2'].fillna(df4['자본집약도1'])
df4['설비투자효율'] = df4['설비투자효율2'].fillna(df4['설비투자효율1'])
# df4['설비투자효율'] = df4['설비투자효율'] * 1000
df4['총자본투자효율'] = df4['총자본투자효율2'].fillna(df4['총자본투자효율1'])
# df4['총자본투자효율'] = df4['총자본투자효율'] * 1000
df4['부가가치율'] = df4['부가가치율2'].fillna(df4['부가가치율1'])
# df4['부가가치율'] = df4['부가가치율'] * 1000
df4['종업원1인딩부가가치'] = df4['종업원1인딩부가가치2'].fillna(df4['종업원1인딩부가가치1'])
# df4['종업원1인딩부가가치'] = df4['종업원1인딩부가가치'] * 1000
t4 = df4[df4['회계년도'].str.contains('2010')].index
r4 = df4[df4['회계년도'].str.contains('2020')].index
df4 = df4.drop(t4)
df4 = df4.drop(r4)

# %%
df4
# Out:
#             회사명  거래소코드     회계년도         유형자산       유형자산연결     건설중인자산  \
# 1      (주)CMG제약  58820  2011-12    9652599.0    9707759.0    24700.0
# 2      (주)CMG제약  58820  2012-12    9264142.0    9307482.0        0.0
# 3      (주)CMG제약  58820  2013-12   10805092.0   10805092.0  1827454.0
# 4      (주)CMG제약  58820  2014-12   18833775.0   18833775.0   154233.0
# 5      (주)CMG제약  58820  2015-12   17822468.0   17822468.0        0.0
# ...         ...    ...      ...          ...          ...        ...
# 18595   흥아해운(주)   3280  2015-12  479816639.0  483319774.0   430166.0
# 18596   흥아해운(주)   3280  2016-12  667913303.0  671042170.0  5172380.0
# 18597   흥아해운(주)   3280  2017-12  557578439.0  560312598.0  8543473.0
# 18598   흥아해운(주)   3280  2018-12  490215607.0  492709259.0        0.0
# 18599   흥아해운(주)   3280  2019-12  237825418.0  238913893.0        0.0
#
#         건설중인자산연결       기계장치     기계장치연결           자산         자산연결        매출액수익  \
# 1        24700.0  3944218.0  3944218.0   27548539.0   27305198.0   17751704.0
# 2            0.0  4288368.0  4288368.0   56988604.0   57108035.0   16255389.0
# 3      1827454.0  4595388.0  4595388.0   55961620.0   55912563.0   20322140.0
# 4       154233.0  7950710.0  7950710.0   58127098.0   58068326.0   22752584.0
# 5            0.0  8328336.0  8328336.0   56591972.0   56532821.0   27041894.0
# ...          ...        ...        ...          ...          ...          ...
# 18595   430166.0        0.0    11570.0  771212062.0  791640802.0  801560945.0
# 18596  5172380.0        0.0    11570.0  942586770.0  958532259.0  779990350.0
# 18597  8543473.0        0.0    11570.0  834107402.0  848958520.0  780863972.0
# 18598        0.0        0.0    11570.0  782787041.0  803698457.0  705007198.0
# 18599        0.0        0.0    11570.0  386550839.0  430962722.0   97376909.0
#
#            매출액수익연결  합계_기말인원      부가가치       부가가치연결         노동장비율1  \
# 1       17751704.0    135.0   3669250    3472170.0   71317.770370
# 2       16255389.0    134.0    -88040     269310.0   69135.388060
# 3       20402140.0    136.0   6952080    6994900.0   66012.044118
# 4       22752584.0    164.0   7065040    7061340.0  113899.646341
# 5       27041894.0    156.0   4316800    4315370.0  114246.589744
# ...            ...      ...       ...          ...            ...
# 18595  845115359.0    813.0  88375300  103792310.0  589651.258303
# 18596  831746081.0    942.0  81449560  105291390.0  703546.627389
# 18597  836427496.0    921.0  41240980   46072270.0  596129.170467
# 18598  753865569.0    796.0   1920690   34054900.0  615848.752513
# 18599  102166838.0    339.0   3363370   13366250.0  701549.905605
#
#               노동장비율2        기계장비율1        기계장비율2        자본집약도1        자본집약도2  \
# 1       71726.362963  29216.429630  29216.429630  2.040633e+05  2.022607e+05
# 2       69458.820896  32002.746269  32002.746269  4.252881e+05  4.261794e+05
df5 = pd.read_csv('./비율/안정성비율2020.csv',encoding='cp949')
df5.columns = df5.columns.str.replace('\(', '')
df5.columns = df5.columns.str.replace('\)', '')
df5.columns = df5.columns.str.replace('\*', '')
df5.columns = df5.columns.str.replace('IFRS', '')
df5.columns = df5.columns.str.replace('천원', '')
df5['회계년도'] = pd.to_datetime(df5['회계년도'],format='%d-%b').dt.strftime('20%d-%m')
df5
# Out:
#             회사명  거래소코드     회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  2010-12   13041215.0   13041215.0    5320707.0
# 1      (주)CMG제약  58820  2011-12   15264885.0   15341167.0    7620349.0
# 2      (주)CMG제약  58820  2012-12   47073443.0   47109213.0    6665126.0
# 3      (주)CMG제약  58820  2013-12   38258866.0   38209699.0    5498201.0
# 4      (주)CMG제약  58820  2014-12   28359823.0   28300941.0    8713579.0
# ...         ...    ...      ...          ...          ...          ...
# 18596   흥아해운(주)   3280  2016-12   90973953.0  102103828.0  254811943.0
# 18597   흥아해운(주)   3280  2017-12  105819304.0  115675013.0  321975170.0
# 18598   흥아해운(주)   3280  2018-12  103181415.0  108354984.0  314936957.0
# 18599   흥아해운(주)   3280  2019-12   61182850.0   93810124.0  178068106.0
# 18600   흥아해운(주)   3280  2020-12   51275586.0   59094649.0  146027933.0
#
#             유동부채연결        재고자산      재고자산연결    현금및현금성자산  현금및현금성자산연결  \
# 0        5320707.0   2782759.0   2782759.0   2447346.0   2447346.0
# 1        7633673.0   2743103.0   2743103.0   1152489.0   1152489.0
# 2        6793095.0   2955172.0   2955172.0   4673134.0   4674359.0
# 3        5500075.0   4618718.0   4618718.0  21704962.0  21705184.0
# 4        8719202.0   4913103.0   4913103.0   8826926.0   8827046.0
# ...            ...         ...         ...         ...         ...
# 18596  258729193.0  17967554.0  17967554.0   2384823.0  14116233.0
# 18597  323503225.0  19976759.0  19976759.0  10380560.0  19969877.0
# 18598  312494268.0  18794127.0  18807927.0   9560545.0  15272818.0
# 18599  202347422.0   7544969.0   7715548.0   7559325.0  13657451.0
# 18600  152820982.0   7553365.0   7553389.0   3326905.0   4912668.0
#
#                 부채         부채연결           자본         자본연결           자산  \
# 0        8370511.0    8370511.0   18405116.0   18405116.0   26775627.0
# 1        9257624.0    9270949.0   18290915.0   18034249.0   27548539.0
# 2       25386064.0   25517350.0   31602540.0   31590685.0   56988604.0
# 3        6913407.0    6915281.0   49048213.0   48997281.0   55961620.0
# 4        9060059.0    9065682.0   49067039.0   49002644.0   58127098.0
# ...            ...          ...          ...          ...          ...
# 18596  758757483.0  766045015.0  183829287.0  192487245.0  942586770.0
# 18597  726492437.0  732074025.0  107614965.0  116884496.0  834107402.0
# 18598  726055487.0  730550282.0   56731554.0   73148175.0  782787041.0
# 18599  368918610.0  400043339.0   17632229.0   30919383.0  386550839.0
# 18600  304928523.0  313059823.0  -20161176.0  -26283865.0  284767347.0
#
#               자산연결        매출채권      매출채권연결      대손충당금    대손충당금연결       장기차입금  \
# 0       26775627.0   7625064.0   7625064.0  2074915.0  2074915.0   2000000.0
profit_tns(df5,'회사명','현금및현금성자산연결','유동부채연결','현금비율2')

profit_tns(df5,'회사명','부채','자본','부채비율1')
profit_tns(df5,'회사명','부채연결','자본연결','부채비율2')

profit_tns(df5,'회사명','유동자산','자산','유동자산구성비율1')
profit_tns(df5,'회사명','유동자산연결','자산연결','유동자산구성비율2')

# %%
profit_tns(df5,'회사명','재고자산','유동자산','재고자산_대_유동자산비율1')
profit_tns(df5,'회사명','재고자산연결','유동자산연결','재고자산_대_유동자산비율2')

ekdwhk(df5,'회사명','유동자산','재고자산','자산','당좌자산구성비율1')
ekdwhk(df5,'회사명','유동자산연결','재고자산연결','자산연결','당좌자산구성비율2')

profit_tns(df5,'회사명','자본','자산','자기자본구성비율1')
profit_tns(df5,'회사명','자본연결','자산연결','자기자본구성비율2')

profit_tns(df5,'회사명','부채','자산','타인자본구성비율1')
profit_tns(df5,'회사명','부채연결','자산연결','타인자본구성비율2')

sulbi(df5,'회사명','재고자산','유동자산','유동부채','재고자산_대_순운전자본비율1')
sulbi(df5,'회사명','재고자산연결','유동자산연결','유동부채연결','재고자산_대_순운전자본비율2')

# %%
ekdwhk(df5,'회사명','매출채권','대손충당금','매입채무','매출채권_대_매입채무비율1')
ekdwhk(df5,'회사명','매출채권연결','대손충당금연결','매입채무연결','매출채권_대_매입채무비율2')

profit_tns(df5,'회사명','유동부채','자본','유동부채비율1')
profit_tns(df5,'회사명','유동부채연결','자본연결','유동부채비율2')

profit_tns(df5,'회사명','장기차입금','자산','차입금의존도1')
profit_tns(df5,'회사명','장기차입금연결','자산연결','차입금의존도2')

cash(df5,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법게별','부채','CASH_FLOW_대_부채비율1')
cash(df5,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','부채연결','CASH_FLOW_대_부채비율2')

cash(df5,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법게별','매출액수익','CASH_FLOW_대_매출액비율1')
cash(df5,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','매출액수익연결','CASH_FLOW_대_매출액비율2')

cash(df5,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법게별','차입금개별','CASH_FLOW_대_차입금비율1')
cash(df5,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','차입금연결','CASH_FLOW_대_차입금비율2')

ekdwhk(df5,'회사명','유동자산','유동부채','자산','순운전자본비율1')
ekdwhk(df5,'회사명','유동자산연결','유동부채연결','자산연결','순운전자본비율2')

profit_tns(df5,'회사명','차입금개별','자산','차입금비율1')
profit_tns(df5,'회사명','차입금연결','자산연결','차입금비율2')

# %%
df5
# Out:
#             회사명  거래소코드     회계년도         유동자산       유동자산연결         유동부채  \
# 0      (주)CMG제약  58820  2010-12   13041215.0   13041215.0    5320707.0
# 1      (주)CMG제약  58820  2011-12   15264885.0   15341167.0    7620349.0
# 18599       15.300273  1009.901278  654.435511  0.000000  0.000000
# 18600             NaN          NaN         NaN       NaN       NaN
#
#        CASH_FLOW_대_부채비율1  CASH_FLOW_대_부채비율2  CASH_FLOW_대_매출액비율1  \
# 0                    NaN                NaN                 NaN
# 1              -0.457576          -0.460811           -0.238629
# 2              -0.077632          -0.080984           -0.121238
# 3              -0.386546          -0.398508           -0.131499
# 4              -0.174445          -0.177269           -0.069464
# ...                  ...                ...                 ...
# 18596           0.019319           0.021228            0.018793
# 18597          -0.006933          -0.005656           -0.006451
# 18598          -0.024663          -0.027847           -0.025399
# 18599          -0.064253          -0.057297           -0.243426
# 18600                NaN                NaN                 NaN
#
#        CASH_FLOW_대_매출액비율2  CASH_FLOW_대_차입금비율1  CASH_FLOW_대_차입금비율2   순운전자본비율1  \
# 0                     NaN                 NaN                 NaN  28.834089
# 1               -0.240661           -1.984990            0.000000  27.749334
# 2               -0.127128           -0.924112          -20.665095  70.905960
# 3               -0.135074            0.000000            0.000000  58.541309
# 4               -0.070632            0.000000         -294.819299  33.798770
# ...                   ...                 ...                 ...        ...
# 18596            0.019552            0.091177            0.100070 -17.381741
# 18597           -0.004951           -0.028026           -0.022831 -25.914632
# 18598           -0.026985           -0.103635           -0.116640 -27.051488
# 18599           -0.224353           -0.535170           -0.517500 -30.238003
# 18600                 NaN                 NaN                 NaN        NaN
#
#         순운전자본비율2     차입금비율1     차입금비율2
# 0      28.834089  13.211556   7.469480
# 1      28.227204   7.746505   0.000000
# 2      70.596227   3.742173   0.175107
# 3      58.501385   0.000000   0.000000
# 4      33.721893   0.000000   0.010000
# ...          ...        ...        ...
# 18596 -16.340125  17.056440  16.953456
# 18597 -24.480373  21.547908  21.363729
# 18598 -25.399985  22.072954  21.701152
# 18599 -25.184846  11.458422  10.277601
# 18600        NaN        NaN        NaN
#
# [18601 rows x 73 columns]

# %%
df5['유동비율'] = df5['유동비율2'].fillna(df5['유동비율1'])
df5['당좌비율'] = df5['당좌비율2'].fillna(df5['당좌비율1'])
df5['현금비율'] = df5['현금비율2'].fillna(df5['현금비율1'])
df5['부채비율'] = df5['부채비율2'].fillna(df5['부채비율1'])
df5['유동자산구성비율'] = df5['유동자산구성비율2'].fillna(df5['유동자산구성비율1'])
df5['재고자산_대_유동자산비율'] = df5['재고자산_대_유동자산비율2'].fillna(df5['재고자산_대_유동자산비율1'])
df5['당좌자산구성비율'] = df5['당좌자산구성비율2'].fillna(df5['당좌자산구성비율1'])
df5['자기자본구성비율'] = df5['자기자본구성비율2'].fillna(df5['자기자본구성비율1'])
df5['타인자본구성비율'] = df5['타인자본구성비율2'].fillna(df5['타인자본구성비율1'])
df5['재고자산_대_순운전자본비율'] = df5['재고자산_대_순운전자본비율2'].fillna(df5['재고자산_대_순운전자본비율1'])
df5['매출채권_대_매입채무비율'] = df5['매출채권_대_매입채무비율2'].fillna(df5['매출채권_대_매입채무비율1'])
df5['유동부채비율'] = df5['유동부채비율2'].fillna(df5['유동부채비율1'])
df5['차입금의존도'] = df5['차입금의존도2'].fillna(df5['차입금의존도1'])
df5['CASH_FLOW_대_부채비율'] = df5['CASH_FLOW_대_부채비율2'].fillna(df5['CASH_FLOW_대_부채비율1'])
df5['CASH_FLOW_대_매출액비율'] = df5['CASH_FLOW_대_매출액비율2'].fillna(df5['CASH_FLOW_대_매출액비율1'])
df5['CASH_FLOW_대_차입금비율'] = df5['CASH_FLOW_대_차입금비율2'].fillna(df5['CASH_FLOW_대_차입금비율1'])
df5['순운전자본비율'] = df5['순운전자본비율2'].fillna(df5['순운전자본비율1'])
df5['차입금비율'] = df5['차입금비율2'].fillna(df5['차입금비율1'])

# %%
t5 = df5[df5['회계년도'].str.contains('2010')].index
r5 = df5[df5['회계년도'].str.contains('2020')].index
df5 = df5.drop(t5)
df5 = df5.drop(r5)
df5
# Out:
#             회사명  거래소코드     회계년도         유동자산       유동자산연결         유동부채  \
# 1      (주)CMG제약  58820  2011-12   15264885.0   15341167.0    7620349.0
# 2      (주)CMG제약  58820  2012-12   47073443.0   47109213.0    6665126.0
# 3      (주)CMG제약  58820  2013-12   38258866.0   38209699.0    5498201.0
# 4      (주)CMG제약  58820  2014-12   28359823.0   28300941.0    8713579.0
# 5      (주)CMG제약  58820  2015-12   26330765.0   26271614.0    8843328.0
# ...         ...    ...      ...          ...          ...          ...
# 18595   흥아해운(주)   3280  2015-12  124478864.0  136280257.0  256595137.0
# 18596   흥아해운(주)   3280  2016-12   90973953.0  102103828.0  254811943.0
# 18597   흥아해운(주)   3280  2017-12  105819304.0  115675013.0  321975170.0
# 18598   흥아해운(주)   3280  2018-12  103181415.0  108354984.0  314936957.0
# 18599   흥아해운(주)   3280  2019-12   61182850.0   93810124.0  178068106.0
#
#             유동부채연결        재고자산      재고자산연결    현금및현금성자산  현금및현금성자산연결  \
# 1        7633673.0   2743103.0   2743103.0   1152489.0   1152489.0
# 2        6793095.0   2955172.0   2955172.0   4673134.0   4674359.0
# 3        5500075.0   4618718.0   4618718.0  21704962.0  21705184.0
# 4        8719202.0   4913103.0   4913103.0   8826926.0   8827046.0
# 5        8849994.0   5455617.0   5455617.0   2566164.0   2566167.0
# ...            ...         ...         ...         ...         ...
# 18595  262487550.0  11488626.0  11488626.0   9908430.0  20371285.0
# 18596  258729193.0  17967554.0  17967554.0   2384823.0  14116233.0
# 18597  323503225.0  19976759.0  19976759.0  10380560.0  19969877.0
# 18598  312494268.0  18794127.0  18807927.0   9560545.0  15272818.0
# 18599  202347422.0   7544969.0   7715548.0   7559325.0  13657451.0
#
#                 부채         부채연결           자본         자본연결           자산  \
# 1        9257624.0    9270949.0   18290915.0   18034249.0   27548539.0
# 2       25386064.0   25517350.0   31602540.0   31590685.0   56988604.0
# 3        6913407.0    6915281.0   49048213.0   48997281.0   55961620.0
# 4        9060059.0    9065682.0   49067039.0   49002644.0   58127098.0
# 5        9719267.0    9725933.0   46872705.0   46806888.0   56591972.0
# ...            ...          ...          ...          ...          ...
# 18595  609387512.0  618564168.0  161824549.0  173076634.0  771212062.0
# 18596 -16.340125  17.056440  16.953456   39.463590   32.519049    5.455988
# 18597 -24.480373  21.547908  21.363729   35.756989   29.581855    6.173007
# 18598 -25.399985  22.072954  21.701152   34.674231   28.655584    4.887391
# 18599 -25.184846  11.458422  10.277601   46.360919   42.547899    6.749506
#
#               부채비율   유동자산구성비율  재고자산_대_유동자산비율   당좌자산구성비율   자기자본구성비율   타인자본구성비율  \
# 1        51.407458  56.184053      17.880667  46.137970  66.046945  33.953055
# 2        80.774918  82.491392       6.273023  77.316688  55.317408  44.682592
# 3        14.113602  68.338307      12.087816  60.077698  87.631971  12.368027
# 4        18.500394  48.737312      17.360211  40.276412  84.387905  15.612095
# 5        20.778850  46.471436      20.766204  36.821083  82.795953  17.204047
# ...            ...        ...            ...        ...        ...        ...
# 18595   357.393227  17.214911       8.430147  15.763668  21.863026  78.136974
# 18596   397.971832  10.652101      17.597336   8.777615  20.081457  79.918543
# 18597   626.322609  13.625520      17.269727  11.272430  13.767987  86.232013
# 18598   998.726601  13.482045      17.357694  11.141872   9.101445  90.898555
# 18599  1293.827044  21.767573       8.224643  19.977268   7.174491  92.825509
#
#        재고자산_대_순운전자본비율  매출채권_대_매입채무비율      유동부채비율    차입금의존도  CASH_FLOW_대_부채비율  \
# 1            0.355901     602.309446   42.328755  0.000000         -0.460811
# 2            0.073300     323.406428   21.503475  0.000000         -0.080984
# 3            0.141204     282.724368   11.225266  0.000000         -0.398508
# 4            0.250902     285.313181   17.793330  0.000000         -0.177269
# 5            0.313152     254.691464   18.907461  0.000000          0.161172
# ...               ...            ...         ...       ...               ...
# 18595       -0.091030      60.439434  151.659727  8.165446          0.027766
# 18596       -0.114717      68.725004  134.413682  4.885538          0.021228
# 18597       -0.096121      64.995838  276.771716  4.471152         -0.005656
# 18598       -0.092133      59.323200  427.207197  3.209418         -0.027847
# 18599       -0.071087      15.300273  654.435511  0.000000         -0.057297
#
#        CASH_FLOW_대_매출액비율    순운전자본비율  CASH_FLOW_대_차입금비율      차입금비율
# 1              -0.240661  28.227204           0.000000   0.000000
# 2              -0.127128  70.596227         -20.665095   0.175107
# 3              -0.135074  58.501385           0.000000   0.000000
# 4              -0.070632  33.721893        -294.819299   0.010000
# 5               0.057967  30.816824         249.888251   0.011096
# ...                  ...        ...                ...        ...
# 18595           0.020323 -15.942495           0.099737  21.752738
# 18596           0.019552 -16.340125           0.100070  16.953456
# 18597          -0.004951 -24.480373          -0.022831  21.363729
# 18598          -0.026985 -25.399985          -0.116640  21.701152
# 18599          -0.224353 -25.184846          -0.517500  10.277601
#
# [15150 rows x 91 columns]

# %%
df5.to_csv('안정성계산식비율.csv',encoding='cp949',index=False)

# %%
df6 = pd.read_csv('최종계산비율.csv',encoding='utf-8')
df6 = df6.round(2)
df6
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  자기자본증가율  \
# 
ASH_FLOW_대_매출액비율  CASH_FLOW_대_차입금비율  자기자본구성비율  당좌자산구성비율  유동자산구성비율  \
# 0                 -24.07            -213.61     66.05     46.14     56.18
# 1                 -12.71           -2066.51     55.32     77.32     82.49
# 2                 -13.51               0.00     87.63     60.08     68.34
# 3                  -7.06          -29481.93     84.39     40.28     48.74
# 4                   5.80           24988.83     82.80     36.82     46.47
# ...                  ...                ...       ...       ...       ...
# 15145               2.03               8.85     21.86     15.76     17.21
# 15146               1.96               8.92     20.08      8.78     10.65
# 15147              -0.50              -2.13     13.77     11.27     13.63
# 15148              -2.70             -11.38      9.10     11.14     13.48
# 15149             -22.44             -28.97      7.17     19.98     21.77
#
#        매출채권_대_매입채무비율  유동부채비율  타인자본구성비율  재고자산_대_유동자산비율  재고자산_대_순운전자본비율  \
# 0             602.31   42.33     33.95          17.88           35.59
# 1             323.41   21.50     44.68           6.27            7.33
# 2             282.72   11.23     12.37          12.09           14.12
# 3             285.31   17.79     15.61          17.36           25.09
# 4             254.69   18.91     17.20          20.77           31.32
# ...              ...     ...       ...            ...             ...
# 15145          60.44  151.66     78.14           8.43           -9.10
# 15146          68.73  134.41     79.92          17.60          -11.47
# 15147          65.00  276.77     86.23          17.27           -9.61
# 15148          59.32  427.21     90.90          17.36           -9.21
# 15149          15.30  654.44     92.83           8.22           -7.11
#
#        순운전자본비율      노동장비율     기계장비율    자본집약도       설비투자효율  총자본투자효율  부가가치율  \
# 0        28.23   71726.36  29216.43   202.26  35.85819316    12.72  19.56
# 1        70.60   69458.82  32002.75   426.18            0     0.47   1.66
# 2        58.50   66012.04  33789.62   411.12  77.91470318    12.51  34.29
# 3        33.72  113899.65  48479.94   354.08  37.80253285    12.16  31.04
# 4        30.82  114246.59  53386.77   362.39            0     7.63  15.96
# ...        ...        ...       ...      ...          ...      ...    ...
# 15145   -15.94  593960.16     14.23   973.73  21.49400366    13.11  12.28
# 15146   -16.34  706868.14     12.28  1017.55  15.81260955    10.98  12.66
# 15147   -24.48  599097.86     12.56   921.78  8.349918093     5.43   5.51
# 15148   -25.40  618981.48     14.54  1009.67            0     4.24   4.52
# 15149   -25.18  704760.75     34.13  1271.28            0     3.10  13.08
#
#        종업원1인딩부가가치
# 0        25719.78
# 1         2009.78
# 2        51433.09
# 3        43056.95
# 4        27662.63
# ...           ...
# 15145   127665.82
# 15146   111774.30
# 15147    50024.18
# 15148    42782.54
# 15149    39428.47
#
# [15150 rows x 48 columns]

# %%
df6.to_csv('확인용입니다.csv',encoding='cp949',index=False)

# %%
df6.isna().sum()
# Out:
# 회사명                    0
# 거래소코드                  0
# 회계년도                   0
# 이자보상배율               107
# 총자산증가율               296
# 유형자산증가율              296
# 유동자산증가율              296
# 자기자본증가율              296
# 매출액증가율               294
# 매출액총이익율              204
# 매출액순이익율              204
# 자기자본순이익율             296
# 총자본영업이익율              48
# 매출액영업이익률               0
# 총자본순이익률              296
# 총자본회전율               295
# 재고자산회전율              285
# 매출채권회전율              295
# 유형자산회전율              295
# 매입채무회전율              295
# 자기자본회전율              295
# 타인자본회전율              295
# 유동자산회전율              295
# 순운전자본회전율             204
# 유동비율                 204
# 당좌비율                 204
# 현금비율                 204
# 부채비율                 204
# 차입금의존도                 0
# CASH_FLOW_대_부채비율       0
# CASH_FLOW_대_매출액비율      0
# CASH_FLOW_대_차입금비율     36
# 자기자본구성비율             204
# 당좌자산구성비율             204
# 유동자산구성비율             204
# 매출채권_대_매입채무비율        206
# 유동부채비율               204
# 타인자본구성비율             204
# 재고자산_대_유동자산비율        204
# 재고자산_대_순운전자본비율         0
# 순운전자본비율              204
# 노동장비율                274
# 기계장비율                267
# 자본집약도                  0
# 설비투자효율                 0
# 총자본투자효율                0
# 부가가치율                  0
# 종업원1인딩부가가치            19
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", family="Malgun Gothic") # 시각화 할때 한글이 볼수 있게 하겠다
plt.rc("axes", unicode_minus=False)
plt.figure(figsize=(30,25))

sns.heatmap(df6.isna())

# %%
dd = pd.read_csv('./비율/ㄴㄴ.csv',encoding='cp949')
dd.columns = dd.columns.str.replace('\(', '')
dd.columns = dd.columns.str.replace('\)', '')
dd.columns = dd.columns.str.replace('\*', '')
dd.columns = dd.columns.str.replace('IFRS', '')
dd.columns = dd.columns.str.replace('천원', '')
dd['회계년도'] = pd.to_datetime(dd['회계년도'],format='%b-%d').dt.strftime('20%d-%m')
dd
# Out:
#             회사명  거래소코드     회계년도        매출액수익  매출채권 및 기타유동채권      매출액수익연결  \
# 0      (주)CMG제약  58820  2010-12   11350419.0      5949004.0   11350419.0
# 1      (주)CMG제약  58820  2011-12   17751704.0      9527407.0   17751704.0
# 2      (주)CMG제약  58820  2012-12   16255389.0      9089645.0   16255389.0
# 3      (주)CMG제약  58820  2013-12   20322140.0     11109760.0   20402140.0
# 4      (주)CMG제약  58820  2014-12   22752584.0     13533700.0   22752584.0
# ...         ...    ...      ...          ...            ...          ...
# 18596   흥아해운(주)   3280  2016-12  779990350.0     50314914.0  831746081.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0     58014242.0  836427496.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0     61151622.0  753865569.0
# 18599   흥아해운(주)   3280  2019-12   97376909.0      4342600.0  102166838.0
# 18600   흥아해운(주)   3280  2020-12   85455349.0      2769724.0   88938838.0
#
#        매출채권 및 기타유동채권연결       장기차입금        단기차입금    유동성장기차입금     장기차입금연결  \
# 0            5949004.0   2000000.0    1537477.0     46200.0   2000000.0
# 1            9533102.0         0.0    2134049.0   2000000.0         0.0
# 2            9084190.0         0.0    2132612.0         0.0         0.0
# 3           11089670.0         0.0          0.0         0.0         0.0
# 4           13503998.0         0.0          0.0         0.0         0.0
# ...                ...         ...          ...         ...         ...
# 18596       49357034.0  46829458.0  113942285.0  19895436.0  46829458.0
# 18597       57834010.0  37958229.0  141774467.0  13008496.0  37958229.0
# 18598       60060449.0  25794042.0  146990180.0   4350107.0  25794042.0
# 18599       11480074.0         0.0   44292628.0  34831973.0         0.0
# 18600        2561458.0         0.0   12525452.0  32598668.0         0.0
#
#            단기차입금연결  유동성장기차입금연결           자산         자산연결  영업활동으로 인한 현금흐름간접법  \
# 0              0.0     46200.0   26775627.0   26775627.0         -5983864.0
# 1              0.0   2000000.0   27548539.0   27305198.0         -2488268.0
# 2         100000.0         0.0   56988604.0   57108035.0         -1453276.0
# 3              0.0         0.0   55961620.0   55912563.0         -3891420.0
# 4           5451.0         0.0   58127098.0   58068326.0           730447.0
# ...            ...         ...          ...          ...                ...
# 18596  115674885.0  19895436.0  942586770.0  958532259.0         -4725664.0
# 18597  143410967.0  13008496.0  834107402.0  848958520.0         -5348563.0
# 18598  148617784.0   4350107.0  782787041.0  803698457.0        -30464257.0
# 18599   44292628.0  34831973.0  386550839.0  430962722.0        -16943933.0
# 18600   12525452.0  32598668.0  284767347.0  286775958.0         -1438708.0
#
#        영업활동으로 인한 현금흐름간접법연결      차입금개별      차입금연결
# 0               -5983864.0    3583677    2046200
# 1               -2560438.0    4134049    2000000
# 2               -1572581.0    2132612     100000
# 3               -3939013.0          0          0
# 4                 724893.0          0       5451
# ...                    ...        ...        ...
# 18596           -1389623.0  180667179  182399779
# 18597           -6892102.0  192741192  194377692
# 18598          -33794586.0  177134329  178761933
# 18599          -12048291.0   79124601   79124601
# 18600           -3958237.0   45124120   45124120
#
# [18601 rows x 19 columns]

# %%
dd['매출채권개별'] = dd['매출채권 및 기타유동채권'].shift(1)
dd['매출채권연결'] = dd['매출채권 및 기타유동채권연결'].shift(1)
dd['영업활동으로_인한_현금흐름간접법개별'] = dd['영업활동으로 인한 현금흐름간접법'].shift(1)
dd['영업활동으로_인한_현금흐름간접법연결'] = dd['영업활동으로 인한 현금흐름간접법연결'].shift(1)

# %%
dd
# Out:
#             회사명  거래소코드     회계년도        매출액수익  매출채권 및 기타유동채권      매출액수익연결  \
# 0      (주)CMG제약  58820  2010-12   11350419.0      5949004.0   11350419.0
# 1      (주)CMG제약  58820  2011-12   17751704.0      9527407.0   17751704.0
# 2      (주)CMG제약  58820  2012-12   16255389.0      9089645.0   16255389.0
# 3      (주)CMG제약  58820  2013-12   20322140.0     11109760.0   20402140.0
# 4      (주)CMG제약  58820  2014-12   22752584.0     13533700.0   22752584.0
# ...         ...    ...      ...          ...            ...          ...
# 18596   흥아해운(주)   3280  2016-12  779990350.0     50314914.0  831746081.0
# 18597   흥아해운(주)   3280  2017-12  780863972.0     58014242.0  836427496.0
# 18598   흥아해운(주)   3280  2018-12  705007198.0     61151622.0  753865569.0
# 18599   흥아해운(주)   3280  2019-12   97376909.0      4342600.0  102166838.0
# 18600   흥아해운(주)   3280  2020-12   85455349.0      2769724.0   88938838.0
#
#        매출채권 및 기타유동채권연결       장기차입금        단기차입금    유동성장기차입금     장기차입금연결  \
# 0            5949004.0   2000000.0    1537477.0     46200.0   2000000.0
# 1            9533102.0         0.0    2134049.0   2000000.0         0.0
# 2            9084190.0         0.0    2132612.0         0.0         0.0
# 3           11089670.0         0.0          0.0         0.0         0.0
# 4           13503998.0         0.0          0.0         0.0         0.0
# ...                ...         ...          ...         ...         ...
# 18596       49357034.0  46829458.0  113942285.0  19895436.0  46829458.0
# 18597       57834010.0  37958229.0  141774467.0  13008496.0  37958229.0
# 18598       60060449.0  25794042.0  146990180.0   4350107.0  25794042.0
# 18599       11480074.0         0.0   44292628.0  34831973.0         0.0
# 18600        2561458.0         0.0   12525452.0  32598668.0         0.0
#
#            단기차입금연결  유동성장기차입금연결           자산         자산연결  영업활동으로 인한 현금흐름간접법  \
# 0              0.0     46200.0   26775627.0   26775627.0         -5983864.0
# 1              0.0   2000000.0   27548539.0   27305198.0         -2488268.0
# 2         100000.0         0.0   56988604.0   57108035.0         -1453276.0
# 3              0.0         0.0   55961620.0   55912563.0         -3891420.0
# 4           5451.0         0.0   58127098.0   58068326.0           730447.0
# ...            ...         ...          ...          ...                ...
# 18596  115674885.0  19895436.0  942586770.0  958532259.0         -4725664.0
# 18597  143410967.0  13008496.0  834107402.0  848958520.0         -5348563.0
# 18598  148617784.0   4350107.0  782787041.0  803698457.0        -30464257.0
# 18599   44292628.0  34831973.0  386550839.0  430962722.0        -16943933.0
# 18600   12525452.0  32598668.0  284767347.0  286775958.0         -1438708.0
#
#        영업활동으로 인한 현금흐름간접법연결      차입금개별      차입금연결      매출채권개별      매출채권연결  \
# 0               -5983864.0    3583677    2046200         NaN         NaN
# 1               -2560438.0    4134049    2000000   5949004.0   5949004.0
# 2               -1572581.0    2132612     100000   9527407.0   9533102.0
# 3               -3939013.0          0          0   9089645.0   9084190.0
# 4                 724893.0          0       5451  11109760.0  11089670.0
# ...                    ...        ...        ...         ...         ...
# 18596           -1389623.0  180667179  182399779  45635972.0  46513910.0
# 18597           -6892102.0  192741192  194377692  50314914.0  49357034.0
# 18598          -33794586.0  177134329  178761933  58014242.0  57834010.0
# 18599          -12048291.0   79124601   79124601  61151622.0  60060449.0
# 18600           -3958237.0   45124120   45124120   4342600.0  11480074.0
#
#        영업활동으로_인한_현금흐름간접법개별  영업활동으로_인한_현금흐름간접법연결
# 0                      NaN                  NaN
# 1               -5983864.0           -5983864.0
# 2               -2488268.0           -2560438.0
# 3               -1453276.0           -1572581.0
# 4               -3891420.0           -3939013.0
# ...                    ...                  ...
# 18596           34042933.0           33913401.0
# 18597           -4725664.0           -1389623.0
# 18598           -5348563.0           -6892102.0
# 18599          -30464257.0          -33794586.0
# 18600          -16943933.0          -12048291.0
#
# [18601 rows x 23 columns]

# %%
# activiti(dd,'회사명','매출액수익','매출채권개별','매출채권 및 기타유동채권','매출채권회전율1')
# activiti(dd,'회사명','매출액수익연결','매출채권연결','매출채권 및 기타유동채권연결','매출채권회전율2')

profit_tns(dd,'회사명','차입금개별','자산','차입금의존도1')
profit_tns(dd,'회사명','차입금연결','자산연결','차입금의존도2')

cash(dd,'회사명','영업활동으로 인한 현금흐름간접법','영업활동으로_인한_현금흐름간접법개별','차입금개별','CASH_FLOW_대_차입금비율1')
cash(dd,'회사명','영업활동으로 인한 현금흐름간접법연결','영업활동으로_인한_현금흐름간접법연결','차입금연결','CASH_FLOW_대_차입금비율2')

# profit_tns(dd,'회사명','차입금개별','자산','차입금비율1')
# profit_tns(dd,'회사명','차입금연결','자산연결','차입금비율2')

# %%
dd = dd.fillna(1254789.63)

# %%
for i in range(len(dd)):
    if dd.iloc[i]['차입금의존도2'] != 1254789.63:
        if dd.iloc[i]['차입금의존도1'] != 1254789.63:
            dd.loc[i,'차입금의존도'] = dd.iloc[i]['차입금의존도2']
        else:
            dd.loc[i,'차입금의존도'] = dd.iloc[i]['차입금의존도2']
    elif dd.iloc[i]['차입금의존도2'] == 1254789.63:
        if dd.iloc[i]['차입금의존도1'] != 1254789.63:
            dd.loc[i,'차입금의존도'] = dd.iloc[i]['차입금의존도1']
        else:
            dd.loc[i,'차입금의존도'] = np.nan
    elif dd.iloc[i]['차입금의존도2'] == 0:
        if dd.iloc[i]['차입금의존도1'] != 0:
            dd.loc[i,'차입금의존도'] = dd.iloc[i]['차입금의존도1']
        else:
            dd.loc[i,'차입금의존도'] = 0
    else:
        dd.loc[i,'차입금의존도'] = np.nan

# %%
for i in range(len(dd)):
    if dd.iloc[i]['CASH_FLOW_대_차입금비율2'] != 1254789.63:
        if dd.iloc[i]['CASH_FLOW_대_차입금비율1'] != 1254789.63:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = dd.iloc[i]['CASH_FLOW_대_차입금비율2']
        else:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = dd.iloc[i]['CASH_FLOW_대_차입금비율2']
    elif dd.iloc[i]['CASH_FLOW_대_차입금비율2'] == 1254789.63:
        if dd.iloc[i]['CASH_FLOW_대_차입금비율1'] != 1254789.63:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = dd.iloc[i]['CASH_FLOW_대_차입금비율1']
        else:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = np.nan
    elif dd.iloc[i]['CASH_FLOW_대_차입금비율2'] == 0:
        if dd.iloc[i]['CASH_FLOW_대_차입금비율1'] != 0:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = dd.iloc[i]['CASH_FLOW_대_차입금비율1']
        else:
            dd.loc[i,'CASH_FLOW_대_차입금비율'] = 0
    else:
        dd.loc[i,'CASH_FLOW_대_차입금비율'] = np.nan

# %%
# dd['매출채권회전율'] = dd['매출채권회전율2'].fillna(dd['매출채권회전율1'])
# dd['차입금의존도'] = dd['차입금의존도2'].fillna(dd['차입금의존도1'])
# dd['CASH_FLOW_대_차입금비율'] = dd['CASH_FLOW_대_차입금비율2'].fillna(dd['CASH_FLOW_대_차입금비율1'])
# dd['차입금비율'] = dd['차입금비율2'].fillna(dd['차입금비율1'])
t9 = dd[dd['회계년도'].str.contains('2010')].index
r9 = dd[dd['회계년도'].str.contains('2020')].index
dd = dd.drop(t9)
dd = dd.drop(r9)
dd
# Out:
#             회사명  거래소코드     회계년도        매출액수익  매출채권 및 기타유동채권      매출액수익연결  \
# 1      (주)CMG제약  58820  2011-12   17751704.0      9527407.0   17751704.0
# 2      (주)CMG제약  58820  2012-12   16255389.0      9089645.0   16255389.0
# 3      (주)CMG제약  58820  2013-12   20322140.0     11109760.0   20402140.0
