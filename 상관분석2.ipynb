# %% [markdown]
# ## 상관분석 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %% [markdown]
# ### 데이터불러오기

# %%
df = pd.read_csv('./02_1년연속성부실징후기업.csv',encoding='cp949')
df
# Out:
#            회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0     (주)CMG제약  58820  11-Dec    3.53    1.98    -5.91    17.64    -1.43
# 1     (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2     (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3     (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# 4     (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17    11.04
# ...        ...    ...     ...     ...     ...      ...      ...      ...
# 9448   흥아해운(주)   3280  14-Dec    1.12   13.69    45.19   -13.68    -8.50
# 9449   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18   -12.92
# 9450   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08    56.39
# 9451   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    11.18
# 9452   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33    -5.85
#
#       자기자본증가율   순이익증가율  ...  노동소득분배율  설비투자효율  총자본투자효율   기계투자효율  부가가치율  \
# ...

# %% [markdown]
# ### 상관계수 만들기

# %%
# 피어슨 상관계수로 상관계수를 계산합니다.
df_corr = df.corr(method='pearson')
df_corr
# Out:
#                       거래소코드    이자보상배율    총자산증가율   유형자산증가율   유동자산증가율   재고자산증가율  \
# 거래소코드              1.000000  0.062813 -0.017542 -0.017581 -0.018225  0.002339
# 이자보상배율             0.062813  1.000000 -0.001081 -0.004411  0.002073 -0.001876
# 총자산증가율            -0.017542 -0.001081  1.000000  0.849390  0.485251  0.012833
# 유형자산증가율           -0.017581 -0.004411  0.849390  1.000000  0.281586  0.010756
# 유동자산증가율           -0.018225  0.002073  0.485251  0.281586  1.000000  0.022878
# 재고자산증가율            0.002339 -0.001876  0.012833  0.010756  0.022878  1.000000
# 자기자본증가율           -0.014272 -0.001427  0.799404  0.670586  0.391331  0.009059
# 순이익증가율             0.004114  0.009801 -0.844135 -0.728568 -0.515457 -0.003283
# 매출액총이익율            0.093130  0.046341 -0.014054 -0.014545 -0.008321  0.023959
# 매출액순이익율           -0.026477  0.001610  0.000966  0.000802  0.000756  0.000225
# 자기자본순이익율          -0.027046  0.025144  0.006535  0.004084  0.008326  0.004788
# ...

# %%
df_corr['순이익증가율'].sort_values()
# Out:
# 자기자본증가율             -0.879512
# 총자산증가율              -0.844135
# 유형자산증가율             -0.728568
# 유동자산증가율             -0.515457
# 타인자본구성비율            -0.024817
# 차입금의존도              -0.024143
# 노동장비율               -0.011586
# 재고자산_대_유동자산비율       -0.009129
# 기계장비율               -0.008058
# 차입금비율               -0.006327
# 부채비율                -0.004409
# 자본집약도               -0.004088
# 재고자산증가율             -0.003283
# 유동부채비율              -0.002211
# 경상개발비(천원)           -0.001188
# CASH_FLOW_대_매출액비율   -0.000103
# 매출액정상영업이익율          -0.000053
# 부가가치율                0.000052
# 재고자산_대_순운전자본비율       0.000116
# R & D 투자효율           0.000143
# 매출액순이익율              0.000175
# 매출채권회전율              0.000484
# 유동자산회전율              0.000538
# 매입채무회전율              0.000695
# CASH_FLOW_대_차입금비율    0.000745
# 재고자산회전율              0.000997
# 매출채권_대_매입채무비율        0.001345
# 설비투자효율               0.001659
# 단기차입금_대_총차입금비율       0.002137
# 무형자산처리무형자산개발비(천원)    0.002344
# 유형자산회전율              0.002378
# ...

# %% [markdown]
# - 0에 가까운 값이면 상관관계가 없다고 볼 수 있다.

# %%
# 상관계수가 0.3이상인 feature만 가져옵니다.
df_corr.loc[df_corr['이자보상배율'] >0.3,'이자보상배율']
# Out:
# 이자보상배율    1.0
# Name: 이자보상배율, dtype: float64

# %%
# 그냥 상관없이 0.3이상인 feature만 가져옵니다.
df_corr.loc[df_corr['노동장비율'] >0.1,'노동장비율']
# Out:
# 노동장비율    1.000000
# 기계장비율    0.815773
# 자본집약도    0.890315
# Name: 노동장비율, dtype: float64

# %%
df_corr['노동장비율'].sort_values()
# Out:
# 유동자산구성비율            -0.097007
# 당좌자산구성비율            -0.073812
# 순운전자본비율             -0.062949
# 자기자본구성비율            -0.052498
# 자기자본구성비율.1          -0.052498
# 타인자본회전율             -0.040769
# 거래소코드               -0.030074
# 재고자산_대_유동자산비율       -0.025753
# 매출액총이익율             -0.021576
# 유동비율                -0.020652
# 당좌비율                -0.017726
# 이자보상배율              -0.015107
# 현금비율                -0.012562
# 순이익증가율              -0.011586
# 유형자산회전율             -0.010886
# 총자본투자효율             -0.010703
# 종업원수증가율             -0.010635
# 자기자본회전율             -0.006147
# 총자본회전율              -0.006147
# 단기차입금_대_총차입금비율      -0.004691
# 매출채권_대_매입채무비율       -0.003204
# 경상개발비(천원)           -0.003155
# 유동자산회전율             -0.001860
# 매출채권회전율             -0.001733
# 매입채무회전율             -0.001688
# CASH_FLOW_대_차입금비율   -0.001605
# R & D 투자효율          -0.001335
# 설비투자효율              -0.000851
# 재고자산증가율             -0.000733
# 기계투자효율              -0.000035
# 노동소득분배율              0.000694
# ...

# %%
# 상관계수를 내림차순으로 정렬합니다.
df_corr['순이익증가율'].sort_values(ascending=False).head(7)
# Out:
# 순이익증가율        1.000000
# 총자본순이익율       0.046506
# 총자본정상영업이익율    0.026552
# 자기자본구성비율      0.025940
# 자기자본구성비율.1    0.025940
# 자기자본순이익율      0.024911
# 유동자산구성비율      0.023031
# Name: 순이익증가율, dtype: float64

# %% [markdown]
# ### 히트맵
# - 그래프와 달리 시각적으로 볼때
# - 상관 관계가 클수록 색이 진해집니다

# %%
# annot 숫자를 나타낼수 있고, fmt는 소수점 갯수를 지정, cmap은 색상을 지정
plt.figure(figsize=(40,20))
sns.heatmap(df_corr, annot=True, fmt=".2f", cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 히트맵 대각선 아래만 표시하는 방법

# %%
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
plt.figure(figsize=(40,20))
sns.heatmap(df_corr, annot=True, fmt=".2f", cmap="Blues", mask=mask)
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_17380\2667953402.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# <AxesSubplot:>
