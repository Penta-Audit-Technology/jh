# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
df = pd.read_csv('다시한번재무비율.csv',encoding='cp949')
df = df.fillna(1254789.63)
df = df.round(2)
df
# Out:
#             회사명  거래소코드     회계년도  총자본증가율(IFRS)  총자본증가율(IFRS연결)  유형자산증가율(IFRS)  \
# 0      (주)CMG제약  58820  2011/12          2.89            1.98          -6.44
# 1      (주)CMG제약  58820  2012/12        106.87          109.15          -4.02
# 2      (주)CMG제약  58820  2013/12         -1.80           -2.09          16.63
# 3      (주)CMG제약  58820  2014/12          3.87            3.86          74.30
# 4      (주)CMG제약  58820  2015/12         -2.64           -2.64          -5.37
# ...         ...    ...      ...           ...             ...            ...
# 15145   흥아해운(주)   3280  2015/12         22.84           21.93          49.93
# 15146   흥아해운(주)   3280  2016/12         22.22           21.08          39.20
# 15147   흥아해운(주)   3280  2017/12        -11.51          -11.43         -16.52
# 15148   흥아해운(주)   3280  2018/12         -6.15           -5.33         -12.08
# 15149   흥아해운(주)   3280  2019/12        -50.62          -46.38         -51.49
#
# ...

# %% [markdown]
# ### 총자산증가율

# %%
for i in range(len(df)):
    if df.loc[i,'총자본증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'총자본증가율(IFRS)'] != 1254789.63:
            df.loc[i,'총자산증가율'] = df.loc[i,'총자본증가율(IFRS연결)']
        else:
            df.loc[i,'총자산증가율'] = df.loc[i,'총자본증가율(IFRS연결)']
            
    elif df.loc[i,'총자본증가율(IFRS연결)'] == 0:
        if df.loc[i,'총자본증가율(IFRS)'] == 0:
            df.loc[i,'총자산증가율'] = 0
        else:
            df.loc[i,'총자산증가율'] = 0
            
    elif df.loc[i,'총자본증가율(IFRS)'] == 0:
        if df.loc[i,'총자본증가율(IFRS연결)'] == 0:
            df.loc[i,'총자산증가율'] = 0
        else:
            df.loc[i,'총자산증가율'] = 0
            
    else:
        if df.loc[i,'총자본증가율(IFRS)'] != 1254789.63:
            df.loc[i,'총자산증가율'] = df.loc[i,'총자본증가율(IFRS)']
        else:
            df.loc[i,'총자산증가율'] = np.nan

# %% [markdown]
# ### 유형자산증가율

# %%
for i in range(len(df)):
    if df.loc[i,'유형자산증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'유형자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'유형자산증가율'] = df.loc[i,'유형자산증가율(IFRS연결)']
        else:
            df.loc[i,'유형자산증가율'] = df.loc[i,'유형자산증가율(IFRS연결)']
            
    elif df.loc[i,'유형자산증가율(IFRS연결)'] == 0:
        if df.loc[i,'유형자산증가율(IFRS)'] == 0:
            df.loc[i,'유형자산증가율'] = 0
        else:
            df.loc[i,'유형자산증가율'] = 0
            
    elif df.loc[i,'유형자산증가율(IFRS)'] == 0:
        if df.loc[i,'유형자산증가율(IFRS연결)'] == 0:
            df.loc[i,'유형자산증가율'] = 0
        else:
            df.loc[i,'유형자산증가율'] = 0
            
    else:
        if df.loc[i,'유형자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'유형자산증가율'] = df.loc[i,'유형자산증가율(IFRS)']
        else:
            df.loc[i,'유형자산증가율'] = np.nan

# %% [markdown]
# ### 유동자산증가율

# %%
for i in range(len(df)):
    if df.loc[i,'유동자산증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'유동자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'유동자산증가율'] = df.loc[i,'유동자산증가율(IFRS연결)']
        else:
            df.loc[i,'유동자산증가율'] = df.loc[i,'유동자산증가율(IFRS연결)']
            
    elif df.loc[i,'유동자산증가율(IFRS연결)'] == 0:
        if df.loc[i,'유동자산증가율(IFRS)'] == 0:
            df.loc[i,'유동자산증가율'] = 0
        else:
            df.loc[i,'유동자산증가율'] = 0
            
    elif df.loc[i,'유동자산증가율(IFRS)'] == 0:
        if df.loc[i,'유동자산증가율(IFRS연결)'] == 0:
            df.loc[i,'유동자산증가율'] = 0
        else:
            df.loc[i,'유동자산증가율'] = 0
            
    else:
        if df.loc[i,'유동자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'유동자산증가율'] = df.loc[i,'유동자산증가율(IFRS)']
        else:
            df.loc[i,'유동자산증가율'] = np.nan

# %% [markdown]
# ### 재고자산증가율

# %%
for i in range(len(df)):
    if df.loc[i,'재고자산증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'재고자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'재고자산증가율'] = df.loc[i,'재고자산증가율(IFRS연결)']
        else:
            df.loc[i,'재고자산증가율'] = df.loc[i,'재고자산증가율(IFRS연결)']
            
    elif df.loc[i,'재고자산증가율(IFRS연결)'] == 0:
        if df.loc[i,'재고자산증가율(IFRS)'] == 0:
            df.loc[i,'재고자산증가율'] = 0
        else:
            df.loc[i,'재고자산증가율'] = 0
            
    elif df.loc[i,'재고자산증가율(IFRS)'] == 0:
        if df.loc[i,'재고자산증가율(IFRS연결)'] == 0:
            df.loc[i,'재고자산증가율'] = 0
        else:
            df.loc[i,'재고자산증가율'] = 0
            
    else:
        if df.loc[i,'재고자산증가율(IFRS)'] != 1254789.63:
            df.loc[i,'재고자산증가율'] = df.loc[i,'재고자산증가율(IFRS)']
        else:
            df.loc[i,'재고자산증가율'] = np.nan

# %% [markdown]
# ### 자기자본증가율

# %%
for i in range(len(df)):
    if df.loc[i,'자기자본증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'자기자본증가율(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본증가율'] = df.loc[i,'자기자본증가율(IFRS연결)']
        else:
            df.loc[i,'자기자본증가율'] = df.loc[i,'자기자본증가율(IFRS연결)']
            
    elif df.loc[i,'자기자본증가율(IFRS연결)'] == 0:
        if df.loc[i,'자기자본증가율(IFRS)'] == 0:
            df.loc[i,'자기자본증가율'] = 0
        else:
            df.loc[i,'자기자본증가율'] = 0
            
    elif df.loc[i,'자기자본증가율(IFRS)'] == 0:
        if df.loc[i,'자기자본증가율(IFRS연결)'] == 0:
            df.loc[i,'자기자본증가율'] = 0
        else:
            df.loc[i,'자기자본증가율'] = 0
            
    else:
        if df.loc[i,'자기자본증가율(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본증가율'] = df.loc[i,'자기자본증가율(IFRS)']
        else:
            df.loc[i,'자기자본증가율'] = np.nan

# %% [markdown]
# ### 순이익증가율

# %%
for i in range(len(df)):
    if df.loc[i,'순이익증가율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'순이익증가율(IFRS)'] != 1254789.63:
            df.loc[i,'순이익증가율'] = df.loc[i,'순이익증가율(IFRS연결)']
        else:
            df.loc[i,'순이익증가율'] = df.loc[i,'순이익증가율(IFRS연결)']
            
    elif df.loc[i,'순이익증가율(IFRS연결)'] == 0:
        if df.loc[i,'순이익증가율(IFRS)'] == 0:
            df.loc[i,'순이익증가율'] = 0
        else:
            df.loc[i,'순이익증가율'] = 0
            
    elif df.loc[i,'순이익증가율(IFRS)'] == 0:
        if df.loc[i,'순이익증가율(IFRS연결)'] == 0:
            df.loc[i,'순이익증가율'] = 0
        else:
            df.loc[i,'순이익증가율'] = 0
            
    else:
        if df.loc[i,'순이익증가율(IFRS)'] != 1254789.63:
            df.loc[i,'순이익증가율'] = df.loc[i,'순이익증가율(IFRS)']
        else:
            df.loc[i,'순이익증가율'] = np.nan

# %% [markdown]
# ### 매출액총이익률

# %%
for i in range(len(df)):
    if df.loc[i,'매출액총이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'매출액총이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액총이익율'] = df.loc[i,'매출액총이익률(IFRS연결)']
        else:
            df.loc[i,'매출액총이익율'] = df.loc[i,'매출액총이익률(IFRS연결)']
            
    elif df.loc[i,'매출액총이익률(IFRS연결)'] == 0:
        if df.loc[i,'매출액총이익률(IFRS)'] == 0:
            df.loc[i,'매출액총이익율'] = 0
        else:
            df.loc[i,'매출액총이익율'] = 0
            
    elif df.loc[i,'매출액총이익률(IFRS)'] == 0:
        if df.loc[i,'매출액총이익률(IFRS연결)'] == 0:
            df.loc[i,'매출액총이익율'] = 0
        else:
            df.loc[i,'매출액총이익율'] = 0
            
    else:
        if df.loc[i,'매출액총이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액총이익율'] = df.loc[i,'매출액총이익률(IFRS)']
        else:
            df.loc[i,'매출액총이익율'] = np.nan

# %% [markdown]
# ### 매출액순이익율

# %%
for i in range(len(df)):
    if df.loc[i,'매출액순이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'매출액순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액순이익율'] = df.loc[i,'매출액순이익률(IFRS연결)']
        else:
            df.loc[i,'매출액순이익율'] = df.loc[i,'매출액순이익률(IFRS연결)']
            
    elif df.loc[i,'매출액순이익률(IFRS연결)'] == 0:
        if df.loc[i,'매출액순이익률(IFRS)'] == 0:
            df.loc[i,'매출액순이익율'] = 0
        else:
            df.loc[i,'매출액순이익율'] = 0
            
    elif df.loc[i,'매출액순이익률(IFRS)'] == 0:
        if df.loc[i,'매출액순이익률(IFRS연결)'] == 0:
            df.loc[i,'매출액순이익율'] = 0
        else:
            df.loc[i,'매출액순이익율'] = 0
            
    else:
        if df.loc[i,'매출액순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액순이익율'] = df.loc[i,'매출액순이익률(IFRS)']
        else:
            df.loc[i,'매출액순이익율'] = np.nan

# %% [markdown]
# ### 자기자본순이익율

# %%
for i in range(len(df)):
    if df.loc[i,'자기자본순이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'자기자본순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본순이익율'] = df.loc[i,'자기자본순이익률(IFRS연결)']
        else:
            df.loc[i,'자기자본순이익율'] = df.loc[i,'자기자본순이익률(IFRS연결)']
            
    elif df.loc[i,'자기자본순이익률(IFRS연결)'] == 0:
        if df.loc[i,'자기자본순이익률(IFRS)'] == 0:
            df.loc[i,'자기자본순이익율'] = 0
        else:
            df.loc[i,'자기자본순이익율'] = 0
            
    elif df.loc[i,'자기자본순이익률(IFRS)'] == 0:
        if df.loc[i,'자기자본순이익률(IFRS연결)'] == 0:
            df.loc[i,'자기자본순이익율'] = 0
        else:
            df.loc[i,'자기자본순이익율'] = 0
            
    else:
        if df.loc[i,'자기자본순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본순이익율'] = df.loc[i,'자기자본순이익률(IFRS)']
        else:
            df.loc[i,'자기자본순이익율'] = np.nan

# %% [markdown]
# ### 총자본정상영업이익율

# %%
for i in range(len(df)):
    if df.loc[i,'총자본정상영업이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'총자본정상영업이익률(IFRS)'] != 1254789.63:
            df.loc[i,'총자본정상영업이익율'] = df.loc[i,'총자본정상영업이익률(IFRS연결)']
        else:
            df.loc[i,'총자본정상영업이익율'] = df.loc[i,'총자본정상영업이익률(IFRS연결)']
            
    elif df.loc[i,'총자본정상영업이익률(IFRS연결)'] == 0:
        if df.loc[i,'총자본정상영업이익률(IFRS)'] == 0:
            df.loc[i,'총자본정상영업이익율'] = 0
        else:
            df.loc[i,'총자본정상영업이익율'] = 0
            
    elif df.loc[i,'총자본정상영업이익률(IFRS)'] == 0:
        if df.loc[i,'총자본정상영업이익률(IFRS연결)'] == 0:
            df.loc[i,'총자본정상영업이익율'] = 0
        else:
            df.loc[i,'총자본정상영업이익율'] = 0
            
    else:
        if df.loc[i,'총자본정상영업이익률(IFRS)'] != 1254789.63:
            df.loc[i,'총자본정상영업이익율'] = df.loc[i,'총자본정상영업이익률(IFRS)']
        else:
            df.loc[i,'총자본정상영업이익율'] = np.nan

# %% [markdown]
# ### 매출액정상영업이익율

# %%
for i in range(len(df)):
    if df.loc[i,'매출액정상영업이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'매출액정상영업이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액정상영업이익율'] = df.loc[i,'매출액정상영업이익률(IFRS연결)']
        else:
            df.loc[i,'매출액정상영업이익율'] = df.loc[i,'매출액정상영업이익률(IFRS연결)']
            
    elif df.loc[i,'매출액정상영업이익률(IFRS연결)'] == 0:
        if df.loc[i,'매출액정상영업이익률(IFRS)'] == 0:
            df.loc[i,'매출액정상영업이익율'] = 0
        else:
            df.loc[i,'매출액정상영업이익율'] = 0
            
    elif df.loc[i,'매출액정상영업이익률(IFRS)'] == 0:
        if df.loc[i,'매출액정상영업이익률(IFRS연결)'] == 0:
            df.loc[i,'매출액정상영업이익율'] = 0
        else:
            df.loc[i,'매출액정상영업이익율'] = 0
            
    else:
        if df.loc[i,'매출액정상영업이익률(IFRS)'] != 1254789.63:
            df.loc[i,'매출액정상영업이익율'] = df.loc[i,'매출액정상영업이익률(IFRS)']
        else:
            df.loc[i,'매출액정상영업이익율'] = np.nan

# %% [markdown]
# ### 총자본순이익율

# %%
for i in range(len(df)):
    if df.loc[i,'총자본순이익률(IFRS연결)'] != 1254789.63:
        if df.loc[i,'총자본순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'총자본순이익율'] = df.loc[i,'총자본순이익률(IFRS연결)']
        else:
            df.loc[i,'총자본순이익율'] = df.loc[i,'총자본순이익률(IFRS연결)']
            
    elif df.loc[i,'총자본순이익률(IFRS연결)'] == 0:
        if df.loc[i,'총자본순이익률(IFRS)'] == 0:
            df.loc[i,'총자본순이익율'] = 0
        else:
            df.loc[i,'총자본순이익율'] = 0
            
    elif df.loc[i,'총자본순이익률(IFRS)'] == 0:
        if df.loc[i,'총자본순이익률(IFRS연결)'] == 0:
            df.loc[i,'총자본순이익율'] = 0
        else:
            df.loc[i,'총자본순이익율'] = 0
            
    else:
        if df.loc[i,'총자본순이익률(IFRS)'] != 1254789.63:
            df.loc[i,'총자본순이익율'] = df.loc[i,'총자본순이익률(IFRS)']
        else:
            df.loc[i,'총자본순이익율'] = np.nan

# %% [markdown]
# ### 유동비율

# %%
for i in range(len(df)):
    if df.loc[i,'유동비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'유동비율(IFRS)'] != 1254789.63:
            df.loc[i,'유동비율'] = df.loc[i,'유동비율(IFRS연결)']
        else:
            df.loc[i,'유동비율'] = df.loc[i,'유동비율(IFRS연결)']
            
    elif df.loc[i,'유동비율(IFRS연결)'] == 0:
        if df.loc[i,'유동비율(IFRS)'] == 0:
            df.loc[i,'유동비율'] = 0
        else:
            df.loc[i,'유동비율'] = 0
            
    elif df.loc[i,'유동비율(IFRS)'] == 0:
        if df.loc[i,'유동비율(IFRS연결)'] == 0:
            df.loc[i,'유동비율'] = 0
        else:
            df.loc[i,'유동비율'] = 0
            
    else:
        if df.loc[i,'유동비율(IFRS)'] != 1254789.63:
            df.loc[i,'유동비율'] = df.loc[i,'유동비율(IFRS)']
        else:
            df.loc[i,'유동비율'] = np.nan

# %% [markdown]
# ### 당좌비율

# %%
for i in range(len(df)):
    if df.loc[i,'당좌비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'당좌비율(IFRS)'] != 1254789.63:
            df.loc[i,'당좌비율'] = df.loc[i,'당좌비율(IFRS연결)']
        else:
            df.loc[i,'당좌비율'] = df.loc[i,'당좌비율(IFRS연결)']
            
    elif df.loc[i,'당좌비율(IFRS연결)'] == 0:
        if df.loc[i,'당좌비율(IFRS)'] == 0:
            df.loc[i,'당좌비율'] = 0
        else:
            df.loc[i,'당좌비율'] = 0
            
    elif df.loc[i,'당좌비율(IFRS)'] == 0:
        if df.loc[i,'당좌비율(IFRS연결)'] == 0:
            df.loc[i,'당좌비율'] = 0
        else:
            df.loc[i,'당좌비율'] = 0
            
    else:
        if df.loc[i,'당좌비율(IFRS)'] != 1254789.63:
            df.loc[i,'당좌비율'] = df.loc[i,'당좌비율(IFRS)']
        else:
            df.loc[i,'당좌비율'] = np.nan

# %% [markdown]
# ### 현금비율

# %%
for i in range(len(df)):
    if df.loc[i,'현금비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'현금비율(IFRS)'] != 1254789.63:
            df.loc[i,'현금비율'] = df.loc[i,'현금비율(IFRS연결)']
        else:
            df.loc[i,'현금비율'] = df.loc[i,'현금비율(IFRS연결)']
            
    elif df.loc[i,'현금비율(IFRS연결)'] == 0:
        if df.loc[i,'현금비율(IFRS)'] == 0:
            df.loc[i,'현금비율'] = 0
        else:
            df.loc[i,'현금비율'] = 0
            
    elif df.loc[i,'현금비율(IFRS)'] == 0:
        if df.loc[i,'현금비율(IFRS연결)'] == 0:
            df.loc[i,'현금비율'] = 0
        else:
            df.loc[i,'현금비율'] = 0
            
    else:
        if df.loc[i,'현금비율(IFRS)'] != 1254789.63:
            df.loc[i,'현금비율'] = df.loc[i,'현금비율(IFRS)']
        else:
            df.loc[i,'현금비율'] = np.nan

# %% [markdown]
# ### 부채비율

# %%
for i in range(len(df)):
    if df.loc[i,'부채비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'부채비율(IFRS)'] != 1254789.63:
            df.loc[i,'부채비율'] = df.loc[i,'부채비율(IFRS연결)']
        else:
            df.loc[i,'부채비율'] = df.loc[i,'부채비율(IFRS연결)']
            
    elif df.loc[i,'부채비율(IFRS연결)'] == 0:
        if df.loc[i,'부채비율(IFRS)'] == 0:
            df.loc[i,'부채비율'] = 0
        else:
            df.loc[i,'부채비율'] = 0
            
    elif df.loc[i,'부채비율(IFRS)'] == 0:
        if df.loc[i,'부채비율(IFRS연결)'] == 0:
            df.loc[i,'부채비율'] = 0
        else:
            df.loc[i,'부채비율'] = 0
            
    else:
        if df.loc[i,'부채비율(IFRS)'] != 1254789.63:
            df.loc[i,'부채비율'] = df.loc[i,'부채비율(IFRS)']
        else:
            df.loc[i,'부채비율'] = np.nan

# %% [markdown]
# ### 차입금의존도

# %%
for i in range(len(df)):
    if df.loc[i,'차입금의존도(IFRS연결)'] != 1254789.63:
        if df.loc[i,'차입금의존도(IFRS)'] != 1254789.63:
            df.loc[i,'차입금의존도'] = df.loc[i,'차입금의존도(IFRS연결)']
        else:
            df.loc[i,'차입금의존도'] = df.loc[i,'차입금의존도(IFRS연결)']
            
    elif df.loc[i,'차입금의존도(IFRS연결)'] == 0:
        if df.loc[i,'차입금의존도(IFRS)'] == 0:
            df.loc[i,'차입금의존도'] = 0
        else:
            df.loc[i,'차입금의존도'] = 0
            
    elif df.loc[i,'차입금의존도(IFRS)'] == 0:
        if df.loc[i,'차입금의존도(IFRS연결)'] == 0:
            df.loc[i,'차입금의존도'] = 0
        else:
            df.loc[i,'차입금의존도'] = 0
            
    else:
        if df.loc[i,'차입금의존도(IFRS)'] != 1254789.63:
            df.loc[i,'차입금의존도'] = df.loc[i,'차입금의존도(IFRS)']
        else:
            df.loc[i,'차입금의존도'] = np.nan

# %% [markdown]
# ### CASH_FLOW_대_부채비율

# %%
for i in range(len(df)):
    if df.loc[i,'CASH FLOW 대 부채비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'CASH FLOW 대 부채비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_부채비율'] = df.loc[i,'CASH FLOW 대 부채비율(IFRS연결)']
        else:
            df.loc[i,'CASH_FLOW_대_부채비율'] = df.loc[i,'CASH FLOW 대 부채비율(IFRS연결)']
            
    elif df.loc[i,'CASH FLOW 대 부채비율(IFRS연결)'] == 0:
        if df.loc[i,'CASH FLOW 대 부채비율(IFRS)'] == 0:
            df.loc[i,'CASH_FLOW_대_부채비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_부채비율'] = 0
            
    elif df.loc[i,'CASH FLOW 대 부채비율(IFRS)'] == 0:
        if df.loc[i,'CASH FLOW 대 부채비율(IFRS연결)'] == 0:
            df.loc[i,'CASH_FLOW_대_부채비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_부채비율'] = 0
            
    else:
        if df.loc[i,'CASH FLOW 대 부채비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_부채비율'] = df.loc[i,'CASH FLOW 대 부채비율(IFRS)']
        else:
            df.loc[i,'CASH_FLOW_대_부채비율'] = np.nan

# %% [markdown]
# ### CASH_FLOW_대_매출액비율

# %%
for i in range(len(df)):
    if df.loc[i,'CASH FLOW 대 매출액비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'CASH FLOW 대 매출액비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = df.loc[i,'CASH FLOW 대 매출액비율(IFRS연결)']
        else:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = df.loc[i,'CASH FLOW 대 매출액비율(IFRS연결)']
            
    elif df.loc[i,'CASH FLOW 대 매출액비율(IFRS연결)'] == 0:
        if df.loc[i,'CASH FLOW 대 매출액비율(IFRS)'] == 0:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = 0
            
    elif df.loc[i,'CASH FLOW 대 매출액비율(IFRS)'] == 0:
        if df.loc[i,'CASH FLOW 대 매출액비율(IFRS연결)'] == 0:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = 0
            
    else:
        if df.loc[i,'CASH FLOW 대 매출액비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = df.loc[i,'CASH FLOW 대 매출액비율(IFRS)']
        else:
            df.loc[i,'CASH_FLOW_대_매출액비율'] = np.nan

# %% [markdown]
# ### CASH_FLOW_대_차입금비율

# %%
for i in range(len(df)):
    if df.loc[i,'CASH FLOW 대 차입금비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'CASH FLOW 대 차입금비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = df.loc[i,'CASH FLOW 대 차입금비율(IFRS연결)']
        else:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = df.loc[i,'CASH FLOW 대 차입금비율(IFRS연결)']
            
    elif df.loc[i,'CASH FLOW 대 차입금비율(IFRS연결)'] == 0:
        if df.loc[i,'CASH FLOW 대 차입금비율(IFRS)'] == 0:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = 0
            
    elif df.loc[i,'CASH FLOW 대 차입금비율(IFRS)'] == 0:
        if df.loc[i,'CASH FLOW 대 차입금비율(IFRS연결)'] == 0:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = 0
        else:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = 0
            
    else:
        if df.loc[i,'CASH FLOW 대 차입금비율(IFRS)'] != 1254789.63:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = df.loc[i,'CASH FLOW 대 차입금비율(IFRS)']
        else:
            df.loc[i,'CASH_FLOW_대_차입금비율'] = np.nan

# %% [markdown]
# ### 자기자본구성비율

# %%
for i in range(len(df)):
    if df.loc[i,'자기자본구성비율(IFRS연결)'] != 1254789.63:
        if df.loc[i,'자기자본구성비율(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본구성비율'] = df.loc[i,'자기자본구성비율(IFRS연결)']
        else:
            df.loc[i,'자기자본구성비율'] = df.loc[i,'자기자본구성비율(IFRS연결)']
            
    elif df.loc[i,'자기자본구성비율(IFRS연결)'] == 0:
        if df.loc[i,'자기자본구성비율(IFRS)'] == 0:
            df.loc[i,'자기자본구성비율'] = 0
        else:
            df.loc[i,'자기자본구성비율'] = 0
            
    elif df.loc[i,'자기자본구성비율(IFRS)'] == 0:
        if df.loc[i,'자기자본구성비율(IFRS연결)'] == 0:
            df.loc[i,'자기자본구성비율'] = 0
        else:
            df.loc[i,'자기자본구성비율'] = 0
            
    else:
        if df.loc[i,'자기자본구성비율(IFRS)'] != 1254789.63:
            df.loc[i,'자기자본구성비율'] = df.loc[i,'자기자본구성비율(IFRS)']
        else:
            df.loc[i,'자기자본구성비율'] = np.nan

# %%
df
# Out:
#             회사명  거래소코드    회계년도  총자산증가율(개별)  총자산증가율(연결)  유형자산증가율(연결)  \
# 0      (주)CMG제약  58820  11-Dec        2.89        1.98        -5.91
# 1      (주)CMG제약  58820  12-Dec      106.87      109.15        -4.12
# 2      (주)CMG제약  58820  13-Dec       -1.80       -2.09        16.09
# 3      (주)CMG제약  58820  14-Dec        3.87        3.86        74.30
# 4      (주)CMG제약  58820  15-Dec       -2.64       -2.64        -5.37
# ...         ...    ...     ...         ...         ...          ...
# 15145   흥아해운(주)   3280  15-Dec       22.84       21.93        49.36
# 15146   흥아해운(주)   3280  16-Dec       22.22       21.08        38.84
# 15147   흥아해운(주)   3280  17-Dec      -11.51      -11.43       -16.50
# 15148   흥아해운(주)   3280  18-Dec       -6.15       -5.33       -12.07
# 15149   흥아해운(주)   3280  19-Dec      -50.62      -46.38       -51.51
#
#        유형자산증가율(개별)  유동자산증가율(연결)  유동자산증가율(개별)  재고자산증가율(개별)  재고자산증가율(연결)  \
# 0            -6.44        17.64        17.05        -1.43        -1.43
# ...

# %%
# df.to_csv('test2.csv',encoding='cp949',index=False)

# %%
# df[df['총자산증가율']==0]

# %%
t1 = pd.read_csv('KOSPI200.csv',encoding='cp949')
t1 = t1.replace(np.inf,np.nan)
t1 = t1.round(2)
t1 = t1.fillna(1254789.63)
t1
# Out:
#        총자본회전율(개별)  총자본회전율(연결)  재고자산회전율(개별)  재고자산회전율(연결)  매출채권회전율(개별)  \
# 0            0.97        0.97         3.74         3.74         1.90
# 1            0.65        0.66         4.09         4.09         1.45
# 2            0.50        0.51         3.30         3.30         1.60
# 3            0.46        0.46         3.00         3.00         1.48
# 4            0.56        0.56         3.32         3.32         1.66
# ...           ...         ...          ...          ...          ...
# 15145        5.08        4.96        61.88        64.23        25.85
# 15146        4.51        4.55        51.40        53.94        25.79
# 15147        5.36        5.41        41.01        43.17        22.93
# 15148        8.58        7.93        37.37        39.24        18.22
# 15149        2.62        1.96         7.50         7.28         4.55
#
#        매출채권회전율(연결)  유형자산회전율(개별)  유형자산회전율(연결))  매입채무회전율(개별)  매입채무회전율(연결)  \
# ...

# %% [markdown]
# ### 총자본회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'총자본회전율(연결)'] != 1254789.63:
        if t1.loc[i,'총자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'총자본회전율'] = t1.loc[i,'총자본회전율(연결)']
        else:
            t1.loc[i,'총자본회전율'] = t1.loc[i,'총자본회전율(연결)']
            
    elif t1.loc[i,'총자본회전율(연결)'] == 0:
        if t1.loc[i,'총자본회전율(개별)'] == 0:
            t1.loc[i,'총자본회전율'] = 0
        else:
            t1.loc[i,'총자본회전율'] = 0
            
    elif t1.loc[i,'총자본회전율(개별)'] == 0:
        if t1.loc[i,'총자본회전율(연결)'] == 0:
            t1.loc[i,'총자본회전율'] = 0
        else:
            t1.loc[i,'총자본회전율'] = 0
            
    else:
        if t1.loc[i,'총자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'총자본회전율'] = t1.loc[i,'총자본회전율(개별)']
        else:
            t1.loc[i,'총자본회전율'] = np.nan

# %% [markdown]
# ### 재고자산회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'재고자산회전율(연결)'] != 1254789.63:
        if t1.loc[i,'재고자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'재고자산회전율'] = t1.loc[i,'재고자산회전율(연결)']
        else:
            t1.loc[i,'재고자산회전율'] = t1.loc[i,'재고자산회전율(연결)']
            
    elif t1.loc[i,'재고자산회전율(연결)'] == 0:
        if t1.loc[i,'재고자산회전율(개별)'] == 0:
            t1.loc[i,'재고자산회전율'] = 0
        else:
            t1.loc[i,'재고자산회전율'] = 0
            
    elif t1.loc[i,'재고자산회전율(개별)'] == 0:
        if t1.loc[i,'재고자산회전율(연결)'] == 0:
            t1.loc[i,'재고자산회전율'] = 0
        else:
            t1.loc[i,'재고자산회전율'] = 0
            
    else:
        if t1.loc[i,'재고자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'재고자산회전율'] = t1.loc[i,'재고자산회전율(개별)']
        else:
            t1.loc[i,'재고자산회전율'] = np.nan

# %% [markdown]
# ### 매출채권회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'매출채권회전율(연결)'] != 1254789.63:
        if t1.loc[i,'매출채권회전율(개별)'] != 1254789.63:
            t1.loc[i,'매출채권회전율'] = t1.loc[i,'매출채권회전율(연결)']
        else:
            t1.loc[i,'매출채권회전율'] = t1.loc[i,'매출채권회전율(연결)']
            
    elif t1.loc[i,'매출채권회전율(연결)'] == 0:
        if t1.loc[i,'매출채권회전율(개별)'] == 0:
            t1.loc[i,'매출채권회전율'] = 0
        else:
            t1.loc[i,'매출채권회전율'] = 0
            
    elif t1.loc[i,'매출채권회전율(개별)'] == 0:
        if t1.loc[i,'매출채권회전율(연결)'] == 0:
            t1.loc[i,'매출채권회전율'] = 0
        else:
            t1.loc[i,'매출채권회전율'] = 0
            
    else:
        if t1.loc[i,'매출채권회전율(개별)'] != 1254789.63:
            t1.loc[i,'매출채권회전율'] = t1.loc[i,'매출채권회전율(개별)']
        else:
            t1.loc[i,'매출채권회전율'] = np.nan

# %% [markdown]
# ### 유형자산회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'유형자산회전율(연결))'] != 1254789.63:
        if t1.loc[i,'유형자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'유형자산회전율'] = t1.loc[i,'유형자산회전율(연결))']
        else:
            t1.loc[i,'유형자산회전율'] = t1.loc[i,'유형자산회전율(연결))']
            
    elif t1.loc[i,'유형자산회전율(연결))'] == 0:
        if t1.loc[i,'유형자산회전율(개별)'] == 0:
            t1.loc[i,'유형자산회전율'] = 0
        else:
            t1.loc[i,'유형자산회전율'] = 0
            
    elif t1.loc[i,'유형자산회전율(개별)'] == 0:
        if t1.loc[i,'유형자산회전율(연결))'] == 0:
            t1.loc[i,'유형자산회전율'] = 0
        else:
            t1.loc[i,'유형자산회전율'] = 0
            
    else:
        if t1.loc[i,'유형자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'유형자산회전율'] = t1.loc[i,'유형자산회전율(개별)']
        else:
            t1.loc[i,'유형자산회전율'] = np.nan

# %% [markdown]
# ### 매입채무회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'매입채무회전율(연결)'] != 1254789.63:
        if t1.loc[i,'매입채무회전율(개별)'] != 1254789.63:
            t1.loc[i,'매입채무회전율'] = t1.loc[i,'매입채무회전율(연결)']
        else:
            t1.loc[i,'매입채무회전율'] = t1.loc[i,'매입채무회전율(연결)']
            
    elif t1.loc[i,'매입채무회전율(연결)'] == 0:
        if t1.loc[i,'매입채무회전율(개별)'] == 0:
            t1.loc[i,'매입채무회전율'] = 0
        else:
            t1.loc[i,'매입채무회전율'] = 0
            
    elif t1.loc[i,'매입채무회전율(개별)'] == 0:
        if t1.loc[i,'매입채무회전율(연결)'] == 0:
            t1.loc[i,'매입채무회전율'] = 0
        else:
            t1.loc[i,'매입채무회전율'] = 0
            
    else:
        if t1.loc[i,'매입채무회전율(개별)'] != 1254789.63:
            t1.loc[i,'매입채무회전율'] = t1.loc[i,'매입채무회전율(개별)']
        else:
            t1.loc[i,'매입채무회전율'] = np.nan

# %% [markdown]
# ### 자기자본회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'자기자본회전율(연결)'] != 1254789.63:
        if t1.loc[i,'자기자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'자기자본회전율'] = t1.loc[i,'자기자본회전율(연결)']
        else:
            t1.loc[i,'자기자본회전율'] = t1.loc[i,'자기자본회전율(연결)']
            
    elif t1.loc[i,'자기자본회전율(연결)'] == 0:
        if t1.loc[i,'자기자본회전율(개별)'] == 0:
            t1.loc[i,'자기자본회전율'] = 0
        else:
            t1.loc[i,'자기자본회전율'] = 0
            
    elif t1.loc[i,'자기자본회전율(개별)'] == 0:
        if t1.loc[i,'자기자본회전율(연결)'] == 0:
            t1.loc[i,'자기자본회전율'] = 0
        else:
            t1.loc[i,'자기자본회전율'] = 0
            
    else:
        if t1.loc[i,'자기자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'자기자본회전율'] = t1.loc[i,'자기자본회전율(개별)']
        else:
            t1.loc[i,'자기자본회전율'] = np.nan

# %% [markdown]
# ### 타인자본회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'타인자본회전율(연결)'] != 1254789.63:
        if t1.loc[i,'타인자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'타인자본회전율'] = t1.loc[i,'타인자본회전율(연결)']
        else:
            t1.loc[i,'타인자본회전율'] = t1.loc[i,'타인자본회전율(연결)']
            
    elif t1.loc[i,'타인자본회전율(연결)'] == 0:
        if t1.loc[i,'타인자본회전율(개별)'] == 0:
            t1.loc[i,'타인자본회전율'] = 0
        else:
            t1.loc[i,'타인자본회전율'] = 0
            
    elif t1.loc[i,'타인자본회전율(개별)'] == 0:
        if t1.loc[i,'타인자본회전율(연결)'] == 0:
            t1.loc[i,'타인자본회전율'] = 0
        else:
            t1.loc[i,'타인자본회전율'] = 0
            
    else:
        if t1.loc[i,'타인자본회전율(개별)'] != 1254789.63:
            t1.loc[i,'타인자본회전율'] = t1.loc[i,'타인자본회전율(개별)']
        else:
            t1.loc[i,'타인자본회전율'] = np.nan

# %% [markdown]
# ### 유동자산회전율

# %%
for i in range(len(t1)):
    if t1.loc[i,'유동자산회전율(연결)'] != 1254789.63:
        if t1.loc[i,'유동자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'유동자산회전율'] = t1.loc[i,'유동자산회전율(연결)']
        else:
            t1.loc[i,'유동자산회전율'] = t1.loc[i,'유동자산회전율(연결)']
            
    elif t1.loc[i,'유동자산회전율(연결)'] == 0:
        if t1.loc[i,'유동자산회전율(개별)'] == 0:
            t1.loc[i,'유동자산회전율'] = 0
        else:
            t1.loc[i,'유동자산회전율'] = 0
            
    elif t1.loc[i,'유동자산회전율(개별)'] == 0:
        if t1.loc[i,'유동자산회전율(연결)'] == 0:
            t1.loc[i,'유동자산회전율'] = 0
        else:
            t1.loc[i,'유동자산회전율'] = 0
            
    else:
        if t1.loc[i,'유동자산회전율(개별)'] != 1254789.63:
            t1.loc[i,'유동자산회전율'] = t1.loc[i,'유동자산회전율(개별)']
        else:
            t1.loc[i,'유동자산회전율'] = np.nan

# %%
t1
# Out:
#        총자본회전율(개별)  총자본회전율(연결)  재고자산회전율(개별)  재고자산회전율(연결)  매출채권회전율(개별)  \
# 0            0.97        0.97         3.74         3.74         1.90
# 1            0.65        0.66         4.09         4.09         1.45
# 2            0.50        0.51         3.30         3.30         1.60
# 3            0.46        0.46         3.00         3.00         1.48
# 4            0.56        0.56         3.32         3.32         1.66
# ...           ...         ...          ...          ...          ...
# 15145        5.08        4.96        61.88        64.23        25.85
# 15146        4.51        4.55        51.40        53.94        25.79
# 15147        5.36        5.41        41.01        43.17        22.93
# 15148        8.58        7.93        37.37        39.24        18.22
# 15149        2.62        1.96         7.50         7.28         4.55
#
#        매출채권회전율(연결)  유형자산회전율(개별)  유형자산회전율(연결))  매입채무회전율(개별)  매입채무회전율(연결)  \
# ...

# %%
t1.to_csv('test3.csv',encoding='cp949',index=False)

# %%
# test.to_csv('test.csv',encoding='cp949',index=False)

# %%
# test = pd.read_csv('test.csv',encoding='cp949')
# test = test.replace(1254789.63,np.nan)

# %%
# df.replace(1254789.63,np.nan)

# %%
# df.tail(30)

# %%
q1 = pd.read_csv('./csv/전체데이터_2011_코스피코스닥_1차전처리_v1.0.csv', encoding='cp949')
q1.drop(columns=['Unnamed: 0','이자보상배율(이자비용)(IFRS)','이자보상배율(이자비용)(IFRS연결)'], inplace=True)
q1
# Out:
#             회사명  거래소코드    회계년도  이자보상배율
# 0      (주)CMG제약  58820  11-Dec    3.53
# 1      (주)CMG제약  58820  12-Dec   -7.75
# 2      (주)CMG제약  58820  13-Dec    0.70
# 3      (주)CMG제약  58820  14-Dec    3.60
# 4      (주)CMG제약  58820  15-Dec  -32.22
# ...         ...    ...     ...     ...
# 15145   흥아해운(주)   3280  15-Dec    1.02
# 15146   흥아해운(주)   3280  16-Dec    0.21
# 15147   흥아해운(주)   3280  17-Dec   -0.42
# 15148   흥아해운(주)   3280  18-Dec   -1.16
# 15149   흥아해운(주)   3280  19-Dec    0.00
#
# [15150 rows x 4 columns]

# %%
q2 = pd.read_csv('진짜재무비율 - 복사본.csv',encoding='cp949')
q2
# Out:
#        총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  자기자본증가율   순이익증가율  매출액총이익율  매출액순이익율  \
# 0        1.98    -5.91    17.64    -1.43    -2.02      NaN    41.83    -8.50
# 1      109.15    -4.12   207.08     7.73    75.17      NaN    28.34   -40.97
# 2       -2.09    16.09   -18.89    56.29    55.10      NaN    38.70     1.45
# 3        3.86    74.30   -25.93     6.37     0.01   -46.64    37.07     0.69
# 4       -2.64    -5.37    -7.17    11.04    -4.48 -2409.61    36.26   -13.50
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 15145   21.93    49.36   -11.18   -12.92     3.39   -42.68     6.20     1.24
# 15146   21.08    38.84   -25.08    56.39    11.22  -263.29     4.49    -2.06
# 15147  -11.43   -16.50    13.29    11.18   -39.28      NaN     2.09    -8.79
# 15148   -5.33   -12.07    -6.33    -5.85   -37.42      NaN    -0.93   -11.48
# 15149  -46.38   -51.51   -13.42   -58.98   -57.73      NaN     5.54   -50.27
#
# ...

# %%
q3 = pd.concat([q1,q2],axis=1)
q3
# Out:
#             회사명  거래소코드    회계년도  이자보상배율  총자산증가율  유형자산증가율  유동자산증가율  재고자산증가율  \
# 0      (주)CMG제약  58820  11-Dec    3.53    1.98    -5.91    17.64    -1.43
# 1      (주)CMG제약  58820  12-Dec   -7.75  109.15    -4.12   207.08     7.73
# 2      (주)CMG제약  58820  13-Dec    0.70   -2.09    16.09   -18.89    56.29
# 3      (주)CMG제약  58820  14-Dec    3.60    3.86    74.30   -25.93     6.37
# 4      (주)CMG제약  58820  15-Dec  -32.22   -2.64    -5.37    -7.17    11.04
# ...         ...    ...     ...     ...     ...      ...      ...      ...
# 15145   흥아해운(주)   3280  15-Dec    1.02   21.93    49.36   -11.18   -12.92
# 15146   흥아해운(주)   3280  16-Dec    0.21   21.08    38.84   -25.08    56.39
# 15147   흥아해운(주)   3280  17-Dec   -0.42  -11.43   -16.50    13.29    11.18
# 15148   흥아해운(주)   3280  18-Dec   -1.16   -5.33   -12.07    -6.33    -5.85
# 15149   흥아해운(주)   3280  19-Dec    0.00  -46.38   -51.51   -13.42   -58.98
#
#        자기자본증가율   순이익증가율  매출액총이익율  매출액순이익율  자기자본순이익율  총자본정상영업이익율  매출액정상영업이익율  \
# ...

# %%
# q3.to_csv('1차테스트데이터.csv',encoding='cp949',index=False)

# %%
w1 = pd.read_csv('01_생산성확인용복사본.csv',encoding='cp949')
# w1 = w1.replace('#NAME?',1254789.63)
w1 = w1.fillna(1254789.63)
w1 = w1.round(2)
# w1.loc[26:]
w1
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  노동장비율(개별)  노동장비율(연결)  기계장비율(개별)  \
# 0               0  (주)CMG제약  58820  11-Dec   71317.77   71726.36   29216.43
# 1               1  (주)CMG제약  58820  12-Dec   69135.39   69458.82   32002.75
# 2               2  (주)CMG제약  58820  13-Dec   66012.04   66012.04   33789.62
# 3               3  (주)CMG제약  58820  14-Dec  113899.65  113899.65   48479.94
# 4               4  (주)CMG제약  58820  15-Dec  114246.59  114246.59   53386.77
# ...           ...       ...    ...     ...        ...        ...        ...
# 15145       15145   흥아해운(주)   3280  15-Dec  589651.26  593960.16       0.00
# 15146       15146   흥아해운(주)   3280  16-Dec  703546.63  706868.14       0.00
# 15147       15147   흥아해운(주)   3280  17-Dec  596129.17  599097.86       0.00
# 15148       15148   흥아해운(주)   3280  18-Dec  615848.75  618981.48       0.00
# 15149       15149   흥아해운(주)   3280  19-Dec  701549.91  704760.75       0.00
#
# ...

# %% [markdown]
# ### 노동장비율

# %%
for i in range(len(w1)):
    if w1.loc[i,'노동장비율(연결)'] != 1254789.63:
        if w1.loc[i,'노동장비율(개별)'] != 1254789.63:
            w1.loc[i,'노동장비율'] = w1.loc[i,'노동장비율(연결)']
        else:
            w1.loc[i,'노동장비율'] = w1.loc[i,'노동장비율(연결)']
            
    elif w1.loc[i,'노동장비율(연결)'] == 0:
        if w1.loc[i,'노동장비율(개별)'] == 0:
            w1.loc[i,'노동장비율'] = 0
        else:
            w1.loc[i,'노동장비율'] = 0
            
    elif w1.loc[i,'노동장비율(개별)'] == 0:
        if w1.loc[i,'노동장비율(연결)'] == 0:
            w1.loc[i,'노동장비율'] = 0
        else:
            w1.loc[i,'노동장비율'] = 0
            
    else:
        if w1.loc[i,'노동장비율(개별)'] != 1254789.63:
            w1.loc[i,'노동장비율'] = w1.loc[i,'노동장비율(개별)']
        else:
            w1.loc[i,'노동장비율'] = np.nan

# %% [markdown]
# ### 기계장비율

# %%
for i in range(len(w1)):
    if w1.loc[i,'기계장비율(연결)'] != 1254789.63:
        if w1.loc[i,'기계장비율(개별)'] != 1254789.63:
            w1.loc[i,'기계장비율'] = w1.loc[i,'기계장비율(연결)']
        else:
            w1.loc[i,'기계장비율'] = w1.loc[i,'기계장비율(연결)']
            
    elif w1.loc[i,'기계장비율(연결)'] == 0:
        if w1.loc[i,'기계장비율(개별)'] == 0:
            w1.loc[i,'기계장비율'] = 0
        else:
            w1.loc[i,'기계장비율'] = 0
            
    elif w1.loc[i,'기계장비율(개별)'] == 0:
        if w1.loc[i,'기계장비율(연결)'] == 0:
            w1.loc[i,'기계장비율'] = 0
        else:
            w1.loc[i,'기계장비율'] = 0
            
    else:
        if w1.loc[i,'기계장비율(개별)'] != 1254789.63:
            w1.loc[i,'기계장비율'] = w1.loc[i,'기계장비율(개별)']
        else:
            w1.loc[i,'기계장비율'] = np.nan

# %% [markdown]
# ### 자본집약도

# %%
for i in range(len(w1)):
    if w1.loc[i,'자본집약도(연결)'] != 1254789.63:
        if w1.loc[i,'자본집약도(개별)'] != 1254789.63:
            w1.loc[i,'자본집약도'] = w1.loc[i,'자본집약도(연결)']
        else:
            w1.loc[i,'자본집약도'] = w1.loc[i,'자본집약도(연결)']
            
    elif w1.loc[i,'자본집약도(연결)'] == 0:
        if w1.loc[i,'자본집약도(개별)'] == 0:
            w1.loc[i,'자본집약도'] = 0
        else:
            w1.loc[i,'자본집약도'] = 0
            
    elif w1.loc[i,'자본집약도(개별)'] == 0:
        if w1.loc[i,'자본집약도(연결)'] == 0:
            w1.loc[i,'자본집약도'] = 0
        else:
            w1.loc[i,'자본집약도'] = 0
            
    else:
        if w1.loc[i,'자본집약도(개별)'] != 1254789.63:
            w1.loc[i,'자본집약도'] = w1.loc[i,'자본집약도(개별)']
        else:
            w1.loc[i,'자본집약도'] = np.nan

# %% [markdown]
# ### 노동소득분배율

# %%
for i in range(len(w1)):
    if w1.loc[i,'노동소득분배율(연결)'] != 1254789.63:
        if w1.loc[i,'노동소득분배율(개별)'] != 1254789.63:
            w1.loc[i,'노동소득분배율'] = w1.loc[i,'노동소득분배율(연결)']
        else:
            w1.loc[i,'노동소득분배율'] = w1.loc[i,'노동소득분배율(연결)']
            
    elif w1.loc[i,'노동소득분배율(연결)'] == 0:
        if w1.loc[i,'노동소득분배율(개별)'] == 0:
            w1.loc[i,'노동소득분배율'] = 0
        else:
            w1.loc[i,'노동소득분배율'] = 0
            
    elif w1.loc[i,'노동소득분배율(개별)'] == 0:
        if w1.loc[i,'노동소득분배율(연결)'] == 0:
            w1.loc[i,'노동소득분배율'] = 0
        else:
            w1.loc[i,'노동소득분배율'] = 0
            
    else:
        if w1.loc[i,'노동소득분배율(개별)'] != 1254789.63:
            w1.loc[i,'노동소득분배율'] = w1.loc[i,'노동소득분배율(개별)']
        else:
            w1.loc[i,'노동소득분배율'] = np.nan

# %% [markdown]
# ### 설비투자효율

# %%
for i in range(len(w1)):
    if w1.loc[i,'설비투자효율(연결)'] != 1254789.63:
        if w1.loc[i,'설비투자효율(개별)'] != 1254789.63:
            w1.loc[i,'설비투자효율'] = w1.loc[i,'설비투자효율(연결)']
        else:
            w1.loc[i,'설비투자효율'] = w1.loc[i,'설비투자효율(연결)']
            
    elif w1.loc[i,'설비투자효율(연결)'] == 0:
        if w1.loc[i,'설비투자효율(개별)'] == 0:
            w1.loc[i,'설비투자효율'] = 0
        else:
            w1.loc[i,'설비투자효율'] = 0
            
    elif w1.loc[i,'설비투자효율(개별)'] == 0:
        if w1.loc[i,'설비투자효율(연결)'] == 0:
            w1.loc[i,'설비투자효율'] = 0
        else:
            w1.loc[i,'설비투자효율'] = 0
            
    else:
        if w1.loc[i,'설비투자효율(개별)'] != 1254789.63:
            w1.loc[i,'설비투자효율'] = w1.loc[i,'설비투자효율(개별)']
        else:
            w1.loc[i,'설비투자효율'] = np.nan

# %% [markdown]
# ### 총자본투자효율

# %%
for i in range(len(w1)):
    if w1.loc[i,'총자본투자효율(연결)'] != 1254789.63:
        if w1.loc[i,'총자본투자효율(개별)'] != 1254789.63:
            w1.loc[i,'총자본투자효율'] = w1.loc[i,'총자본투자효율(연결)']
        else:
            w1.loc[i,'총자본투자효율'] = w1.loc[i,'총자본투자효율(연결)']
            
    elif w1.loc[i,'총자본투자효율(연결)'] == 0:
        if w1.loc[i,'총자본투자효율(개별)'] == 0:
            w1.loc[i,'총자본투자효율'] = 0
        else:
            w1.loc[i,'총자본투자효율'] = 0
            
    elif w1.loc[i,'총자본투자효율(개별)'] == 0:
        if w1.loc[i,'총자본투자효율(연결)'] == 0:
            w1.loc[i,'총자본투자효율'] = 0
        else:
            w1.loc[i,'총자본투자효율'] = 0
            
    else:
        if w1.loc[i,'총자본투자효율(개별)'] != 1254789.63:
            w1.loc[i,'총자본투자효율'] = w1.loc[i,'총자본투자효율(개별)']
        else:
            w1.loc[i,'총자본투자효율'] = np.nan

# %% [markdown]
# ### 기계투자효율

# %%
for i in range(len(w1)):
    if w1.loc[i,'기계투자효율(연결)'] != 1254789.63:
        if w1.loc[i,'기계투자효율(개별)'] != 1254789.63:
            w1.loc[i,'기계투자효율'] = w1.loc[i,'기계투자효율(연결)']
        else:
            w1.loc[i,'기계투자효율'] = w1.loc[i,'기계투자효율(연결)']
            
    elif w1.loc[i,'기계투자효율(연결)'] == 0:
        if w1.loc[i,'기계투자효율(개별)'] == 0:
            w1.loc[i,'기계투자효율'] = 0
        else:
            w1.loc[i,'기계투자효율'] = 0
            
    elif w1.loc[i,'기계투자효율(개별)'] == 0:
        if w1.loc[i,'기계투자효율(연결)'] == 0:
            w1.loc[i,'기계투자효율'] = 0
        else:
            w1.loc[i,'기계투자효율'] = 0
            
    else:
        if w1.loc[i,'기계투자효율(개별)'] != 1254789.63:
            w1.loc[i,'기계투자효율'] = w1.loc[i,'기계투자효율(개별)']
        else:
            w1.loc[i,'기계투자효율'] = np.nan

# %% [markdown]
# ### 부가가치율

# %%
for i in range(len(w1)):
    if w1.loc[i,'부가가치율(연결)'] != 1254789.63:
        if w1.loc[i,'부가가치율(개별)'] != 1254789.63:
            w1.loc[i,'부가가치율'] = w1.loc[i,'부가가치율(연결)']
        else:
            w1.loc[i,'부가가치율'] = w1.loc[i,'부가가치율(연결)']
            
    elif w1.loc[i,'부가가치율(연결)'] == 0:
        if w1.loc[i,'부가가치율(개별)'] == 0:
            w1.loc[i,'부가가치율'] = 0
        else:
            w1.loc[i,'부가가치율'] = 0
            
    elif w1.loc[i,'부가가치율(개별)'] == 0:
        if w1.loc[i,'부가가치율(연결)'] == 0:
            w1.loc[i,'부가가치율'] = 0
        else:
            w1.loc[i,'부가가치율'] = 0
            
    else:
        if w1.loc[i,'부가가치율(개별)'] != 1254789.63:
            w1.loc[i,'부가가치율'] = w1.loc[i,'부가가치율(개별)']
        else:
            w1.loc[i,'부가가치율'] = np.nan

# %%
w1
# Out:
#        Unnamed: 0       회사명  거래소코드    회계년도  노동장비율(개별)  노동장비율(연결)  기계장비율(개별)  \
# 0               0  (주)CMG제약  58820  11-Dec   71317.77   71726.36   29216.43
# 1               1  (주)CMG제약  58820  12-Dec   69135.39   69458.82   32002.75
# 2               2  (주)CMG제약  58820  13-Dec   66012.04   66012.04   33789.62
# 3               3  (주)CMG제약  58820  14-Dec  113899.65  113899.65   48479.94
# 4               4  (주)CMG제약  58820  15-Dec  114246.59  114246.59   53386.77
# ...           ...       ...    ...     ...        ...        ...        ...
# 15145       15145   흥아해운(주)   3280  15-Dec  589651.26  593960.16       0.00
# 15146       15146   흥아해운(주)   3280  16-Dec  703546.63  706868.14       0.00
# 15147       15147   흥아해운(주)   3280  17-Dec  596129.17  599097.86       0.00
# 15148       15148   흥아해운(주)   3280  18-Dec  615848.75  618981.48       0.00
# 15149       15149   흥아해운(주)   3280  19-Dec  701549.91  704760.75       0.00
#
# ...

# %%
# w1.to_csv('test4.csv',encoding='cp949',index=False)

# %%
e1 = pd.read_csv('안정성비율_2.csv',encoding='cp949')
e1 = e1.fillna(1254789.63)
e1
# Out:
#             회사명  거래소코드    회계년도  차입금비율(IFRS)  차입금비율(IFRS연결)  당좌자산구성비율(IFRS)  \
# 0      (주)CMG제약  58820  Dec-11        25.22          13.74           45.45
# 1      (주)CMG제약  58820  Dec-12        61.69          55.28           77.42
# 2      (주)CMG제약  58820  Dec-13         2.89           2.89           60.11
# 3      (주)CMG제약  58820  Dec-14         3.13           3.15           40.34
# 4      (주)CMG제약  58820  Dec-15         0.00           0.01           36.89
# ...         ...    ...     ...          ...            ...             ...
# 15145   흥아해운(주)   3280  Dec-15       159.46         150.12           14.65
# 15146   흥아해운(주)   3280  Dec-16       139.54         134.16            7.75
# 15147   흥아해운(주)   3280  Dec-17       248.86         231.23           10.29
# 15148   흥아해운(주)   3280  Dec-18       444.78         347.18           10.78
# 15149   흥아해운(주)   3280  Dec-19      1766.45        1010.48           13.88
#
#        당좌자산구성비율(IFRS연결)  유동자산구성비율(IFRS)  유동자산구성비율(IFRS연결)  \
# ...

# %% [markdown]
# ### 차입금비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'차입금비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'차입금비율(IFRS)'] != 1254789.63:
            e1.loc[i,'차입금비율'] = e1.loc[i,'차입금비율(IFRS연결)']
        else:
            e1.loc[i,'차입금비율'] = e1.loc[i,'차입금비율(IFRS연결)']
            
    elif e1.loc[i,'차입금비율(IFRS연결)'] == 0:
        if e1.loc[i,'차입금비율(IFRS)'] == 0:
            e1.loc[i,'차입금비율'] = 0
        else:
            e1.loc[i,'차입금비율'] = 0
            
    elif e1.loc[i,'차입금비율(IFRS)'] == 0:
        if e1.loc[i,'차입금비율(IFRS연결)'] == 0:
            e1.loc[i,'차입금비율'] = 0
        else:
            e1.loc[i,'차입금비율'] = 0
            
    else:
        if e1.loc[i,'차입금비율(IFRS)'] != 1254789.63:
            e1.loc[i,'차입금비율'] = e1.loc[i,'차입금비율(IFRS)']
        else:
            e1.loc[i,'차입금비율'] = np.nan

# %% [markdown]
# ### 당좌자산구성비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'당좌자산구성비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'당좌자산구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'당좌자산구성비율'] = e1.loc[i,'당좌자산구성비율(IFRS연결)']
        else:
            e1.loc[i,'당좌자산구성비율'] = e1.loc[i,'당좌자산구성비율(IFRS연결)']
            
    elif e1.loc[i,'당좌자산구성비율(IFRS연결)'] == 0:
        if e1.loc[i,'당좌자산구성비율(IFRS)'] == 0:
            e1.loc[i,'당좌자산구성비율'] = 0
        else:
            e1.loc[i,'당좌자산구성비율'] = 0
            
    elif e1.loc[i,'당좌자산구성비율(IFRS)'] == 0:
        if e1.loc[i,'당좌자산구성비율(IFRS연결)'] == 0:
            e1.loc[i,'당좌자산구성비율'] = 0
        else:
            e1.loc[i,'당좌자산구성비율'] = 0
            
    else:
        if e1.loc[i,'당좌자산구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'당좌자산구성비율'] = e1.loc[i,'당좌자산구성비율(IFRS)']
        else:
            e1.loc[i,'당좌자산구성비율'] = np.nan

# %% [markdown]
# ### 유동자산구성비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'유동자산구성비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'유동자산구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'유동자산구성비율'] = e1.loc[i,'유동자산구성비율(IFRS연결)']
        else:
            e1.loc[i,'유동자산구성비율'] = e1.loc[i,'유동자산구성비율(IFRS연결)']
            
    elif e1.loc[i,'유동자산구성비율(IFRS연결)'] == 0:
        if e1.loc[i,'유동자산구성비율(IFRS)'] == 0:
            e1.loc[i,'유동자산구성비율'] = 0
        else:
            e1.loc[i,'유동자산구성비율'] = 0
            
    elif e1.loc[i,'유동자산구성비율(IFRS)'] == 0:
        if e1.loc[i,'유동자산구성비율(IFRS연결)'] == 0:
            e1.loc[i,'유동자산구성비율'] = 0
        else:
            e1.loc[i,'유동자산구성비율'] = 0
            
    else:
        if e1.loc[i,'유동자산구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'유동자산구성비율'] = e1.loc[i,'유동자산구성비율(IFRS)']
        else:
            e1.loc[i,'유동자산구성비율'] = np.nan

# %% [markdown]
# ### 매출채권_대_매입채무비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'매출채권 대 매입채무비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'매출채권 대 매입채무비율(IFRS)'] != 1254789.63:
            e1.loc[i,'매출채권_대_매입채무비율'] = e1.loc[i,'매출채권 대 매입채무비율(IFRS연결)']
        else:
            e1.loc[i,'매출채권_대_매입채무비율'] = e1.loc[i,'매출채권 대 매입채무비율(IFRS연결)']
            
    elif e1.loc[i,'매출채권 대 매입채무비율(IFRS연결)'] == 0:
        if e1.loc[i,'매출채권 대 매입채무비율(IFRS)'] == 0:
            e1.loc[i,'매출채권_대_매입채무비율'] = 0
        else:
            e1.loc[i,'매출채권_대_매입채무비율'] = 0
            
    elif e1.loc[i,'매출채권 대 매입채무비율(IFRS)'] == 0:
        if e1.loc[i,'매출채권 대 매입채무비율(IFRS연결)'] == 0:
            e1.loc[i,'매출채권_대_매입채무비율'] = 0
        else:
            e1.loc[i,'매출채권_대_매입채무비율'] = 0
            
    else:
        if e1.loc[i,'매출채권 대 매입채무비율(IFRS)'] != 1254789.63:
            e1.loc[i,'매출채권_대_매입채무비율'] = e1.loc[i,'매출채권 대 매입채무비율(IFRS)']
        else:
            e1.loc[i,'매출채권_대_매입채무비율'] = np.nan

# %% [markdown]
# ### 단기차입금_대_총차입금비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'단기차입금 대 총차입금비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'단기차입금 대 총차입금비율(IFRS)'] != 1254789.63:
            e1.loc[i,'단기차입금_대_총차입금비율'] = e1.loc[i,'단기차입금 대 총차입금비율(IFRS연결)']
        else:
            e1.loc[i,'단기차입금_대_총차입금비율'] = e1.loc[i,'단기차입금 대 총차입금비율(IFRS연결)']
            
    elif e1.loc[i,'단기차입금 대 총차입금비율(IFRS연결)'] == 0:
        if e1.loc[i,'단기차입금 대 총차입금비율(IFRS)'] == 0:
            e1.loc[i,'단기차입금_대_총차입금비율'] = 0
        else:
            e1.loc[i,'단기차입금_대_총차입금비율'] = 0
            
    elif e1.loc[i,'단기차입금 대 총차입금비율(IFRS)'] == 0:
        if e1.loc[i,'단기차입금 대 총차입금비율(IFRS연결)'] == 0:
            e1.loc[i,'단기차입금_대_총차입금비율'] = 0
        else:
            e1.loc[i,'단기차입금_대_총차입금비율'] = 0
            
    else:
        if e1.loc[i,'단기차입금 대 총차입금비율(IFRS)'] != 1254789.63:
            e1.loc[i,'단기차입금_대_총차입금비율'] = e1.loc[i,'단기차입금 대 총차입금비율(IFRS)']
        else:
            e1.loc[i,'단기차입금_대_총차입금비율'] = np.nan

# %% [markdown]
# ### 유동부채비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'유동부채비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'유동부채비율(IFRS)'] != 1254789.63:
            e1.loc[i,'유동부채비율'] = e1.loc[i,'유동부채비율(IFRS연결)']
        else:
            e1.loc[i,'유동부채비율'] = e1.loc[i,'유동부채비율(IFRS연결)']
            
    elif e1.loc[i,'유동부채비율(IFRS연결)'] == 0:
        if e1.loc[i,'유동부채비율(IFRS)'] == 0:
            e1.loc[i,'유동부채비율'] = 0
        else:
            e1.loc[i,'유동부채비율'] = 0
            
    elif e1.loc[i,'유동부채비율(IFRS)'] == 0:
        if e1.loc[i,'유동부채비율(IFRS연결)'] == 0:
            e1.loc[i,'유동부채비율'] = 0
        else:
            e1.loc[i,'유동부채비율'] = 0
            
    else:
        if e1.loc[i,'유동부채비율(IFRS)'] != 1254789.63:
            e1.loc[i,'유동부채비율'] = e1.loc[i,'유동부채비율(IFRS)']
        else:
            e1.loc[i,'유동부채비율'] = np.nan

# %% [markdown]
# ### 타인자본구성비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'타인자본구성비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'타인자본구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'타인자본구성비율'] = e1.loc[i,'타인자본구성비율(IFRS연결)']
        else:
            e1.loc[i,'타인자본구성비율'] = e1.loc[i,'타인자본구성비율(IFRS연결)']
            
    elif e1.loc[i,'타인자본구성비율(IFRS연결)'] == 0:
        if e1.loc[i,'타인자본구성비율(IFRS)'] == 0:
            e1.loc[i,'타인자본구성비율'] = 0
        else:
            e1.loc[i,'타인자본구성비율'] = 0
            
    elif e1.loc[i,'타인자본구성비율(IFRS)'] == 0:
        if e1.loc[i,'타인자본구성비율(IFRS연결)'] == 0:
            e1.loc[i,'타인자본구성비율'] = 0
        else:
            e1.loc[i,'타인자본구성비율'] = 0
            
    else:
        if e1.loc[i,'타인자본구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'타인자본구성비율'] = e1.loc[i,'타인자본구성비율(IFRS)']
        else:
            e1.loc[i,'타인자본구성비율'] = np.nan

# %% [markdown]
# ### 자기자본구성비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'자기자본구성비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'자기자본구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'자기자본구성비율'] = e1.loc[i,'자기자본구성비율(IFRS연결)']
        else:
            e1.loc[i,'자기자본구성비율'] = e1.loc[i,'자기자본구성비율(IFRS연결)']
            
    elif e1.loc[i,'자기자본구성비율(IFRS연결)'] == 0:
        if e1.loc[i,'자기자본구성비율(IFRS)'] == 0:
            e1.loc[i,'자기자본구성비율'] = 0
        else:
            e1.loc[i,'자기자본구성비율'] = 0
            
    elif e1.loc[i,'자기자본구성비율(IFRS)'] == 0:
        if e1.loc[i,'자기자본구성비율(IFRS연결)'] == 0:
            e1.loc[i,'자기자본구성비율'] = 0
        else:
            e1.loc[i,'자기자본구성비율'] = 0
            
    else:
        if e1.loc[i,'자기자본구성비율(IFRS)'] != 1254789.63:
            e1.loc[i,'자기자본구성비율'] = e1.loc[i,'자기자본구성비율(IFRS)']
        else:
            e1.loc[i,'자기자본구성비율'] = np.nan

# %% [markdown]
# ### 재고자산_대_유동자산비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'재고자산 대 유동자산비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'재고자산 대 유동자산비율(IFRS)'] != 1254789.63:
            e1.loc[i,'재고자산_대_유동자산비율'] = e1.loc[i,'재고자산 대 유동자산비율(IFRS연결)']
        else:
            e1.loc[i,'재고자산_대_유동자산비율'] = e1.loc[i,'재고자산 대 유동자산비율(IFRS연결)']
            
    elif e1.loc[i,'재고자산 대 유동자산비율(IFRS연결)'] == 0:
        if e1.loc[i,'재고자산 대 유동자산비율(IFRS)'] == 0:
            e1.loc[i,'재고자산_대_유동자산비율'] = 0
        else:
            e1.loc[i,'재고자산_대_유동자산비율'] = 0
            
    elif e1.loc[i,'재고자산 대 유동자산비율(IFRS)'] == 0:
        if e1.loc[i,'재고자산 대 유동자산비율(IFRS연결)'] == 0:
            e1.loc[i,'재고자산_대_유동자산비율'] = 0
        else:
            e1.loc[i,'재고자산_대_유동자산비율'] = 0
            
    else:
        if e1.loc[i,'재고자산 대 유동자산비율(IFRS)'] != 1254789.63:
            e1.loc[i,'재고자산_대_유동자산비율'] = e1.loc[i,'재고자산 대 유동자산비율(IFRS)']
        else:
            e1.loc[i,'재고자산_대_유동자산비율'] = np.nan

# %% [markdown]
# ### 재고자산_대_순운전자본비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'재고자산 대 순운전자본비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'재고자산 대 순운전자본비율(IFRS)'] != 1254789.63:
            e1.loc[i,'재고자산_대_순운전자본비율'] = e1.loc[i,'재고자산 대 순운전자본비율(IFRS연결)']
        else:
            e1.loc[i,'재고자산_대_순운전자본비율'] = e1.loc[i,'재고자산 대 순운전자본비율(IFRS연결)']
            
    elif e1.loc[i,'재고자산 대 순운전자본비율(IFRS연결)'] == 0:
        if e1.loc[i,'재고자산 대 순운전자본비율(IFRS)'] == 0:
            e1.loc[i,'재고자산_대_순운전자본비율'] = 0
        else:
            e1.loc[i,'재고자산_대_순운전자본비율'] = 0
            
    elif e1.loc[i,'재고자산 대 순운전자본비율(IFRS)'] == 0:
        if e1.loc[i,'재고자산 대 순운전자본비율(IFRS연결)'] == 0:
            e1.loc[i,'재고자산_대_순운전자본비율'] = 0
        else:
            e1.loc[i,'재고자산_대_순운전자본비율'] = 0
            
    else:
        if e1.loc[i,'재고자산 대 순운전자본비율(IFRS)'] != 1254789.63:
            e1.loc[i,'재고자산_대_순운전자본비율'] = e1.loc[i,'재고자산 대 순운전자본비율(IFRS)']
        else:
            e1.loc[i,'재고자산_대_순운전자본비율'] = np.nan

# %% [markdown]
# ### 순운전자본비율

# %%
for i in range(len(e1)):
    if e1.loc[i,'순운전자본비율(IFRS연결)'] != 1254789.63:
        if e1.loc[i,'순운전자본비율(IFRS)'] != 1254789.63:
            e1.loc[i,'순운전자본비율'] = e1.loc[i,'순운전자본비율(IFRS연결)']
        else:
            e1.loc[i,'순운전자본비율'] = e1.loc[i,'순운전자본비율(IFRS연결)']
            
    elif e1.loc[i,'순운전자본비율(IFRS연결)'] == 0:
        if e1.loc[i,'순운전자본비율(IFRS)'] == 0:
            e1.loc[i,'순운전자본비율'] = 0
        else:
            e1.loc[i,'순운전자본비율'] = 0
            
    elif e1.loc[i,'순운전자본비율(IFRS)'] == 0:
        if e1.loc[i,'순운전자본비율(IFRS연결)'] == 0:
            e1.loc[i,'순운전자본비율'] = 0
        else:
            e1.loc[i,'순운전자본비율'] = 0
            
    else:
        if e1.loc[i,'순운전자본비율(IFRS)'] != 1254789.63:
            e1.loc[i,'순운전자본비율'] = e1.loc[i,'순운전자본비율(IFRS)']
        else:
            e1.loc[i,'순운전자본비율'] = np.nan

# %%
e1
# Out:
#             회사명  거래소코드    회계년도  차입금비율(IFRS)  차입금비율(IFRS연결)  당좌자산구성비율(IFRS)  \
# 0      (주)CMG제약  58820  Dec-11        25.22          13.74           45.45
# 1      (주)CMG제약  58820  Dec-12        61.69          55.28           77.42
# 2      (주)CMG제약  58820  Dec-13         2.89           2.89           60.11
# 3      (주)CMG제약  58820  Dec-14         3.13           3.15           40.34
# 4      (주)CMG제약  58820  Dec-15         0.00           0.01           36.89
# ...         ...    ...     ...          ...            ...             ...
# 15145   흥아해운(주)   3280  Dec-15       159.46         150.12           14.65
# 15146   흥아해운(주)   3280  Dec-16       139.54         134.16            7.75
# 15147   흥아해운(주)   3280  Dec-17       248.86         231.23           10.29
# 15148   흥아해운(주)   3280  Dec-18       444.78         347.18           10.78
# 15149   흥아해운(주)   3280  Dec-19      1766.45        1010.48           13.88
#
#        당좌자산구성비율(IFRS연결)  유동자산구성비율(IFRS)  유동자산구성비율(IFRS연결)  \
# ...

# %%
# e1.to_csv('2안정성비율.csv',encoding='cp949')
