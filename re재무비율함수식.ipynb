# %%
import pandas as pd
import numpy as np

# %%
############################ WARNING ######################################
# 회사명 기준으로 shift 등의 조치가 필요한 경우 따로 취한 다음에 함수 적용하세요
# 안 그러면 터집니다...
###########################################################################


# 단순하게 나누는 함수
# df_name : raw_data 들어있는 데이터프레임
# a, b : 계산을 하고자하는 데이터프레임의 컬럼명을 입력 (a가 분자, b가 분모)
# c : 계산 결과를 저장하고자 하는 데이터프레임의 컬럼명을 입력

# 증가율 함수
def pct (df_name,a,b,c):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            if 0 < (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)-100) < 0.01:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)-100)
        #분모 +, 분자 - 인 상황
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            if -0.01 < (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100)-100)*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100)-100)*-1
        # 분모 -, 분자 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            if 0.01 < (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100)-100) < 0:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100)-100)
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            if 0 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)-100) < 0.01:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)-100)
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i][c] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][c] = np.nan

# 수익성 계산
def profit (df_name,a,b,c):
    for i in range(len(df_name)):
        # 분모, 분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i][c] = (((abs(df_name.iloc[i][a]) - abs(df_name.iloc[i][b]))/df_name.iloc[i][a])*100) # 분모 -
        # a - (-b) / a 일때
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i][c] = (((df_name.iloc[i][a] - abs(df_name.iloc[i][b]))/df_name.iloc[i][a])*100) # b 절대값 변환
        # -a - b / -a 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i][c] = (((abs(df_name.iloc[i][a]) - df_name.iloc[i][b])/df_name.iloc[i][a])*100) # a 아무대나 절대값 하나
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i][c] = (((df_name.iloc[i][a] - df_name.iloc[i][b])/df_name.iloc[i][a])*100)
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i][c] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][c] = np.nan
            
# 매출액순이익률,현금비율,부채비율,유동자산구성비율,재고자산 대 유동자산비율,
# 자기자본구성비율, 타인자본구성비율, 유동부채비율, 차입금비율
def profit_tns(df_name,a,b,c):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            if 0 < (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)) < 0.01:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100))
        #분모 +, 분자 - 인 상황
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            if -0.01 < (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100))*-1 < 0: # 전년에 양수였다가 음수로 하락이기 때문에  -1을 곱한elif
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100))*-1
        # 분모 -, 분자 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            if 0.01 < (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100)) < 0:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((df_name.iloc[i][a]/abs(df_name.iloc[i][b]))*100))
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            if 0 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)) < 0.01:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((df_name.iloc[i][a]/df_name.iloc[i][b])*100))
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i][c] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][c] = np.nan
            
def profit_chddud(df_name,a,b,c,d):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
            df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((abs(df_name.iloc[i][b])+abs(df_name.iloc[i][c]))/2))*100)*-1 # 절대값 변환
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)* -1 
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            # 절대값 변환 후 음수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)*-1
        # a(+), b(+), c(-)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
        # a(+), b(-), c(+)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
        # 분모,분자가 - 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2))*100)
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
            df_name.loc[i][d] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][d] = np.nan
            
# 활동성 계산
def activity(df_name,a,b,c,d):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
            df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((abs(df_name.iloc[i][b])+abs(df_name.iloc[i][c]))/2)))*-1 # 절대값 변환
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))* -1 
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            # 절대값 변환 후 음수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))*-1
        # a(+), b(+), c(-)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
        # a(+), b(-), c(+)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
        # 분모,분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
            df_name.loc[i][d] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][d] = np.nan
            
def activity_tnsdns(df_name,a,b,c,d):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] < 0:
            df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((abs(df_name.iloc[i][b])-abs(df_name.iloc[i][c]))/2)))*-1 # 절대값 변환
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]-abs(df_name.iloc[i][c]))/2)))* -1 
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]-abs(df_name.iloc[i][c]))/2)))
        # a(-), b(+), c(-) 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            # 절대값 변환 후 음수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((abs(df_name.iloc[i][b])-df_name.iloc[i][c])/2)))*-1
            else:
                df_name.loc[i][d] = ((abs(df_name.iloc[i][a])/((df_name.iloc[i][b]-df_name.iloc[i][c])/2)))
        # a(+), b(+), c(-)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] < 0:
            # 절대값 변환 후 양수일 때
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]-abs(df_name.iloc[i][c]))/2)))
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]-abs(df_name.iloc[i][c]))/2)))
        # a(+), b(-), c(+)
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0 and df_name.iloc[i][c] > 0:
            if abs(df_name.iloc[i][b]) > abs(df_name.iloc[i][c]):
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]-df_name.iloc[i][c])/2)))
            else:
                df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]-df_name.iloc[i][c])/2)))
        # 분모,분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0 and df_name.iloc[i][c] > 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a]/((df_name.iloc[i][b]+df_name.iloc[i][c])/2)))
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0 or df_name.iloc[i][c] == 0:
            df_name.loc[i][d] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][d] = np.nan
            
# 생산성 계산
def produce (df_name,a,b,c,d):
    for i in range(len(df_name)):
        # (-a) - (-b) 일때
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i][d] = ((abs(df_name.iloc[i][a]) - abs(df_name.iloc[i][b]))/df_name.iloc[i][c])
        # a - (-b) 일때
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a] - abs(df_name.iloc[i][b]))/df_name.iloc[i][c]) # b 절대값 변환
        # (-a) - b 일때
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a] - df_name.iloc[i][b])/df_name.iloc[i][c]) # a 아무대나 절대값 하나
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            df_name.loc[i][d] = ((df_name.iloc[i][a] - df_name.iloc[i][b])/df_name.iloc[i][c])
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i][d] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][d] = np.nan
            
# 안정성 계산
def stability(df_name,a,b,c):
    for i in range(len(df_name)):
        # 분모,분자가 - 인 상황
        if df_name.iloc[i][a] < 0 and df_name.iloc[i][b] < 0:
            if -0.01 < (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)*-1) < 0:
                df_name.loc[i][c] = -0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/abs(df_name.iloc[i][b]))*100)*-1)
        #분모 -, 분자 + 인 상황
        elif df_name.iloc[i][a] < 0 and df_name.iloc[i][b] > 0:
            if -0.01 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)) < 0:
                df_name.loc[i][c] = -0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100))
        # 분모 -, 분자 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] < 0:
            if -0.01 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)) < 0:
                df_name.loc[i][c] = -0.01
            else:
                df_name.loc[i][c] = (((abs(df_name.iloc[i][a])/df_name.iloc[i][b])*100)) 
        # 분모, 분자가 + 인 상황
        elif df_name.iloc[i][a] > 0 and df_name.iloc[i][b] > 0:
            if 0 < (((df_name.iloc[i][a]/df_name.iloc[i][b])*100)) < 0.01:
                df_name.loc[i][c] = 0.01
            else:
                df_name.loc[i][c] = (((df_name.iloc[i][a]/df_name.iloc[i][b])*100))
        # 분모 또는 분자가 0인 경우
        elif df_name.iloc[i][a] == 0 or df_name.iloc[i][b] == 0:
            df_name.loc[i][c] = 0
        # 둘다 결측치인 경우
        else:
            df_name.loc[i][c] = np.nan

# %%
df1 = pd.read_csv('./비율/성장성비율.csv',encoding='cp949')
df1
# Out:
#             회사명  거래소코드     회계년도  자산(*)(IFRS)(천원)  자산(*)(IFRS연결)(천원)  \
# 0      (주)CMG제약  58820  2011/12       27548539.0         27305198.0
# 1      (주)CMG제약  58820  2012/12       56988604.0         57108035.0
# 2      (주)CMG제약  58820  2013/12       55961620.0         55912563.0
# 3      (주)CMG제약  58820  2014/12       58127098.0         58068326.0
# 4      (주)CMG제약  58820  2015/12       56591972.0         56532821.0
# ...         ...    ...      ...              ...                ...
# 15145   흥아해운(주)   3280  2015/12      771212062.0        791640802.0
# 15146   흥아해운(주)   3280  2016/12      942586770.0        958532259.0
# 15147   흥아해운(주)   3280  2017/12      834107402.0        848958520.0
# 15148   흥아해운(주)   3280  2018/12      782787041.0        803698457.0
# 15149   흥아해운(주)   3280  2019/12      386550839.0        430962722.0
#
#        유형자산(*)(IFRS)(천원)  유형자산(*)(IFRS연결)(천원)  유동자산(*)(IFRS)(천원)  \
# 0              9652599.0            9707759.0         15264885.0
# ...

# %%
df1['자산개별'] = df1['자산(*)(IFRS)(천원)'].shift(1)
# pct(df1,'자산(*)(IFRS)(천원)')
pct(df1,'자산(*)(IFRS)(천원)','자산개별','자산개별율')
# Out:
# C:\Users\82104\AppData\Local\Temp\ipykernel_18300\12640101.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_name.loc[i][c] = np.nan
# C:\Users\82104\AppData\Local\Temp\ipykernel_18300\12640101.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_name.loc[i][c] = np.nan
# C:\Users\82104\AppData\Local\Temp\ipykernel_18300\12640101.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
