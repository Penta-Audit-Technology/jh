# %% [markdown]
# ### 반정형 데이터 수명주기

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./csv/전체데이터_2011_KOSPI+KOSDAQ_수명주기.csv', encoding='cp949')
df
# Out:
#             회사명  거래소코드     회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                        -2488268.0
# 1      (주)CMG제약  58820  2012/12                        -1453276.0
# 2      (주)CMG제약  58820  2013/12                        -3891420.0
# 3      (주)CMG제약  58820  2014/12                          730447.0
# 4      (주)CMG제약  58820  2015/12                         2411254.0
# ...         ...    ...      ...                               ...
# 15145   흥아해운(주)   3280  2015/12                        34042933.0
# 15146   흥아해운(주)   3280  2016/12                        -4725664.0
# 15147   흥아해운(주)   3280  2017/12                        -5348563.0
# 15148   흥아해운(주)   3280  2018/12                       -30464257.0
# 15149   흥아해운(주)   3280  2019/12                       -16943933.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0                       -1845332.0                    3038758.0
# ...

# %% [markdown]
# ### 영업활동 만들기

# %%
for i in range(len(df)):
    if df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)'] == 0:
        df.loc[i, '영업활동'] = 9
    elif df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)'] < 0:
        df.loc[i, '영업활동'] = 0
    elif df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)'] > 0:
        df.loc[i, '영업활동'] = 1
    else:
        df.loc[i, '영업활동'] = 8
        
    if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] == 0:
        df.loc[i, '투자활동'] = 9
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0:
        df.loc[i, '투자활동'] = 0
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0:
        df.loc[i, '투자활동'] = 1
    else:
        df.loc[i, '투자활동'] = 8
        
    if df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS)(천원)'] == 0:
        df.loc[i, '재무활동'] = 9
    elif df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS)(천원)'] < 0:
        df.loc[i, '재무활동'] = 0
    elif df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS)(천원)'] > 0:
        df.loc[i, '재무활동'] = 1
    else:
        df.loc[i, '재무활동'] = 8
    
    if df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)'] == 0:
        df.loc[i, '영업활동(연결)'] = 9
    elif df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)'] < 0:
        df.loc[i, '영업활동(연결)'] = 0
    elif df.loc[i,'영업활동으로 인한 현금흐름(간접법)(*)(IFRS연결)(천원)'] > 0:
        df.loc[i, '영업활동(연결)'] = 1
    else:
        df.loc[i, '영업활동(연결)'] = 8
        
    if df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] == 0:
        df.loc[i, '투자활동(연결)'] = 9
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0:
        df.loc[i, '투자활동(연결)'] = 0
    elif df.loc[i,'투자활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0:
        df.loc[i, '투자활동(연결)'] = 1
    else:
        df.loc[i, '투자활동(연결)'] = 8
        
    if df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] == 0:
        df.loc[i, '재무활동(연결)'] = 9
    elif df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] < 0:
        df.loc[i, '재무활동(연결)'] = 0
    elif df.loc[i,'재무활동으로 인한 현금흐름(*)(IFRS연결)(천원)'] > 0:
        df.loc[i, '재무활동(연결)'] = 1
    else:
        df.loc[i, '재무활동(연결)'] = 8
df
# Out:
#             회사명  거래소코드     회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                        -2488268.0
# 1      (주)CMG제약  58820  2012/12                        -1453276.0
# 2      (주)CMG제약  58820  2013/12                        -3891420.0
# 3      (주)CMG제약  58820  2014/12                          730447.0
# 4      (주)CMG제약  58820  2015/12                         2411254.0
# ...         ...    ...      ...                               ...
# 15145   흥아해운(주)   3280  2015/12                        34042933.0
# 15146   흥아해운(주)   3280  2016/12                        -4725664.0
# 15147   흥아해운(주)   3280  2017/12                        -5348563.0
# 15148   흥아해운(주)   3280  2018/12                       -30464257.0
# 15149   흥아해운(주)   3280  2019/12                       -16943933.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0                       -1845332.0                    3038758.0
# ...

# %% [markdown]
# ### 기업수명주기 만들기

# %%
df_1 = df.copy()
for i in range(len(df_1)):
    # 도입기
    if df_1.loc[i,'영업활동'] == 0 and df_1.loc[i,'투자활동'] == 0 and df_1.loc[i,'재무활동'] == 1:
        df_1.loc[i,'기업수명'] = 1
    # 성장기
    elif df_1.loc[i,'영업활동'] == 1 and df_1.loc[i,'투자활동'] == 0 and df_1.loc[i,'재무활동'] == 1:
        df_1.loc[i,'기업수명'] = 2
    # 성숙기
    elif df_1.loc[i,'영업활동'] == 1 and df_1.loc[i,'투자활동'] == 0 and df_1.loc[i,'재무활동'] == 0:
        df_1.loc[i,'기업수명'] = 3
    # 쇠퇴기
    elif df_1.loc[i,'영업활동'] == 0 and df_1.loc[i,'투자활동'] == 1 and df_1.loc[i,'재무활동'] == 1:
        df_1.loc[i,'기업수명'] = 5
    elif df_1.loc[i,'영업활동'] == 0 and df_1.loc[i,'투자활동'] == 1 and df_1.loc[i,'재무활동'] == 0:
        df_1.loc[i,'기업수명'] = 5
    # 결측치인 경우
    elif df_1.loc[i,'영업활동'] == 8 or df_1.loc[i,'투자활동'] == 8 or df_1.loc[i,'재무활동'] == 8:
        df_1.loc[i,'기업수명'] = 8
    elif df_1.loc[i,'영업활동'] == 8 and df_1.loc[i,'투자활동'] == 8 and df_1.loc[i,'재무활동'] == 8:
        df_1.loc[i,'기업수명'] = 8
    # 0인 경우
    elif df_1.loc[i,'영업활동'] == 9 or df_1.loc[i,'투자활동'] == 9 or df_1.loc[i,'재무활동'] == 9:
        df_1.loc[i,'기업수명'] = 9
    elif df_1.loc[i,'영업활동'] == 9 and df_1.loc[i,'투자활동'] == 9 and df_1.loc[i,'재무활동'] == 9:
        df_1.loc[i,'기업수명'] = 9
    # 나머지는 쇠신기라고 할 경우
    else:
        df_1.loc[i,'기업수명'] = 4
        
    # 연결일 경우
        
    # 도입기
    if df_1.loc[i,'영업활동(연결)'] == 0 and df_1.loc[i,'투자활동(연결)'] == 0 and df_1.loc[i,'재무활동(연결)'] == 1:
        df_1.loc[i,'기업수명(연결)'] = 1
    # 성장기
    elif df_1.loc[i,'영업활동(연결)'] == 1 and df_1.loc[i,'투자활동(연결)'] == 0 and df_1.loc[i,'재무활동(연결)'] == 1:
        df_1.loc[i,'기업수명(연결)'] = 2
    # 성숙기
    elif df_1.loc[i,'영업활동(연결)'] == 1 and df_1.loc[i,'투자활동(연결)'] == 0 and df_1.loc[i,'재무활동(연결)'] == 0:
        df_1.loc[i,'기업수명(연결)'] = 3
    # 쇠퇴기
    elif df_1.loc[i,'영업활동(연결)'] == 0 and df_1.loc[i,'투자활동(연결)'] == 1 and df_1.loc[i,'재무활동(연결)'] == 1:
        df_1.loc[i,'기업수명(연결)'] = 5
    elif df_1.loc[i,'영업활동(연결)'] == 0 and df_1.loc[i,'투자활동(연결)'] == 1 and df_1.loc[i,'재무활동(연결)'] == 0:
        df_1.loc[i,'기업수명(연결)'] = 5
    # 결측치인 경우
    elif df_1.loc[i,'영업활동(연결)'] == 8 or df_1.loc[i,'투자활동(연결)'] == 8 or df_1.loc[i,'재무활동(연결)'] == 8:
        df_1.loc[i,'기업수명(연결)'] = 8
    elif df_1.loc[i,'영업활동(연결)'] == 8 and df_1.loc[i,'투자활동(연결)'] == 8 and df_1.loc[i,'재무활동(연결)'] == 8:
        df_1.loc[i,'기업수명(연결)'] = 8
    # 0인 경우
    elif df_1.loc[i,'영업활동(연결)'] == 9 or df_1.loc[i,'투자활동(연결)'] == 9 or df_1.loc[i,'재무활동(연결)'] == 9:
        df_1.loc[i,'기업수명(연결)'] = 9
    elif df_1.loc[i,'영업활동(연결)'] == 9 and df_1.loc[i,'투자활동(연결)'] == 9 and df_1.loc[i,'재무활동(연결)'] == 9:
        df_1.loc[i,'기업수명(연결)'] = 9
    # 나머지는 쇠신기라고 할 경우
    else:
        df_1.loc[i,'기업수명(연결)'] = 4
df_1
# Out:
#             회사명  거래소코드     회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                        -2488268.0
# 1      (주)CMG제약  58820  2012/12                        -1453276.0
# 2      (주)CMG제약  58820  2013/12                        -3891420.0
# 3      (주)CMG제약  58820  2014/12                          730447.0
# 4      (주)CMG제약  58820  2015/12                         2411254.0
# ...         ...    ...      ...                               ...
# 15145   흥아해운(주)   3280  2015/12                        34042933.0
# 15146   흥아해운(주)   3280  2016/12                        -4725664.0
# 15147   흥아해운(주)   3280  2017/12                        -5348563.0
# 15148   흥아해운(주)   3280  2018/12                       -30464257.0
# 15149   흥아해운(주)   3280  2019/12                       -16943933.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0                       -1845332.0                    3038758.0
# ...

# %%
a = df_1[df_1['기업수명(연결)']==1]
a
# Out:
#             회사명  거래소코드     회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 0      (주)CMG제약  58820  2011/12                        -2488268.0
# 1      (주)CMG제약  58820  2012/12                        -1453276.0
# 25      (주)ES큐브  50120  2018/12                          116879.0
# 29     (주)HJ중공업  97230  2013/12                      -186309000.0
# 32     (주)HJ중공업  97230  2016/12                        78719000.0
# ...         ...    ...      ...                               ...
# 15112   휴림로봇(주)  90710  2011/12                        -4740528.0
# 15113   휴림로봇(주)  90710  2012/12                         -260771.0
# 15115   휴림로봇(주)  90710  2014/12                         -315529.0
# 15146   흥아해운(주)   3280  2016/12                        -4725664.0
# 15147   흥아해운(주)   3280  2017/12                        -5348563.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 0                       -1845332.0                    3038758.0
# ...

# %% [markdown]
# ### 수명주기 결측치나 0값 처리하기

# %%
for i in range(len(df_1)):
    if df_1.iloc[i]['기업수명(연결)'] != 8:
        if df_1.iloc[i]['기업수명'] != 8:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명(연결)']
        else:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명(연결)']
    elif df_1.iloc[i]['기업수명(연결)'] == 8:
        if df_1.iloc[i]['기업수명'] != 8:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명']
        else:
            df_1.loc[i,'기업수명주기'] = 8
            
    elif df_1.iloc[i]['기업수명(연결)'] != 9:
        if df_1.iloc[i]['기업수명'] != 9:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명(연결)']
        else:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명(연결)']
    elif df_1.iloc[i]['기업수명(연결)'] == 9:
        if df_1.iloc[i]['기업수명'] != 9:
            df_1.loc[i,'기업수명주기'] = df_1.iloc[i]['기업수명']
        else:
            df_1.loc[i,'기업수명주기'] = 9

# %%
df_1[df_1['기업수명주기']==9]
# Out:
#               회사명   거래소코드     회계년도  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  \
# 7        (주)CMG제약   58820  2018/12                          886779.0
# 69      (주)SNT에너지  100840  2017/12                        -5579426.0
# 137    (주)갤럭시아에스엠   11420  2017/12                        -7384193.0
# 138    (주)갤럭시아에스엠   11420  2018/12                        -2638766.0
# 433       (주)나노엔텍   39860  2017/12                         2638359.0
# ...           ...     ...      ...                               ...
# 14535    한국화장품(주)  123690  2015/12                       -20215093.0
# 14536    한국화장품(주)  123690  2016/12                        -2105011.0
# 14730  한올바이오파마(주)    9420  2018/12                        -2963631.0
# 15059     화천기계(주)   10660  2017/12                        -6153040.0
# 15108   휴림네트웍스(주)  192410  2016/12                         2151690.0
#
#        투자활동으로 인한 현금흐름(*)(IFRS)(천원)  재무활동으로 인한 현금흐름(*)(IFRS)(천원)  \
# 7                        8779219.0                          0.0
# ...

# %%
df_1.to_csv('수명주기.csv',encoding='cp949',index=False)
